# %% [markdown]
# # Meep 计算光子晶体能带 (一) 简单周期结构计算
# 日期：2023-04-22
#
# ## 说明
#
# 回归科研以后，一些爱好需要重新拾取起来了。最近学会了用COMSOL计算光子晶体能带，现在尝试来用Meep计算光子晶体能带，希望可以以后有机会作为主力的程序来使用。
#
# 我主要参考的是官方文档：https://mpb.readthedocs.io/en/latest/Python_Tutorial/
#
# ## 简单二维光子晶体能带例子
#
# ### 能带计算
#
# 书籍[Photonic Crystals: Molding the Flow of Light second edition](http://ab-initio.mit.edu/book/) 第五章的结果。
#
# ![image.png](attachment:image.png)

# %%
import math
import meep as mp
from meep import mpb

num_bands = 8

# 定义好扫描的k波矢
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma

# 对k波矢进行插值
k_points = mp.interpolate(20, k_points)

# 基本结构和材料性质
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=8.9))]

# 基本二维cell
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))

resolution = 32

# mode solver设置
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)

# 计算te模式
print("Square lattice of rods: TE bands")
ms.run_te()
# Out:
# Square lattice of rods: TE bands
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 64 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.023809523809523808, 0.0, 0.0>
#   Vector3<0.047619047619047616, 0.0, 0.0>
#   Vector3<0.07142857142857142, 0.0, 0.0>
#   Vector3<0.09523809523809523, 0.0, 0.0>
#   Vector3<0.11904761904761904, 0.0, 0.0>
#   Vector3<0.14285714285714285, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.19047619047619047, 0.0, 0.0>
#   Vector3<0.21428571428571427, 0.0, 0.0>
#   Vector3<0.23809523809523808, 0.0, 0.0>
#   Vector3<0.26190476190476186, 0.0, 0.0>
#   Vector3<0.2857142857142857, 0.0, 0.0>
#   Vector3<0.30952380952380953, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.3571428571428571, 0.0, 0.0>
#   Vector3<0.38095238095238093, 0.0, 0.0>
#   Vector3<0.40476190476190477, 0.0, 0.0>
#   Vector3<0.42857142857142855, 0.0, 0.0>
#   Vector3<0.45238095238095233, 0.0, 0.0>
#   Vector3<0.47619047619047616, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.023809523809523808, 0.0>
#   Vector3<0.5, 0.047619047619047616, 0.0>
#   Vector3<0.5, 0.07142857142857142, 0.0>
#   Vector3<0.5, 0.09523809523809523, 0.0>
#   Vector3<0.5, 0.11904761904761904, 0.0>
#   Vector3<0.5, 0.14285714285714285, 0.0>
#   Vector3<0.5, 0.16666666666666666, 0.0>
#   Vector3<0.5, 0.19047619047619047, 0.0>
#   Vector3<0.5, 0.21428571428571427, 0.0>
#   Vector3<0.5, 0.23809523809523808, 0.0>
#   Vector3<0.5, 0.26190476190476186, 0.0>
#   Vector3<0.5, 0.2857142857142857, 0.0>
#   Vector3<0.5, 0.30952380952380953, 0.0>
#   Vector3<0.5, 0.3333333333333333, 0.0>
#   Vector3<0.5, 0.3571428571428571, 0.0>
#   Vector3<0.5, 0.38095238095238093, 0.0>
#   Vector3<0.5, 0.40476190476190477, 0.0>
#   Vector3<0.5, 0.42857142857142855, 0.0>
#   Vector3<0.5, 0.45238095238095233, 0.0>
#   Vector3<0.5, 0.47619047619047616, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.47619047619047616, 0.47619047619047616, 0.0>
#   Vector3<0.4523809523809524, 0.4523809523809524, 0.0>
#   Vector3<0.4285714285714286, 0.4285714285714286, 0.0>
#   Vector3<0.40476190476190477, 0.40476190476190477, 0.0>
#   Vector3<0.38095238095238093, 0.38095238095238093, 0.0>
#   Vector3<0.35714285714285715, 0.35714285714285715, 0.0>
#   Vector3<0.33333333333333337, 0.33333333333333337, 0.0>
#   Vector3<0.30952380952380953, 0.30952380952380953, 0.0>
#   Vector3<0.2857142857142857, 0.2857142857142857, 0.0>
#   Vector3<0.2619047619047619, 0.2619047619047619, 0.0>
#   Vector3<0.23809523809523814, 0.23809523809523814, 0.0>
#   Vector3<0.2142857142857143, 0.2142857142857143, 0.0>
#   Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
#   Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
#   Vector3<0.1428571428571429, 0.1428571428571429, 0.0>
#   Vector3<0.11904761904761907, 0.11904761904761907, 0.0>
#   Vector3<0.09523809523809523, 0.09523809523809523, 0.0>
#   Vector3<0.07142857142857145, 0.07142857142857145, 0.0>
#   Vector3<0.04761904761904767, 0.04761904761904767, 0.0>
#   Vector3<0.023809523809523836, 0.023809523809523836, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.012918949127197266
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 18.70131237099172 (193.147% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 7.586338935548641 (84.5642% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.728474595863506 (11.9857% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.486109613367323 (3.66814% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.396493278234585 (1.39128% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.320597706071167 (1.1936% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 6.259374579812907 (0.973343% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.228858173951396 (0.488723% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.216137725344589 (0.204427% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 6.213162728411081 (0.0478707% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 6.212048263053776 (0.0179388% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 6.211676022456511 (0.00599242% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.211508716369823 (0.00269345% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.211442865345036 (0.00106015% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.211419055361155 (0.000383325% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 6.211409102764373 (0.000160231% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 6.211405894144131 (5.16569e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 6.21140440631937 (2.39531e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 6.211403832287264 (9.24158e-06% change)
# Finished solving for bands 2 to 8 after 19 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.629133, 0.824541, 0.824544, 0.932016, 1.07556, 1.07556, 1.12851
# elapsed time for k point: 0.7227656841278076
# solve_kpoint (0.0238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.213381749430869 (0.0144106% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.213009174682318 (0.00599651% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.212936892962962 (0.0011634% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.212912760245986 (0.000388428% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.212906402338397 (0.000102334% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.212903771835435 (4.23393e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.212903052525226 (1.15777e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.212902869359286 (2.94815e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 2, 0.0238095, 0, 0, 0.0238095, 0.0215254, 0.628956, 0.822985, 0.824693, 0.933119, 1.07351, 1.07547, 1.13122
# elapsed time for k point: 0.11669301986694336
# solve_kpoint (0.047619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.21785860367379 (0.0146261% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.21747267500333 (0.00620697% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.217393948401575 (0.00126622% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.217368026595975 (0.000416925% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.217360930368674 (0.000114136% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.217358117738311 (4.52383e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.217357351775988 (1.23197e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.217357154424788 (3.1742e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 3, 0.047619, 0, 0, 0.047619, 0.0430435, 0.628411, 0.818532, 0.825144, 0.936218, 1.06841, 1.07519, 1.1383
# elapsed time for k point: 0.06790661811828613
# solve_kpoint (0.0714286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.225175185505993 (0.01524% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.224754048962208 (0.00676528% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.224665432571671 (0.00142362% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.224636344129283 (0.00046731% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.224628300175636 (0.000129228% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.224625167951384 (5.03199e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.224624310557679 (1.37742e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.224624086535044 (3.59897e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 4, 0.0714286, 0, 0, 0.0714286, 0.0645469, 0.627463, 0.811723, 0.825888, 0.940752, 1.06203, 1.07472, 1.14796
# elapsed time for k point: 0.07337260246276855
# solve_kpoint (0.0952381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.235078470828713 (0.0163196% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.234596314856611 (0.00773326% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.234491592032149 (0.00167972% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.234457004768398 (0.000554774% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.234447183726626 (0.000157529% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.234443324875564 (6.18957e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.234442250775396 (1.72285e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.234441960170487 (4.66128e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 5, 0.0952381, 0, 0, 0.0952381, 0.086028, 0.626057, 0.803187, 0.826915, 0.946053, 1.05561, 1.07406, 1.15899
# elapsed time for k point: 0.07077598571777344
# solve_kpoint (0.119048,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.247160903234866 (0.0180019% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.246581416961364 (0.00927642% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.246450907530118 (0.00208932% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.246406891830684 (0.000704654% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.246393676588454 (0.000211566% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.246388282995197 (8.63474e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.246386741562313 (2.46772e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.24638630105408 (7.05221e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 6, 0.119048, 0, 0, 0.119048, 0.107479, 0.62411, 0.793499, 0.828211, 0.951469, 1.04994, 1.07321, 1.1706
# elapsed time for k point: 0.07358956336975098
# solve_kpoint (0.142857,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.260790494109619 (0.0205073% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.260060260564817 (0.0116643% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.259888896381376 (0.00273746% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.259828956566226 (0.000957527% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 57.674%)
#     iteration    5: trace = 6.259809446277906 (0.000311675% change)
#     switching back to exact line minimization
#     iteration    6: trace = 6.25980108142509 (0.000133628% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.259798653209165 (3.87906e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.259797929123576 (1.15672e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.259797720193653 (3.33765e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 7, 0.142857, 0, 0, 0.142857, 0.128891, 0.62151, 0.783143, 0.829756, 0.956404, 1.04556, 1.07217, 1.18222
# elapsed time for k point: 0.09896588325500488
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.275006088774306 (0.0241309% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.274048682728342 (0.0152586% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.273814145023097 (0.00373829% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.273727555094769 (0.00138019% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.273697123067142 (0.000485072% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.273683801921061 (0.000212333% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.273679876560926 (6.25687e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.273678657659639 (1.94288e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.273678263666467 (6.2801e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 8, 0.166667, 0, 0, 0.166667, 0.150254, 0.618116, 0.772533, 0.831526, 0.960325, 1.04295, 1.07094, 1.19328
# elapsed time for k point: 0.07472085952758789
# solve_kpoint (0.190476,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.288391775900777 (0.0291861% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.287108915468829 (0.0204025% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.286782265903518 (0.00519568% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.286657603031832 (0.00198296% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.286610717770064 (0.000745793% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.286590001904603 (0.000329524% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 62.6443%)
#     iteration    7: trace = 6.286583976719605 (9.58419e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 6.286582081271344 (3.01507e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.28658141460338 (1.06046e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.286581104452681 (4.93354e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 9, 0.190476, 0, 0, 0.190476, 0.171559, 0.613763, 0.762034, 0.833495, 0.962835, 1.04244, 1.06953, 1.20308
# elapsed time for k point: 0.08904504776000977
# solve_kpoint (0.214286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.299027793650639 (0.0355142% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.2973512592331 (0.0266193% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.296911529035047 (0.00698302% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.296735263892917 (0.00279927% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.296667152488287 (0.0010817% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.296636348192095 (0.000489217% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.296627364273849 (0.000142678% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.296624348000115 (4.7903e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.296622879506089 (2.33219e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.296621617476794 (2.0043e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.296619595370481 (3.21142e-05% change)
#     large trace change predicted (0.00105237%)
#     linmin: converged after 5 iterations.
#     iteration   12: trace = 6.296556496641267 (0.00100211% change)
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     switching to approximate line minimization (decrease time by 55.991%)
#     iteration   13: trace = 6.296338917255608 (0.00345559% change)
#     switching back to exact line minimization
#     iteration   14: trace = 6.297576039176774 (0.0196463% change)
#     linmin: converged after 7 iterations.
#     iteration   15: trace = 6.296487510131105 (0.0172864% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 6.296457666422604 (0.000473975% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 6.29643247965645 (0.000400016% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 6.296410054110029 (0.000356163% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 6.296389467415459 (0.00032696% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 6.296370188797916 (0.000306186% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 6.29635187975365 (0.000290788% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 6.296334308594393 (0.000279069% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 6.296317308265715 (0.000270004% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 6.296300753356264 (0.00026293% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 6.296284546615563 (0.000257401% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 6.29626861058598 (0.000253102% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 6.296252882168157 (0.000249806% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 6.296237308959375 (0.000247341% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 6.29622184670991 (0.00024558% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 6.296206457510905 (0.00024442% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 6.296191108475677 (0.000243783% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 6.296175770763121 (0.000243603% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 6.296160418843984 (0.00024383% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 6.29614502994322 (0.000244418% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 6.296129583612549 (0.00024533% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 6.296114061400358 (0.000246536% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 6.296098446598441 (0.000248007% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 6.296082724042044 (0.000249719% change)
#     linmin: converged after 4 iterations.
#     iteration   39: trace = 6.296066879959275 (0.00025165% change)
#     linmin: converged after 4 iterations.
#     iteration   40: trace = 6.296050901853739 (0.000253779% change)
#     linmin: converged after 4 iterations.
#     iteration   41: trace = 6.296034778415569 (0.000256088% change)
#     linmin: converged after 4 iterations.
#     iteration   42: trace = 6.296018499454412 (0.000258559% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 6.296002055849632 (0.000261175% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 6.295985439516014 (0.000263919% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 6.295968643367493 (0.000266776% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 6.295951661311165 (0.000269729% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 6.295934488221992 (0.000272764% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 6.295917119931113 (0.000275866% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 6.295899553211662 (0.000279018% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 6.295881785762569 (0.000282207% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 6.295863816188861 (0.000285418% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 6.295845643977191 (0.000288638% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 6.295827269465544 (0.000291852% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 6.295808693806565 (0.000295048% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 6.295789918924124 (0.000298213% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 6.29577094746312 (0.000301336% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 6.295751782732967 (0.000304407% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 6.295732428645394 (0.000307416% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 6.295712889647644 (0.000310354% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 6.295693170652323 (0.000313214% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 6.295673276965422 (0.000315989% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 6.29565321421423 (0.000318676% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 6.295632988276835 (0.000321269% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 6.295612605215048 (0.000323766% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 6.295592071212434 (0.000326164% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 6.295571392519069 (0.000328464% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 6.295550575404397 (0.000330663% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 6.295529626119322 (0.000332764% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 6.295508550868476 (0.000334766% change)
#     resetting CG direction...
#     large trace change predicted (0.652493%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 6.254275501774501 (0.657112% change)
#     linmin: converged after 3 iterations.
#     iteration   71: trace = 6.243754304068331 (0.168366% change)
#     linmin: converged after 3 iterations.
#     iteration   72: trace = 6.240288080761637 (0.0555305% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 6.238366077913888 (0.0308046% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 6.237382996027979 (0.0157599% change)
#     linmin: converged after 3 iterations.
#     iteration   75: trace = 6.236304289391252 (0.0172957% change)
#     linmin: converged after 3 iterations.
#     iteration   76: trace = 6.235389530137417 (0.0146694% change)
#     linmin: converged after 3 iterations.
#     iteration   77: trace = 6.234699390015297 (0.0110687% change)
#     linmin: converged after 3 iterations.
#     iteration   78: trace = 6.234272571964456 (0.00684608% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 6.23399576057755 (0.00444025% change)
#     linmin: converged after 3 iterations.
#     iteration   80: trace = 6.23387880257407 (0.00187615% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 6.233856488784718 (0.000357945% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 6.233849502117954 (0.000112076% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 6.233845952241555 (5.69452e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 6.233844429655663 (2.44245e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 6.233843856327217 (9.19703e-06% change)
# Finished solving for bands 1 to 8 after 85 iterations.
# tefreqs:, 10, 0.214286, 0, 0, 0.214286, 0.192795, 0.60827, 0.751976, 0.835627, 0.963788, 1.04414, 1.06794, 1.18462
# elapsed time for k point: 0.6452820301055908
# solve_kpoint (0.238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.221803524372521 (0.0184317% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.221335379396644 (0.00752455% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.221215517693667 (0.00192664% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.221175854170562 (0.000637555% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.221160377176384 (0.00024878% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.221155771433583 (7.40335e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.221154569854094 (1.93144e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.221154290602918 (4.48874e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 11, 0.238095, 0, 0, 0.238095, 0.213947, 0.601462, 0.742646, 0.837886, 0.963334, 1.04785, 1.0662, 1.18205
# elapsed time for k point: 0.07758498191833496
# solve_kpoint (0.261905,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.211243244391968 (0.0172158% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.210804478962658 (0.0070643% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.210685610145353 (0.00191392% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.210644362537029 (0.000664142% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.210628298772765 (0.000258649% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.21062362452749 (7.52621e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.210622438519084 (1.90964e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.210622157654739 (4.52232e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 12, 0.261905, 0, 0, 0.261905, 0.235001, 0.593206, 0.73427, 0.840227, 0.961829, 1.05321, 1.06433, 1.17949
# elapsed time for k point: 0.08899164199829102
# solve_kpoint (0.285714,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.203060018969656 (0.0161091% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.202645236223526 (0.00668697% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.202528318819601 (0.00188498% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.202486884369955 (0.000668027% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.2024710760652 (0.000254871% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.202466506125171 (7.36794e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.202465369585916 (1.8324e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.202465097198127 (4.39161e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 13, 0.285714, 0, 0, 0.285714, 0.255937, 0.583432, 0.726993, 0.842603, 0.959669, 1.05978, 1.06237, 1.177
# elapsed time for k point: 0.08194446563720703
# solve_kpoint (0.309524,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.197447342725349 (0.0151406% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.197052804146304 (0.00636635% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.196937165489857 (0.00186604% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.196895361946671 (0.000674586% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.196879846461966 (0.000250375% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.19687542781608 (7.13044e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.196874360640871 (1.72212e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.196874108840649 (4.06334e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 14, 0.309524, 0, 0, 0.309524, 0.276733, 0.572161, 0.720863, 0.844961, 0.957192, 1.06036, 1.06722, 1.17464
# elapsed time for k point: 0.1012566089630127
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.19456568515052 (0.0143251% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.194186299148662 (0.00612468% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.194070657968357 (0.00186695% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.194027950867288 (0.000689486% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.19401255620361 (0.000248541% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.194008243089845 (6.96336e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.194007237491649 (1.6235e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.19400701028355 (3.66819e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 15, 0.333333, 0, 0, 0.333333, 0.297358, 0.559493, 0.715843, 0.847243, 0.95465, 1.05836, 1.07524, 1.17247
# elapsed time for k point: 0.08254027366638184
# solve_kpoint (0.357143,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.194533975601431 (0.0136841% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.194162438385604 (0.005998% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.194044242340988 (0.0019082% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.193999269104346 (0.000726075% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.193983384940006 (0.000256445% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.193978914800805 (7.21691e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.193977876253738 (1.6767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.193977638431571 (3.83957e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 16, 0.357143, 0, 0, 0.357143, 0.31777, 0.545594, 0.711836, 0.849391, 0.952219, 1.05642, 1.08366, 1.17051
# elapsed time for k point: 0.07809209823608398
# solve_kpoint (0.380952,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.19741253328632 (0.0132526% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.197037666936366 (0.00604894% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.196911954533995 (0.00202861% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.196861632108909 (0.00081206% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.196843664302719 (0.000289951% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.196838215749508 (8.79247e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.196836779001657 (2.31852e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.196836343599839 (7.02619e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 17, 0.380952, 0, 0, 0.380952, 0.337906, 0.530672, 0.708716, 0.851343, 0.95002, 1.05462, 1.09229, 1.16881
# elapsed time for k point: 0.08655381202697754
# solve_kpoint (0.404762,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.20316944473488 (0.0130982% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.202772366816379 (0.00640142% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.202629078459553 (0.0023101% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.202566341366086 (0.00101146% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.20254214263492 (0.000390141% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.202533253923494 (0.000143308% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.202530156624658 (4.9936e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.202528796667169 (2.19259e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.202528206431361 (9.51605e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 18, 0.404762, 0, 0, 0.404762, 0.35766, 0.514977, 0.706355, 0.853041, 0.948136, 1.05303, 1.10098, 1.1674
# elapsed time for k point: 0.11255645751953125
# solve_kpoint (0.428571,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.211599891462298 (0.0133648% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.211145137648637 (0.00732131% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.21096179085097 (0.00295194% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.210868628970672 (0.00149997% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.210827710898457 (0.000658816% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.210808286102775 (0.000312757% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.210799494759422 (0.000141549% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.210795073816103 (7.11816e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.210793310071759 (2.8398e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.21079270880352 (9.68102e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 19, 0.428571, 0, 0, 0.428571, 0.376826, 0.498838, 0.70464, 0.854428, 0.946623, 1.0517, 1.10951, 1.16628
# elapsed time for k point: 0.13285112380981445
# solve_kpoint (0.452381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.222120403378336 (0.0144468% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.221519322073424 (0.00966086% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.221238407128239 (0.00451532% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.221065121958112 (0.00278542% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.220978758492607 (0.00138825% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.220924765723267 (0.000867918% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.220898374749431 (0.00042423% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.220886173020293 (0.000196141% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.220882091117318 (6.56161e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.220880905935283 (1.90517e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.22088064238793 (4.2365e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 20, 0.452381, 0, 0, 0.452381, 0.394906, 0.48285, 0.703479, 0.855457, 0.945517, 1.05071, 1.11748, 1.16548
# elapsed time for k point: 0.0951533317565918
# solve_kpoint (0.47619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.233154442724722 (0.0173506% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.232158021219595 (0.0159871% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.231609024162077 (0.00880949% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.231197608018028 (0.0066023% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.230975684485728 (0.00356155% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.230820053437936 (0.00249773% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.230748936332026 (0.00114138% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.230719783869606 (0.000467882% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.23071121607376 (0.000137509% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.230708999648277 (3.55726e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.230708517956399 (7.73093e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 21, 0.47619, 0, 0, 0.47619, 0.410336, 0.468648, 0.70281, 0.856091, 0.944844, 1.05009, 1.12393, 1.16499
# elapsed time for k point: 0.11271548271179199
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.240383884339064 (0.0240579% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.238335698347479 (0.0328269% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.237182307297633 (0.0184905% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.236284072437082 (0.0144023% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.235842983495183 (0.0070732% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.235534969307854 (0.00493954% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.235410935939596 (0.00198916% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.235365856222703 (0.000722966% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.235353272153762 (0.000201818% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.235350214985051 (4.90296e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.235349488169314 (1.16564e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.235349278896988 (3.35622e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 22, 0.5, 0, 0, 0.5, 0.41762, 0.461769, 0.702592, 0.856305, 0.944617, 1.04989, 1.12669, 1.16483
# elapsed time for k point: 0.11934804916381836
# solve_kpoint (0.5,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.23410903439461 (0.0622585% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.23106055749165 (0.0489119% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.226951786011364 (0.0659619% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.221542381520779 (0.0869086% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.215831534777748 (0.0918336% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.208898568711072 (0.111599% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.206384141794585 (0.0405054% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.205593176423598 (0.0127452% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.205439278585761 (0.00248002% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.205375483345429 (0.00102806% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.205350892786722 (0.000396279% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.205340895938819 (0.000161101% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.2053376381339 (5.25e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.205336340463095 (2.09122e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.205334873810529 (2.36353e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 6.205332760738569 (3.40525e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 6.205330975131485 (2.87754e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 6.205329806845516 (1.88271e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 6.205329204728464 (9.70322e-06% change)
# Finished solving for bands 1 to 8 after 19 iterations.
# tefreqs:, 23, 0.5, 0.0238095, 0, 0.500567, 0.418249, 0.462077, 0.702171, 0.856613, 0.943598, 1.04723, 1.13017, 1.15139
# elapsed time for k point: 0.18202805519104004
# solve_kpoint (0.5,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.189346420351268 (0.0198848% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.188620628788162 (0.0117272% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.188342591859701 (0.00449281% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.188131368644097 (0.0034133% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.188022936863831 (0.00175227% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.187885640834196 (0.00221876% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.187814340684956 (0.00115226% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.187789132721331 (0.000407382% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.187784841963406 (6.93424e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.187783889724495 (1.5389e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.187783668038692 (3.58264e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 24, 0.5, 0.047619, 0, 0.502262, 0.42013, 0.462998, 0.700913, 0.85754, 0.940472, 1.04067, 1.13928, 1.14229
# elapsed time for k point: 0.10954523086547852
# solve_kpoint (0.5,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.172373488250195 (0.0194995% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.171764888778295 (0.00986054% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.17158139509193 (0.00297316% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.171480720773207 (0.00163127% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.171447917989593 (0.000531524% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.171422918178774 (0.000405089% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.171405477940659 (0.000282597% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.171397207151067 (0.000134018% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.171395413252581 (2.9068e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.171394983410597 (6.96507e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 25, 0.5, 0.0714286, 0, 0.505076, 0.423244, 0.464524, 0.698845, 0.85906, 0.935082, 1.03265, 1.13273, 1.15165
# elapsed time for k point: 0.060630083084106445
# solve_kpoint (0.5,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.157394504403903 (0.0198374% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.156777792404835 (0.0100163% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.156594925691595 (0.00297021% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.15650566345491 (0.00144987% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.156482884206072 (0.000370004% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.15647345495088 (0.00015316% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.156467953246016 (8.93646e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.156465084772959 (4.65928e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.156464225858375 (1.39514e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.156463957199255 (4.36385e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 26, 0.5, 0.0952381, 0, 0.508989, 0.427562, 0.466643, 0.696013, 0.861131, 0.927299, 1.0249, 1.12296, 1.16558
# elapsed time for k point: 0.10379719734191895
# solve_kpoint (0.5,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.143822268326652 (0.0206171% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.14314920531813 (0.0109557% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.142941318987528 (0.00338409% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.142845943901362 (0.00155261% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.142824684526281 (0.000346084% change)
#     linmin: converged after 2 iterations.
# ...
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.180078510493785 (0.00711645% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.17990839001521 (0.00275276% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.17985553117887 (0.000855337% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.179834691261058 (0.000337224% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.179821785230021 (0.000208841% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.179813383361012 (0.000135957% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.179810615601901 (4.47871e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.179809951806571 (1.07414e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.179809810089703 (2.29322e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 56, 0.190476, 0.190476, 0, 0.269374, 0.242388, 0.610152, 0.721968, 0.843893, 0.954477, 0.978107, 1.14994, 1.15122
# elapsed time for k point: 0.14376401901245117
# solve_kpoint (0.166667,0.166667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.213143989852794 (0.056241% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.211229991974139 (0.0308104% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.210769929586217 (0.00740722% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.210574126629508 (0.00315269% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.210501566012811 (0.00116835% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.210459082254406 (0.000684066% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.210428075680616 (0.000499265% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.210405203337384 (0.00036829% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.210396774949364 (0.000135714% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.210394070951185 (4.35399e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.210392995072247 (1.73238e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.21039246689514 (8.50473e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 57, 0.166667, 0.166667, 0, 0.235702, 0.212343, 0.614002, 0.738048, 0.839902, 0.973001, 0.973763, 1.13489, 1.16415
# elapsed time for k point: 0.1105051040649414
# solve_kpoint (0.142857,0.142857,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.242172840581269 (0.057637% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.240201596807792 (0.0315844% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.239713512007186 (0.00782193% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.239483521712296 (0.00368598% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.239380756031178 (0.00164704% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.239302243845564 (0.00125834% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.239231396253953 (0.00113551% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.239159002790409 (0.0011603% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.525%)
#     iteration    9: trace = 6.239118742162871 (0.000645291% change)
#     iteration   10: trace = 6.239099791488794 (0.00030374% change)
#     iteration   11: trace = 6.239090567675937 (0.000147839% change)
#     switching back to exact line minimization
#     iteration   12: trace = 6.23908672010921 (6.16687e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.239085743517615 (1.56528e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.239085447627184 (4.74253e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 58, 0.142857, 0.142857, 0, 0.202031, 0.182189, 0.617612, 0.754339, 0.836156, 0.968513, 0.991203, 1.12049, 1.17485
# elapsed time for k point: 0.1892099380493164
# solve_kpoint (0.119048,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.268447757961138 (0.0573443% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.266496481485166 (0.0311334% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.265980323612049 (0.00823712% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.265698437016315 (0.00449878% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.265514529017635 (0.0029352% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.265275286194766 (0.00381848% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.264909434349168 (0.00583953% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 6.264315983043815 (0.00947307% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.263825169668189 (0.00783537% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 6.26354869857802 (0.00441387% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.263416343068863 (0.00211313% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.26337110519692 (0.000722258% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.263360296887545 (0.000172564% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.263356962022975 (5.3244e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.263356355028757 (9.6912e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 59, 0.119048, 0.119048, 0, 0.168359, 0.151948, 0.620882, 0.770531, 0.832799, 0.962261, 1.00899, 1.10739, 1.18203
# elapsed time for k point: 0.2302396297454834
# solve_kpoint (0.0952381,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 64.6661%)
#     iteration    1: trace = 6.282234752419563 (0.0563809% change)
#     switching back to exact line minimization
#     iteration    2: trace = 6.279619463204862 (0.0416386% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.277983909706383 (0.0260488% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.275547639863635 (0.0388141% change)
#     large trace change predicted (0.085669%)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.270562836077309 (0.0794637% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.263532468301637 (0.11218% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 6.259543899789485 (0.0636995% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.257772526669886 (0.0283028% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.256931503544477 (0.0134406% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 6.256538886024865 (0.00627512% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.256403192715588 (0.00216885% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.256341482954071 (0.000986351% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.25631145947388 (0.00047989% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.256278616187288 (0.000524964% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.256240698631865 (0.000606074% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.1935%)
#     iteration   16: trace = 6.256182179626504 (0.000935374% change)
#     switching back to exact line minimization
#     iteration   17: trace = 6.256136823727946 (0.00072498% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 6.256116674824582 (0.000322067% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 6.256112419353197 (6.8021e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 6.25611175480428 (1.06224e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 6.256111566647008 (3.00758e-06% change)
# Finished solving for bands 1 to 8 after 21 iterations.
# tefreqs:, 60, 0.0952381, 0.0952381, 0, 0.134687, 0.121637, 0.623716, 0.786188, 0.829926, 0.955066, 1.02625, 1.09615, 1.17411
# elapsed time for k point: 0.26157331466674805
# solve_kpoint (0.0714286,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.240379882369871 (0.0354916% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.239086299944736 (0.0207314% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.238648852081779 (0.00701165% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.23829842845121 (0.00561714% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.237987344466655 (0.0049868% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.237714511090062 (0.00437384% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.237623010744273 (0.0014669% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.237595149591985 (0.000446664% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.23758846436253 (0.000107176% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.237586589353652 (3.00598e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.237586192673383 (6.35952e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 61, 0.0714286, 0.0714286, 0, 0.101015, 0.0912728, 0.626026, 0.800651, 0.827613, 0.947305, 1.04276, 1.08719, 1.15959
# elapsed time for k point: 0.10540771484375
# solve_kpoint (0.047619,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.224584133775218 (0.0316145% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.223694163667993 (0.0142987% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.223486565956203 (0.00333566% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.223394596225481 (0.0014778% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.223346269545745 (0.000776535% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.22330254475854 (0.000702595% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.22328170891772 (0.000334804% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.223273237580178 (0.000136123% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.223270730706843 (4.02822e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.223269873286186 (1.37777e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.223269696964371 (2.83327e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 62, 0.047619, 0.047619, 0, 0.0673435, 0.0608696, 0.627734, 0.812898, 0.825918, 0.939852, 1.05798, 1.08073, 1.14541
# elapsed time for k point: 0.1548154354095459
# solve_kpoint (0.0238095,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.215453860968716 (0.0300212% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.214668545687696 (0.0126357% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.214500972483121 (0.00269645% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.214442201306159 (0.000945715% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.8083%)
#     iteration    5: trace = 6.214422022583022 (0.000324707% change)
#     iteration    6: trace = 6.214409519718992 (0.000201191% change)
#     iteration    7: trace = 6.214404194784022 (8.56869e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 6.214401691098412 (4.02884e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.214400664191265 (1.65246e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.214400134985034 (8.51581e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 63, 0.0238095, 0.0238095, 0, 0.0336718, 0.0304413, 0.628782, 0.821428, 0.824885, 0.93418, 1.07027, 1.07685, 1.13364
# elapsed time for k point: 0.1285533905029297
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.212361095365784 (0.0286549% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.211623603804594 (0.0118721% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.211475938001112 (0.00237728% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.2114269607799 (0.000788499% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.211411203673207 (0.00025368% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.21140568384495 (8.8866e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.211403954319681 (2.78443e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.2114035974126 (5.746e-06% change)
# Finished solving for bands 2 to 8 after 8 iterations.
# tefreqs:, 64, 0, 0, 0, 0, 0, 0.629133, 0.824541, 0.824544, 0.932016, 1.07556, 1.07556, 1.12851
# elapsed time for k point: 0.13083839416503906
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.549517410953484 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.46176908671934697 at Vector3<0.5, 0.0, 0.0> to 0.629132850409634 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.6021802907005969 at Vector3<0.5, 0.5, 0.0> to 0.8245408228597301 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.6810332825203594 at Vector3<0.5, 0.5, 0.0> to 0.8739078047992697 at Vector3<0.5, 0.19047619047619047, 0.0>
# Band 5 range: 0.8756586421838969 at Vector3<0.5, 0.19047619047619047, 0.0> to 0.973000953136474 at Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
# Band 6 range: 0.9737627754094028 at Vector3<0.16666666666666669, 0.16666666666666669, 0.0> to 1.0755594623451332 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.9971255180373908 at Vector3<0.5, 0.5, 0.0> to 1.1499357275754747 at Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
# Band 8 range: 1.1285131578243133 at Vector3<0.0, 0.0, 0.0> to 1.2466840661507883 at Vector3<0.5, 0.26190476190476186, 0.0>
# Gap from band 4 (0.8739078047992697) to band 5 (0.8756586421838969), 0.20014528601028544%
# Gap from band 5 (0.973000953136474) to band 6 (0.9737627754094028), 0.07826550924060084%
# total elapsed time for run: 8.661495208740234
# done

# %% [markdown]
# 按照官方文档说法，要查看得到的本振频率，需要从输出的类似的log文件中提取，比如：
# ```bash
# tefreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.372604, 0.540287, 0.644083, 0.81406, 0.828135, 0.890673, 1.01328, 1.1124
# ```
# 我们需要手动将这些信息提取出来，在Linux里面主要通过正则表达式提取，这种方式感觉太不优雅了，官方文章还有例子[MPBData](https://mpb.readthedocs.io/en/latest/Python_Data_Analysis_Tutorial/)：
# ```python
# tm_freqs = ms.all_freqs
# ```
# 可以在我们的结果中进行提取

# %%
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
import numpy as np
print(np.shape(te_freqs))
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 64 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.023809523809523808, 0.0, 0.0>
#   Vector3<0.047619047619047616, 0.0, 0.0>
#   Vector3<0.07142857142857142, 0.0, 0.0>
#   Vector3<0.09523809523809523, 0.0, 0.0>
#   Vector3<0.11904761904761904, 0.0, 0.0>
#   Vector3<0.14285714285714285, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.19047619047619047, 0.0, 0.0>
#   Vector3<0.21428571428571427, 0.0, 0.0>
#   Vector3<0.23809523809523808, 0.0, 0.0>
#   Vector3<0.26190476190476186, 0.0, 0.0>
#   Vector3<0.2857142857142857, 0.0, 0.0>
#   Vector3<0.30952380952380953, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.3571428571428571, 0.0, 0.0>
#   Vector3<0.38095238095238093, 0.0, 0.0>
#   Vector3<0.40476190476190477, 0.0, 0.0>
#   Vector3<0.42857142857142855, 0.0, 0.0>
#   Vector3<0.45238095238095233, 0.0, 0.0>
#   Vector3<0.47619047619047616, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.023809523809523808, 0.0>
#   Vector3<0.5, 0.047619047619047616, 0.0>
#   Vector3<0.5, 0.07142857142857142, 0.0>
#   Vector3<0.5, 0.09523809523809523, 0.0>
#   Vector3<0.5, 0.11904761904761904, 0.0>
#   Vector3<0.5, 0.14285714285714285, 0.0>
#   Vector3<0.5, 0.16666666666666666, 0.0>
#   Vector3<0.5, 0.19047619047619047, 0.0>
#   Vector3<0.5, 0.21428571428571427, 0.0>
#   Vector3<0.5, 0.23809523809523808, 0.0>
#   Vector3<0.5, 0.26190476190476186, 0.0>
#   Vector3<0.5, 0.2857142857142857, 0.0>
#   Vector3<0.5, 0.30952380952380953, 0.0>
#   Vector3<0.5, 0.3333333333333333, 0.0>
#   Vector3<0.5, 0.3571428571428571, 0.0>
#   Vector3<0.5, 0.38095238095238093, 0.0>
#   Vector3<0.5, 0.40476190476190477, 0.0>
#   Vector3<0.5, 0.42857142857142855, 0.0>
#   Vector3<0.5, 0.45238095238095233, 0.0>
#   Vector3<0.5, 0.47619047619047616, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.47619047619047616, 0.47619047619047616, 0.0>
#   Vector3<0.4523809523809524, 0.4523809523809524, 0.0>
#   Vector3<0.4285714285714286, 0.4285714285714286, 0.0>
#   Vector3<0.40476190476190477, 0.40476190476190477, 0.0>
#   Vector3<0.38095238095238093, 0.38095238095238093, 0.0>
#   Vector3<0.35714285714285715, 0.35714285714285715, 0.0>
#   Vector3<0.33333333333333337, 0.33333333333333337, 0.0>
#   Vector3<0.30952380952380953, 0.30952380952380953, 0.0>
#   Vector3<0.2857142857142857, 0.2857142857142857, 0.0>
#   Vector3<0.2619047619047619, 0.2619047619047619, 0.0>
#   Vector3<0.23809523809523814, 0.23809523809523814, 0.0>
#   Vector3<0.2142857142857143, 0.2142857142857143, 0.0>
#   Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
#   Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
#   Vector3<0.1428571428571429, 0.1428571428571429, 0.0>
#   Vector3<0.11904761904761907, 0.11904761904761907, 0.0>
#   Vector3<0.09523809523809523, 0.09523809523809523, 0.0>
#   Vector3<0.07142857142857145, 0.07142857142857145, 0.0>
#   Vector3<0.04761904761904767, 0.04761904761904767, 0.0>
#   Vector3<0.023809523809523836, 0.023809523809523836, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.012705564498901367
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 17.18714715143128 (193.712% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 7.542431548110847 (78.0015% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 6.766574728485415 (10.8443% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 6.452778092299158 (4.74753% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.30891913366508 (2.25454% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 6.251235449088364 (0.918519% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 6.226177878439849 (0.401647% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 6.216830550345919 (0.150242% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 6.212816228383155 (0.0645927% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 6.211836811189372 (0.0157657% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.211547835749169 (0.00465212% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.211461051872532 (0.00139715% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.211429967534816 (0.000500436% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.211414992568344 (0.000241088% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.211408769608373 (0.000100186% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 6.211405658188418 (5.0092e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 6.211404227594381 (2.30317e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 6.211403656425933 (9.19548e-06% change)
# Finished solving for bands 2 to 8 after 18 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.629133, 0.824541, 0.824544, 0.932016, 1.07556, 1.07556, 1.12851
# elapsed time for k point: 0.7485442161560059
# solve_kpoint (0.0238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.213381560010636 (0.0144184% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.213009752809187 (0.00598415% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.212937577117806 (0.00116169% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.212912897625431 (0.000397228% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.212906418640793 (0.000104283% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.21290377627764 (4.25302e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.212903052463612 (1.16502e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.212902868770795 (2.95663e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 2, 0.0238095, 0, 0, 0.0238095, 0.0215254, 0.628956, 0.822985, 0.824693, 0.933119, 1.07351, 1.07547, 1.13122
# elapsed time for k point: 0.07077765464782715
# solve_kpoint (0.047619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.21785861563942 (0.0146266% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.21747264808457 (0.0062076% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.217393921164409 (0.00126623% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.217368020121979 (0.000416591% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.217360929806791 (0.000114041% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.21735811765973 (4.52306e-05% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.3628%)
#     iteration    7: trace = 6.217357351737613 (1.23191e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 6.21735715442605 (3.17356e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 3, 0.047619, 0, 0, 0.047619, 0.0430435, 0.628411, 0.818532, 0.825144, 0.936218, 1.06841, 1.07519, 1.1383
# elapsed time for k point: 0.06965065002441406
# solve_kpoint (0.0714286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.225175185529308 (0.01524% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.224754049424837 (0.00676528% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.224665433381436 (0.00142362% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.224636344371611 (0.00046732% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.224628300205385 (0.000129231% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.224625167966853 (5.03201e-05% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 63.4417%)
#     iteration    7: trace = 6.224624310578464 (1.37741e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 6.22462408655293 (3.59902e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 4, 0.0714286, 0, 0, 0.0714286, 0.0645469, 0.627463, 0.811723, 0.825888, 0.940752, 1.06203, 1.07472, 1.14796
# elapsed time for k point: 0.06938338279724121
# solve_kpoint (0.0952381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 67.0731%)
#     iteration    1: trace = 6.235078470989889 (0.0163196% change)
#     iteration    2: trace = 6.234596333647792 (0.00773296% change)
#     switching back to exact line minimization
#     iteration    3: trace = 6.234491618982545 (0.00167959% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.234457008245164 (0.000555151% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.234447185324053 (0.000157559% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.234443325186689 (6.19163e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.234442250885477 (1.72317e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.234441960196225 (4.66263e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 5, 0.0952381, 0, 0, 0.0952381, 0.086028, 0.626057, 0.803187, 0.826915, 0.946053, 1.05561, 1.07406, 1.15899
# elapsed time for k point: 0.08386373519897461
# solve_kpoint (0.119048,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.247160992069769 (0.0180005% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.246581372730953 (0.00927855% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.246450853499791 (0.00208947% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.246406878495847 (0.000704002% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.246393674422302 (0.000211387% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.246388282536323 (8.632e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.2463867414665 (2.46714e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.246386301034891 (7.05098e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 6, 0.119048, 0, 0, 0.119048, 0.107479, 0.62411, 0.793499, 0.828211, 0.951469, 1.04994, 1.07321, 1.1706
# elapsed time for k point: 0.057708740234375
# solve_kpoint (0.142857,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.260790493788591 (0.0205073% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 64.3043%)
#     iteration    2: trace = 6.260060260304379 (0.0116643% change)
#     switching back to exact line minimization
#     iteration    3: trace = 6.259888897176355 (0.00273744% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.259828955767929 (0.000957552% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.259809445991885 (0.000311667% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.259801081221752 (0.000133627% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.259798653168262 (3.8788e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.259797929125832 (1.15665e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 67.4082%)
#     iteration    9: trace = 6.259797720203119 (3.33753e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 7, 0.142857, 0, 0, 0.142857, 0.128891, 0.62151, 0.783143, 0.829756, 0.956404, 1.04556, 1.07217, 1.18222
# elapsed time for k point: 0.07980585098266602
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.27500607924885 (0.0241308% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.274048734608527 (0.0152576% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.27381421141602 (0.00373806% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.273727577052465 (0.0013809% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.273697127202751 (0.000485356% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.273683802634775 (0.000212388% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.273679876733148 (6.25773e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.273678657767052 (1.94298e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.273678263785939 (6.27991e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 8, 0.166667, 0, 0, 0.166667, 0.150254, 0.618116, 0.772533, 0.831526, 0.960325, 1.04295, 1.07094, 1.19328
# elapsed time for k point: 0.06738090515136719
# solve_kpoint (0.190476,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 59.0841%)
#     iteration    1: trace = 6.288391776630359 (0.0291861% change)
#     switching back to exact line minimization
#     iteration    2: trace = 6.287109055518778 (0.0204003% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.28678243228657 (0.00519526% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.286657679769394 (0.00198438% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.286610740868169 (0.000746646% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.286590010463077 (0.000329755% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.286583979890597 (9.59276e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.286582082853931 (3.0176e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.286581415489678 (1.06157e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.286581105026197 (4.93851e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 9, 0.190476, 0, 0, 0.190476, 0.171559, 0.613763, 0.762034, 0.833495, 0.962835, 1.04244, 1.06953, 1.20308
# elapsed time for k point: 0.12994050979614258
# solve_kpoint (0.214286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.299027862009543 (0.0355226% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.297351358187003 (0.0266188% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.296911404914907 (0.00698657% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.296735199823617 (0.00279832% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.296667147653271 (0.00108076% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.29663635078192 (0.000489099% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.296627367889563 (0.000142662% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.29662435233352 (4.78916e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.296622885053319 (2.33027e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.296621625146132 (2.00093e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.296619608746525 (3.20235e-05% change)
#     large trace change predicted (0.00102946%)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 6.296557695983696 (0.000983275% change)
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration   13: trace = 6.296334370305368 (0.00354685% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 6.296299146307963 (0.000559438% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 6.296270530483058 (0.000454487% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 6.296245749523437 (0.000393582% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 6.296223460574284 (0.000354004% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 6.296202909813141 (0.000326399% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 6.296183629310001 (0.000306225% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 6.296165306851491 (0.000291009% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 6.296147722456682 (0.000279288% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 6.296130714376642 (0.000270135% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 6.296114159505515 (0.000262938% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 6.29609796143088 (0.000257271% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 6.296082042798123 (0.000252834% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 6.296066340241063 (0.000249402% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 6.296050800907357 (0.000246811% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 6.296035380012052 (0.00024493% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 6.296020039075495 (0.000243661% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 6.29600474462955 (0.000242923% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 6.295989467252311 (0.000242652% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 65.9811%)
#     iteration   32: trace = 6.295974180838268 (0.000242796% change)
#     switching back to exact line minimization
#     iteration   33: trace = 6.295958862502671 (0.000243304% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 6.295943660423971 (0.000241458% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 6.295928215770451 (0.000245311% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 6.295912681417091 (0.000246737% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 6.29589704162299 (0.000248412% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 6.295881282027508 (0.000250316% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.4123%)
#     iteration   39: trace = 6.295865389537145 (0.000252427% change)
#     switching back to exact line minimization
#     iteration   40: trace = 6.295849353811755 (0.000254703% change)
#     linmin: converged after 4 iterations.
#     iteration   41: trace = 6.295832837807787 (0.000262332% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 6.295816479564511 (0.000259827% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 6.295799947227512 (0.000262593% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 6.295783233079424 (0.000265481% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 6.295766330385836 (0.000268477% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 6.295749233388641 (0.000271564% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 6.295731937296946 (0.000274727% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 6.295714438279614 (0.000277951% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 6.295696733456454 (0.000281221% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 6.295678820886351 (0.000284521% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 6.29566069955079 (0.000287838% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 6.29564236933156 (0.000291157% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 6.295623830981757 (0.000294464% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 6.295605086089374 (0.000297745% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 6.295586137033252 (0.000300989% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 6.29556698693156 (0.000304183% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 6.295547639583156 (0.000307317% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 6.295528099402736 (0.000310381% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 6.295508371350932 (0.000313367% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 6.295488460860756 (0.000316266% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 6.29546837376208 (0.000319072% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 61.2357%)
#     iteration   62: trace = 6.295448116206046 (0.00032178% change)
#     switching back to exact line minimization
#     iteration   63: trace = 6.295427707679538 (0.00032418% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 6.295406075162967 (0.000343623% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 81.6449%)
#     iteration   65: trace = 6.295385345833005 (0.000329278% change)
#     iteration   66: trace = 6.295364485420843 (0.000331361% change)
#     iteration   67: trace = 6.295342428723573 (0.000350365% change)
#     switching back to exact line minimization
#     iteration   68: trace = 6.295320211946988 (0.000352909% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 6.295297850095543 (0.000355215% change)
#     resetting CG direction...
#     large trace change predicted (0.652583%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 6.254070261214388 (0.657046% change)
#     linmin: converged after 3 iterations.
#     iteration   71: trace = 6.243679321536841 (0.166285% change)
#     linmin: converged after 3 iterations.
#     iteration   72: trace = 6.240193245892373 (0.0558493% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 6.238257948399487 (0.0310182% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 6.237289267185743 (0.0155293% change)
#     linmin: converged after 3 iterations.
#     iteration   75: trace = 6.236241563251784 (0.0167988% change)
#     linmin: converged after 3 iterations.
#     iteration   76: trace = 6.235360115672403 (0.0141353% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 52.1599%)
#     iteration   77: trace = 6.234697337660597 (0.0106299% change)
#     switching back to exact line minimization
#     iteration   78: trace = 6.23427208564237 (0.00682096% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 6.233992837756502 (0.00447934% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 6.233877601674338 (0.00184853% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 6.233856152319965 (0.000344078% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 6.233849398134236 (0.000108347% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 6.233845944715238 (5.53979e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 6.233844441768637 (2.41095e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 6.233843848101025 (9.5233e-06% change)
# Finished solving for bands 1 to 8 after 85 iterations.
# tefreqs:, 10, 0.214286, 0, 0, 0.214286, 0.192795, 0.60827, 0.751976, 0.835627, 0.963788, 1.04414, 1.06794, 1.18462
# elapsed time for k point: 0.620089054107666
# solve_kpoint (0.238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.221803543193196 (0.0184284% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.221335409773644 (0.00752436% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.221215478416379 (0.00192776% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.221175818541817 (0.000637496% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.221160374195614 (0.000248255% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.22115577355165 (7.39516e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.221154569530447 (1.93537e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.221154289054326 (4.50843e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 11, 0.238095, 0, 0, 0.238095, 0.213947, 0.601462, 0.742646, 0.837886, 0.963334, 1.04785, 1.0662, 1.18205
# elapsed time for k point: 0.07735252380371094
# solve_kpoint (0.261905,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.211243269138144 (0.0172156% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.210804505737666 (0.00706427% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.210685612871901 (0.00191431% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.210644359558509 (0.000664233% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.210628299775636 (0.000258585% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.210623624917577 (7.52719e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.210622438335451 (1.91057e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.210622157401352 (4.52345e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 12, 0.261905, 0, 0, 0.261905, 0.235001, 0.593206, 0.73427, 0.840227, 0.961829, 1.05321, 1.06433, 1.17949
# elapsed time for k point: 0.06073260307312012
# solve_kpoint (0.285714,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.203060020690113 (0.0161091% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.202645239864841 (0.00668694% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.202528320924813 (0.001885% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.202486884903951 (0.000668053% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.20247107607985 (0.000254879% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.20246650611143 (7.36798e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.202465369573044 (1.8324e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.2341%)
#     iteration    8: trace = 6.202465097183198 (4.39164e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 13, 0.285714, 0, 0, 0.285714, 0.255937, 0.583432, 0.726993, 0.842603, 0.959669, 1.05978, 1.06237, 1.177
# elapsed time for k point: 0.06562471389770508
# solve_kpoint (0.309524,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.197447342941008 (0.0151406% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.197052804666553 (0.00636634% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.196937165795148 (0.00186605% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.196895362007576 (0.00067459% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.196879846461164 (0.000250376% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.196875427803156 (7.13046e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.196874360627201 (1.72212e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.196874108829599 (4.0633e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 14, 0.309524, 0, 0, 0.309524, 0.276733, 0.572161, 0.720863, 0.844961, 0.957192, 1.06036, 1.06722, 1.17464
# elapsed time for k point: 0.0828099250793457
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.194565685119848 (0.0143251% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.194186299136107 (0.00612468% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.194070657966039 (0.00186695% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.194027950853295 (0.000689486% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.194012556184571 (0.000248541% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.194008243074896 (6.96336e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.194007237479433 (1.6235e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.194007010272967 (3.66817e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 15, 0.333333, 0, 0, 0.333333, 0.297358, 0.559493, 0.715843, 0.847243, 0.95465, 1.05836, 1.07524, 1.17247
# elapsed time for k point: 0.05743122100830078
# solve_kpoint (0.357143,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.194533975589808 (0.0136841% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.194162438381826 (0.005998% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.194044242331142 (0.0019082% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.19399926908584 (0.000726075% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.193983384923564 (0.000256445% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.193978914786637 (7.2169e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.193977876241389 (1.6767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.193977638420802 (3.83955e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 16, 0.357143, 0, 0, 0.357143, 0.31777, 0.545594, 0.711836, 0.849391, 0.952219, 1.05642, 1.08366, 1.17051
# elapsed time for k point: 0.06666159629821777
# solve_kpoint (0.380952,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.197412533274617 (0.0132526% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.197037666926196 (0.00604894% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.196911954521755 (0.00202861% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.196861632091707 (0.00081206% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.196843664286982 (0.00028995% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.196838215735901 (8.79247e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.196836778989621 (2.31852e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.19683634358924 (7.02617e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tefreqs:, 17, 0.380952, 0, 0, 0.380952, 0.337906, 0.530672, 0.708716, 0.851343, 0.95002, 1.05462, 1.09229, 1.16881
# elapsed time for k point: 0.07925939559936523
# solve_kpoint (0.404762,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.203169444725512 (0.0130982% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.202772366807511 (0.00640142% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.202629078447696 (0.0023101% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.202566341349542 (0.00101146% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.202542142619313 (0.000390141% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.202533253909385 (0.000143308% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.202530156611859 (4.9936e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.202528796655761 (2.19258e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.20252820642129 (9.51603e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 18, 0.404762, 0, 0, 0.404762, 0.35766, 0.514977, 0.706355, 0.853041, 0.948136, 1.05303, 1.10098, 1.1674
# elapsed time for k point: 0.06923294067382812
# solve_kpoint (0.428571,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.211599891452409 (0.0133648% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.211145137634443 (0.00732131% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.210961790836082 (0.00295194% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.2108686289538 (0.00149997% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.210827710881616 (0.000658816% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.21080828608642 (0.000312757% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60.4033%)
#     iteration    7: trace = 6.210799494744103 (0.000141549% change)
#     switching back to exact line minimization
#     iteration    8: trace = 6.210795073802409 (7.11815e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.210793310062678 (2.8398e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.210792708793694 (9.68103e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 19, 0.428571, 0, 0, 0.428571, 0.376826, 0.498838, 0.70464, 0.854428, 0.946623, 1.0517, 1.10951, 1.16628
# elapsed time for k point: 0.09147214889526367
# solve_kpoint (0.452381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.222120397016109 (0.0144468% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.221519315471523 (0.00966086% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.221238406067215 (0.00451523% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.221065121609586 (0.00278541% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.220978758081521 (0.00138825% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.220924765626053 (0.000867913% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.220898374755932 (0.000424228% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.220886173032232 (0.000196141% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.220882091106932 (6.56165e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.220880905914941 (1.90518e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.220880642364727 (4.23654e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 20, 0.452381, 0, 0, 0.452381, 0.394906, 0.48285, 0.703479, 0.855457, 0.945517, 1.05071, 1.11748, 1.16548
# elapsed time for k point: 0.08217787742614746
# solve_kpoint (0.47619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.233154442718275 (0.0173506% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.232158021088745 (0.0159871% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.231609023875044 (0.00880949% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.231197607780669 (0.0066023% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.230975684397178 (0.00356155% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.230820053365991 (0.00249773% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 63.5404%)
#     iteration    7: trace = 6.230748936258473 (0.00114138% change)
#     switching back to exact line minimization
#     iteration    8: trace = 6.230719783797843 (0.000467882% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.230711215936463 (0.00013751% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.23070899950474 (3.55727e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.230708517812753 (7.73093e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 21, 0.47619, 0, 0, 0.47619, 0.410336, 0.468648, 0.70281, 0.856091, 0.944844, 1.05009, 1.12393, 1.16499
# elapsed time for k point: 0.1286754608154297
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.240383910372757 (0.0240579% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.238335723583409 (0.0328269% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.237182313947441 (0.0184908% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.23628407144607 (0.0144025% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.235842982392173 (0.0070732% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.23553496831005 (0.00493954% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 70.7407%)
#     iteration    7: trace = 6.235410935398892 (0.00198915% change)
#     iteration    8: trace = 6.235365856071363 (0.000722959% change)
#     switching back to exact line minimization
#     iteration    9: trace = 6.235353270846461 (0.000201836% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.235350213511142 (4.90323e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.235349486749355 (1.16555e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.235349277595086 (3.35433e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 22, 0.5, 0, 0, 0.5, 0.41762, 0.461769, 0.702592, 0.856305, 0.944617, 1.04989, 1.12669, 1.16483
# elapsed time for k point: 0.08217549324035645
# solve_kpoint (0.5,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.234109002229221 (0.0622585% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.231060521762791 (0.048912% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.226951723420619 (0.0659623% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.221542324082765 (0.0869085% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.215831501561097 (0.0918333% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.1385%)
#     iteration    6: trace = 6.208898559221446 (0.111599% change)
#     switching back to exact line minimization
#     iteration    7: trace = 6.206423501319996 (0.039871% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.205615898925368 (0.0130132% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.205444892811172 (0.00275571% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.205370554618892 (0.00119796% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.205344137222418 (0.000425719% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.205334978239289 (0.000147598% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.20533233634756 (4.25745e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.205331649233175 (1.1073e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.2053312132021 (7.02672e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 23, 0.5, 0.0238095, 0, 0.500567, 0.418249, 0.462077, 0.702171, 0.856613, 0.943598, 1.04723, 1.13017, 1.15139
# elapsed time for k point: 0.12653017044067383
# solve_kpoint (0.5,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.189450498057513 (0.0203036% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.188687966535672 (0.0123206% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.188386387811629 (0.00487318% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 65.8497%)
#     iteration    4: trace = 6.188156253083269 (0.00371889% change)
#     iteration    5: trace = 6.188038843949585 (0.00189734% change)
#     switching back to exact line minimization
#     iteration    6: trace = 6.187889243465412 (0.0024176% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.187815315018882 (0.00119474% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.187789160219817 (0.000422683% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.187784799021125 (7.04808e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.187783877962871 (1.48851e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.187783664704325 (3.44644e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 24, 0.5, 0.047619, 0, 0.502262, 0.42013, 0.462998, 0.700913, 0.85754, 0.940472, 1.04067, 1.13928, 1.14229
# elapsed time for k point: 0.09910058975219727
# solve_kpoint (0.5,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.172373477554619 (0.0194946% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.171765275003189 (0.00985411% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.171581941990329 (0.00297056% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.17148098365444 (0.00163587% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.171447927535776 (0.000535628% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 6.171422944475065 (0.000404818% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.171405511419 (0.000282481% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.171397229297242 (0.000134202% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.171395418926395 (2.93349e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.171394983836261 (7.05011e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 25, 0.5, 0.0714286, 0, 0.505076, 0.423244, 0.464524, 0.698845, 0.85906, 0.935082, 1.03265, 1.13273, 1.15165
# elapsed time for k point: 0.07338666915893555
# solve_kpoint (0.5,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.157394485609629 (0.0198377% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.156777714099134 (0.0100173% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.156594818498148 (0.00297068% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.156505612547954 (0.00144896% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.156482881328658 (0.000369223% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.156473455638976 (0.000153102% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.156467954017677 (8.93632e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.156465085067304 (4.66006e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.156464225957127 (1.39546e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.156463957237706 (4.36483e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 26, 0.5, 0.0952381, 0, 0.508989, 0.427562, 0.466643, 0.696013, 0.861131, 0.927299, 1.0249, 1.12296, 1.16558
# elapsed time for k point: 0.09284758567810059
# solve_kpoint (0.5,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.143822270318001 (0.0206171% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.143149213710275 (0.0109556% change)
#     linmin: converged after 2 iterations.
# ...
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.180078511015846 (0.00711645% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.17990839017491 (0.00275277% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.179855531190817 (0.00085534% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.179834691263009 (0.000337224% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.179821785230927 (0.000208841% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.179813383363129 (0.000135957% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.179810615603284 (4.47871e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.179809951806881 (1.07414e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.179809810089754 (2.29323e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 56, 0.190476, 0.190476, 0, 0.269374, 0.242388, 0.610152, 0.721968, 0.843893, 0.954477, 0.978107, 1.14994, 1.15122
# elapsed time for k point: 0.10938835144042969
# solve_kpoint (0.166667,0.166667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.213143989844713 (0.056241% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.211229991954327 (0.0308104% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.2107699295667 (0.00740722% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.210574126622554 (0.00315269% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.210501566012333 (0.00116835% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.21045908225397 (0.000684066% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.210428075679776 (0.000499265% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.21040520333661 (0.00036829% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.210396774949137 (0.000135714% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.210394070951153 (4.35399e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.210392995072218 (1.73238e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.210392466895123 (8.50473e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 57, 0.166667, 0.166667, 0, 0.235702, 0.212343, 0.614002, 0.738048, 0.839902, 0.973001, 0.973763, 1.13489, 1.16415
# elapsed time for k point: 0.12966275215148926
# solve_kpoint (0.142857,0.142857,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.242172840581643 (0.057637% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.240201596807322 (0.0315844% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.239713512005843 (0.00782193% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.239483521711452 (0.00368598% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.239380756031059 (0.00164704% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.239302243845793 (0.00125834% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.239231396254158 (0.00113551% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.239159002790349 (0.0011603% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.239118742162781 (0.000645291% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.23909979059979 (0.000303754% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.239090566428446 (0.000147845% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.239086719322993 (6.16613e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.239085742950028 (1.56493e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.239085447214781 (4.74004e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 58, 0.142857, 0.142857, 0, 0.202031, 0.182189, 0.617612, 0.754339, 0.836156, 0.968513, 0.991203, 1.12049, 1.17485
# elapsed time for k point: 0.14049983024597168
# solve_kpoint (0.119048,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.268447012329495 (0.0573428% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.266495747974322 (0.0311332% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.265979664306266 (0.00823594% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.265697809628882 (0.00449828% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.265513934869603 (0.00293467% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.265274772803209 (0.00381719% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.264909082843324 (0.00583694% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 6.264315863281615 (0.00946937% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.263825109885633 (0.00783442% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 6.263548648767256 (0.00441371% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.263416319487311 (0.00211271% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.263371102529169 (0.000721924% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.263360296250208 (0.000172532% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 63.342%)
#     iteration   14: trace = 6.263356961643964 (5.32399e-05% change)
#     switching back to exact line minimization
#     iteration   15: trace = 6.263356354722754 (9.69003e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 59, 0.119048, 0.119048, 0, 0.168359, 0.151948, 0.620882, 0.770531, 0.832799, 0.962261, 1.00899, 1.10739, 1.18203
# elapsed time for k point: 0.2097935676574707
# solve_kpoint (0.0952381,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.282234887008324 (0.0563811% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.27961957207218 (0.041639% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.277984378713187 (0.0260431% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.275547373819567 (0.0388258% change)
#     large trace change predicted (0.0856936%)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.270560290615476 (0.0795001% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.263520264114779 (0.112334% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 6.259528070593736 (0.0637575% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.257761037729599 (0.0282335% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.256924342710635 (0.0133714% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 6.256533636963076 (0.00624457% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.256398581460194 (0.00215865% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.256337573504937 (0.000975134% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.256308035739974 (0.000472127% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.256275797383565 (0.000515295% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.8119%)
#     iteration   15: trace = 6.256238621414445 (0.000594221% change)
#     switching back to exact line minimization
#     iteration   16: trace = 6.256180881971575 (0.000922914% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 6.256136113153331 (0.000715596% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 6.256116550108713 (0.000312702% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 6.256112359270918 (6.69879e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 6.256111705580587 (1.04488e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 6.25611152189589 (2.93608e-06% change)
# Finished solving for bands 1 to 8 after 21 iterations.
# tefreqs:, 60, 0.0952381, 0.0952381, 0, 0.134687, 0.121637, 0.623716, 0.786188, 0.829926, 0.955066, 1.02625, 1.09615, 1.17411
# elapsed time for k point: 0.21039795875549316
# solve_kpoint (0.0714286,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.240377671848306 (0.0354948% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.239084670016242 (0.0207221% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.238647743137419 (0.00700331% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.238297810900823 (0.00560926% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.237987168703002 (0.00497972% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 6.237714545463174 (0.00437047% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.237623028824819 (0.00146716% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 73.9716%)
#     iteration    8: trace = 6.237595155288983 (0.000446862% change)
#     iteration    9: trace = 6.237588466909495 (0.000107227% change)
#     switching back to exact line minimization
#     iteration   10: trace = 6.237586590259781 (3.00861e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.237586192958256 (6.36948e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 61, 0.0714286, 0.0714286, 0, 0.101015, 0.0912728, 0.626026, 0.800651, 0.827613, 0.947305, 1.04276, 1.08719, 1.15959
# elapsed time for k point: 0.12099218368530273
# solve_kpoint (0.047619,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.224584143848762 (0.0316147% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.223694166393979 (0.0142988% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.223486563839226 (0.00333574% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 6.223394596615165 (0.00147776% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 6.223346271013266 (0.000776518% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.223302544868187 (0.000702617% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.223281708040227 (0.00033482% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.223273237231881 (0.000136115% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.223270730576336 (4.02787e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.223269873260865 (1.3776e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.223269696959986 (2.83293e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 62, 0.047619, 0.047619, 0, 0.0673435, 0.0608696, 0.627734, 0.812898, 0.825918, 0.939852, 1.05798, 1.08073, 1.14541
# elapsed time for k point: 0.13801240921020508
# solve_kpoint (0.0238095,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 58.9073%)
#     iteration    1: trace = 6.215453861081666 (0.0300212% change)
#     iteration    2: trace = 6.214669112394022 (0.0126266% change)
#     iteration    3: trace = 6.214501608693382 (0.00269533% change)
#     iteration    4: trace = 6.214442388569678 (0.000952939% change)
#     iteration    5: trace = 6.214422135090871 (0.00032591% change)
#     iteration    6: trace = 6.214409571090453 (0.000202175% change)
#     iteration    7: trace = 6.214404242539779 (8.57451e-05% change)
#     iteration    8: trace = 6.214401729526279 (4.04385e-05% change)
#     switching back to exact line minimization
#     iteration    9: trace = 6.214400697748807 (1.6603e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.214400149029521 (8.8298e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 63, 0.0238095, 0.0238095, 0, 0.0336718, 0.0304413, 0.628782, 0.821428, 0.824885, 0.93418, 1.07027, 1.07685, 1.13364
# elapsed time for k point: 0.1290585994720459
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.212360426763487 (0.0286258% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 6.211625270117459 (0.0118345% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 6.211477297703408 (0.00238221% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 59.0099%)
#     iteration    4: trace = 6.211427239411748 (0.000805903% change)
#     switching back to exact line minimization
#     iteration    5: trace = 6.211411209763973 (0.000258067% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 6.211405681244098 (8.90059e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.211403953577627 (2.78144e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.211403596790272 (5.74407e-06% change)
# Finished solving for bands 2 to 8 after 8 iterations.
# tefreqs:, 64, 0, 0, 0, 0, 0, 0.629133, 0.824541, 0.824544, 0.932016, 1.07556, 1.07556, 1.12851
# elapsed time for k point: 0.10911941528320312
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5495174109534839 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.46176908672107236 at Vector3<0.5, 0.0, 0.0> to 0.629132846063919 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.6021802907005981 at Vector3<0.5, 0.5, 0.0> to 0.8245408228814005 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.681033282520359 at Vector3<0.5, 0.5, 0.0> to 0.8739078047992819 at Vector3<0.5, 0.19047619047619047, 0.0>
# Band 5 range: 0.8756586421839114 at Vector3<0.5, 0.19047619047619047, 0.0> to 0.9730009531364721 at Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
# Band 6 range: 0.9737627754094007 at Vector3<0.16666666666666669, 0.16666666666666669, 0.0> to 1.0755594427344313 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.9971255180373905 at Vector3<0.5, 0.5, 0.0> to 1.1499357275754778 at Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
# Band 8 range: 1.1285131236119725 at Vector3<0.0, 0.0, 0.0> to 1.2466840649425306 at Vector3<0.5, 0.26190476190476186, 0.0>
# Gap from band 4 (0.8739078047992819) to band 5 (0.8756586421839114), 0.20014528601054893%
# Gap from band 5 (0.9730009531364721) to band 6 (0.9737627754094007), 0.07826550924057818%
# total elapsed time for run: 7.8609397411346436
# done
# (64, 8)

# %% [markdown]
# 所以可以直接从计算的modesoler中得到所需的结果，如果我们再计算一下tm呢？

# %%
ms.run_tm()
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
print(np.shape(tm_freqs))
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 64 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.023809523809523808, 0.0, 0.0>
#   Vector3<0.047619047619047616, 0.0, 0.0>
#   Vector3<0.07142857142857142, 0.0, 0.0>
#   Vector3<0.09523809523809523, 0.0, 0.0>
#   Vector3<0.11904761904761904, 0.0, 0.0>
#   Vector3<0.14285714285714285, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.19047619047619047, 0.0, 0.0>
#   Vector3<0.21428571428571427, 0.0, 0.0>
#   Vector3<0.23809523809523808, 0.0, 0.0>
#   Vector3<0.26190476190476186, 0.0, 0.0>
#   Vector3<0.2857142857142857, 0.0, 0.0>
#   Vector3<0.30952380952380953, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.3571428571428571, 0.0, 0.0>
#   Vector3<0.38095238095238093, 0.0, 0.0>
#   Vector3<0.40476190476190477, 0.0, 0.0>
#   Vector3<0.42857142857142855, 0.0, 0.0>
#   Vector3<0.45238095238095233, 0.0, 0.0>
#   Vector3<0.47619047619047616, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.023809523809523808, 0.0>
#   Vector3<0.5, 0.047619047619047616, 0.0>
#   Vector3<0.5, 0.07142857142857142, 0.0>
#   Vector3<0.5, 0.09523809523809523, 0.0>
#   Vector3<0.5, 0.11904761904761904, 0.0>
#   Vector3<0.5, 0.14285714285714285, 0.0>
#   Vector3<0.5, 0.16666666666666666, 0.0>
#   Vector3<0.5, 0.19047619047619047, 0.0>
#   Vector3<0.5, 0.21428571428571427, 0.0>
#   Vector3<0.5, 0.23809523809523808, 0.0>
#   Vector3<0.5, 0.26190476190476186, 0.0>
#   Vector3<0.5, 0.2857142857142857, 0.0>
#   Vector3<0.5, 0.30952380952380953, 0.0>
#   Vector3<0.5, 0.3333333333333333, 0.0>
#   Vector3<0.5, 0.3571428571428571, 0.0>
#   Vector3<0.5, 0.38095238095238093, 0.0>
#   Vector3<0.5, 0.40476190476190477, 0.0>
#   Vector3<0.5, 0.42857142857142855, 0.0>
#   Vector3<0.5, 0.45238095238095233, 0.0>
#   Vector3<0.5, 0.47619047619047616, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.47619047619047616, 0.47619047619047616, 0.0>
#   Vector3<0.4523809523809524, 0.4523809523809524, 0.0>
#   Vector3<0.4285714285714286, 0.4285714285714286, 0.0>
#   Vector3<0.40476190476190477, 0.40476190476190477, 0.0>
#   Vector3<0.38095238095238093, 0.38095238095238093, 0.0>
#   Vector3<0.35714285714285715, 0.35714285714285715, 0.0>
#   Vector3<0.33333333333333337, 0.33333333333333337, 0.0>
#   Vector3<0.30952380952380953, 0.30952380952380953, 0.0>
#   Vector3<0.2857142857142857, 0.2857142857142857, 0.0>
#   Vector3<0.2619047619047619, 0.2619047619047619, 0.0>
#   Vector3<0.23809523809523814, 0.23809523809523814, 0.0>
#   Vector3<0.2142857142857143, 0.2142857142857143, 0.0>
#   Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
#   Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
#   Vector3<0.1428571428571429, 0.1428571428571429, 0.0>
#   Vector3<0.11904761904761907, 0.11904761904761907, 0.0>
#   Vector3<0.09523809523809523, 0.09523809523809523, 0.0>
#   Vector3<0.07142857142857145, 0.07142857142857145, 0.0>
#   Vector3<0.04761904761904767, 0.04761904761904767, 0.0>
#   Vector3<0.023809523809523836, 0.023809523809523836, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0129241943359375
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 14.57086736867354 (194.652% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 5.940694717302973 (84.1493% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.427584744825663 (9.02705% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 5.305254074324726 (2.27956% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.282662127526967 (0.42675% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.27573929163619 (0.131134% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.272723290144707 (0.0571837% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.271456349787605 (0.0240311% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.270927081481013 (0.0100408% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.270566615563156 (0.00683899% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.270321459530276 (0.00465153% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.270256313997242 (0.00123609% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.270240993512749 (0.000290698% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.270235995733547 (9.48302e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.270233595149866 (4.55498e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.27023260057411 (1.88716e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.270232400235883 (3.80132e-06% change)
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.582551, 0.628589, 0.628591, 0.890132, 0.974373, 1.06601, 1.12361
# elapsed time for k point: 0.6341028213500977
# solve_kpoint (0.0238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.269745658516396 (0.0540128% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.267504474315281 (0.0425383% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.266173111141038 (0.0252782% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.265456582029683 (0.0136072% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.265286776543011 (0.00322495% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.26519533515152 (0.0017367% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.265132123400081 (0.00120057% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.265081919358792 (0.000953524% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.265057061188318 (0.000472134% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.265039638545251 (0.000330911% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.265006160712555 (0.000635854% change)
#     large trace change predicted (0.00146052%)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 5.264929198960233 (0.00146177% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 5.264821777541753 (0.00204034% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 5.264732791924503 (0.00169021% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 5.264670612343889 (0.00118107% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 5.264587997633943 (0.00156924% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 5.26443283422886 (0.00294735% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.264261592788952 (0.00325285% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.264188889412509 (0.00138108% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 5.264172896385285 (0.000303808% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 5.264168816845022 (7.74963e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 5.264165646470181 (6.02256e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 5.264163715216995 (3.66868e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 5.264162781046097 (1.77459e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 5.264162149433882 (1.19983e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 5.264161492217314 (1.24847e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.264161125581207 (6.96476e-06% change)
# Finished solving for bands 1 to 8 after 27 iterations.
# tmfreqs:, 2, 0.0238095, 0, 0, 0.0238095, 0.016862, 0.581289, 0.628635, 0.629713, 0.890164, 0.974171, 1.06425, 1.1226
# elapsed time for k point: 0.18361377716064453
# solve_kpoint (0.047619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.252426756220225 (0.0493881% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.250624237118306 (0.0343237% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.249609396340394 (0.0193299% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.249016040880763 (0.0113035% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.248936774058284 (0.00151014% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.248923768566074 (0.000247774% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.248921957884994 (3.44962e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.248921110132931 (1.6151e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.248920125604615 (1.87568e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.24891845656772 (3.17977e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.248917058618039 (2.66331e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.248915846400094 (2.30946e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.248914243441134 (3.05389e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.248913579032616 (1.2658e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.248913231816372 (6.61501e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tmfreqs:, 3, 0.047619, 0, 0, 0.047619, 0.0336967, 0.577798, 0.628768, 0.632793, 0.890242, 0.973574, 1.05928, 1.12058
# elapsed time for k point: 0.13674378395080566
# solve_kpoint (0.0714286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.230958392638888 (0.040553% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.229823674968481 (0.0216947% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.229323356090588 (0.00956711% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.229046030153284 (0.00530343% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.228999112522092 (0.000897254% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.228991286479435 (0.000149666% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.5272%)
#     iteration    7: trace = 5.228990601785442 (1.30942e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 5.228990496092241 (2.02129e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0.0714286, 0, 0, 0.0714286, 0.0504762, 0.572683, 0.628986, 0.637235, 0.890316, 0.972605, 1.05187, 1.11881
# elapsed time for k point: 0.06692171096801758
# solve_kpoint (0.0952381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.208299075139873 (0.0341363% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.207553643359365 (0.0143134% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.207295332563072 (0.00496043% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.207161783492728 (0.00256469% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.207134220572199 (0.000529329% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.207129360830753 (9.33286e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.207128992089082 (7.08148e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0.0952381, 0, 0, 0.0952381, 0.0671717, 0.566465, 0.629284, 0.642537, 0.890299, 0.9713, 1.04293, 1.11764
# elapsed time for k point: 0.0575101375579834
# solve_kpoint (0.119048,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.185599925399526 (0.0300431% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.185062384380974 (0.0103666% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.184910753528947 (0.00292442% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.184839631190124 (0.00137173% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.184823030684481 (0.000320174% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.18481989344825 (6.05081e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.184819677838298 (4.15848e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0.119048, 0, 0, 0.119048, 0.0837527, 0.559482, 0.629658, 0.648386, 0.890065, 0.969708, 1.03326, 1.11702
# elapsed time for k point: 0.053865671157836914
# solve_kpoint (0.142857,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.163504622517151 (0.0271404% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.16309356263285 (0.00796119% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.162996115545715 (0.0018874% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.162954960713211 (0.000797115% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.162944402098445 (0.000204507% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.162942250856675 (4.1667e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.162942109488068 (2.73814e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0.142857, 0, 0, 0.142857, 0.100187, 0.551937, 0.630098, 0.65461, 0.889445, 0.96788, 1.0235, 1.11682
# elapsed time for k point: 0.0780794620513916
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.142494083926939 (0.0249928% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.142165367400763 (0.00639237% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.142098066977304 (0.0013088% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.142072296039938 (0.000501177% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.142065169288461 (0.000138597% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.142063592924272 (3.06563e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.14206348979944 (2.00551e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, 0.166667, 0, 0, 0.166667, 0.116437, 0.543957, 0.630597, 0.661123, 0.888234, 0.965874, 1.01413, 1.11694
# elapsed time for k point: 0.07675862312316895
# solve_kpoint (0.190476,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.122919839580018 (0.0233652% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.122647291477596 (0.00532031% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.122598095911794 (0.000960359% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.122580842350384 (0.000336813% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.122575717374682 (0.000100047% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.122574480939411 (2.4137e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.122574397357829 (1.63163e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 9, 0.190476, 0, 0, 0.190476, 0.132464, 0.535627, 0.631143, 0.667881, 0.886198, 0.963745, 1.00556, 1.11732
# elapsed time for k point: 0.07504415512084961
# solve_kpoint (0.214286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.105042808946421 (0.0221227% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.104809521163291 (0.00456986% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.104771848254334 (0.000737991% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 59.0856%)
#     iteration    4: trace = 5.104759709362649 (0.000237795% change)
#     switching back to exact line minimization
#     iteration    5: trace = 5.104755813824621 (7.63119e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.104754779186015 (2.02681e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.104754704095462 (1.47099e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 10, 0.214286, 0, 0, 0.214286, 0.148221, 0.527016, 0.631725, 0.67487, 0.883108, 0.961547, 0.998132, 1.11794
# elapsed time for k point: 0.05789756774902344
# solve_kpoint (0.238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.089056934654733 (0.021183% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.088851099694953 (0.00404474% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.088821028963713 (0.000590916% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.088812249007658 (0.000172534% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.088809191033202 (6.00921e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.088808275738739 (1.79864e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.088808201523072 (1.45841e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 11, 0.238095, 0, 0, 0.238095, 0.163655, 0.518184, 0.63233, 0.682087, 0.878789, 0.959333, 0.992057, 1.11878
# elapsed time for k point: 0.06845593452453613
# solve_kpoint (0.261905,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.075103957998966 (0.0204936% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 57.5472%)
#     iteration    2: trace = 5.074916723007986 (0.00368935% change)
#     switching back to exact line minimization
#     iteration    3: trace = 5.074891707903217 (0.000492918% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.074885341588741 (0.000125447% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.074882971354627 (4.67052e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.074882132749339 (1.65246e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.07488205322429 (1.56703e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 12, 0.261905, 0, 0, 0.261905, 0.1787, 0.509198, 0.632945, 0.689537, 0.873166, 0.957151, 0.987436, 1.11982
# elapsed time for k point: 0.13324809074401855
# solve_kpoint (0.285714,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.063282757380165 (0.0200199% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.063107013071527 (0.00347102% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.063085236235673 (0.000430109% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.06308071368407 (8.93241e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.063079043554207 (3.29864e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.063078288825262 (1.49065e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.063078198883284 (1.77643e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, 0.285714, 0, 0, 0.285714, 0.193278, 0.500132, 0.633557, 0.697229, 0.86629, 0.955044, 0.984213, 1.12108
# elapsed time for k point: 0.06869816780090332
# solve_kpoint (0.309524,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.053655005215152 (0.0197405% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.05348459560815 (0.00337206% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.053464599621009 (0.000395688% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.05346146134795 (6.21014e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.053460547392152 (1.80857e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.053459978007028 (1.12672e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.053459877593108 (1.98703e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 14, 0.309524, 0, 0, 0.309524, 0.20729, 0.491079, 0.634151, 0.70517, 0.85832, 0.953052, 0.982211, 1.12257
# elapsed time for k point: 0.1481180191040039
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.046247680842967 (0.0196432% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.046076810555677 (0.00338614% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.046057229501244 (0.000388046% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.046054960407762 (4.49677e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.046054655913248 (6.03431e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 15, 0.333333, 0, 0, 0.333333, 0.22061, 0.482157, 0.634713, 0.713367, 0.849478, 0.951211, 0.981183, 1.12429
# elapsed time for k point: 0.08213615417480469
# solve_kpoint (0.357143,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.041051773984186 (0.0197311% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.040874546640236 (0.00351574% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.040853883360734 (0.000409915% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.04085178652879 (4.15968e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.040851647648386 (2.7551e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 16, 0.357143, 0, 0, 0.357143, 0.23308, 0.473518, 0.635232, 0.721825, 0.839993, 0.949552, 0.980866, 1.12624
# elapsed time for k point: 0.08636641502380371
# solve_kpoint (0.380952,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.038017463683481 (0.0200059% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.037826228229668 (0.00379592% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.037801879726896 (0.000483315% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.03779855139074 (6.60673e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.037797384447618 (2.31638e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.03779625302969 (2.24586e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.037796005382722 (4.91578e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 17, 0.380952, 0, 0, 0.380952, 0.24449, 0.465362, 0.635694, 0.730542, 0.83008, 0.948102, 0.981013, 1.12843
# elapsed time for k point: 0.06271767616271973
# solve_kpoint (0.404762,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.037032257371977 (0.020512% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.03681735342403 (0.00426657% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.036785264016916 (0.000637099% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.036776602635991 (0.000171963% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.036768801964568 (0.000154874% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.036764568037405 (8.40604e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.036764117935397 (8.93633e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 18, 0.404762, 0, 0, 0.404762, 0.25458, 0.457946, 0.636088, 0.739509, 0.81992, 0.946883, 0.981414, 1.13081
# elapsed time for k point: 0.05978083610534668
# solve_kpoint (0.428571,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.037881464744292 (0.0213219% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.037627567241856 (0.00503989% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.037578895523724 (0.000966168% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.03755113207542 (0.000551128% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.037521553471553 (0.000587164% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.0375122147477 (0.000185383% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.037511467706389 (1.48296e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.037511395923659 (1.42496e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 19, 0.428571, 0, 0, 0.428571, 0.263024, 0.451587, 0.636406, 0.7487, 0.809674, 0.945916, 0.981898, 1.1333
# elapsed time for k point: 0.07893800735473633
# solve_kpoint (0.452381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.040145047977836 (0.0225834% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.039825805226156 (0.0063342% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.03974032592742 (0.00169609% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.039650310723252 (0.00178612% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.03956608508587 (0.00167127% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.039548224422381 (0.000354409% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.03954693870983 (2.55125e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.039546824822192 (2.25988e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 20, 0.452381, 0, 0, 0.452381, 0.269455, 0.44665, 0.636638, 0.758048, 0.799508, 0.945215, 0.982336, 1.13573
# elapsed time for k point: 0.08367156982421875
# solve_kpoint (0.47619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.042972001781757 (0.0244958% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.042543664067621 (0.00849412% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.042377183881838 (0.00330157% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.042113668838958 (0.00522614% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.041923153406831 (0.00377855% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.041892892042591 (0.000600197% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.041890714140663 (4.31961e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.041890526588922 (3.71987e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 21, 0.47619, 0, 0, 0.47619, 0.273504, 0.443498, 0.63678, 0.767275, 0.789764, 0.94479, 0.982635, 1.13766
# elapsed time for k point: 0.137664794921875
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.044764471455587 (0.026952% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.04418681663955 (0.0114512% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.043885751179574 (0.00596874% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.043327726276294 (0.011064% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.043031729048804 (0.00586926% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.042993599968922 (0.000756077% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.042990712699156 (5.72531e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.042990454145841 (5.12698e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 22, 0.5, 0, 0, 0.5, 0.27489, 0.442411, 0.636827, 0.773453, 0.783411, 0.944647, 0.982741, 1.13844
# elapsed time for k point: 0.08190608024597168
# solve_kpoint (0.5,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.042260861123276 (0.0598949% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.041431085714962 (0.0164578% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.041312620434976 (0.00234986% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.041294608496234 (0.000357287% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.041292201311895 (4.77493e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.041291983772572 (4.31515e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 23, 0.5, 0.0238095, 0, 0.500567, 0.275126, 0.442854, 0.636171, 0.77321, 0.784166, 0.944541, 0.98275, 1.13756
# elapsed time for k point: 0.0631253719329834
# solve_kpoint (0.5,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.037248686071385 (0.0587956% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.036460007601044 (0.0156582% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.036352608290817 (0.00213246% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.036337764137143 (0.000294741% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.03633570859863 (4.08142e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.036335491200437 (4.31659e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 24, 0.5, 0.047619, 0, 0.502262, 0.27583, 0.444178, 0.634246, 0.772481, 0.786389, 0.944224, 0.982779, 1.13496
# elapsed time for k point: 0.06447434425354004
# solve_kpoint (0.5,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.029319578407259 (0.056371% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.028599889232007 (0.0143109% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.02850819027821 (0.00182357% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.028497449868108 (0.000213591% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 74.0053%)
#     iteration    5: trace = 5.028495965937374 (2.95104e-05% change)
#     switching back to exact line minimization
#     iteration    6: trace = 5.028495771668889 (3.86335e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 25, 0.5, 0.0714286, 0, 0.505076, 0.276991, 0.446367, 0.631173, 0.771258, 0.789965, 0.943699, 0.982826, 1.13082
# elapsed time for k point: 0.07149815559387207
# solve_kpoint (0.5,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.019010252912369 (0.0531834% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.018368437253573 (0.0127885% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.018291716662655 (0.00152881% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.018284503329234 (0.000143741% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.018283670589325 (1.65941e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.018283539528261 (2.61167e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 26, 0.5, 0.0952381, 0, 0.508989, 0.278589, 0.449397, 0.627121, 0.76953, 0.794729, 0.942971, 0.982889, 1.12534
# elapsed time for k point: 0.059384822845458984
# solve_kpoint (0.5,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.006883929802512 (0.0497781% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.006313810412468 (0.0113874% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.006247812455895 (0.0013183% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.006242632826857 (0.000103463% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.006242240704127 (7.83268e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 27, 0.5, 0.119048, 0, 0.513977, 0.280597, 0.453234, 0.622281, 0.767285, 0.800504, 0.942048, 0.982969, 1.11877
# elapsed time for k point: 0.05354046821594238
# solve_kpoint (0.5,0.142857,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.993456434050554 (0.0465138% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.992944366838753 (0.0102553% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.992883482857168 (0.00121941% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.992878693705275 (9.59196e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.99287834021569 (7.07988e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 28, 0.5, 0.142857, 0, 0.520008, 0.282982, 0.457832, 0.61684, 0.764509, 0.807114, 0.940943, 0.983063, 1.11131
# elapsed time for k point: 0.05478239059448242
# solve_kpoint (0.5,0.166667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.979169332229585 (0.0435496% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.97869956788575 (0.00943504% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.978638358081617 (0.00122944% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.978632472978793 (0.000118207% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.978631823691235 (1.30415e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.978631721045423 (2.06173e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 29, 0.5, 0.166667, 0, 0.527046, 0.285702, 0.463139, 0.610969, 0.761191, 0.814405, 0.939671, 0.983168, 1.10316
# elapsed time for k point: 0.08139896392822266
# solve_kpoint (0.5,0.190476,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.964388577040031 (0.0408873% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.963948636579494 (0.00886232% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.96388298805751 (0.00132251% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.963875018742389 (0.000160546% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.963873997647818 (2.05705e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.96387386363406 (2.69978e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 30, 0.5, 0.190476, 0, 0.535053, 0.288709, 0.469092, 0.604822, 0.757327, 0.822243, 0.938254, 0.983283, 1.09447
# elapsed time for k point: 0.09797120094299316
# solve_kpoint (0.5,0.214286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.949425125531992 (0.0384933% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.949005045724889 (0.00848781% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.948931643955765 (0.00148317% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.948921284117418 (0.000209335% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.948920029722759 (2.53468e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.94891989853154 (2.65091e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 31, 0.5, 0.214286, 0, 0.543984, 0.29195, 0.475619, 0.598533, 0.752921, 0.830516, 0.936721, 0.983405, 1.08538
# elapsed time for k point: 0.06768012046813965
# solve_kpoint (0.5,0.238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.934548395581826 (0.0363015% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.934141703990576 (0.00824206% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.934058778205108 (0.00168067% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.934046263899465 (0.000253631% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.934044934624477 (2.69409e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.934044821338009 (2.29602e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 32, 0.5, 0.238095, 0, 0.553795, 0.295364, 0.482637, 0.592223, 0.747993, 0.839129, 0.935104, 0.98353, 1.07599
# elapsed time for k point: 0.06269621849060059
# solve_kpoint (0.5,0.261905,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.920002943759407 (0.0342608% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.919606057617511 (0.00806711% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.919513211372993 (0.00188729% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.919499086727009 (0.000287115% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.919497776737495 (2.66285e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.919497684244552 (1.88013e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 33, 0.5, 0.261905, 0, 0.564441, 0.298885, 0.490052, 0.586001, 0.742581, 0.848, 0.933444, 0.983656, 1.06639
# elapsed time for k point: 0.06881332397460938
# solve_kpoint (0.5,0.285714,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.90601844310219 (0.0323438% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.905629908712122 (0.00791986% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.905527877502226 (0.0020799% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.905512758536148 (0.000308203% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.905511498380102 (2.56886e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.905511422878714 (1.53911e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 34, 0.5, 0.285714, 0, 0.575876, 0.30244, 0.497753, 0.579967, 0.736748, 0.857056, 0.931781, 0.98378, 1.05666
# elapsed time for k point: 0.1256852149963379
# solve_kpoint (0.5,0.309524,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.892814590424795 (0.030547% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.892434258279965 (0.00777358% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.892324532300739 (0.00224279% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.892308970343029 (0.00031809% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.892307751194588 (2.49197e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.892307685939939 (1.33382e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 35, 0.5, 0.309524, 0, 0.588052, 0.305953, 0.505614, 0.574219, 0.730585, 0.866223, 0.930162, 0.983898, 1.04689
# elapsed time for k point: 0.049562692642211914
# solve_kpoint (0.5,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.880601466585244 (0.0288846% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.88022973586858 (0.00761678% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.880114154046176 (0.0023684% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.880098579338632 (0.000319147% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.880097374749298 (2.46837e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.880097312789791 (1.26964e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 36, 0.5, 0.333333, 0, 0.600925, 0.309341, 0.513483, 0.56885, 0.72422, 0.875424, 0.928628, 0.984006, 1.03715
# elapsed time for k point: 0.027897357940673828
# solve_kpoint (0.5,0.357143,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.869576730958546 (0.0273794% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.869213963910497 (0.00744994% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.869094368519916 (0.00245618% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.869079077553938 (0.000314042% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.869077857667812 (2.50537e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.869077793916034 (1.30932e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 37, 0.5, 0.357143, 0, 0.614452, 0.312519, 0.521179, 0.563952, 0.717821, 0.884563, 0.927221, 0.9841, 1.02754
# elapsed time for k point: 0.026432514190673828
# solve_kpoint (0.5,0.380952,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.859921251702461 (0.0260548% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.85956740610441 (0.00728116% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.859445404249692 (0.00251058% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.859430568894761 (0.00030529% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.859429309079867 (2.59252e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.859429241876141 (1.38296e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 38, 0.5, 0.380952, 0, 0.628589, 0.3154, 0.528484, 0.559615, 0.711599, 0.893512, 0.925975, 0.984174, 1.0182
# elapsed time for k point: 0.02515435218811035
# solve_kpoint (0.5,0.404762,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.851794560548974 (0.0249292% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.851449028432862 (0.00712199% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.851325864958999 (0.00253873% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.851311552507118 (0.000295022% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.851310238061677 (2.70946e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.851310169094404 (1.42162e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 39, 0.5, 0.404762, 0, 0.643298, 0.317901, 0.535137, 0.555925, 0.705819, 0.902077, 0.924919, 0.984217, 1.00933
# elapsed time for k point: 0.07183599472045898
# solve_kpoint (0.5,0.428571,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.845331022122487 (0.0240143% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.8449926228227 (0.00698427% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.844869148233414 (0.00254853% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.844855344680528 (0.000284911% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.844853972024393 (2.83322e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.844853904170439 (1.40054e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 40, 0.5, 0.428571, 0, 0.658539, 0.319943, 0.540835, 0.55296, 0.700789, 0.909948, 0.924076, 0.984211, 1.00126
# elapsed time for k point: 0.02943897247314453
# solve_kpoint (0.5,0.452381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.840637084978455 (0.0233151% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.840304150527915 (0.00687814% change)
# ...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 50, 0.333333, 0.333333, 0, 0.471405, 0.285404, 0.516594, 0.568273, 0.733084, 0.883008, 0.908852, 1.00926, 1.00939
# elapsed time for k point: 0.039469242095947266
# solve_kpoint (0.309524,0.309524,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.861211870447823 (0.0483107% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.860821477920282 (0.00803109% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.86076730934045 (0.0011144% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.5676%)
#     iteration    4: trace = 4.860751445301066 (0.00032637% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.860745573495049 (0.0001208% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.860745002838169 (1.17401e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.860744966143271 (7.54923e-07% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 51, 0.309524, 0.309524, 0, 0.437733, 0.272551, 0.514555, 0.573524, 0.733971, 0.884661, 0.906147, 1.00922, 1.01577
# elapsed time for k point: 0.06843400001525879
# solve_kpoint (0.285714,0.285714,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.874269654006889 (0.0472545% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.873909555483168 (0.00738802% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.873871202692993 (0.000786903% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.873864636735806 (0.000134718% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.873862072095086 (5.26203e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.873861744804589 (6.71522e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 52, 0.285714, 0.285714, 0, 0.404061, 0.257769, 0.514262, 0.579124, 0.731659, 0.889763, 0.903583, 1.0092, 1.02255
# elapsed time for k point: 0.024689435958862305
# solve_kpoint (0.261905,0.261905,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.891683985261304 (0.0467204% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.891333309703643 (0.00716907% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.891301052565908 (0.000659478% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.89129770144296 (6.85119e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.891296716575964 (2.01351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.891296524283834 (3.93131e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 53, 0.261905, 0.261905, 0, 0.370389, 0.241245, 0.515652, 0.584956, 0.726537, 0.897755, 0.901207, 1.00932, 1.02971
# elapsed time for k point: 0.0693216323852539
# solve_kpoint (0.238095,0.238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.913434884880475 (0.0465375% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.913080473019818 (0.00721338% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.913049345912546 (0.000633558% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.913046816989205 (5.14736e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.913046430677663 (7.86297e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 54, 0.238095, 0.238095, 0, 0.336718, 0.223201, 0.518583, 0.590893, 0.719238, 0.899053, 0.907814, 1.00974, 1.03723
# elapsed time for k point: 0.017903566360473633
# solve_kpoint (0.214286,0.214286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.939449068181959 (0.0466266% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.939080782531199 (0.00745628% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.939047384371102 (0.000676204% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.939044484562429 (5.87119e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.939044172997969 (6.30819e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 55, 0.214286, 0.214286, 0, 0.303046, 0.203866, 0.522874, 0.596804, 0.710394, 0.89714, 0.919083, 1.01066, 1.0451
# elapsed time for k point: 0.021475791931152344
# solve_kpoint (0.190476,0.190476,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.969603672695536 (0.0469559% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.969211151914154 (0.00789874% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.96917224413342 (0.00078298% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.969168035751434 (8.46898e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.969167559629013 (9.58153e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 56, 0.190476, 0.190476, 0, 0.269374, 0.183457, 0.528338, 0.602555, 0.70052, 0.895481, 0.930738, 1.01237, 1.05334
# elapsed time for k point: 0.020746707916259766
# solve_kpoint (0.166667,0.166667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.003719570779799 (0.0475391% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.003290642276558 (0.00857256% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.003242024335421 (0.000971724% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.003235211761404 (0.000136163% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.003234365294421 (1.69184e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.00323427282966 (1.8481e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 57, 0.166667, 0.166667, 0, 0.235702, 0.162167, 0.534785, 0.608013, 0.690011, 0.894076, 0.941975, 1.01524, 1.06195
# elapsed time for k point: 0.022350072860717773
# solve_kpoint (0.142857,0.142857,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.04154356156636 (0.0484424% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.041060469378325 (0.00958269% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.040995651278351 (0.00128581% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.04098408147261 (0.000229515% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.040982557023923 (3.02411e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.04098236908963 (3.72813e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 58, 0.142857, 0.142857, 0, 0.202031, 0.140162, 0.542029, 0.613049, 0.67917, 0.892917, 0.952001, 1.01975, 1.07096
# elapsed time for k point: 0.07313728332519531
# solve_kpoint (0.119048,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.082707856863615 (0.0498243% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.082140134188635 (0.0111703% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.082046273895207 (0.00184688% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.082025549811521 (0.000407791% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.082022659798609 (5.68674e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.082022235391664 (8.35114e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 59, 0.119048, 0.119048, 0, 0.168359, 0.117588, 0.549875, 0.617542, 0.668251, 0.891991, 0.960154, 1.02626, 1.08036
# elapsed time for k point: 0.04127359390258789
# solve_kpoint (0.0952381,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.12663644674161 (0.0520353% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.125924926867937 (0.0138798% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.125774482028641 (0.00293502% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.125734563245459 (0.000778788% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.125728543466173 (0.000117442% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.125727440132845 (2.15254e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.125727305493787 (2.62673e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 60, 0.0952381, 0.0952381, 0, 0.134687, 0.0945668, 0.558092, 0.621383, 0.657515, 0.891278, 0.966151, 1.03473, 1.09013
# elapsed time for k point: 0.028801918029785156
# solve_kpoint (0.0714286,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.17233017132806 (0.0558606% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.171343140953121 (0.0190847% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.171068885751499 (0.00530351% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.170984349434859 (0.00163481% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.170970029537833 (0.000276928% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.170966686855432 (6.46433e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.170966131747235 (1.07351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.170965941033282 (3.68817e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 61, 0.0714286, 0.0714286, 0, 0.101015, 0.0712067, 0.56635, 0.624475, 0.647299, 0.890756, 0.970173, 1.04456, 1.10018
# elapsed time for k point: 0.08086109161376953
# solve_kpoint (0.047619,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.21780887440093 (0.0631803% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.216209110363085 (0.0306644% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.215630980658892 (0.0110839% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.215429178691387 (0.00386925% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.215389060286752 (0.000769228% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.21537667521747 (0.000237472% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.215373255875861 (6.55627e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.215371469022058 (3.42613e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.215371096626984 (7.14034e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 62, 0.047619, 0.047619, 0, 0.0673435, 0.0476024, 0.574072, 0.626741, 0.638182, 0.890402, 0.972644, 1.05452, 1.11023
# elapsed time for k point: 0.03299713134765625
# solve_kpoint (0.0238095,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.258507204937741 (0.078973% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.25531110908484 (0.060798% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.25396836578421 (0.0255535% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.253436199323897 (0.0101294% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.253298394759899 (0.00262317% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.253232311792416 (0.00125794% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.253199541855216 (0.000623807% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.253180657353379 (0.000359486% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.253176898134241 (7.15608e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.25317652872624 (7.03209e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 63, 0.0238095, 0.0238095, 0, 0.0336718, 0.02384, 0.580116, 0.628125, 0.631303, 0.890198, 0.973961, 1.06266, 1.11924
# elapsed time for k point: 0.03252434730529785
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.282495032755373 (0.114387% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.275344292268315 (0.135458% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.272534446933962 (0.0532779% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.271230312528377 (0.0247375% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.270766757117344 (0.00879445% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.270467061328242 (0.00568616% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.270292000605295 (0.0033216% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.27023863108757 (0.00101265% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.270232989448685 (0.000107047% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.270232578173142 (7.80375e-06% change)
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 64, 0, 0, 0, 0, 0, 0.582551, 0.628589, 0.628591, 0.890132, 0.974373, 1.06601, 1.12361
# elapsed time for k point: 0.03038501739501953
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3227007683641675 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.4424114401147182 at Vector3<0.5, 0.0, 0.0> to 0.5825513800415811 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.5490173589165511 at Vector3<0.5, 0.5, 0.0> to 0.6368273370004359 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.6285908513770742 at Vector3<0.0, 0.0, 0.0> to 0.7734526435268153 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.7834109542391956 at Vector3<0.5, 0.0, 0.0> to 0.9229658358713245 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.9012070101781644 at Vector3<0.2619047619047619, 0.2619047619047619, 0.0> to 0.9743733319386263 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.9808655078127164 at Vector3<0.3571428571428571, 0.0, 0.0> to 1.0660071794506136 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.9886251265279932 at Vector3<0.5, 0.5, 0.0> to 1.138441637224038 at Vector3<0.5, 0.0, 0.0>
# Gap from band 1 (0.3227007683641675) to band 2 (0.4424114401147182), 31.292317760435864%
# Gap from band 4 (0.7734526435268153) to band 5 (0.7834109542391956), 1.2792785092630805%
# Gap from band 6 (0.9743733319386263) to band 7 (0.9808655078127164), 0.6640800849594175%
# total elapsed time for run: 4.648085832595825
# done
# (64, 8)

# %% [markdown]
# 从结果看，是直接覆盖的，因此我们需要跑两次，每次都单独存一下，现在来将能带画出来

# %%
import matplotlib.pyplot as plt
numk,tmp=np.shape(te_freqs)
klist=range(numk)

fig,ax=plt.subplots()
x = range(len(tm_freqs))

for l in range(num_bands):
    plt.plot(te_freqs[:,l],'r-')
    plt.plot(tm_freqs[:,l],'b-')
plt.ylim([0,0.8])
plt.ylabel('$\omega a/(2\pi c)$')

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)
        

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
# Out:
# [Text(0.0, 0, 'Γ'), Text(21.0, 0, 'X'), Text(42.0, 0, 'M'), Text(63.0, 0, 'Γ')]

# %% [markdown]
# ![](attachment:image.png)
#
# 可以看到与书籍的结果是一样的。并且可以比较方便的导出Band Gap，还是比较方便的。

# %% [markdown]
# ### 电场、磁场导出
#
# 以上是能带计算的例子，我们也可以导出相应的电场分布，观察tm模式的Ez，

# %%
efields = []
def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1/2, 0,0), mpb.fix_efield_phase,
          get_efields))
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 64 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.023809523809523808, 0.0, 0.0>
#   Vector3<0.047619047619047616, 0.0, 0.0>
#   Vector3<0.07142857142857142, 0.0, 0.0>
#   Vector3<0.09523809523809523, 0.0, 0.0>
#   Vector3<0.11904761904761904, 0.0, 0.0>
#   Vector3<0.14285714285714285, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.19047619047619047, 0.0, 0.0>
#   Vector3<0.21428571428571427, 0.0, 0.0>
#   Vector3<0.23809523809523808, 0.0, 0.0>
#   Vector3<0.26190476190476186, 0.0, 0.0>
#   Vector3<0.2857142857142857, 0.0, 0.0>
#   Vector3<0.30952380952380953, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.3571428571428571, 0.0, 0.0>
#   Vector3<0.38095238095238093, 0.0, 0.0>
#   Vector3<0.40476190476190477, 0.0, 0.0>
#   Vector3<0.42857142857142855, 0.0, 0.0>
#   Vector3<0.45238095238095233, 0.0, 0.0>
#   Vector3<0.47619047619047616, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.023809523809523808, 0.0>
#   Vector3<0.5, 0.047619047619047616, 0.0>
#   Vector3<0.5, 0.07142857142857142, 0.0>
#   Vector3<0.5, 0.09523809523809523, 0.0>
#   Vector3<0.5, 0.11904761904761904, 0.0>
#   Vector3<0.5, 0.14285714285714285, 0.0>
#   Vector3<0.5, 0.16666666666666666, 0.0>
#   Vector3<0.5, 0.19047619047619047, 0.0>
#   Vector3<0.5, 0.21428571428571427, 0.0>
#   Vector3<0.5, 0.23809523809523808, 0.0>
#   Vector3<0.5, 0.26190476190476186, 0.0>
#   Vector3<0.5, 0.2857142857142857, 0.0>
#   Vector3<0.5, 0.30952380952380953, 0.0>
#   Vector3<0.5, 0.3333333333333333, 0.0>
#   Vector3<0.5, 0.3571428571428571, 0.0>
#   Vector3<0.5, 0.38095238095238093, 0.0>
#   Vector3<0.5, 0.40476190476190477, 0.0>
#   Vector3<0.5, 0.42857142857142855, 0.0>
#   Vector3<0.5, 0.45238095238095233, 0.0>
#   Vector3<0.5, 0.47619047619047616, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.47619047619047616, 0.47619047619047616, 0.0>
#   Vector3<0.4523809523809524, 0.4523809523809524, 0.0>
#   Vector3<0.4285714285714286, 0.4285714285714286, 0.0>
#   Vector3<0.40476190476190477, 0.40476190476190477, 0.0>
#   Vector3<0.38095238095238093, 0.38095238095238093, 0.0>
#   Vector3<0.35714285714285715, 0.35714285714285715, 0.0>
#   Vector3<0.33333333333333337, 0.33333333333333337, 0.0>
#   Vector3<0.30952380952380953, 0.30952380952380953, 0.0>
#   Vector3<0.2857142857142857, 0.2857142857142857, 0.0>
#   Vector3<0.2619047619047619, 0.2619047619047619, 0.0>
#   Vector3<0.23809523809523814, 0.23809523809523814, 0.0>
#   Vector3<0.2142857142857143, 0.2142857142857143, 0.0>
#   Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
#   Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
#   Vector3<0.1428571428571429, 0.1428571428571429, 0.0>
#   Vector3<0.11904761904761907, 0.11904761904761907, 0.0>
#   Vector3<0.09523809523809523, 0.09523809523809523, 0.0>
#   Vector3<0.07142857142857145, 0.07142857142857145, 0.0>
#   Vector3<0.04761904761904767, 0.04761904761904767, 0.0>
#   Vector3<0.023809523809523836, 0.023809523809523836, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.012652873992919922
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 14.94228747935573 (194.522% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 6.243277844949086 (82.122% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 5.514190872108879 (12.4021% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 5.321365913859257 (3.55911% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.28644208472869 (0.658455% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.277855642767953 (0.162556% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.272989130569304 (0.0922488% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.271371400472603 (0.0306843% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 75.2613%)
#     iteration    9: trace = 5.270863474702219 (0.00963602% change)
#     iteration   10: trace = 5.270556355198801 (0.00582691% change)
#     iteration   11: trace = 5.270362449940598 (0.0036791% change)
#     iteration   12: trace = 5.270277260344423 (0.0016164% change)
#     iteration   13: trace = 5.270251747944218 (0.000484082% change)
#     iteration   14: trace = 5.27024070194691 (0.000209592% change)
#     iteration   15: trace = 5.270234211065597 (0.000123161% change)
#     switching back to exact line minimization
#     iteration   16: trace = 5.270232607480649 (3.04272e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.270232282322668 (6.16971e-06% change)
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.582551, 0.628589, 0.628591, 0.890132, 0.974373, 1.06601, 1.12361
# elapsed time for k point: 0.7988505363464355
# solve_kpoint (0.0238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.269671008893575 (0.0552743% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.267275299563242 (0.0454726% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.265792224799474 (0.0281604% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.264898237166549 (0.0169787% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.264710779508908 (0.00356058% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.26464047081892 (0.00133548% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.264597038558493 (0.000824984% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.264561588076914 (0.000673377% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.264536364695827 (0.000479118% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.264523489551705 (0.000244564% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.264509432047332 (0.000267024% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.264491273037218 (0.000344933% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 5.264468230815257 (0.000437692% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.264447497641699 (0.000393833% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 5.264430639683489 (0.000320223% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.26441302675222 (0.000334565% change)
#     large trace change predicted (0.000698756%)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 5.26437621668018 (0.000699227% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.264316445133097 (0.0011354% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.264264299818722 (0.000990548% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.264227676230718 (0.000695704% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.264200172305356 (0.00052247% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.26418198565729 (0.000345478% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 5.264174072794957 (0.000150315% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 5.264170443654159 (6.89404e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 5.264166084983856 (8.27988e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 5.264161161329456 (9.35316e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.264158566590782 (4.92907e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 5.264157936640926 (1.19668e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 5.26415776117971 (3.33313e-06% change)
# Finished solving for bands 1 to 8 after 29 iterations.
# tmfreqs:, 2, 0.0238095, 0, 0, 0.0238095, 0.016862, 0.581289, 0.628635, 0.629713, 0.890164, 0.974171, 1.06425, 1.1226
# elapsed time for k point: 0.19947242736816406
# solve_kpoint (0.047619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.252457642568801 (0.0497917% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.250633771700826 (0.0347302% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.249605682890874 (0.0195822% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.24900797017544 (0.0113865% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.248928388620056 (0.00151614% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.248915696050084 (0.000241813% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.248914193376621 (2.86283e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.248913816376408 (7.18244e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0.047619, 0, 0, 0.047619, 0.0336967, 0.577798, 0.628768, 0.632793, 0.890242, 0.973574, 1.05928, 1.12058
# elapsed time for k point: 0.07551884651184082
# solve_kpoint (0.0714286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.230907288835743 (0.0400598% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.229801751582431 (0.0211369% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.229318087309113 (0.00924866% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.229046548188125 (0.00519276% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.228999671274162 (0.000896476% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.228991856611582 (0.000149449% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.228991141963848 (1.3667e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.228990997776889 (2.75745e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0.0714286, 0, 0, 0.0714286, 0.0504762, 0.572683, 0.628986, 0.637235, 0.890316, 0.972605, 1.05187, 1.11881
# elapsed time for k point: 0.08256006240844727
# solve_kpoint (0.0952381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.20829979862477 (0.0341404% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.2075541825727 (0.0143169% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.207295796825918 (0.00496187% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.207162229011753 (0.00256505% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.207134573236415 (0.000531112% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.207129676470089 (9.40396e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.207129284279606 (7.5318e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0.0952381, 0, 0, 0.0952381, 0.0671717, 0.566465, 0.629284, 0.642537, 0.890299, 0.9713, 1.04293, 1.11764
# elapsed time for k point: 0.07004141807556152
# solve_kpoint (0.119048,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.185600088021152 (0.0300428% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.185062566169881 (0.0103662% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.184910960129155 (0.00292394% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.184839822326218 (0.00137203% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.184823189090118 (0.000320806% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.184820030988965 (6.09105e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.184819802809214 (4.40092e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0.119048, 0, 0, 0.119048, 0.0837527, 0.559482, 0.629658, 0.648386, 0.890065, 0.969708, 1.03326, 1.11702
# elapsed time for k point: 0.0705573558807373
# solve_kpoint (0.142857,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.163504648051569 (0.0271399% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.163093610264736 (0.00796076% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.162996182735437 (0.00188702% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.162955029626032 (0.000797081% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.162944456876829 (0.000204781% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.16294229646868 (4.18445e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.162942150068844 (2.83559e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0.142857, 0, 0, 0.142857, 0.100187, 0.551937, 0.630098, 0.65461, 0.889445, 0.96788, 1.0235, 1.11682
# elapsed time for k point: 0.05166745185852051
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.142494077981469 (0.0249925% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.142165373030359 (0.00639214% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.142098082111316 (0.00130862% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.142072314822538 (0.000501106% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.142065183798991 (0.00013868% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.142063604436637 (3.07146e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 62.7943%)
#     iteration    7: trace = 5.142063499803001 (2.03486e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, 0.166667, 0, 0, 0.166667, 0.116437, 0.543957, 0.630597, 0.661123, 0.888234, 0.965874, 1.01413, 1.11694
# elapsed time for k point: 0.09978842735290527
# solve_kpoint (0.190476,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.122919834080948 (0.0233651% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.122647290127682 (0.00532023% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.122598097805517 (0.000960296% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.122580846069271 (0.000336778% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.122575720259107 (0.000100063% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.122574483107762 (2.4151e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.122574399189645 (1.6382e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 9, 0.190476, 0, 0, 0.190476, 0.132464, 0.535627, 0.631143, 0.667881, 0.886198, 0.963745, 1.00556, 1.11732
# elapsed time for k point: 0.07451033592224121
# solve_kpoint (0.214286,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.105042807053621 (0.0221227% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.104809520319187 (0.00456984% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.104771848197759 (0.000737976% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.104759709849924 (0.000237785% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.104755814238152 (7.63134e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.104754779480227 (2.02705e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.104754704335383 (1.47206e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 10, 0.214286, 0, 0, 0.214286, 0.148221, 0.527016, 0.631725, 0.67487, 0.883108, 0.961547, 0.998132, 1.11794
# elapsed time for k point: 0.06240653991699219
# solve_kpoint (0.238095,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.089056933733432 (0.021183% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.088851099251013 (0.00404473% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.088821028785518 (0.00059091% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.088812249009296 (0.000172531% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.088809191070045 (6.00914e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.088808275766095 (1.79866e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.08880820154437 (1.45853e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 11, 0.238095, 0, 0, 0.238095, 0.163655, 0.518184, 0.63233, 0.682087, 0.878789, 0.959333, 0.992057, 1.11878
# elapsed time for k point: 0.07169032096862793
# solve_kpoint (0.261905,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.075103957949031 (0.0204936% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.074916722979394 (0.00368935% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.074891707884742 (0.000492918% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.074885341585778 (0.000125447% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.074882971357079 (4.67051e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.074882132750542 (1.65246e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.074882053225336 (1.56704e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 12, 0.261905, 0, 0, 0.261905, 0.1787, 0.509198, 0.632945, 0.689537, 0.873166, 0.957151, 0.987436, 1.11982
# elapsed time for k point: 0.08244681358337402
# solve_kpoint (0.285714,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.063282761407343 (0.0200201% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.063107014118188 (0.00347107% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.063085236692205 (0.000430121% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.063080713874315 (8.93293e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.063079043595081 (3.29894e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.063078288827167 (1.49073e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.063078198883515 (1.77646e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, 0.285714, 0, 0, 0.285714, 0.193278, 0.500132, 0.633557, 0.697229, 0.86629, 0.955044, 0.984213, 1.12108
# elapsed time for k point: 0.10161185264587402
# solve_kpoint (0.309524,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.053655005213624 (0.0197405% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.053484595606754 (0.00337206% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.053464599620177 (0.000395688% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.053461461347586 (6.21014e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.053460547392026 (1.80857e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.05345997800702 (1.12672e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.053459877593109 (1.98703e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 14, 0.309524, 0, 0, 0.309524, 0.20729, 0.491079, 0.634151, 0.70517, 0.85832, 0.953052, 0.982211, 1.12257
# elapsed time for k point: 0.07935166358947754
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.046247680842914 (0.0196432% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.046076810555673 (0.00338614% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.046057229501248 (0.000388046% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.046054960407764 (4.49677e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.046054655913248 (6.03431e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 15, 0.333333, 0, 0, 0.333333, 0.22061, 0.482157, 0.634713, 0.713367, 0.849478, 0.951211, 0.981183, 1.12429
# elapsed time for k point: 0.10025739669799805
# solve_kpoint (0.357143,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.041051773984183 (0.0197311% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.040874546640234 (0.00351574% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.040853883360736 (0.000409915% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.040851786528792 (4.15968e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.040851647648389 (2.7551e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 16, 0.357143, 0, 0, 0.357143, 0.23308, 0.473518, 0.635232, 0.721825, 0.839993, 0.949552, 0.980866, 1.12624
# elapsed time for k point: 0.0696563720703125
# solve_kpoint (0.380952,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.038017463683481 (0.0200059% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.037826228229665 (0.00379592% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.037801879726896 (0.000483315% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.037798551390742 (6.60673e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.037797384447618 (2.31638e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.03779625302969 (2.24586e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.037796005382722 (4.91578e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 17, 0.380952, 0, 0, 0.380952, 0.24449, 0.465362, 0.635694, 0.730542, 0.83008, 0.948102, 0.981013, 1.12843
# elapsed time for k point: 0.08253693580627441
# solve_kpoint (0.404762,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.037032257371977 (0.020512% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.036817353424031 (0.00426657% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.036785264016915 (0.000637099% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.036776602635991 (0.000171963% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.036768801964571 (0.000154874% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.036764568037405 (8.40604e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.036764117935398 (8.93633e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 18, 0.404762, 0, 0, 0.404762, 0.25458, 0.457946, 0.636088, 0.739509, 0.81992, 0.946883, 0.981414, 1.13081
# elapsed time for k point: 0.07017898559570312
# solve_kpoint (0.428571,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.037881464744292 (0.0213219% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.037627567241855 (0.00503989% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.037578895523724 (0.000966168% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.037551132075421 (0.000551128% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.037521553471554 (0.000587164% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.0375122147477 (0.000185383% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.037511467706389 (1.48296e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.037511395923658 (1.42496e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 19, 0.428571, 0, 0, 0.428571, 0.263024, 0.451587, 0.636406, 0.7487, 0.809674, 0.945916, 0.981898, 1.1333
# elapsed time for k point: 0.08201074600219727
# solve_kpoint (0.452381,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.040145047977836 (0.0225834% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.039825805226156 (0.0063342% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.039740325927418 (0.00169609% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.039650310723253 (0.00178612% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.039566085085869 (0.00167127% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.039548224422383 (0.000354409% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.039546938709831 (2.55125e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.039546824822193 (2.25988e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 20, 0.452381, 0, 0, 0.452381, 0.269455, 0.44665, 0.636638, 0.758048, 0.799508, 0.945215, 0.982336, 1.13573
# elapsed time for k point: 0.07784748077392578
# solve_kpoint (0.47619,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 5.042972001781756 (0.0244958% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.042543664067621 (0.00849412% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.042377183881838 (0.00330157% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.042113668838956 (0.00522614% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.041923153406831 (0.00377855% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.041892892042591 (0.000600197% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.041890714140663 (4.31961e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.041890526588923 (3.71987e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 21, 0.47619, 0, 0, 0.47619, 0.273504, 0.443498, 0.63678, 0.767275, 0.789764, 0.94479, 0.982635, 1.13766
# elapsed time for k point: 0.09309577941894531
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.044764471455563 (0.026952% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.044186816639531 (0.0114512% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 79.6178%)
#     iteration    3: trace = 5.043885751179561 (0.00596874% change)
#     switching back to exact line minimization
#     iteration    4: trace = 5.0433277546194 (0.0110634% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.043031791659248 (0.00586858% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.042993635108774 (0.000756622% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.042990740775423 (5.73932e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.042990478514736 (5.2005e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 22, 0.5, 0, 0, 0.5, 0.27489, 0.442411, 0.636827, 0.773453, 0.783411, 0.944647, 0.982741, 1.13844
# elapsed time for k point: 0.07589483261108398
# Fixing e-field (band 1) phase by -1 + 1.13221e-05i; max ampl. = 0.987259
# Fixing e-field (band 2) phase by 1 + -1.13221e-05i; max ampl. = 1.1786
# Fixing e-field (band 3) phase by 0.034556 + 0.999403i; max ampl. = 1.39499
# Fixing e-field (band 4) phase by 1 + -1.13221e-05i; max ampl. = 1.37383
# Fixing e-field (band 5) phase by -1 + 1.13221e-05i; max ampl. = 1.79927
# Fixing e-field (band 6) phase by 0.743515 + -0.668719i; max ampl. = 1.25822
# Fixing e-field (band 7) phase by 1 + -1.13221e-05i; max ampl. = 1.36109
# Fixing e-field (band 8) phase by 1 + -1.13221e-05i; max ampl. = 1.85108
# solve_kpoint (0.5,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.042260881316885 (0.059895% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.041431101393512 (0.0164579% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.04131263357821 (0.00234991% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.041294619549744 (0.000357329% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.041292210935358 (4.77777e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.041291992298033 (4.33693e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 23, 0.5, 0.0238095, 0, 0.500567, 0.275126, 0.442854, 0.636171, 0.77321, 0.784166, 0.944541, 0.98275, 1.13756
# elapsed time for k point: 0.07329201698303223
# solve_kpoint (0.5,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.037248686660966 (0.0587955% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.036460010002595 (0.0156581% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.036352612445726 (0.00213242% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.036337767635661 (0.000294754% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.036335711782121 (4.08204e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.036335494145402 (4.32133e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 24, 0.5, 0.047619, 0, 0.502262, 0.27583, 0.444178, 0.634246, 0.772481, 0.786389, 0.944224, 0.982779, 1.13496
# elapsed time for k point: 0.06869006156921387
# solve_kpoint (0.5,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.029319578415045 (0.056371% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.02859988958484 (0.0143109% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.028508191000157 (0.00182356% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.028497450531884 (0.000213592% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.028495966576166 (2.95109e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.3133%)
#     iteration    6: trace = 5.02849577229057 (3.86369e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 25, 0.5, 0.0714286, 0, 0.505076, 0.276991, 0.446367, 0.631173, 0.771258, 0.789965, 0.943699, 0.982826, 1.13082
# elapsed time for k point: 0.07966971397399902
# solve_kpoint (0.5,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.019010251782052 (0.0531834% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.018368436132154 (0.0127885% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.018291715516426 (0.00152881% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.018284502150066 (0.000143742% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.018283669377654 (1.65948e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.018283538280611 (2.61239e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 26, 0.5, 0.0952381, 0, 0.508989, 0.278589, 0.449397, 0.627121, 0.76953, 0.794729, 0.942971, 0.982889, 1.12534
# elapsed time for k point: 0.06193804740905762
# solve_kpoint (0.5,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.006883926743178 (0.0497781% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.006313807146835 (0.0113874% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.006247809021741 (0.00131831% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.006242629192462 (0.000103467% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.006242236867189 (7.83672e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 27, 0.5, 0.119048, 0, 0.513977, 0.280597, 0.453234, 0.622281, 0.767285, 0.800504, 0.942048, 0.982969, 1.11877
# elapsed time for k point: 0.05554819107055664
# solve_kpoint (0.5,0.142857,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.993456427531394 (0.0465138% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.99294436016923 (0.0102553% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.99288347571566 (0.00121942% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.992878685960403 (9.59317e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.992878331844364 (7.09242e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 28, 0.5, 0.142857, 0, 0.520008, 0.282982, 0.457832, 0.61684, 0.764509, 0.807114, 0.940943, 0.983063, 1.11131
# elapsed time for k point: 0.060784101486206055
# solve_kpoint (0.5,0.166667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.97916931857207 (0.0435496% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.978699554770587 (0.00943503% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.978638344129612 (0.00122946% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.978632457510145 (0.000118238% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.978631806457868 (1.30769e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.978631701620736 (2.10574e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 29, 0.5, 0.166667, 0, 0.527046, 0.285702, 0.463139, 0.610969, 0.761191, 0.814405, 0.939671, 0.983168, 1.10316
# elapsed time for k point: 0.07165122032165527
# solve_kpoint (0.5,0.190476,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.964388539270221 (0.0408872% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.96394860423951 (0.00886221% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.963882957823369 (0.00132247% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.7805%)
#     iteration    4: trace = 4.963874984390653 (0.000160629% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.963873958783875 (2.06614e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.963873819788738 (2.80013e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 30, 0.5, 0.190476, 0, 0.535053, 0.288709, 0.469092, 0.604822, 0.757327, 0.822243, 0.938254, 0.983283, 1.09447
# elapsed time for k point: 0.06670308113098145
# solve_kpoint (0.5,0.214286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.949425045728458 (0.0384931% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.949004977004121 (0.00848758% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.948931580277323 (0.00148307% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.948921210566418 (0.000209535% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.948919946668168 (2.55389e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.948919805368318 (2.85517e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 31, 0.5, 0.214286, 0, 0.543984, 0.29195, 0.475619, 0.598533, 0.752921, 0.830516, 0.936721, 0.983405, 1.08538
# elapsed time for k point: 0.0846562385559082
# solve_kpoint (0.5,0.238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.934548239478758 (0.0363013% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.934141569299794 (0.00824162% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.934058655162771 (0.00168043% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.934046120259244 (0.000254049% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.934044774387679 (2.72772e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.934044643330515 (2.65618e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 32, 0.5, 0.238095, 0, 0.553795, 0.295364, 0.482637, 0.592223, 0.747993, 0.839129, 0.935104, 0.98353, 1.07599
# elapsed time for k point: 0.055411577224731445
# solve_kpoint (0.5,0.261905,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.92000267537707 (0.0342604% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.919605827079943 (0.00806634% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.919513005746514 (0.00188678% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.919498846216733 (0.000287824% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.91949751326647 (2.70952e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.919497395796562 (2.38784e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 33, 0.5, 0.261905, 0, 0.564441, 0.298885, 0.490052, 0.586001, 0.742581, 0.848, 0.933444, 0.983656, 1.06639
# elapsed time for k point: 0.07589507102966309
# solve_kpoint (0.5,0.285714,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.906018067760447 (0.0323433% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.905629590517758 (0.0079187% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.905527604158106 (0.00207899% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.905512440924748 (0.000309106% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.905511158069852 (2.61513e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.905511058156129 (2.03676e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 34, 0.5, 0.285714, 0, 0.575876, 0.30244, 0.497753, 0.579967, 0.736748, 0.857056, 0.931781, 0.98378, 1.05666
# elapsed time for k point: 0.05331897735595703
# solve_kpoint (0.5,0.309524,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.89281421970785 (0.0305464% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.892433952787826 (0.00777225% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.892324285931783 (0.00224159% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.892308687393698 (0.000318837% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.89230745556037 (2.5179e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.892307377785137 (1.58975e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 35, 0.5, 0.309524, 0, 0.588052, 0.305953, 0.505614, 0.574219, 0.730585, 0.866223, 0.930162, 0.983898, 1.04689
# elapsed time for k point: 0.12405633926391602
# solve_kpoint (0.5,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.880601307403886 (0.0288841% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.880229620939275 (0.00761588% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.880114082228479 (0.00236751% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.880098492871006 (0.000319447% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.880097286629042 (2.47176e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.880097223686057 (1.28979e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 36, 0.5, 0.333333, 0, 0.600925, 0.309341, 0.513483, 0.56885, 0.72422, 0.875424, 0.928628, 0.984006, 1.03715
# elapsed time for k point: 0.07849287986755371
# solve_kpoint (0.5,0.357143,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.869576902344105 (0.0273793% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.869214136886891 (0.00744991% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.869094539524097 (0.00245622% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.869079242322648 (0.00031417% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.869078018535991 (2.51338e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.869077951074406 (1.38551e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 37, 0.5, 0.357143, 0, 0.614452, 0.312519, 0.521179, 0.563952, 0.717821, 0.884563, 0.927221, 0.9841, 1.02754
# elapsed time for k point: 0.05985236167907715
# solve_kpoint (0.5,0.380952,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.859921607408243 (0.0260551% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.859567740724685 (0.00728159% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.859445715518236 (0.00251106% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.859430852161694 (0.000305866% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.859429574886189 (2.62845e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.859429491361166 (1.71882e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 38, 0.5, 0.380952, 0, 0.628589, 0.3154, 0.528484, 0.559615, 0.711599, 0.893512, 0.925975, 0.984174, 1.0182
# elapsed time for k point: 0.07113456726074219
# solve_kpoint (0.5,0.404762,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.851794827289513 (0.0249294% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.85144929537505 (0.00712199% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.851326138087805 (0.0025386% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.851311774036624 (0.000296085% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.85131043584144 (2.75842e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.851310347387479 (1.8233e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 39, 0.5, 0.404762, 0, 0.643298, 0.317901, 0.535137, 0.555925, 0.705819, 0.902077, 0.924919, 0.984217, 1.00933
# elapsed time for k point: 0.05994057655334473
# solve_kpoint (0.5,0.428571,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.845331107238692 (0.0240141% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.844992737225166 (0.00698367% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.844869298378795 (0.00254779% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.844855448576885 (0.000285866% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.844854059533898 (2.86705e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.844853980531665 (1.63064e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 40, 0.5, 0.428571, 0, 0.658539, 0.319943, 0.540835, 0.55296, 0.700789, 0.909948, 0.924076, 0.984211, 1.00126
# elapsed time for k point: 0.07209372520446777
# solve_kpoint (0.5,0.452381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.840637081526517 (0.0233148% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.840304176343951 (0.00687754% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.840180915670269 (0.00254658% change)
#     linmin: converged after 2 iterations.
# ...
#     iteration    7: trace = 4.851856914867825 (2.2179e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 50, 0.333333, 0.333333, 0, 0.471405, 0.285404, 0.516594, 0.568273, 0.733084, 0.883008, 0.908852, 1.00926, 1.00939
# elapsed time for k point: 0.07747340202331543
# solve_kpoint (0.309524,0.309524,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.86121187044782 (0.0483107% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.860821477920279 (0.00803109% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.86076730934045 (0.0011144% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.860751445301065 (0.00032637% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.860745573494888 (0.0001208% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.860745002838352 (1.17401e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.860744966143339 (7.54926e-07% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 51, 0.309524, 0.309524, 0, 0.437733, 0.272551, 0.514555, 0.573524, 0.733971, 0.884661, 0.906147, 1.00922, 1.01577
# elapsed time for k point: 0.0917809009552002
# solve_kpoint (0.285714,0.285714,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.874269652516452 (0.0472545% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.873909554873377 (0.007388% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.873871202447964 (0.000786896% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.873864636676892 (0.000134714% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.873862072093604 (5.26191e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.873861744804597 (6.71519e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 52, 0.285714, 0.285714, 0, 0.404061, 0.257769, 0.514262, 0.579124, 0.731659, 0.889763, 0.903583, 1.0092, 1.02255
# elapsed time for k point: 0.07600975036621094
# solve_kpoint (0.261905,0.261905,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.891683985263323 (0.0467204% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.891333309704519 (0.00716907% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.891301052566233 (0.000659478% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.891297701443064 (6.85119e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.891296716575971 (2.01351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.891296524283834 (3.93131e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 53, 0.261905, 0.261905, 0, 0.370389, 0.241245, 0.515652, 0.584956, 0.726537, 0.897755, 0.901207, 1.00932, 1.02971
# elapsed time for k point: 0.06807160377502441
# solve_kpoint (0.238095,0.238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.913434884880462 (0.0465375% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.913080473019815 (0.00721338% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.913049345912544 (0.000633558% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.913046816989204 (5.14736e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.913046430677662 (7.86297e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 54, 0.238095, 0.238095, 0, 0.336718, 0.223201, 0.518583, 0.590893, 0.719238, 0.899053, 0.907814, 1.00974, 1.03723
# elapsed time for k point: 0.06776618957519531
# solve_kpoint (0.214286,0.214286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.939449068181959 (0.0466266% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.939080782531197 (0.00745628% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.939047384371102 (0.000676204% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.939044484562428 (5.87119e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.939044172997966 (6.30819e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 55, 0.214286, 0.214286, 0, 0.303046, 0.203866, 0.522874, 0.596804, 0.710394, 0.89714, 0.919083, 1.01066, 1.0451
# elapsed time for k point: 0.09828948974609375
# solve_kpoint (0.190476,0.190476,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.969603672695537 (0.0469559% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 4.969211151914152 (0.00789874% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.96917224413342 (0.00078298% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.969168035751432 (8.46898e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.969167559629011 (9.58153e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 56, 0.190476, 0.190476, 0, 0.269374, 0.183457, 0.528338, 0.602555, 0.70052, 0.895481, 0.930738, 1.01237, 1.05334
# elapsed time for k point: 0.06857132911682129
# solve_kpoint (0.166667,0.166667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.003719570779798 (0.0475391% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 5.003290642276559 (0.00857256% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.003242024335421 (0.000971724% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.003235211761403 (0.000136163% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.00323436529442 (1.69184e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.003234272829659 (1.8481e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 57, 0.166667, 0.166667, 0, 0.235702, 0.162167, 0.534785, 0.608013, 0.690011, 0.894076, 0.941975, 1.01524, 1.06195
# elapsed time for k point: 0.07177615165710449
# solve_kpoint (0.142857,0.142857,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.04154356156636 (0.0484424% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.041060469378325 (0.00958269% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.040995651278351 (0.00128581% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.04098408147261 (0.000229515% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.040982557023922 (3.02411e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.040982369089628 (3.72813e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 58, 0.142857, 0.142857, 0, 0.202031, 0.140162, 0.542029, 0.613049, 0.67917, 0.892917, 0.952001, 1.01975, 1.07096
# elapsed time for k point: 0.07633113861083984
# solve_kpoint (0.119048,0.119048,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.082707856863616 (0.0498243% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.9755%)
#     iteration    2: trace = 5.082140134188637 (0.0111703% change)
#     iteration    3: trace = 5.082046273921816 (0.00184688% change)
#     switching back to exact line minimization
#     iteration    4: trace = 5.082025549811179 (0.000407792% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.082022659800133 (5.68673e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.082022235392511 (8.35116e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 59, 0.119048, 0.119048, 0, 0.168359, 0.117588, 0.549875, 0.617542, 0.668251, 0.891991, 0.960154, 1.02626, 1.08036
# elapsed time for k point: 0.07527303695678711
# solve_kpoint (0.0952381,0.0952381,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.126636462100723 (0.0520357% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.125924930466507 (0.0138801% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.12577448274669 (0.00293508% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.125734563336446 (0.000778801% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.125728543481517 (0.000117444% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.125727440134333 (2.15257e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.125727305494355 (2.62675e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 60, 0.0952381, 0.0952381, 0, 0.134687, 0.0945668, 0.558092, 0.621383, 0.657515, 0.891278, 0.966151, 1.03473, 1.09013
# elapsed time for k point: 0.12051153182983398
# solve_kpoint (0.0714286,0.0714286,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.172330171318796 (0.0558606% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.171343140950607 (0.0190847% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.171068885751806 (0.00530351% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.170984349435648 (0.00163481% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.17097002953787 (0.000276928% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.17096668685542 (6.46433e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.170966131747226 (1.07351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.17096594103328 (3.68817e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 61, 0.0714286, 0.0714286, 0, 0.101015, 0.0712067, 0.56635, 0.624475, 0.647299, 0.890756, 0.970173, 1.04456, 1.10018
# elapsed time for k point: 0.09501290321350098
# solve_kpoint (0.047619,0.047619,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.217808874400623 (0.0631803% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.216209110362978 (0.0306644% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.215630980658869 (0.0110839% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.215429178691378 (0.00386925% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.215389060286752 (0.000769228% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.215376675217472 (0.000237472% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.215373255875861 (6.55627e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.215371469022056 (3.42613e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.215371096626982 (7.14034e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 62, 0.047619, 0.047619, 0, 0.0673435, 0.0476024, 0.574072, 0.626741, 0.638182, 0.890402, 0.972644, 1.05452, 1.11023
# elapsed time for k point: 0.09064292907714844
# solve_kpoint (0.0238095,0.0238095,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.258507204937739 (0.078973% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.255311109084841 (0.060798% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.253968365784211 (0.0255535% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.253436199323898 (0.0101294% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.253298394759897 (0.00262317% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.253232311792413 (0.00125794% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.253199541855216 (0.000623807% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.253180657353379 (0.000359486% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.253176898134242 (7.15608e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.253176528726239 (7.03209e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 63, 0.0238095, 0.0238095, 0, 0.0336718, 0.02384, 0.580116, 0.628125, 0.631303, 0.890198, 0.973961, 1.06266, 1.11924
# elapsed time for k point: 0.10508489608764648
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.282495032755373 (0.114387% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.275344292268316 (0.135458% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.272534446933959 (0.0532779% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.271230312528377 (0.0247375% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.270766757117343 (0.00879445% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.270467061328243 (0.00568616% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.270292000605293 (0.0033216% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.270238631087571 (0.00101265% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.270232989448684 (0.000107047% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.27023257817314 (7.80375e-06% change)
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 64, 0, 0, 0, 0, 0, 0.582551, 0.628589, 0.628591, 0.890132, 0.974373, 1.06601, 1.12361
# elapsed time for k point: 0.11987519264221191
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3227007683661239 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.44241144013582645 at Vector3<0.5, 0.0, 0.0> to 0.5825513800415816 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.5490173589171936 at Vector3<0.5, 0.5, 0.0> to 0.6368273370486994 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.6285908517559831 at Vector3<0.0, 0.0, 0.0> to 0.7734526435787314 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.7834109542202529 at Vector3<0.5, 0.0, 0.0> to 0.9229658358710118 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.9012070101781646 at Vector3<0.2619047619047619, 0.2619047619047619, 0.0> to 0.9743733322901724 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.9808655078127159 at Vector3<0.3571428571428571, 0.0, 0.0> to 1.066007179450614 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.9886251268929407 at Vector3<0.5, 0.5, 0.0> to 1.1384416480674846 at Vector3<0.5, 0.0, 0.0>
# Gap from band 1 (0.3227007683661239) to band 2 (0.44241144013582645), 31.29231776449883%
# Gap from band 4 (0.7734526435787314) to band 5 (0.7834109542202529), 1.2792785001332136%
# Gap from band 6 (0.9743733322901724) to band 7 (0.9808655078127159), 0.6640800488805564%
# total elapsed time for run: 5.995318412780762
# done

# %%
# Create an MPBData instance to transform the efields
eps = ms.get_epsilon() # 得到折射率分布
md = mpb.MPBData(rectify=True, resolution=32, periods=3)
converted_eps = md.convert(eps)


converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))


for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='jet', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# epsilon: 1-8.9, mean 1.99274, harm. mean 1.13848, 14.5508% > 1, 12.5663% "fill"
# real part range: 1 .. 8.9
# real part range: -0.000669461 .. 0.000669461
# imag part range: -0.987259 .. 0.987259
# real part range: -1.1786 .. 1.1786
# imag part range: -0.000236176 .. 0.000236176
# real part range: -0.000177279 .. 0.000177279
# imag part range: -1.39499 .. 1.39499
# real part range: -1.37383 .. 1.37383
# imag part range: -0.000149481 .. 0.000149481
# real part range: -0.000187996 .. 0.000187996
# imag part range: -1.79927 .. 1.79927
# real part range: -0.000237724 .. 0.000237724
# imag part range: -1.36192 .. 1.36192
# real part range: -0.00044431 .. 0.00044431
# imag part range: -1.62651 .. 1.62651
# real part range: -0.00190285 .. 0.00190285
# imag part range: -1.85108 .. 1.85108

# %% [markdown]
# 按道理应该没有Ex,Ey分量，可以进行测试,绘制一下Ex

# %%
# Create an MPBData instance to transform the efields
eps = ms.get_epsilon() # 得到折射率分布
md = mpb.MPBData(rectify=True, resolution=32, periods=3)
converted_eps = md.convert(eps)


converted = []
for f in efields:
    # Get just the  component of the efields
    f = f[..., 0, 0]
    converted.append(md.convert(f))


for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='jet', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# epsilon: 1-8.9, mean 1.99274, harm. mean 1.13848, 14.5508% > 1, 12.5663% "fill"
# real part range: 1 .. 8.9
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0
# real part range: 0 .. 0
# imag part range: 0 .. 0

# %% [markdown]
# 结果与预期一致，都是0，确实是TM模式.

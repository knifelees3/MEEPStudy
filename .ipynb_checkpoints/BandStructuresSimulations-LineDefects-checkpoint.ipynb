# %% [markdown]
# # Line Defect Simulations

# %% [markdown]
# Now we try to simulate different line defect using MEEP
#
# I will begin with 2D lattice and then the 3D lattice case.

# %% [markdown]
# ## 2D line defect in triangle lattice
# ![image.png](attachment:image.png)
# What I will trying to simulate is shown above,

# %%
from meep import mpb
import numpy as np
import meep as mp
import matplotlib.pyplot as plt
from mayavi import mlab

import math

import meep as mp
from meep import mpb

# A line_defect waveguide in a 2d triangular lattice of dielectric
# rods (c.f. tri_rods.ctl), formed by a row of missing rods along the
# "x" direction.  (Here, "x" and "y" refer to the first and second
# basis directions.)  This structure supports a single guided band
# within the band gap, much like the analogous waveguide in a square
# lattice of rods (see "Photonic Crystals" by Joannopoulos et al.).

supercell_y = 7  # the (odd) number of lateral supercell periods

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, supercell_y),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)

eps = 12  # the dielectric constant of the rods
r = 0.14  # the rod radius in the bulk crystal

geometry = [mp.Cylinder(r, material=mp.Medium(epsilon=eps))]

# duplicate the bulk crystal rods over the supercell:
geometry = mp.geometric_objects_lattice_duplicates(geometry_lattice, geometry)

# add a rod of air, to erase a row of rods and form a waveguide:
geometry += [mp.Cylinder(r, material=mp.air)]

Gamma = mp.Vector3()
K_prime = mp.lattice_to_reciprocal(
    mp.Vector3(0.5), geometry_lattice
)  # edge of Brillouin zone.
k_points = mp.interpolate(6, [Gamma, K_prime])

# the bigger the supercell, the more bands you need to compute to get
# to the defect modes (the lowest band is "folded" supercell_y times):
extra_bands = 25  # number of extra bands to compute above the gap
num_bands = supercell_y + extra_bands

resolution = 32

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    geometry=geometry,
    k_points=k_points,
    num_bands=num_bands,
    resolution=resolution,
)
ms.run_tm()
tm_freqs = ms.all_freqs
# Out:
# Initializing eigensolver data
# Computing 32 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 224 x 1.
# Solving for 11 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (6.06218, -3.5, 0)
#      (0, 0, 1)
# Cell volume = 6.06218
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.0824786, -0.142857, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,3,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,2,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,1,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-1,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-2,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-3,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 9 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 8 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.07142857142857147, 0.25000000000000006, 0.0>
#   Vector3<0.14285714285714293, 0.5000000000000001, 0.0>
#   Vector3<0.2142857142857144, 0.7500000000000002, 0.0>
#   Vector3<0.28571428571428586, 1.0000000000000002, 0.0>
#   Vector3<0.3571428571428573, 1.2500000000000002, 0.0>
#   Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
#   Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# elapsed time for initialization: 0.0399169921875
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8, tm band 9, tm band 10, tm band 11, tm band 12, tm band 13, tm band 14, tm band 15, tm band 16, tm band 17, tm band 18, tm band 19, tm band 20, tm band 21, tm band 22, tm band 23, tm band 24, tm band 25, tm band 26, tm band 27, tm band 28, tm band 29, tm band 30, tm band 31, tm band 32
# Solving for bands 2 to 12...
#     near maximum in trace
#     linmin: converged after 13 iterations.
#     iteration    1: trace = 7.887584787297721 (198.664% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 2.434187274155406 (105.668% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 2.091688336076575 (15.1351% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 2.022821555135869 (3.34751% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.01169192122862 (0.551721% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.00842326096146 (0.162615% change)
#     large trace change predicted (0.506667%)
#     linmin: converged after 6 iterations.
#     iteration    7: trace = 2.001034955414712 (0.368544% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.994656754722733 (0.319254% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 1.992874914081382 (0.0893706% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.992486085178386 (0.0195129% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.992300642037697 (0.00930756% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.992117882628011 (0.00917371% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 1.99187212938169 (0.012337% change)
#     large trace change predicted (0.0354466%)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.991235542793666 (0.0319643% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 1.990594678448479 (0.0321894% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 1.990295510378615 (0.0150302% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 1.990175944971926 (0.0060076% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 1.990105262501023 (0.00355163% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 1.990064141309439 (0.0020663% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 1.990051872025965 (0.000616529% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.990048935707404 (0.00014755% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.990047964302194 (4.88131e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.990046930809898 (5.1933e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.990045137999796 (9.00889e-05% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 1.990042524541146 (0.000131327% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 1.990040628103128 (9.52964e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 1.990039864370168 (3.83778e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 1.990039625316056 (1.20125e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 1.990039561088838 (3.22743e-06% change)
# Finished solving for bands 2 to 12 after 29 iterations.
# Solving for bands 13 to 23...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 25.03226714884838 (195.793% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 8.106791064017143 (102.148% change)
#     linmin: converged after 8 iterations.
#     iteration    3: trace = 6.521656631254549 (21.6719% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.224818275592578 (4.65758% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 6.140023720023755 (1.37154% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 6.093111454135258 (0.76697% change)
#     linmin: converged after 5 iterations.
#     iteration    7: trace = 6.063582663748906 (0.485803% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 6.045545609852558 (0.297908% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 6.034271714288512 (0.186657% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 6.025808801862428 (0.140346% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 6.019429813050969 (0.105917% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 6.015006047379158 (0.0735185% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 6.011198146558566 (0.0633267% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 6.007191631985635 (0.0666731% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 6.002925330740268 (0.0710451% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 5.999279644514427 (0.0607503% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 5.997072776293931 (0.0367923% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 5.995905728762279 (0.0194622% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.995234651059741 (0.0111929% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.994927750595229 (0.0051192% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.994785305921498 (0.00237611% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.994690989943354 (0.00157331% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 5.994642167458657 (0.000814432% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 5.994620843638994 (0.000355715% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 5.99461195754972 (0.000148234% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 5.994608930971793 (5.04883e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.994607645983484 (2.14357e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 5.994607102509251 (9.06605e-06% change)
# Finished solving for bands 13 to 23 after 28 iterations.
# Solving for bands 24 to 32...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 29.95048425417713 (193.91% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 10.37423833417047 (97.093% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 8.593949733428019 (18.7713% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 8.041829406360195 (6.63775% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.838461010671622 (2.56127% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 7.744124597997011 (1.21079% change)
#     linmin: converged after 5 iterations.
#     iteration    7: trace = 7.700447481591311 (0.565598% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.684895403476347 (0.202167% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 7.680106333975639 (0.0623374% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 7.677799001439849 (0.0300475% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 7.676267368046466 (0.0199509% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 7.67500469937055 (0.0164503% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 7.673676512356945 (0.0173069% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 7.67220440640541 (0.0191857% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 7.670689538773066 (0.0197468% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 7.668851781992892 (0.023961% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 7.666151454334475 (0.0352178% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 7.663372384762248 (0.0362577% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 7.661303765250401 (0.0269972% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 7.660418799436285 (0.0115518% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 7.660151891726994 (0.00348431% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 7.66008629738382 (0.00085631% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 7.66006625382395 (0.000261663% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 7.660058559517124 (0.000100447% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 7.660054601556144 (5.16701e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 7.660051361392463 (4.22995e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 7.660049211842908 (2.80618e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 7.660048268550198 (1.23144e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 7.660047782430009 (6.34618e-06% change)
# Finished solving for bands 24 to 32 after 29 iterations.
# Finished k-point with 27.75 mean iterations/band.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.122045, 0.130388, 0.233103, 0.250015, 0.310192, 0.368416, 0.543779, 0.548594, 0.573916, 0.574363, 0.594497, 0.598029, 0.735587, 0.736633, 0.738906, 0.74246, 0.746224, 0.749942, 0.752355, 0.757302, 0.770152, 0.777227, 0.791494, 0.796365, 0.847849, 0.883457, 0.92611, 0.934139, 1.02112, 1.02338, 1.03911
# elapsed time for k point: 3.889535665512085
# solve_kpoint (0.0714286,0.25,0):
# Solving for bands 1 to 11...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 1.662136164464729 (0.723624% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.660285680771406 (0.111394% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.66010890918732 (0.0106476% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.660100620276704 (0.0004993% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.660098426458639 (0.00013215% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.660096390159757 (0.000122661% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.660095540565606 (5.11774e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.660095320477368 (1.32576e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.660095211911307 (6.53975e-06% change)
# Finished solving for bands 1 to 11 after 9 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.727766125537116 (0.898171% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.709558603339658 (0.318388% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.704017178585465 (0.0971023% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.702455111482203 (0.0273891% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.702034020880729 (0.00738465% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.701825469077392 (0.00365757% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.701750400292548 (0.00131658% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.701722794124567 (0.000484171% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.701711822026737 (0.000192435% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.701706048177109 (0.000101265% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.701702334393584 (6.51346e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.701700165006649 (3.80481e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.701698974117032 (2.08866e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.701697530643871 (2.53165e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.701696213900231 (2.30939e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.701695042992547 (2.05361e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.701693865143447 (2.06579e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.701693494350915 (6.5032e-06% change)
# Finished solving for bands 12 to 22 after 18 iterations.
# Solving for bands 23 to 32...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 8.230541742391006 (1.62782% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 8.17622139947928 (0.66217% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.16204576055399 (0.173527% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.15944786370903 (0.0318341% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 8.158982499799624 (0.00570354% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 8.158872271940119 (0.00135101% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 8.158839858146818 (0.000397284% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 8.158832555280629 (8.95087e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 8.15883067946211 (2.29913e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 8.158830234258101 (5.45671e-06% change)
# Finished solving for bands 23 to 32 after 10 iterations.
# Finished k-point with 12.4062 mean iterations/band.
# tmfreqs:, 2, 0.0714286, 0.25, 0, 0.0714286, 0.0550799, 0.13266, 0.141691, 0.2377, 0.254841, 0.312013, 0.37225, 0.546685, 0.551469, 0.573977, 0.574096, 0.592841, 0.596083, 0.72057, 0.723515, 0.735323, 0.736867, 0.746873, 0.749305, 0.756146, 0.758549, 0.775965, 0.781474, 0.800964, 0.807116, 0.850494, 0.883229, 0.925626, 0.931369, 0.981862, 1.01485, 1.01662
# elapsed time for k point: 1.9669947624206543
# solve_kpoint (0.142857,0.5,0):
# Solving for bands 1 to 11...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.729948390953895 (0.863577% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.727379269342604 (0.148619% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.727099118665421 (0.0162196% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.727058733392297 (0.00233836% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.727007124237227 (0.00298831% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.726978333925083 (0.00166708% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.726971967394481 (0.000368652% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.726969063494657 (0.00016815% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.72696652803739 (0.000146816% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.72696579990476 (4.21625e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.726965699193556 (5.83169e-06% change)
# Finished solving for bands 1 to 11 after 11 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.630217778493265 (0.675984% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.623198660123777 (0.124746% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.62187104266047 (0.0236124% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.621366558325454 (0.008974% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.621165813641539 (0.00357116% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.621070463577597 (0.00169628% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.621032601314841 (0.00067358% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.621015659508952 (0.000301401% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.621007584369143 (0.00014366% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.621003003849 (8.14893e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.620998154626339 (8.62697e-05% change)
#     large trace change predicted (0.000178876%)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.620988103905135 (0.000178807% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.620969650355493 (0.000328298% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 5.620942758809137 (0.000478416% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 5.620922712658824 (0.000356634% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.620913102436038 (0.000170972% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.620907739846395 (9.54043e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.620904858279473 (5.12652e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.62090387385522 (1.75136e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 5.620903617787192 (4.55564e-06% change)
# Finished solving for bands 12 to 22 after 20 iterations.
# Solving for bands 23 to 32...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 8.054699580281586 (0.773615% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 8.038407585232594 (0.202472% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.034756877133916 (0.0454261% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.033998654638379 (0.00943723% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 8.033863469004965 (0.00168268% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 8.033831968540312 (0.000392097% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 8.033824576062239 (9.20169e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 8.033821823112806 (3.4267e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 8.033820987469419 (1.04016e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 8.033820801893386 (2.30993e-06% change)
# Finished solving for bands 23 to 32 after 10 iterations.
# Finished k-point with 13.7812 mean iterations/band.
# tmfreqs:, 3, 0.142857, 0.5, 0, 0.142857, 0.109044, 0.159783, 0.170451, 0.250517, 0.268115, 0.317038, 0.383725, 0.554986, 0.559127, 0.572494, 0.574201, 0.588185, 0.590547, 0.69724, 0.697843, 0.725542, 0.726474, 0.745707, 0.747988, 0.76109, 0.764379, 0.787269, 0.788675, 0.81934, 0.824858, 0.858728, 0.880368, 0.909573, 0.923098, 0.941151, 0.995468, 0.995735
# elapsed time for k point: 2.0263216495513916
# solve_kpoint (0.214286,0.75,0):
# Solving for bands 1 to 11...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.830494758780456 (1.15317% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.826348554316858 (0.226764% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.825583744148134 (0.0418852% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.825135770906062 (0.0245416% change)
#     large trace change predicted (0.0507434%)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.824228440090558 (0.0497254% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.823673534506224 (0.0304233% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.823492110292552 (0.00994878% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.823454973770064 (0.00203658% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.823439258134293 (0.000861864% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.823421990111287 (0.000947007% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.823413457135768 (0.000467966% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.823412315940806 (6.25857e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 1.823412097591229 (1.19748e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 1.823412015774022 (4.48704e-06% change)
# Finished solving for bands 1 to 11 after 14 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.55236215011294 (0.600501% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.546825648589099 (0.0997641% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.545520223075672 (0.0235374% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.544810002341173 (0.0128079% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.544490870999427 (0.00575566% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.544285332101117 (0.00370715% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.544127988824876 (0.00283798% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.543883348547904 (0.0044127% change)
#     large trace change predicted (0.0136408%)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.54318146367042 (0.0126613% change)
#     large trace change predicted (0.0283109%)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.541778526145047 (0.0253125% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.540408081363279 (0.0247324% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 5.539463123674317 (0.0170572% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.539083300409398 (0.00685692% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 5.538962988785634 (0.00217207% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.538923896540108 (0.000705771% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.538913171638384 (0.000193628% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.538910134925636 (5.48251e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.538909224111426 (1.64439e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.538908823259896 (7.23701e-06% change)
# Finished solving for bands 12 to 22 after 19 iterations.
# Solving for bands 23 to 32...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.900401972371319 (0.906815% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.882622497375309 (0.225299% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.879830492649414 (0.035426% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.87936762760509 (0.00587422% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.879243941498454 (0.00156976% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.87918641905423 (0.000730053% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.879162962749599 (0.0002977% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.879152358899406 (0.000134581% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.879147296118643 (6.42554e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.879144603193859 (3.41779e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.879143715466391 (1.12668e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.879143434436926 (3.56675e-06% change)
# Finished solving for bands 23 to 32 after 12 iterations.
# Finished k-point with 15.0938 mean iterations/band.
# tmfreqs:, 4, 0.214286, 0.75, 0, 0.214286, 0.160787, 0.195237, 0.20758, 0.26899, 0.286569, 0.323958, 0.402792, 0.565366, 0.56649, 0.569406, 0.574379, 0.582331, 0.583617, 0.67092, 0.673585, 0.717154, 0.719721, 0.743588, 0.745473, 0.765657, 0.773479, 0.793649, 0.797814, 0.833928, 0.83738, 0.850309, 0.871452, 0.891098, 0.91579, 0.927974, 0.966087, 0.967654
# elapsed time for k point: 2.2491109371185303
# solve_kpoint (0.285714,1,0):
# Solving for bands 1 to 11...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.93175779615874 (1.61957% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.924268222191006 (0.388461% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.921357723505599 (0.151367% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.919641720819748 (0.0893519% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.918180712108928 (0.0761374% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.917346159396197 (0.043517% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.91694342730424 (0.0210069% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.916431327585892 (0.026718% change)
#     large trace change predicted (0.219935%)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.914339828249024 (0.109195% change)
#     linmin: converged after 5 iterations.
#     iteration   10: trace = 1.91203661533126 (0.120386% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.911102174384206 (0.0488834% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.910714805846783 (0.0202714% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.910295654456871 (0.0219393% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.910071818215189 (0.011718% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.91000191568484 (0.00365975% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.909981974588651 (0.00104404% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.909976073269946 (0.000308973% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.909973310222781 (0.000144664% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.909969761720906 (0.000185788% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.909966741773804 (0.000158115% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.909965748706338 (5.1994e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.909964976671377 (4.04214e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.909964066250301 (4.76669e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.909963723872806 (1.79259e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.909963641715651 (4.3015e-06% change)
# Finished solving for bands 1 to 11 after 25 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.508662148859345 (1.29912% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.499173085666361 (0.172406% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.495448349624279 (0.0677556% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.492824241614505 (0.047762% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.490911631084085 (0.0348262% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.489119830593421 (0.0326374% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.488001187546646 (0.0203814% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.487448400893994 (0.0100731% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.487187466690517 (0.00475522% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.487072455259339 (0.00209602% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.487015711478339 (0.00103414% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.486984919831634 (0.000561175% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.486961317183441 (0.000430158% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.486915455228254 (0.000835839% change)
#     large trace change predicted (0.00349557%)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 5.486730616688781 (0.00336877% change)
#     near maximum in trace
#     linmin: converged after 5 iterations.
#     iteration   16: trace = 5.485731358921414 (0.0182139% change)
#     linmin: converged after 5 iterations.
#     iteration   17: trace = 5.485063286576182 (0.0121791% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.484331872891974 (0.0133355% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.483714521863231 (0.0112573% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.483192894369052 (0.00951275% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.482754450545242 (0.00799646% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 5.48237832885078 (0.00686032% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 5.482070020473362 (0.00562378% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 5.481826227120018 (0.0044472% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.481639798305455 (0.00340091% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.481520307549031 (0.00217986% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 5.481446227200652 (0.00135147% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.481394988438307 (0.000934772% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.481353825724709 (0.000750956% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.481312668564098 (0.00075086% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.481268363696127 (0.000808293% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.481225950734669 (0.000773783% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 5.481191734785519 (0.000624241% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 5.481168473214383 (0.00042439% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 5.481152956489279 (0.000283092% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 5.481141408724091 (0.000210682% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 5.481132619948506 (0.000160346% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 5.481125516166911 (0.000129604% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 5.48111860668755 (0.00012606% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 5.481111319039833 (0.000132959% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 5.481103993292546 (0.000133655% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 5.481097374476876 (0.000120757% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 5.481092402838877 (9.07052e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   44: trace = 5.481089142889184 (5.94763e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 5.481086870901284 (4.14514e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 5.481084891529171 (3.61128e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 5.481082796596166 (3.82211e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 5.481080559176796 (4.08208e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 5.48107838079418 (3.97437e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 5.481076425307833 (3.5677e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 5.481074802776478 (2.96024e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 5.481073500384975 (2.37616e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 5.481072461077487 (1.89618e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   54: trace = 5.481071677835653 (1.42899e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   55: trace = 5.481071084437519 (1.08263e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   56: trace = 5.481070566882145 (9.4426e-06% change)
# Finished solving for bands 12 to 22 after 56 iterations.
# Solving for bands 23 to 32...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 7.749978483966875 (2.41956% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.72191599408935 (0.362754% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.718067343190699 (0.049853% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.717328398337046 (0.00957468% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.717146439194746 (0.00235783% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.717042367766786 (0.00134858% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.716956874075453 (0.00110786% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.716917450773237 (0.000510867% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.716901229858063 (0.0002102% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.716895139527368 (7.8922e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.716893213787635 (2.49549e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.716892556991566 (8.51115e-06% change)
# Finished solving for bands 23 to 32 after 12 iterations.
# Finished k-point with 31.5938 mean iterations/band.
# tmfreqs:, 5, 0.285714, 1, 0, 0.285714, 0.209115, 0.232969, 0.24601, 0.289633, 0.305622, 0.330596, 0.429187, 0.561173, 0.561599, 0.567904, 0.572564, 0.579941, 0.588268, 0.651658, 0.655495, 0.714277, 0.718837, 0.735936, 0.739419, 0.772982, 0.777626, 0.79176, 0.795594, 0.815047, 0.842939, 0.855057, 0.881019, 0.890062, 0.902449, 0.915935, 0.93343, 0.940694
# elapsed time for k point: 4.768661737442017
# solve_kpoint (0.357143,1.25,0):
# Solving for bands 1 to 11...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.980785378504297 (1.78269% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.976917078224764 (0.195482% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.976389419107485 (0.0266946% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.976265613876562 (0.00626441% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.976198437902745 (0.00339919% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.976163144381474 (0.00178595% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.976149691213472 (0.000680774% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.97614703690134 (0.000134317% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.976146393532447 (3.25567e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.976146088625206 (1.54294e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.976145863763421 (1.13788e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.976145826649323 (1.87811e-06% change)
# Finished solving for bands 1 to 11 after 12 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.433843273856556 (0.633374% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.425761577598742 (0.14884% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.423586326520407 (0.0400992% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.422517097380168 (0.0197164% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.421736759215436 (0.0143917% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.420962559648289 (0.0142806% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.420565307576137 (0.00732834% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.420398760208051 (0.00307256% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.420341413967632 (0.00105798% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.420328947720443 (0.00022999% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.420325326171303 (6.68142e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.420321740421612 (6.61538e-05% change)
#     large trace change predicted (0.000175656%)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.420312223514366 (0.000175578% change)
#     large trace change predicted (0.000937913%)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 5.420262321694056 (0.000920649% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration   15: trace = 5.419779152683252 (0.00891452% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 5.419551847701827 (0.00419408% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 5.419248864878166 (0.00559071% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.418877856268905 (0.00684636% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.418532851933106 (0.00636691% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.41824755107287 (0.00526542% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.418019105275645 (0.00421632% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 5.417830506233365 (0.00348102% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 5.417663541095058 (0.00308182% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 5.417506950707729 (0.00289041% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.417357295247027 (0.00276248% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.417216145657529 (0.00260554% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 5.417086076904008 (0.00240105% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.416967989284498 (0.00217993% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.416860962671342 (0.00197579% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.41676343603756 (0.00180044% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.416674107611488 (0.00164912% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.416592092131242 (0.00151414% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 5.416516661408158 (0.0013926% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.416446990213025 (0.00128628% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.416382105906925 (0.00119792% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.416321012464062 (0.00112794% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.416262868975383 (0.00107349% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.416207124146048 (0.00102922% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.416153560141787 (0.000988963% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.416102241087298 (0.000947523% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.41605339279541 (0.000901913% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.416007261667967 (0.000851752% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.415964003538814 (0.000798712% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.415923633488142 (0.000745393% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.415886036478262 (0.000694196% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.415851014865839 (0.000646648% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.415818342928384 (0.000603267% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.415787806982033 (0.00056383% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.415759222760109 (0.000527796% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.41573243247282 (0.000494674% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.415707289988603 (0.00046425% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.41568364390189 (0.000436621% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.415661325886289 (0.000412101% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.415640147492473 (0.000391059% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.415619904567365 (0.000373787% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.415600386261021 (0.000360408% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.415581385321369 (0.000350856% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.415562707307804 (0.000344895% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 5.415544177562315 (0.000342158% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 5.415525645744806 (0.000342197% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 5.415506988343872 (0.000344517% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.415488109910799 (0.0003486% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.415468943908069 (0.000353912% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.415449454010472 (0.000359894% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.415429636397953 (0.000365947% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 5.41540952300995 (0.00037141% change)
#     linmin: converged after 3 iterations.
# ...
#     iteration   69: trace = 7.597853601834329 (0.000208562% change)
#     resetting CG direction...
#     large trace change predicted (0.0204017%)
#     linmin: converged after 3 iterations.
#     iteration   70: trace = 7.596305618026546 (0.020376% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 7.595872430986295 (0.00570276% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 7.595690852609327 (0.00239052% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 7.595601325820629 (0.00117866% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 7.595554674504312 (0.00061419% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 7.595540356982056 (0.000188499% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 7.595531910005745 (0.00011121% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 7.595526995288417 (6.47054e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 7.595524564296097 (3.20056e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 7.595523397856683 (1.53569e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 7.595522984878196 (5.43713e-06% change)
# Finished solving for bands 23 to 32 after 80 iterations.
# Finished k-point with 58.3438 mean iterations/band.
# tmfreqs:, 6, 0.357143, 1.25, 0, 0.357143, 0.252471, 0.268695, 0.280499, 0.308344, 0.320171, 0.333848, 0.461231, 0.552157, 0.552573, 0.558337, 0.563737, 0.583344, 0.584553, 0.652253, 0.65358, 0.707176, 0.716633, 0.723768, 0.728501, 0.752767, 0.781195, 0.796672, 0.800388, 0.819223, 0.840639, 0.863461, 0.878466, 0.883232, 0.886944, 0.903307, 0.905417, 0.925917
# elapsed time for k point: 9.258927345275879
# solve_kpoint (0.428571,1.5,0):
# Solving for bands 1 to 11...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.038259382169903 (1.96272% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.033857399237097 (0.216201% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.033014688256318 (0.0414427% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.032883217837989 (0.00646698% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.032856720154004 (0.00130346% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.032841597458341 (0.000743916% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.032837250030827 (0.00021386% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.032836565138311 (3.36915e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.032836372124498 (9.4948e-06% change)
# Finished solving for bands 1 to 11 after 9 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.380753221376656 (0.642954% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.373522228548003 (0.134477% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.3718383243375 (0.031342% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.371335873668823 (0.00935386% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.371205874521439 (0.00242027% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.3711118142361 (0.00175121% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.371034374187063 (0.0014418% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.371001506512547 (0.000611945% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.370990554144378 (0.000203917% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.370987118523243 (6.39663e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.37098602937302 (2.02784e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.370985520305727 (9.4781e-06% change)
# Finished solving for bands 12 to 22 after 12 iterations.
# Solving for bands 23 to 32...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.46893107343597 (0.635612% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.459685812528209 (0.12386% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.457575250976488 (0.0282969% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.456462476324118 (0.0149225% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.456051368038852 (0.0055136% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.455954746543539 (0.00129589% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.455935965066525 (0.000251899% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.455932022594213 (5.2877e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.455930510149286 (2.02851e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.455930004053192 (6.78783e-06% change)
# Finished solving for bands 23 to 32 after 10 iterations.
# Finished k-point with 10.3438 mean iterations/band.
# tmfreqs:, 7, 0.428571, 1.5, 0, 0.428571, 0.288629, 0.29856, 0.306376, 0.320464, 0.325393, 0.329887, 0.492515, 0.543582, 0.544486, 0.550916, 0.557761, 0.570032, 0.583261, 0.655395, 0.671842, 0.675841, 0.707124, 0.724042, 0.7322, 0.737045, 0.782959, 0.807182, 0.812724, 0.824412, 0.827566, 0.861545, 0.862511, 0.879196, 0.879623, 0.888203, 0.889379, 0.904479
# elapsed time for k point: 2.0136682987213135
# solve_kpoint (0.5,1.75,0):
# Solving for bands 1 to 11...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.071115029101438 (2.26799% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.062787465870298 (0.402891% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.060344285549195 (0.118511% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.059976080663626 (0.0178726% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.059856990730101 (0.0057813% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.059794601700104 (0.00302885% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.059780864132673 (0.000666941% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.059777975646133 (0.000140233% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.059776702774843 (6.17965e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.05977609461026 (2.95258e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.059775863145847 (1.12374e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.059775722064484 (6.84936e-06% change)
# Finished solving for bands 1 to 11 after 12 iterations.
# Solving for bands 12 to 22...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.390227707027115 (0.682048% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.38157383151815 (0.160676% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.37738756453051 (0.0778192% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.3720569164305 (0.09918% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 5.364177333578405 (0.146785% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.356255131063667 (0.147796% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.35248897192095 (0.070338% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.351365294152151 (0.0209958% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.351056332130895 (0.00577368% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.350921969701134 (0.00251098% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.350844495566854 (0.00144788% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.350807643708885 (0.000688713% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.35079438379096 (0.000247812% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.350789339632024 (9.42694e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.350787483504607 (3.46889e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.350786276236687 (2.25624e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.350785289294183 (1.84448e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.350784712428959 (1.07809e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.350784439975826 (5.09184e-06% change)
# Finished solving for bands 12 to 22 after 19 iterations.
# Solving for bands 23 to 32...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.408648849079454 (0.613235% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.402883957531383 (0.0778433% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 7.402325282113305 (0.00754701% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.402224507802702 (0.0013614% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.402187509079604 (0.000499834% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.402173660394181 (0.000187089% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.402169225674049 (5.99111e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.402168441254254 (1.05972e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.402168312505376 (1.73934e-06% change)
# Finished solving for bands 23 to 32 after 9 iterations.
# Finished k-point with 13.4688 mean iterations/band.
# tmfreqs:, 8, 0.5, 1.75, 0, 0.5, 0.314408, 0.315385, 0.317029, 0.318786, 0.320452, 0.32162, 0.506789, 0.539884, 0.542346, 0.549062, 0.556127, 0.560879, 0.586344, 0.637145, 0.679641, 0.692501, 0.696176, 0.720475, 0.720975, 0.741483, 0.78818, 0.806475, 0.814341, 0.82775, 0.835595, 0.840323, 0.858614, 0.879109, 0.879646, 0.884731, 0.886602, 0.892661
# elapsed time for k point: 2.4648549556732178
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.31440770900981846 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 2 range: 0.12204498095943948 at Vector3<0.0, 0.0, 0.0> to 0.3153846374720158 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 3 range: 0.13038820797700365 at Vector3<0.0, 0.0, 0.0> to 0.3170294480855881 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 4 range: 0.23310255797235022 at Vector3<0.0, 0.0, 0.0> to 0.3204636228212291 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 5 range: 0.25001459491619543 at Vector3<0.0, 0.0, 0.0> to 0.3253934802481656 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 6 range: 0.31019188218783417 at Vector3<0.0, 0.0, 0.0> to 0.3338484146163221 at Vector3<0.3571428571428573, 1.2500000000000002, 0.0>
# Band 7 range: 0.36841604984258464 at Vector3<0.0, 0.0, 0.0> to 0.5067894167929198 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 8 range: 0.5398842292528555 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.5653655057501378 at Vector3<0.2142857142857144, 0.7500000000000002, 0.0>
# Band 9 range: 0.5423455032152159 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.5664901134927587 at Vector3<0.2142857142857144, 0.7500000000000002, 0.0>
# Band 10 range: 0.549061861727701 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.5739774143385025 at Vector3<0.07142857142857147, 0.25000000000000006, 0.0>
# Band 11 range: 0.5561270690365178 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.5743793753676204 at Vector3<0.2142857142857144, 0.7500000000000002, 0.0>
# Band 12 range: 0.5608790519249381 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.5944974349870821 at Vector3<0.0, 0.0, 0.0>
# Band 13 range: 0.5832610608047643 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0> to 0.5980287632420751 at Vector3<0.0, 0.0, 0.0>
# Band 14 range: 0.6371448254757912 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.735586980370028 at Vector3<0.0, 0.0, 0.0>
# Band 15 range: 0.653579501239326 at Vector3<0.3571428571428573, 1.2500000000000002, 0.0> to 0.7366325098850846 at Vector3<0.0, 0.0, 0.0>
# Band 16 range: 0.6758411244954624 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0> to 0.7389064393114602 at Vector3<0.0, 0.0, 0.0>
# Band 17 range: 0.6961760667412294 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.7424595763558498 at Vector3<0.0, 0.0, 0.0>
# Band 18 range: 0.7204747170840988 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.746872644801111 at Vector3<0.07142857142857147, 0.25000000000000006, 0.0>
# Band 19 range: 0.7209750002850193 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.7499421529270316 at Vector3<0.0, 0.0, 0.0>
# Band 20 range: 0.7370449459896902 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0> to 0.7729821511327389 at Vector3<0.28571428571428586, 1.0000000000000002, 0.0>
# Band 21 range: 0.7573019888640187 at Vector3<0.0, 0.0, 0.0> to 0.7881801530721784 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 22 range: 0.7701524400379199 at Vector3<0.0, 0.0, 0.0> to 0.8071823992647646 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 23 range: 0.7772268164780918 at Vector3<0.0, 0.0, 0.0> to 0.8143407550108104 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 24 range: 0.7914937433304797 at Vector3<0.0, 0.0, 0.0> to 0.8339277033739314 at Vector3<0.2142857142857144, 0.7500000000000002, 0.0>
# Band 25 range: 0.7963645621862919 at Vector3<0.0, 0.0, 0.0> to 0.84293897617645 at Vector3<0.28571428571428586, 1.0000000000000002, 0.0>
# Band 26 range: 0.8403229406073799 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.863460763867246 at Vector3<0.3571428571428573, 1.2500000000000002, 0.0>
# Band 27 range: 0.8586142518509 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.8834565452158901 at Vector3<0.0, 0.0, 0.0>
# Band 28 range: 0.8791094192603289 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 0.9261096160987734 at Vector3<0.0, 0.0, 0.0>
# Band 29 range: 0.879623126600397 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0> to 0.9341393919058147 at Vector3<0.0, 0.0, 0.0>
# Band 30 range: 0.8847307389075585 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 1.0211204448267877 at Vector3<0.0, 0.0, 0.0>
# Band 31 range: 0.8866024948818205 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 1.0233787218326356 at Vector3<0.0, 0.0, 0.0>
# Band 32 range: 0.8926609297914166 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0> to 1.0391146354277023 at Vector3<0.0, 0.0, 0.0>
# Gap from band 6 (0.3338484146163221) to band 7 (0.36841604984258464), 9.844620360478254%
# Gap from band 7 (0.5067894167929198) to band 8 (0.5398842292528555), 6.323807346246752%
# Gap from band 13 (0.5980287632420751) to band 14 (0.6371448254757912), 6.333694727770099%
# total elapsed time for run: 28.692246437072754
# done

# %%
import matplotlib.pyplot as plt
md = mpb.MPBData(rectify=True, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

import matplotlib.pyplot as plt
md = mpb.MPBData(rectify=False, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-12, mean 2.36812, harm. mean 1.14348, 14.8158% > 1, 12.4375% "fill"
# real part range: 1 .. 12
# epsilon: 1-12, mean 2.36812, harm. mean 1.14348, 14.8158% > 1, 12.4375% "fill"
# real part range: 1 .. 12

# %%
import matplotlib.pyplot as plt
numk,tmp=np.shape(tm_freqs)
klist=range(numk)

fig,ax=plt.subplots()
x = range(len(tm_freqs))
for l in range(num_bands):
    plt.plot(tm_freqs[:,l],'b-')
plt.ylim([0,0.65])
plt.ylabel('$\omega a/(2\pi c)$')
# Out:
# Text(0, 0.5, '$\\omega a/(2\\pi c)$')

# %% [markdown]
# We can see that the results are neally the same with results from textbook.

# %% [markdown]
# ## 3D line defect
# Now I will try to simulate the 3D line defect

# %%
from meep import mpb
import numpy as np
import meep as mp
import matplotlib.pyplot as plt
from mayavi import mlab

import math

import meep as mp
from meep import mpb

# A line_defect waveguide in a 3d triangular lattice of dielectric
# rods (c.f. tri_rods.ctl), formed by a row of missing rods along the
# "x" direction.  (Here, "x" and "y" refer to the first and second
# basis directions.)  This structure supports a single guided band
# within the band gap, much like the analogous waveguide in a square
# lattice of rods (see "Photonic Crystals" by Joannopoulos et al.).

supercell_y = 9  # the (odd) number of lateral supercell periods

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, supercell_y,6),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)

eps = 12  # the dielectric constant of the rods
r = 0.14  # the rod radius in the bulk crystal
h=2

geometry = [mp.Cylinder(center=mp.Vector3(),radius=r, height=h,material=mp.Medium(epsilon=eps))]


# duplicate the bulk crystal rods over the supercell:
geometry = mp.geometric_objects_lattice_duplicates(geometry_lattice, geometry)

# add a rod of air, to erase a row of rods and form a waveguide:
geometry += [mp.Cylinder(center=mp.Vector3(),radius=r, height=h,material=mp.air)]

Gamma = mp.Vector3()
K_prime = mp.lattice_to_reciprocal(
    mp.Vector3(0.5), geometry_lattice
)  # edge of Brillouin zone.
k_points = mp.interpolate(6, [Gamma, K_prime])

# the bigger the supercell, the more bands you need to compute to get
# to the defect modes (the lowest band is "folded" supercell_y times):
extra_bands = 20  # number of extra bands to compute above the gap
num_bands = supercell_y + extra_bands

resolution = 10

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    geometry=geometry,
    k_points=k_points,
    num_bands=num_bands,
    resolution=resolution,
)
ms.run_tm()
tm_freqs = ms.all_freqs
# Out:
# Initializing eigensolver data
# Computing 27 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 10 x 70 x 50.
# Solving for 9 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (6.06218, -3.5, 0)
#      (0, 0, 5)
# Cell volume = 30.3109
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.0824786, -0.142857, 0)
#      (-0, 0, 0.2)
# Geometric objects:
#      cylinder, center = (0,3,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,2,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,1,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,0,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-1,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-2,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-3,2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,3,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,2,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,1,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,0,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-1,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-2,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-3,1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,3,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,2,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,1,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-1,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-2,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-3,0)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,3,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,2,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,1,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,0,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-1,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-2,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-3,-1)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,3,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,2,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,1,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,0,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-1,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-2,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,-3,-2)
#           radius 0.14, height 2, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.14, height 2, axis (0, 0, 1)
# Geometric object tree has depth 7 and 154 object nodes (vs. 36 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 8 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.07142857142857147, 0.25000000000000006, 0.0>
#   Vector3<0.14285714285714293, 0.5000000000000001, 0.0>
#   Vector3<0.2142857142857144, 0.7500000000000002, 0.0>
#   Vector3<0.28571428571428586, 1.0000000000000002, 0.0>
#   Vector3<0.3571428571428573, 1.2500000000000002, 0.0>
#   Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
#   Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# elapsed time for initialization: 0.1460585594177246
# solve_kpoint (0,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4, zodd band 5, zodd band 6, zodd band 7, zodd band 8, zodd band 9, zodd band 10, zodd band 11, zodd band 12, zodd band 13, zodd band 14, zodd band 15, zodd band 16, zodd band 17, zodd band 18, zodd band 19, zodd band 20, zodd band 21, zodd band 22, zodd band 23, zodd band 24, zodd band 25, zodd band 26, zodd band 27
# Solving for bands 2 to 10...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 3.600953835273105 (194.461% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.5521535153317675 (146.82% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.4191078267299946 (27.3965% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.3910829023201277 (6.91811% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.380450574339334 (2.75615% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.3779136811144931 (0.669043% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.3765384960879855 (0.364552% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.3760737790395129 (0.123494% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 0.3757815795521563 (0.0777276% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 0.3755579926310909 (0.0595169% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 0.3753450306610672 (0.0567216% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 0.3752288973108143 (0.0309452% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 0.3751857958117753 (0.0114874% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 0.3751634433177826 (0.00595789% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 0.3751460091384562 (0.0046472% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 0.3751305561349594 (0.00411928% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 0.3751189216457421 (0.0031015% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 0.3751129426127601 (0.00159392% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 0.3751107257469022 (0.000590988% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 0.3751097555455264 (0.000258644% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 0.3751092719784003 (0.000128914% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 0.3751085847192686 (0.000183216% change)
#     large trace change predicted (0.00050593%)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 0.3751066813820895 (0.000507411% change)
#     large trace change predicted (0.00248102%)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 0.375097415745766 (0.00247016% change)
#     large trace change predicted (0.0356971%)
#     linmin: converged after 6 iterations.
#     iteration   25: trace = 0.3750502022587346 (0.0125878% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 0.3750109367895467 (0.0104699% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 0.3749703061343999 (0.0108351% change)
#     linmin: converged after 6 iterations.
#     iteration   28: trace = 0.3749030732651735 (0.0179318% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 0.3748441637305706 (0.0157145% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 0.3748015483536407 (0.0113695% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 0.3747832636033631 (0.00487863% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 0.3747754234441849 (0.00209194% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 0.3747710013701338 (0.00117993% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 0.3747678383208149 (0.000843999% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 0.3747644508177547 (0.000903898% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 0.3747611199120925 (0.000888804% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 0.3747561969107516 (0.00131365% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 0.3747499981631794 (0.00165409% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 0.3747406795175223 (0.00248666% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 0.3747305611393286 (0.00270014% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 0.3747203992009333 (0.00271184% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 0.37471092749197 (0.00252771% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 0.374702161790502 (0.00233935% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 0.374695416673599 (0.00180014% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 0.3746909615329872 (0.00118901% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 0.3746884916380722 (0.000659184% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 0.3746872946858328 (0.000319453% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 0.3746866903827995 (0.000161282% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 0.3746864138760633 (7.37968e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 0.3746862469279464 (4.45568e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 0.3746861424656901 (2.78799e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 0.3746860571457367 (2.2771e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 0.374685989027002 (1.81802e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   54: trace = 0.3746859333311582 (1.48647e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   55: trace = 0.3746858853058542 (1.28175e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   56: trace = 0.3746858473930582 (1.01186e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   57: trace = 0.3746858140999504 (8.88561e-06% change)
# Finished solving for bands 2 to 10 after 57 iterations.
# Solving for bands 11 to 19...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 7.845001151525254 (188.115% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 1.692203731767815 (129.027% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 1.212676023900603 (33.0153% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 1.092394715476211 (10.4362% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.041836526471439 (4.73784% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 1.022998571501882 (1.82464% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.010539417650028 (1.22537% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.004171861618676 (0.632106% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 0.999581177274229 (0.458209% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 0.99600428515694 (0.35848% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 0.9922285192787121 (0.379811% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 0.9886220508363672 (0.364133% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 0.9858126990888763 (0.284573% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 0.9836217691251017 (0.222493% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 0.9822661627261373 (0.137913% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 0.9812752621941577 (0.10093% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 0.9806475864001408 (0.0639858% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 0.9802375613807779 (0.0418204% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 0.9799669916833385 (0.0276063% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 0.9797671815082523 (0.0203916% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 0.9795935488271533 (0.0177234% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 0.9794446498947372 (0.0152012% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 0.9793180022220824 (0.0129314% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 0.9792203500361746 (0.00997195% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 0.9791548885098089 (0.00668529% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 0.9791129696347818 (0.00428122% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 0.9790891933866612 (0.00242838% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 0.9790743181779114 (0.0015193% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 0.9790661820805316 (0.000831002% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 0.9790615305658115 (0.000475098% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 0.9790581714375275 (0.000343097% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 0.9790547604242996 (0.000348398% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 0.979050547294696 (0.000430327% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 0.9790451071780464 (0.000555654% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 0.9790357679786625 (0.000953914% change)
#     large trace change predicted (0.00213329%)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 0.9790147539287307 (0.00214643% change)
#     large trace change predicted (0.0063598%)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 0.9789555131423138 (0.00605124% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 0.9788555015881875 (0.0102167% change)
#     linmin: converged after 4 iterations.
#     iteration   39: trace = 0.9787371330178674 (0.0120933% change)
#     linmin: converged after 4 iterations.
#     iteration   40: trace = 0.9786266442754824 (0.0112895% change)
#     linmin: converged after 4 iterations.
#     iteration   41: trace = 0.9785416101535694 (0.00868951% change)
#     linmin: converged after 4 iterations.
#     iteration   42: trace = 0.9784774869032461 (0.00655316% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 0.9784384748509776 (0.0039871% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 0.978419215846039 (0.00196836% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 0.9784111500445498 (0.000824374% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 0.9784074244914044 (0.000380777% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 0.9784050299189486 (0.000244742% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 0.9784034052435805 (0.000166054% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 0.9784022781552154 (0.000115197% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 0.9784014459472949 (8.50579e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 0.978400791244863 (6.69155e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 0.978400315244198 (4.86509e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 0.9784000236129824 (2.98069e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   54: trace = 0.9783998318506012 (1.95996e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   55: trace = 0.9783997225583912 (1.11705e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   56: trace = 0.9783996552323435 (6.88124e-06% change)
# Finished solving for bands 11 to 19 after 56 iterations.
# Solving for bands 20 to 27...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 8.796118138051735 (185.149% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 2.285329796220323 (117.508% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 1.650684070675901 (32.2481% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 1.468750807209762 (11.6645% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 1.396585371163424 (5.03714% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.370914698732306 (1.85515% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.356284751415539 (1.07289% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.34654565426246 (0.720659% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.336651373406561 (0.737499% change)
#     linmin: converged after 5 iterations.
#     iteration   10: trace = 1.327916288473783 (0.655647% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.321572604734601 (0.478861% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.317906946792091 (0.277756% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 1.316080605016532 (0.138675% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 1.315143626940522 (0.0712199% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.314725467404722 (0.0318008% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 1.314528999402499 (0.0149448% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 1.314451740146264 (0.00587751% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.314421468401035 (0.00230302% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.314409490791125 (0.00091125% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.314404242517897 (0.000399288% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.314401748744977 (0.000189727% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.314400531235506 (9.26285e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.314400026106622 (3.84304e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.314399821975651 (1.55304e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.314399745326581 (5.83149e-06% change)
# Finished solving for bands 20 to 27 after 25 iterations.
# Finished k-point with 45.0741 mean iterations/band.
# zoddfreqs:, 1, 0, 0, 0, 0, 0, 0.122208, 0.126445, 0.187617, 0.187876, 0.224253, 0.224924, 0.233602, 0.242607, 0.24281, 0.243684, 0.299843, 0.303137, 0.311498, 0.331621, 0.359644, 0.36087, 0.364466, 0.371227, 0.372205, 0.389535, 0.392613, 0.397109, 0.399914, 0.403506, 0.439954, 0.442693
# elapsed time for k point: 15.253494501113892
# solve_kpoint (0.0714286,0.25,0):
# Solving for bands 1 to 9...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.3446811007895977 (1.49262% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.3439075699953334 (0.224671% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.343820519569093 (0.0253154% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.3437979455694609 (0.00656585% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.3437910509887961 (0.00200544% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.3437775081266172 (0.00393935% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.3437626587219226 (0.00431957% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.3437379606766702 (0.00718488% change)
#     large trace change predicted (0.0178402%)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.3436791676036435 (0.0171055% change)
#     large trace change predicted (0.818296%)
#     linmin: converged after 8 iterations.
#     iteration   10: trace = 0.3434551263051937 (0.0652103% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 0.3433209339789617 (0.0390789% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 0.3431714757894997 (0.0435426% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 0.3429915629199221 (0.0524403% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 0.3427900708043088 (0.0587628% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 0.3425939297878868 (0.0572354% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 0.3424277421133666 (0.0485204% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 0.3422983974868744 (0.03778% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 0.3422036043390937 (0.027697% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 0.3421384134738967 (0.0190521% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 0.3420903580390648 (0.0140466% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 0.3420463226814234 (0.0128733% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 0.3420081071996482 (0.0111732% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 0.3419766245989722 (0.00920564% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 0.3419542068142043 (0.00655557% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 0.3419360432309286 (0.00531184% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 0.3419194308230917 (0.00485846% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 0.341907059367927 (0.0036183% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 0.3418969986718876 (0.00294257% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 0.3418892883260153 (0.00225519% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 0.3418830320327972 (0.00182993% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 0.3418755693884239 (0.00218283% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 0.3418694027038034 (0.0018038% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 0.3418657925301798 (0.00105602% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 0.3418632344523407 (0.000748272% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 0.3418610060157622 (0.000651852% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 0.34185887950952 (0.00062204% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 0.3418571233629598 (0.000513706% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 0.3418557954576659 (0.000388439% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 0.3418548194433123 (0.000285505% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 0.3418541738584037 (0.000188848% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 0.341853720731363 (0.00013255% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 0.3418533486575698 (0.00010884% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 0.3418530128926855 (9.8219e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   44: trace = 0.3418527427386776 (7.90264e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 0.3418525279526672 (6.283e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 0.3418523827171194 (4.24849e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 0.3418522700753511 (3.29504e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 0.3418521878213037 (2.40613e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 0.3418521296354075 (1.70208e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 0.3418520696091557 (1.75591e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 0.3418520186953952 (1.48935e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 0.3418519797596887 (1.13896e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 0.3418519487076635 (9.08347e-06% change)
# Finished solving for bands 1 to 9 after 53 iterations.
# Solving for bands 10 to 18...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.9287015782089941 (1.73471% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.9256158280269021 (0.332818% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.925390428040478 (0.0243543% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.9253144740884343 (0.00820811% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.9253021298708062 (0.00133407% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.9252931338176701 (0.000972233% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.9252805842710647 (0.00135629% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.9252730054187625 (0.00081909% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.9252678629425141 (0.000555781% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.9252659506554712 (0.000206674% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.9252643928495847 (0.000168363% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.9252636791356608 (7.71362e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.9252632858144162 (4.25091e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.9252631185076421 (1.80821e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.9252630147347323 (1.12155e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.9252629412066895 (7.94672e-06% change)
# Finished solving for bands 10 to 18 after 16 iterations.
# Solving for bands 19 to 27...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.48320371502991 (0.853761% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.480595506597281 (0.176004% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.480078729983455 (0.0349094% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.479987925105255 (0.00613533% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.479972208914769 (0.00106192% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.47996742854034 (0.000323005% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.479964966971491 (0.000166326% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.47996372019525 (8.42437e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.479963072697609 (4.37509e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.47996288119576 (1.29396e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.47996280669085 (5.03424e-06% change)
# Finished solving for bands 19 to 27 after 11 iterations.
# Finished k-point with 26.6667 mean iterations/band.
# zoddfreqs:, 2, 0.0714286, 0.25, 0, 0.0714286, 0.054344, 0.132846, 0.137403, 0.1954, 0.199258, 0.230057, 0.231057, 0.238231, 0.247828, 0.251766, 0.25255, 0.303405, 0.306503, 0.313349, 0.334104, 0.365729, 0.36599, 0.366849, 0.375632, 0.37723, 0.393048, 0.395351, 0.400416, 0.40581, 0.408348, 0.442224, 0.445473
# elapsed time for k point: 9.904978036880493
# solve_kpoint (0.142857,0.5,0):
# Solving for bands 1 to 9...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.419077239633703 (1.70356% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.4184751162157994 (0.143782% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.4183996465344827 (0.0180361% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.4183771972340985 (0.00536566% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4183741291471303 (0.000733333% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4183722929050392 (0.0004389% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4183718159271054 (0.000114008% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4183716145751239 (4.81275e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4183715600854557 (1.30242e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.418371540795007 (4.61084e-06% change)
# Finished solving for bands 1 to 9 after 10 iterations.
# Solving for bands 10 to 18...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.002754428541093 (0.44574% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.001463827403582 (0.128788% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.001340643006 (0.0123012% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.001282146792474 (0.00584196% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.001265019282099 (0.00171057% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.001246123510577 (0.00188721% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.001228237456963 (0.0017864% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.001210307578662 (0.0017908% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.001181746378885 (0.00285271% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.001154143483645 (0.00275707% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.001133448316056 (0.00206715% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.001124210398826 (0.00092275% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.001115207233978 (0.00089931% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.001108449887572 (0.000674984% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.001103328830422 (0.00051154% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.001100804567538 (0.000252148% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.001099199306645 (0.00016035% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.001098459404601 (7.3909e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.001097891718195 (5.67064e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.001097432724133 (4.58491e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.001097071956738 (3.60372e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.001096901315067 (1.70455e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.001096827772284 (7.34622e-06% change)
# Finished solving for bands 10 to 18 after 23 iterations.
# Solving for bands 19 to 27...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.565179690018718 (0.509753% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.563483447883156 (0.108432% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.563222621922059 (0.0166838% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.563139367896737 (0.00532594% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.563124873004953 (0.000927298% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.563117512911228 (0.000470859% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.563114465360636 (0.000194966% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.56311312549972 (8.57174e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.563112559943335 (3.61814e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.563112436247478 (7.91343e-06% change)
# Finished solving for bands 19 to 27 after 10 iterations.
# Finished k-point with 14.3333 mean iterations/band.
# zoddfreqs:, 3, 0.142857, 0.5, 0, 0.142857, 0.107816, 0.16004, 0.165353, 0.216252, 0.230439, 0.246529, 0.247828, 0.251145, 0.262024, 0.27714, 0.277535, 0.313561, 0.315733, 0.318459, 0.341275, 0.370189, 0.383311, 0.383933, 0.386845, 0.393728, 0.402647, 0.404424, 0.410709, 0.421796, 0.422874, 0.449018, 0.453569
# elapsed time for k point: 5.346791505813599
# solve_kpoint (0.214286,0.75,0):
# Solving for bands 1 to 9...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5410155726696984 (2.15007% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5402077135510331 (0.149434% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.5400796175563679 (0.0237152% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5400356024573182 (0.00815007% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.540027267541795 (0.00154341% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.540021857321494 (0.00100185% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5400206197330474 (0.000229174% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5400201012484934 (9.6012e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5400199719609776 (2.39412e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5400199396649357 (5.98053e-06% change)
# Finished solving for bands 1 to 9 after 10 iterations.
# Solving for bands 10 to 18...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.123631044659216 (0.665082% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.121725901486148 (0.169696% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.121407065758748 (0.0284277% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.120990015722457 (0.0371968% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.120506044043331 (0.0431829% change)
#     large trace change predicted (0.132545%)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.119217484868092 (0.115064% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.118236952277403 (0.0876472% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.11737479090861 (0.0771298% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 1.116842874530837 (0.0476154% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 1.116606533544521 (0.0211638% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.11652898892809 (0.00694491% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.116510106963152 (0.00169115% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 1.116496169955965 (0.00124827% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 1.116485880451757 (0.000921593% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.116473702181734 (0.00109077% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 1.116463870954762 (0.000880564% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.116455757461601 (0.000726716% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.116450067440795 (0.000509652% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.116445097319436 (0.000445173% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.116440826331472 (0.000382553% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 1.116436941555357 (0.000347961% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.116433638966901 (0.000295815% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.116430675076289 (0.000265479% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.116426391330165 (0.000383701% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 1.116419705667891 (0.000598847% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 1.116411080339124 (0.000772591% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 1.11640209882426 (0.000804502% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 1.116395914949365 (0.000553913% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 1.116390713692091 (0.000465898% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 1.116386288941245 (0.000396345% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 1.116382963638522 (0.000297864% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 1.116380713986374 (0.000201513% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 1.116379280986542 (0.000128361% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 1.116378337684174 (8.44966e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 1.116377674531806 (5.94021e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 1.116377058300852 (5.51992e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 1.116376559396756 (4.46896e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 1.11637626327825 (2.6525e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 1.116376091279207 (1.54069e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 1.116375965151842 (1.12979e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 1.116375907438999 (5.16966e-06% change)
# Finished solving for bands 10 to 18 after 41 iterations.
# Solving for bands 19 to 27...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.707952077809268 (0.80129% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.705412917037901 (0.148778% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.705037488493127 (0.0220164% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.704874572656432 (0.00955543% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.704840567619873 (0.0019946% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.704817959924677 (0.0013261% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.704810250943131 (0.000452189% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.70480625440018 (0.000234428% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.704804708886267 (9.06563e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.704804421465278 (1.68595e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.704804300353617 (7.10414e-06% change)
# Finished solving for bands 19 to 27 after 11 iterations.
# Finished k-point with 20.6667 mean iterations/band.
# zoddfreqs:, 4, 0.214286, 0.75, 0, 0.214286, 0.159461, 0.195623, 0.201757, 0.245834, 0.269785, 0.27079, 0.271118, 0.274538, 0.28319, 0.314359, 0.314998, 0.325507, 0.328304, 0.328668, 0.352174, 0.376111, 0.402998, 0.410702, 0.411613, 0.417109, 0.418157, 0.420828, 0.427461, 0.44545, 0.447043, 0.459765, 0.465905
# elapsed time for k point: 7.8696393966674805
# solve_kpoint (0.285714,1,0):
# Solving for bands 1 to 9...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6981203261187169 (2.54535% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6969542156808909 (0.167175% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6967177036501594 (0.0339408% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6966205092891327 (0.0139513% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.69658912293269 (0.00450562% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6965635083418589 (0.00367721% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6965556785588258 (0.00112407% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6965516445205819 (0.000579142% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6965506140454735 (0.00014794% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6965501819098684 (6.20394e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6965499164163936 (3.81155e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.6965498043036402 (1.60954e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.6965497739286323 (4.36078e-06% change)
# Finished solving for bands 1 to 9 after 13 iterations.
# Solving for bands 10 to 18...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.266127840049103 (1.09168% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 1.263799117566066 (0.184094% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.263421480676885 (0.0298856% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.263223470338487 (0.0156738% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.263162191939093 (0.00485107% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.263095829934153 (0.00525378% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.263032811274129 (0.00498935% change)
#     large trace change predicted (0.0114879%)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.262888624657353 (0.0114166% change)
#     large trace change predicted (0.0284532%)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.262560318689648 (0.0259998% change)
#     large trace change predicted (0.080245%)
#     linmin: converged after 5 iterations.
#     iteration   10: trace = 1.261899665390193 (0.0523402% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.261457340928914 (0.0350584% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.261080104606568 (0.0299093% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.260655752473643 (0.0336556% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.260066114889329 (0.0467832% change)
#     linmin: converged after 5 iterations.
#     iteration   15: trace = 1.259236601838448 (0.0658526% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 1.258195778149128 (0.0826893% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 1.25751149580847 (0.0544008% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 1.257050075569781 (0.0366999% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 1.256814441237457 (0.0187468% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 1.256643682921437 (0.0135875% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 1.256489441620591 (0.0122748% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 1.256373220039495 (0.00925013% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 1.256246667786726 (0.0100733% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 1.256142433971565 (0.00829759% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 1.256059509825858 (0.00660171% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 1.255986724738254 (0.00579488% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 1.255942612170684 (0.00351225% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 1.255901481945972 (0.0032749% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 1.255864326762754 (0.00295849% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 1.255828622941937 (0.00284301% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 1.255794788416726 (0.00269424% change)
# ...
#     iteration   36: trace = 1.767776920722931 (0.0338722% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 1.767170126507055 (0.0343312% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 1.766528705906628 (0.0363031% change)
#     linmin: converged after 4 iterations.
#     iteration   39: trace = 1.766004840271516 (0.0296595% change)
#     linmin: converged after 4 iterations.
#     iteration   40: trace = 1.765613110342575 (0.0221842% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 1.765334700436418 (0.0157697% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 1.765120819800941 (0.0121163% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 1.764936143449284 (0.0104631% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 1.764814062392385 (0.00691726% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 1.764729940600251 (0.00476672% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 1.764660099506299 (0.00395769% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 1.764589911839563 (0.00397748% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 1.76452215135923 (0.00384009% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 1.764461775967048 (0.00342169% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 1.764408776701432 (0.00300375% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 1.764363120613931 (0.00258765% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 1.764327960600821 (0.00199281% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 1.764306294867646 (0.001228% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 1.764291927368566 (0.000814346% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 1.76428329009267 (0.000489562% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 1.764276334557397 (0.000394242% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 1.764270030979994 (0.00035729% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 1.76426372534588 (0.000357408% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 1.764258866728281 (0.000275391% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 1.764255076675824 (0.000214824% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 1.764251776222056 (0.000187074% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 1.764249445803703 (0.000132091% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 1.764247991638675 (8.2424e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   64: trace = 1.764247210727142 (4.42631e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   65: trace = 1.764246424892714 (4.45422e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 1.764245679087906 (4.22733e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 1.764244933589513 (4.22559e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 1.764244329482436 (3.42417e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 1.764243684653302 (3.65499e-05% change)
#     resetting CG direction...
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 1.764242961239572 (4.10042e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 1.764242494759577 (2.64408e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 1.76424241774762 (4.36516e-06% change)
# Finished solving for bands 10 to 18 after 72 iterations.
# Solving for bands 19 to 27...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.79703037209427 (3.79398% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.747567137312191 (1.7842% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 2.686923651277166 (2.2318% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 2.603986302140334 (3.13509% change)
#     linmin: converged after 6 iterations.
#     iteration    5: trace = 2.536372799759519 (2.63069% change)
#     linmin: converged after 6 iterations.
#     iteration    6: trace = 2.488481069310142 (1.90619% change)
#     linmin: converged after 5 iterations.
#     iteration    7: trace = 2.454715218860059 (1.36615% change)
#     linmin: converged after 5 iterations.
#     iteration    8: trace = 2.434640330896116 (0.821167% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.424103220520164 (0.433738% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.414348092095509 (0.403234% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.405355803198362 (0.373147% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.396613491869078 (0.364114% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.387040427662258 (0.400241% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 2.379245395898401 (0.32709% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 2.37207746267527 (0.301724% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 2.368144814920957 (0.165927% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 2.365630700441608 (0.10622% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 2.363939411978439 (0.0715198% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 2.363062147188141 (0.0371172% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 2.362488776830071 (0.0242668% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 2.362140224082791 (0.0147547% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 2.361889064320308 (0.0106333% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 2.361706439193402 (0.00773246% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 2.361582990802799 (0.00522722% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 2.36145409708669 (0.00545809% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 2.361327939375319 (0.00534252% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 2.361210790289566 (0.00496128% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 2.36109479488642 (0.00491266% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 2.360990288232405 (0.00442629% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 2.360902735988321 (0.00370835% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 2.360839736121552 (0.0026685% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 2.36078581994009 (0.0022838% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 2.360740278112627 (0.00192911% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 2.360704082080785 (0.00153326% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 2.360672600096315 (0.00133359% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 2.360639612872857 (0.00139738% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 2.36059867697861 (0.00173412% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 2.360558423692539 (0.00170523% change)
#     linmin: converged after 4 iterations.
#     iteration   39: trace = 2.360520233188563 (0.00161787% change)
#     linmin: converged after 4 iterations.
#     iteration   40: trace = 2.360481833978749 (0.00162674% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 2.360452003433011 (0.00126376% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 2.360424456263105 (0.00116704% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 2.360402063630919 (0.000948674% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 2.360387271118317 (0.000626697% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 2.360376630236854 (0.000450812% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 2.360369792358207 (0.000289695% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 2.3603646905535 (0.000216145% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 2.36036026572568 (0.000187464% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 2.360356642116629 (0.000153519% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 2.360353256857586 (0.000143422% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 2.360350356689517 (0.00012287% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 2.360347446235799 (0.000123306% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 2.360344062606215 (0.000143353% change)
#     linmin: converged after 2 iterations.
#     iteration   54: trace = 2.360340126836308 (0.000166746% change)
#     linmin: converged after 2 iterations.
#     iteration   55: trace = 2.360335567392635 (0.000193169% change)
#     linmin: converged after 2 iterations.
#     iteration   56: trace = 2.360331377154971 (0.000177527% change)
#     linmin: converged after 2 iterations.
#     iteration   57: trace = 2.360328212864929 (0.000134061% change)
#     linmin: converged after 2 iterations.
#     iteration   58: trace = 2.360325587976642 (0.000111209% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 2.360323443544569 (9.08533e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 2.360321626503499 (7.69827e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 2.360320095625918 (6.48589e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   62: trace = 2.360318749221372 (5.70433e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   63: trace = 2.360317487580244 (5.34522e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   64: trace = 2.360316326330649 (4.91989e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   65: trace = 2.360315279849035 (4.43365e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 2.360314348309449 (3.94668e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 2.360313623778265 (3.06964e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 2.360313082786538 (2.29203e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 2.360312700373088 (1.62018e-05% change)
#     resetting CG direction...
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 2.360312588908977 (4.72243e-06% change)
# Finished solving for bands 19 to 27 after 70 iterations.
# Finished k-point with 93.6667 mean iterations/band.
# zoddfreqs:, 8, 0.5, 1.75, 0, 0.5, 0.315805, 0.316881, 0.318422, 0.320355, 0.321973, 0.323259, 0.346611, 0.367569, 0.368674, 0.370296, 0.371823, 0.373589, 0.374737, 0.488821, 0.490596, 0.491797, 0.493528, 0.493771, 0.496329, 0.497221, 0.497597, 0.502319, 0.504484, 0.516422, 0.518782, 0.536287, 0.537476
# elapsed time for k point: 37.607287883758545
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3158053718791236 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 2 range: 0.12220775623762363 at Vector3<0.0, 0.0, 0.0> to 0.31688083275767054 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 3 range: 0.12644488381959978 at Vector3<0.0, 0.0, 0.0> to 0.3184220925306114 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 4 range: 0.1876171271588143 at Vector3<0.0, 0.0, 0.0> to 0.3220542832230255 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 5 range: 0.1878763291412388 at Vector3<0.0, 0.0, 0.0> to 0.32608294646450636 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 6 range: 0.22425264113418666 at Vector3<0.0, 0.0, 0.0> to 0.33163116333442233 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 7 range: 0.224924316457588 at Vector3<0.0, 0.0, 0.0> to 0.3466107673897147 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 8 range: 0.23360224679322975 at Vector3<0.0, 0.0, 0.0> to 0.3675692245223977 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 9 range: 0.24260739982427748 at Vector3<0.0, 0.0, 0.0> to 0.36867401326056265 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 10 range: 0.24280962289484054 at Vector3<0.0, 0.0, 0.0> to 0.3702964903882974 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 11 range: 0.24368431367835044 at Vector3<0.0, 0.0, 0.0> to 0.37354265799357916 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 12 range: 0.299843037475378 at Vector3<0.0, 0.0, 0.0> to 0.3780184389971942 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 13 range: 0.3031366346541765 at Vector3<0.0, 0.0, 0.0> to 0.3816705858987252 at Vector3<0.3571428571428573, 1.2500000000000002, 0.0>
# Band 14 range: 0.3114975791429868 at Vector3<0.0, 0.0, 0.0> to 0.4888205461421807 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 15 range: 0.33162130898755565 at Vector3<0.0, 0.0, 0.0> to 0.4905962988714817 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 16 range: 0.3596441366365064 at Vector3<0.0, 0.0, 0.0> to 0.49179668654385544 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 17 range: 0.3608704053232207 at Vector3<0.0, 0.0, 0.0> to 0.49352812712644856 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 18 range: 0.3644662557952345 at Vector3<0.0, 0.0, 0.0> to 0.49377121293957804 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 19 range: 0.37122702441015243 at Vector3<0.0, 0.0, 0.0> to 0.4963291059866434 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 20 range: 0.3722051986605207 at Vector3<0.0, 0.0, 0.0> to 0.4972207682932132 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 21 range: 0.3895348810206308 at Vector3<0.0, 0.0, 0.0> to 0.49759697229503824 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 22 range: 0.39261328381698274 at Vector3<0.0, 0.0, 0.0> to 0.5023191481650867 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 23 range: 0.3971090580765883 at Vector3<0.0, 0.0, 0.0> to 0.5044841681458985 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 24 range: 0.39991448365257043 at Vector3<0.0, 0.0, 0.0> to 0.526548010569461 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 25 range: 0.403505943625657 at Vector3<0.0, 0.0, 0.0> to 0.5279459389847703 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# Band 26 range: 0.43995356727901147 at Vector3<0.0, 0.0, 0.0> to 0.5362869266104026 at Vector3<0.5000000000000002, 1.7500000000000004, 0.0>
# Band 27 range: 0.44269293546544375 at Vector3<0.0, 0.0, 0.0> to 0.5412953434592751 at Vector3<0.4285714285714288, 1.5000000000000004, 0.0>
# total elapsed time for run: 149.34646463394165
# done

# %%
import matplotlib.pyplot as plt
numk,tmp=np.shape(tm_freqs)
klist=np.linspace(0,0.5,numk)
fig,ax=plt.subplots()
x = range(len(tm_freqs))
ratio=len(tm_freqs)
for l in range(num_bands):
    plt.plot(klist,tm_freqs[:,l],'b-')
plt.plot(klist,klist,'r-')
plt.ylim([0,0.65])
plt.ylabel('$\omega a/(2\pi c)$')

# %% [markdown]
# 可以看到，与最右边的图是一样的

# %% [markdown]
# ## 3D hole defect
#
# Now we change the rods into holes

# %%
from meep import mpb
import numpy as np
import meep as mp
import matplotlib.pyplot as plt
#from mayavi import mlab

import math

import meep as mp
from meep import mpb

# A line_defect waveguide in a 3d triangular lattice of dielectric
# rods (c.f. tri_rods.ctl), formed by a row of missing rods along the
# "x" direction.  (Here, "x" and "y" refer to the first and second
# basis directions.)  This structure supports a single guided band
# within the band gap, much like the analogous waveguide in a square
# lattice of rods (see "Photonic Crystals" by Joannopoulos et al.).

supercell_y = 7  # the (odd) number of lateral supercell periods

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, supercell_y,3),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)
a=1
r = 0.35  # the rod radius in the bulk crystal
h=0.3

Si = mp.Medium(index=2.1376)

geometry = [ mp.Block(material=Si,size=(a,a,h),
                      center=mp.Vector3(),
                      e1=mp.cartesian_to_lattice(mp.Vector3(1,0,0),geometry_lattice),
                      e2=mp.cartesian_to_lattice(mp.Vector3(0,1,0),geometry_lattice),
                      e3=mp.cartesian_to_lattice(mp.Vector3(0,0,1),geometry_lattice),),
             mp.Cylinder(center=mp.Vector3(),radius=r, height=h, material=mp.air)]

# duplicate the bulk crystal rods over the supercell:
geometry = mp.geometric_objects_lattice_duplicates(geometry_lattice, geometry)

# add a rod of Si, to erase a row of rods and form a waveguide:
geometry += [mp.Cylinder(center=mp.Vector3(),radius=r, height=h, material=Si)]


num_k = 12
k_points = mp.interpolate(num_k, [mp.Vector3(0,0,),mp.Vector3(0.5,0)])

# the bigger the supercell, the more bands you need to compute to get
# to the defect modes (the lowest band is "folded" supercell_y times):
extra_bands = 30  # number of extra bands to compute above the gap
num_bands = supercell_y + extra_bands

resolution = 22

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    geometry=geometry,
    k_points=k_points,
    num_bands=num_bands,
    resolution=resolution,
)
ms.run_te()
te_freqs = ms.all_freqs
# Out:
# Initializing eigensolver data
# Computing 37 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 24 x 160 x 70.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (6.06218, -3.5, 0)
#      (0, 0, 3)
# Cell volume = 18.1865
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.0824786, -0.142857, 0)
#      (-0, 0, 0.333333)
# Geometric objects:
#      block, center = (0,3,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,2,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,1,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,0,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-1,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-2,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-3,1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,3,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,2,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,1,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,0,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-1,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-2,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-3,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,3,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,2,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,1,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,0,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-1,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-2,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-3,-1)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      cylinder, center = (0,3,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,2,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,1,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,0,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-1,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-2,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-3,1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,3,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,2,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,1,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-1,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-2,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-3,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,3,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,2,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,1,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,0,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-1,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-2,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-3,-1)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
# Geometric object tree has depth 7 and 424 object nodes (vs. 43 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 8 k-points
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.4142857142857143, 0.0, 0.0>
#   Vector3<0.4285714285714286, 0.0, 0.0>
#   Vector3<0.44285714285714284, 0.0, 0.0>
#   Vector3<0.45714285714285713, 0.0, 0.0>
#   Vector3<0.4714285714285714, 0.0, 0.0>
#   Vector3<0.4857142857142857, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.7025196552276611
# solve_kpoint (0.4,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4, zeven band 5, zeven band 6, zeven band 7, zeven band 8, zeven band 9, zeven band 10, zeven band 11, zeven band 12, zeven band 13, zeven band 14, zeven band 15, zeven band 16, zeven band 17, zeven band 18, zeven band 19, zeven band 20, zeven band 21, zeven band 22, zeven band 23, zeven band 24, zeven band 25, zeven band 26, zeven band 27, zeven band 28, zeven band 29, zeven band 30, zeven band 31, zeven band 32, zeven band 33, zeven band 34, zeven band 35, zeven band 36, zeven band 37
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 20.80520629390541 (194.392% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 2.216657002710922 (161.486% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 1.707538560839079 (25.9477% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 1.592144475127294 (6.99425% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 1.554556590804611 (2.38903% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.538394693103223 (1.04508% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.529813199744425 (0.559381% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.525084289356601 (0.309595% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.52250990178537 (0.168946% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.521300461280514 (0.0794688% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.520733288559283 (0.037289% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 1.520413320407904 (0.0210426% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.520223937554024 (0.0124568% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.52011692020433 (0.00703983% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.52005249431133 (0.00423831% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 1.520012735390964 (0.00261566% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 1.519988022231681 (0.00162587% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 1.519975417280769 (0.000829283% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.519968623629299 (0.000446959% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.519965119225322 (0.000230558% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.519963528623426 (0.000104647% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.519962813313632 (4.7061e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.519962407178153 (2.67201e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.519962199453536 (1.36664e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.519962113494314 (5.65535e-06% change)
# Finished solving for bands 1 to 10 after 25 iterations.
# Solving for bands 11 to 20...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 28.47065855288733 (192.362% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 3.501030438314159 (156.198% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 2.679962939233526 (26.5675% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 2.460415901912052 (8.54206% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.36644990176996 (3.89346% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.320808206576692 (1.94748% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.300638236741661 (0.872886% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 2.290710580356474 (0.432451% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.284157447247155 (0.286484% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.279564682636261 (0.201273% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 2.276243820776686 (0.145786% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 2.273909251699817 (0.102615% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 2.272398462730237 (0.0664622% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 2.271608077002505 (0.0347881% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 2.271232145270023 (0.0165505% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 2.271083728373865 (0.00653486% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 2.271027662689735 (0.00246871% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 2.271006969493027 (0.000911186% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.270997930839053 (0.000398003% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.270993715461492 (0.000185618% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.270992034464209 (7.40204e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.270991397945321 (2.80282e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 2.270991117174686 (1.23634e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 2.270990997699588 (5.26092e-06% change)
# Finished solving for bands 11 to 20 after 24 iterations.
# Solving for bands 21 to 30...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 33.01698086403734 (191.174% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 4.668139180847092 (150.451% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 3.683545740739649 (23.5783% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 3.420934510502738 (7.39283% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 3.302021388585227 (3.53752% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 3.241872577661915 (1.83832% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.209890260814475 (0.991429% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 3.193078030295268 (0.525139% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 3.184177398646491 (0.279137% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 3.178517324740296 (0.177914% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 3.174822677060328 (0.116306% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 3.172466822837164 (0.0742318% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 3.170917165603685 (0.048859% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 3.169811892842513 (0.0348626% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 3.168874873798341 (0.0295651% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 3.168055171745138 (0.0258706% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 3.167255652596006 (0.0252401% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 3.166504431966408 (0.0237212% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 3.165813654523407 (0.0218175% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 3.165224488336151 (0.018612% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 3.164764706276049 (0.0145271% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 3.164376768314913 (0.0122588% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 3.164060577599574 (0.00999269% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 3.16378651765504 (0.00866203% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 3.163587169604408 (0.00630113% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 3.163433405997657 (0.00486054% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 3.163315444000463 (0.00372899% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 3.163219124621624 (0.00304493% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 3.163138479737166 (0.00254949% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 3.163079988433831 (0.00184917% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 3.163036382183448 (0.00137861% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 3.163006462029213 (0.000945936% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 3.162984361536282 (0.00069872% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 3.162968718928657 (0.000494553% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 3.162957378788461 (0.000358529% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 3.162949376904183 (0.000252988% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 3.16294418670913 (0.000164094% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 3.162941208300933 (9.41657e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 3.162939608376754 (5.05834e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 3.162938698269201 (2.87741e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 3.162938190177283 (1.60639e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 3.162937908204854 (8.91489e-06% change)
# Finished solving for bands 21 to 30 after 42 iterations.
# Solving for bands 31 to 37...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 25.97779000484707 (190.167% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 3.867559534506262 (148.165% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 3.040057261986199 (23.9591% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 2.818577407396427 (7.5608% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 2.709004565656396 (3.96458% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 2.649267420893614 (2.22972% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.61709071752135 (1.22197% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.59824267740408 (0.722793% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.586874689217185 (0.438485% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.577091110166901 (0.378917% change)
#     linmin: converged after 5 iterations.
#     iteration   11: trace = 2.567709653662714 (0.364697% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.560463687671741 (0.282594% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.555777790207737 (0.183177% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 2.553076442610971 (0.105752% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 2.551461555930335 (0.0632726% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 2.550489155368604 (0.0381188% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 2.549832078929239 (0.0257661% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 2.549377613476928 (0.0178249% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 2.54903092900075 (0.0135997% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 2.548785918801483 (0.00961236% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 2.548624932448364 (0.0063164% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 2.548518617482209 (0.00417155% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 2.54845094741935 (0.00265531% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 2.548403734151048 (0.00185264% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 2.54837060965205 (0.00129982% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 2.548345184889765 (0.000997692% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 2.548325124605071 (0.000787192% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 2.548309716376605 (0.000604643% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 2.54829864028459 (0.000434646% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 2.5482906413149 (0.000313895% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 2.548285043828089 (0.000219657% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 2.548281624219217 (0.000134193% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 2.548279586168768 (7.99775e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 2.548278484334346 (4.32384e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 2.548277922338164 (2.2054e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 2.54827757336464 (1.36945e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 2.548277351571702 (8.70364e-06% change)
# Finished solving for bands 31 to 37 after 37 iterations.
# Finished k-point with 31.5946 mean iterations/band.
# zevenfreqs:, 1, 0.4, 0, 0, 0.46188, 0.318042, 0.327028, 0.359624, 0.371187, 0.390524, 0.404731, 0.418878, 0.425915, 0.427925, 0.434116, 0.444542, 0.451042, 0.456986, 0.463124, 0.467974, 0.475378, 0.491246, 0.492679, 0.504432, 0.512955, 0.532181, 0.536951, 0.550882, 0.554058, 0.561398, 0.565039, 0.574679, 0.578228, 0.582224, 0.5856, 0.589701, 0.593134, 0.598144, 0.608146, 0.609148, 0.611663, 0.613116
# elapsed time for k point: 206.5157744884491
# solve_kpoint (0.414286,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.566539459470976 (0.153753% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.565946849586441 (0.0378364% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.565751239506153 (0.0124923% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.565650630702662 (0.0064258% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.565588401920093 (0.00397471% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.565541882015044 (0.00297144% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.565514526435292 (0.00174737% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.56549860914775 (0.00101675% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.565488387677398 (0.000652923% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.565483288431681 (0.000325729% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.565479152442247 (0.000264199% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.565475168378436 (0.000254495% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.565471109465648 (0.000259277% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.565467837046243 (0.000209038% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.565465923357087 (0.000122244% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.565465041241512 (5.63485e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.565464562466627 (3.05836e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.565464236509116 (2.08218e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.565463986318912 (1.59819e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.565463774803096 (1.35114e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.565463618888161 (9.95966e-06% change)
# Finished solving for bands 1 to 10 after 21 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.293425078845222 (0.111009% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.292813581967804 (0.0266666% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 2.292702375336869 (0.00485034% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.292675944663058 (0.00115282% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.292664495419019 (0.000499385% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.292659344492446 (0.00022467% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.29265719578672 (9.37212e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.292656455207684 (3.23022e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.292656159093217 (1.29158e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.29265589598546 (1.14761e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.292655739794964 (6.81264e-06% change)
# Finished solving for bands 11 to 20 after 11 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.151425432457539 (0.0656554% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.150298849485892 (0.0357548% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.149504785626289 (0.0252092% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 3.149241370396589 (0.00836405% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 3.149140367259566 (0.00320727% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.149086232188281 (0.00171906% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.149043398555655 (0.0013602% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 3.149015116968854 (0.000898105% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 3.148998986902588 (0.000512227% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 3.148986088000708 (0.00040962% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 3.148978801642402 (0.000231388% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 3.148973466582808 (0.000169422% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 3.148968370287458 (0.00016184% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 3.148964486709141 (0.000123329% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 3.148961390529342 (9.83238e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 3.148958914308832 (7.86361e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 3.148956861104154 (6.52027e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 3.148955124121436 (5.51606e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 3.148953895919691 (3.90035e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 3.148952997020427 (2.8546e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 3.148952449973026 (1.73724e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 3.148952109738018 (1.08047e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 3.14895181652446 (9.31146e-06% change)
# Finished solving for bands 21 to 30 after 23 iterations.
# Solving for bands 31 to 37...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.512597731246295 (0.0483393% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.512243031944702 (0.0141178% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.51207690168041 (0.00661304% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.51198532111355 (0.00364568% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.511935342503352 (0.00198963% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.511912368184878 (0.00091461% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.511901514397651 (0.000432094% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.511895227613546 (0.00025028% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.51189219139148 (0.000120874% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.511890132499894 (8.19658e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.511888454306745 (6.681e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.511887548055015 (3.60785e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.511887135512059 (1.64236e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.5118868015448 (1.32955e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.511886571297764 (9.1663e-06% change)
# Finished solving for bands 31 to 37 after 15 iterations.
# Finished k-point with 17.7027 mean iterations/band.
# zevenfreqs:, 2, 0.414286, 0, 0, 0.478376, 0.328162, 0.336748, 0.370049, 0.376557, 0.397055, 0.411456, 0.423929, 0.427131, 0.432263, 0.435529, 0.439497, 0.460527, 0.461725, 0.465817, 0.468968, 0.474313, 0.489026, 0.502192, 0.508211, 0.512553, 0.528576, 0.532346, 0.548278, 0.552441, 0.561297, 0.57026, 0.573984, 0.578691, 0.580137, 0.582422, 0.585418, 0.593427, 0.594975, 0.599865, 0.603153, 0.604648, 0.611384
# elapsed time for k point: 112.54313158988953
# solve_kpoint (0.428571,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.608598134271519 (0.172922% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.607886128709923 (0.0442723% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.60763795372568 (0.0154361% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.607453395904644 (0.0114807% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.60727307139165 (0.0112187% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.607030257720359 (0.0151083% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.606763663847545 (0.0165906% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.606444457343486 (0.0198684% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.605954066821031 (0.0305311% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 1.605436543309722 (0.0322305% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.604921331290806 (0.0320969% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.60461514171517 (0.01908% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 1.604468942399019 (0.00911159% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 1.604403441268458 (0.0040825% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.604373801449374 (0.00184742% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.604362921910261 (0.00067812% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.60435651950323 (0.000399063% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.604352398990474 (0.000256833% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.604349063434277 (0.000207907% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.604345865574028 (0.000199325% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.604342916959183 (0.000183789% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.604340779694537 (0.000133218% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.604338899223158 (0.000117212% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.604335820715804 (0.000191887% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.604330199356518 (0.000350386% change)
#     large trace change predicted (0.000775229%)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 1.604317630927026 (0.00078341% change)
#     large trace change predicted (0.00192826%)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 1.604287074219309 (0.00190467% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 1.604240497162396 (0.00290333% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 1.60419904064048 (0.00258422% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 1.60415718248956 (0.00260932% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 1.604122710507023 (0.00214894% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 1.604106150683521 (0.00103233% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 1.604098396223361 (0.000483414% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 1.604094279503601 (0.000256638% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 1.604091395212992 (0.000179808% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 1.604089564754423 (0.000114112% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 1.604088505380781 (6.60421e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 1.604087647100449 (5.35058e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 1.604086802882269 (5.26292e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 1.60408602213344 (4.86725e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 1.604085502357573 (3.24032e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 1.604085137611702 (2.27386e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 1.60408486340305 (1.70944e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   44: trace = 1.604084685771246 (1.10737e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 1.604084604050355 (5.09455e-06% change)
# Finished solving for bands 1 to 10 after 45 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 2.322322686164091 (0.578162% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.319377600746814 (0.126897% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.318986795619423 (0.016851% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.318920931518867 (0.00284025% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.318894370889066 (0.00114539% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.318878295534327 (0.000693236% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.318865373779932 (0.000557243% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.318858255232148 (0.000306985% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.31885488077532 (0.000145522% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.318852326289456 (0.000110162% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.318850464733776 (8.02792e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.318849279160138 (5.11277e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.318848503416328 (3.34538e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.318848093656052 (1.76709e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.318847976290821 (5.06136e-06% change)
# Finished solving for bands 11 to 20 after 15 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.136535611506928 (0.0787803% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.134722885695284 (0.0578106% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.133220056038605 (0.0479529% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 3.132642567029644 (0.0184329% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 3.132384612067068 (0.00823476% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 3.132257097103778 (0.00407094% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.132175812195335 (0.00259512% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 3.132138114146111 (0.00120358% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 3.132117025660471 (0.000673296% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 3.132092354496035 (0.000787686% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 3.132070377655458 (0.000701669% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 3.13204939561024 (0.000669912% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 3.132031730330672 (0.000564018% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 3.132019446374411 (0.000392205% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 3.132008269959737 (0.000356844% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 3.131997598534991 (0.000340722% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 3.131986679108236 (0.000348642% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 3.131974309629439 (0.000394941% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 3.131958200060024 (0.00051436% change)
#     large trace change predicted (0.00122037%)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 3.131919430595429 (0.00123787% change)
#     large trace change predicted (0.00311432%)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 3.131825016256549 (0.00301463% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 3.131687681009779 (0.00438525% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 3.13152656682428 (0.00514478% change)
#     linmin: converged after 5 iterations.
#     iteration   24: trace = 3.131318023542033 (0.0066597% change)
#     linmin: converged after 5 iterations.
#     iteration   25: trace = 3.131077373798782 (0.00768555% change)
#     linmin: converged after 5 iterations.
#     iteration   26: trace = 3.130835532748055 (0.00772419% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 3.130629635581575 (0.00657664% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 3.130496670490549 (0.00424732% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 3.130423338994314 (0.00234252% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 3.130372897883201 (0.00161133% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 3.130332819409211 (0.00128032% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 3.13030469197564 (0.000898549% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 3.1302839777072 (0.000661735% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 3.130270805659928 (0.000420795% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 3.130261807005504 (0.000287472% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 3.130254610397429 (0.000229905% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 3.130248526882993 (0.000194346% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 3.130243289142183 (0.000167327% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 3.13023840351469 (0.000156078% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 3.130233060793371 (0.000170681% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 3.130227688928537 (0.000171612% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 3.130223418553149 (0.000136424% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 3.130220099002964 (0.000106048% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 3.130217473102986 (8.38887e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 3.130215674929868 (5.74456e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 3.130214328184587 (4.30241e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 3.130213215901035 (3.55338e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 3.130212445222806 (2.46206e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 3.130211893169452 (1.76363e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 3.130211488116682 (1.29401e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 3.130211160368831 (1.04705e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 3.130210845557801 (1.00572e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 3.130210587063156 (8.25806e-06% change)
# Finished solving for bands 21 to 30 after 53 iterations.
# Solving for bands 31 to 37...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.491522250808223 (0.503366% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.489240088883238 (0.0916391% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.488662090831723 (0.0232226% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.488458254591606 (0.00819093% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.488331437384643 (0.00509635% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.488265331548966 (0.00265667% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.488237502849789 (0.0011184% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.488221065644487 (0.000660598% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.488210054106629 (0.000442548% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.488196233751015 (0.000555435% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 2.488174273936305 (0.000882563% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.488147506884683 (0.00107578% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.488124493562245 (0.000924922% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 2.48810535845371 (0.00076906% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 2.488090198309253 (0.000609307% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 2.488076507345913 (0.000550261% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 2.488064014403871 (0.000502114% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 2.488057928555341 (0.000244602% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.488055173841027 (0.000110718% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.488053873518815 (5.22626e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.488053138978528 (2.95227e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.488052631959224 (2.03782e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 2.488052303005656 (1.32213e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 2.488052080834212 (8.92953e-06% change)
# Finished solving for bands 31 to 37 after 24 iterations.
# Finished k-point with 35.0811 mean iterations/band.
# zevenfreqs:, 3, 0.428571, 0, 0, 0.494872, 0.337857, 0.346856, 0.378964, 0.383094, 0.403298, 0.418251, 0.422403, 0.427615, 0.434107, 0.438112, 0.438512, 0.458222, 0.466696, 0.472856, 0.473078, 0.475815, 0.486677, 0.503175, 0.51698, 0.517378, 0.525366, 0.527374, 0.545216, 0.550684, 0.562667, 0.564463, 0.575463, 0.578859, 0.580446, 0.58069, 0.58228, 0.59106, 0.591688, 0.596029, 0.598841, 0.600407, 0.612542
# elapsed time for k point: 230.4565200805664
# solve_kpoint (0.442857,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.635759385389555 (0.189473% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.635018068307414 (0.0453297% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.634787610377154 (0.0140961% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.634628484684119 (0.0097342% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.6345077751802 (0.00738479% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.634397966556078 (0.00671837% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.634308105544006 (0.00549826% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.634214781117046 (0.0057105% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 1.634049901047576 (0.0100898% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.633812541868917 (0.0145269% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.633526531404589 (0.0175072% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.633335029290012 (0.0117239% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 1.633237354397318 (0.00598027% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 1.633191607786868 (0.00280102% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.633161112955934 (0.00186721% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.63314700609363 (0.00086378% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.63313954882854 (0.00045662% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.633136441350924 (0.000190276% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.633135203379459 (7.58033e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.633134603723225 (3.67181e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.633134274496667 (2.01592e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.633134043750363 (1.4129e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.633133924854496 (7.28023e-06% change)
# Finished solving for bands 1 to 10 after 23 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.352481669853244 (0.127149% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.351702899860023 (0.0331097% change)
#     linmin: converged after 4 iterations.
# ...
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 2.396860533853129 (0.0376122% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.395714432117976 (0.0478282% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.394430827430839 (0.0535936% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.393259903027158 (0.048914% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 2.392275245158046 (0.0411514% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 2.391508688042439 (0.0320481% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 2.39102295664855 (0.0203127% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 2.390640967226067 (0.0159773% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 2.390353417711283 (0.0120289% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 2.39015537903562 (0.00828526% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 2.390039844870604 (0.00483387% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 2.389969728834791 (0.00293372% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 2.389919525445616 (0.00210061% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.389894807496946 (0.00103426% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.38988453668129 (0.000429761% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.389878798194352 (0.000240116% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 2.38987461332355 (0.000175108% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 2.389872737375374 (7.84957e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 2.389871775238376 (4.02589e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 2.38987112226232 (2.73226e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 2.389870650444144 (1.97424e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 2.38987028605611 (1.52472e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 2.389870055349159 (9.65353e-06% change)
# Finished solving for bands 11 to 20 after 29 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.053667656451136 (0.234087% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.051543782390266 (0.0695758% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.050333483220541 (0.0396697% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 3.049296990003232 (0.0339854% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 3.048592717863151 (0.0230989% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 3.048128862946166 (0.0152165% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.047871369028454 (0.00844796% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 3.047774294301301 (0.00318505% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 3.047723987902397 (0.00165061% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 3.047687229765727 (0.00120609% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 3.04766439488484 (0.000749256% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 3.0476394543612 (0.000818352% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 3.047615963220538 (0.000770801% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 3.047588142151306 (0.000912884% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 3.047532506475955 (0.00182558% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 3.04747582386429 (0.00185997% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 3.047425363152284 (0.00165583% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 3.047384646134821 (0.00133612% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 3.047355732388632 (0.00094881% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 3.047331869385168 (0.000783076% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 3.047306903946818 (0.000819259% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 3.047283288094635 (0.000774978% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 3.047270680111406 (0.000413746% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 3.047262450279366 (0.000270073% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 3.047256067912442 (0.000209446% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 3.047251266022459 (0.000157581% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 3.047247937648365 (0.000109226% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 3.047246223757859 (5.62439e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 3.047244957507897 (4.15539e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 3.04724393969367 (3.34011e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 3.047243419394086 (1.70744e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 3.047243159983971 (8.51294e-06% change)
# Finished solving for bands 21 to 30 after 32 iterations.
# Solving for bands 31 to 37...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.469848931394258 (0.0528458% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.469145595042606 (0.028481% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 2.468298035704725 (0.0343319% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 2.467139948405906 (0.0469295% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.466199391994408 (0.0381306% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 2.465707927915672 (0.01993% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 2.465337971298329 (0.0150052% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 2.465054999807117 (0.0114787% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 2.464918111279281 (0.00555332% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 2.464858563351931 (0.00241585% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.464821707620801 (0.00149526% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 2.46478786396775 (0.00137308% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 2.464753994966015 (0.00137412% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.464715416241707 (0.00156523% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.464678227777114 (0.00150885% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 2.464645059251676 (0.00134576% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 2.464620955447669 (0.000977988% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 2.464606871808383 (0.000571434% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 2.464594933890739 (0.000484375% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 2.464580544245921 (0.000583856% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 2.464562503257953 (0.000732013% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 2.464542865459868 (0.00079681% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 2.464518447441444 (0.000990778% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 2.464489513716339 (0.00117402% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 2.464467033127387 (0.000912185% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 2.464456795898813 (0.000415394% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 2.464449802257884 (0.000283781% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 2.464440998280244 (0.00035724% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 2.464429206744127 (0.000478468% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 2.464415339527974 (0.000562696% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 2.46440209385439 (0.000537479% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 2.464392623339231 (0.000384293% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 2.464387008691702 (0.000227831% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 2.464384076643594 (0.000118977% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 2.464382470057706 (6.51922e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 2.464381292387181 (4.77877e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 2.464380454839364 (3.39861e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 2.464379895741081 (2.26872e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 2.46437939594208 (2.02809e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 2.464378887727932 (2.06224e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 2.464378528419116 (1.45801e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 2.464378296903569 (9.39448e-06% change)
# Finished solving for bands 31 to 37 after 42 iterations.
# Finished k-point with 30.9189 mean iterations/band.
# zevenfreqs:, 8, 0.5, 0, 0, 0.57735, 0.377483, 0.389101, 0.397696, 0.397818, 0.406968, 0.409337, 0.414538, 0.429444, 0.439568, 0.449361, 0.453278, 0.454333, 0.458004, 0.458746, 0.481717, 0.493987, 0.516768, 0.519522, 0.519663, 0.524118, 0.529919, 0.530514, 0.542077, 0.542259, 0.549043, 0.549324, 0.557147, 0.569752, 0.570091, 0.5778, 0.579114, 0.583217, 0.583956, 0.587156, 0.605027, 0.605132, 0.608987
# elapsed time for k point: 188.55883955955505
# Band 1 range: 0.318042408931343 at Vector3<0.4, 0.0, 0.0> to 0.3774830119817022 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.3270276467527297 at Vector3<0.4, 0.0, 0.0> to 0.38910094994475125 at Vector3<0.5, 0.0, 0.0>
# Band 3 range: 0.3596235335320783 at Vector3<0.4, 0.0, 0.0> to 0.3976963148329859 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.3711873296270657 at Vector3<0.4, 0.0, 0.0> to 0.4025886241562323 at Vector3<0.4857142857142857, 0.0, 0.0>
# Band 5 range: 0.3905239192257506 at Vector3<0.4, 0.0, 0.0> to 0.40831693978121086 at Vector3<0.44285714285714284, 0.0, 0.0>
# Band 6 range: 0.404730822129725 at Vector3<0.4, 0.0, 0.0> to 0.418632629506531 at Vector3<0.45714285714285713, 0.0, 0.0>
# Band 7 range: 0.41369121374355083 at Vector3<0.4857142857142857, 0.0, 0.0> to 0.42428594320936747 at Vector3<0.44285714285714284, 0.0, 0.0>
# Band 8 range: 0.4229075624042789 at Vector3<0.45714285714285713, 0.0, 0.0> to 0.42944360671808757 at Vector3<0.5, 0.0, 0.0>
# Band 9 range: 0.42792450071849136 at Vector3<0.4, 0.0, 0.0> to 0.4416329321295893 at Vector3<0.4857142857142857, 0.0, 0.0>
# Band 10 range: 0.43411625454232156 at Vector3<0.4, 0.0, 0.0> to 0.4493612879162964 at Vector3<0.5, 0.0, 0.0>
# Band 11 range: 0.43851155234466654 at Vector3<0.4285714285714286, 0.0, 0.0> to 0.45327770501681813 at Vector3<0.5, 0.0, 0.0>
# Band 12 range: 0.4510419493497435 at Vector3<0.4, 0.0, 0.0> to 0.46052711404549246 at Vector3<0.4142857142857143, 0.0, 0.0>
# Band 13 range: 0.4569860474195143 at Vector3<0.4, 0.0, 0.0> to 0.46669550762546375 at Vector3<0.4285714285714286, 0.0, 0.0>
# Band 14 range: 0.458746047670684 at Vector3<0.5, 0.0, 0.0> to 0.4728561520370441 at Vector3<0.4285714285714286, 0.0, 0.0>
# Band 15 range: 0.46797448024132143 at Vector3<0.4, 0.0, 0.0> to 0.48382424185693435 at Vector3<0.45714285714285713, 0.0, 0.0>
# Band 16 range: 0.4743125420415993 at Vector3<0.4142857142857143, 0.0, 0.0> to 0.49429706649825683 at Vector3<0.4857142857142857, 0.0, 0.0>
# Band 17 range: 0.48654205738441836 at Vector3<0.44285714285714284, 0.0, 0.0> to 0.5167679147166041 at Vector3<0.5, 0.0, 0.0>
# Band 18 range: 0.49267905214697594 at Vector3<0.4, 0.0, 0.0> to 0.5195223276005078 at Vector3<0.5, 0.0, 0.0>
# Band 19 range: 0.5044320233476783 at Vector3<0.4, 0.0, 0.0> to 0.5219327535083207 at Vector3<0.44285714285714284, 0.0, 0.0>
# Band 20 range: 0.5125533594413648 at Vector3<0.4142857142857143, 0.0, 0.0> to 0.5241175420651415 at Vector3<0.5, 0.0, 0.0>
# Band 21 range: 0.5235853595046728 at Vector3<0.44285714285714284, 0.0, 0.0> to 0.5355689912228115 at Vector3<0.4714285714285714, 0.0, 0.0>
# Band 22 range: 0.5273735209612775 at Vector3<0.4285714285714286, 0.0, 0.0> to 0.5400433901544195 at Vector3<0.4857142857142857, 0.0, 0.0>
# Band 23 range: 0.5403520295411715 at Vector3<0.4714285714285714, 0.0, 0.0> to 0.5508817287175211 at Vector3<0.4, 0.0, 0.0>
# Band 24 range: 0.5421706969808417 at Vector3<0.4857142857142857, 0.0, 0.0> to 0.554057543243247 at Vector3<0.4, 0.0, 0.0>
# Band 25 range: 0.5447847433611036 at Vector3<0.4857142857142857, 0.0, 0.0> to 0.5626669044005552 at Vector3<0.4285714285714286, 0.0, 0.0>
# Band 26 range: 0.5493236221510271 at Vector3<0.5, 0.0, 0.0> to 0.5702600859863343 at Vector3<0.4142857142857143, 0.0, 0.0>
# Band 27 range: 0.5571474427527393 at Vector3<0.5, 0.0, 0.0> to 0.5754625776647624 at Vector3<0.4285714285714286, 0.0, 0.0>
# Band 28 range: 0.5632285462909493 at Vector3<0.4857142857142857, 0.0, 0.0> to 0.5788587187165846 at Vector3<0.4285714285714286, 0.0, 0.0>
# Band 29 range: 0.56900774659942 at Vector3<0.4714285714285714, 0.0, 0.0> to 0.5822242615270169 at Vector3<0.4, 0.0, 0.0>
# Band 30 range: 0.5764779243442832 at Vector3<0.4714285714285714, 0.0, 0.0> to 0.5856000896436562 at Vector3<0.4, 0.0, 0.0>
# Band 31 range: 0.5791138531863285 at Vector3<0.5, 0.0, 0.0> to 0.5897011412929366 at Vector3<0.4, 0.0, 0.0>
# Band 32 range: 0.5814552449879127 at Vector3<0.4857142857142857, 0.0, 0.0> to 0.5934270817938744 at Vector3<0.4142857142857143, 0.0, 0.0>
# Band 33 range: 0.5839555472211996 at Vector3<0.5, 0.0, 0.0> to 0.5981444419014373 at Vector3<0.4, 0.0, 0.0>
# Band 34 range: 0.5871557527315724 at Vector3<0.5, 0.0, 0.0> to 0.6081458329363809 at Vector3<0.4, 0.0, 0.0>
# Band 35 range: 0.5988405573579028 at Vector3<0.4285714285714286, 0.0, 0.0> to 0.6091476076426512 at Vector3<0.4, 0.0, 0.0>
# Band 36 range: 0.6004074734781406 at Vector3<0.4285714285714286, 0.0, 0.0> to 0.6116630746846136 at Vector3<0.4, 0.0, 0.0>
# Band 37 range: 0.6036884538954559 at Vector3<0.4714285714285714, 0.0, 0.0> to 0.6131163051259017 at Vector3<0.4, 0.0, 0.0>
# Gap from band 22 (0.5400433901544195) to band 23 (0.5403520295411715), 0.05713452336532944%
# total elapsed time for run: 1378.4798488616943
# done

# %%
import matplotlib.pyplot as plt
numk,tmp=np.shape(te_freqs)
klist=np.linspace(0.4,0.5,numk)
fig,ax=plt.subplots()
x = range(len(te_freqs))
ratio=len(te_freqs)
for l in range(num_bands):
    plt.plot(klist,te_freqs[:,l],'b-')
plt.plot(klist,klist,'r-')
plt.ylim([0.3,0.55])
plt.grid()
plt.ylabel('$\omega a/(2\pi c)$')
# Out:
# Text(0, 0.5, '$\\omega a/(2\\pi c)$')

# %% [markdown]
# 修改一下计算的区域大小

# %%
from meep import mpb
import numpy as np
import meep as mp
import matplotlib.pyplot as plt
#from mayavi import mlab

import math

import meep as mp
from meep import mpb

# A line_defect waveguide in a 3d triangular lattice of dielectric
# rods (c.f. tri_rods.ctl), formed by a row of missing rods along the
# "x" direction.  (Here, "x" and "y" refer to the first and second
# basis directions.)  This structure supports a single guided band
# within the band gap, much like the analogous waveguide in a square
# lattice of rods (see "Photonic Crystals" by Joannopoulos et al.).

supercell_y = 9  # the (odd) number of lateral supercell periods

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, supercell_y,5),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)
geometry_lattice_copy = mp.Lattice(
    size=mp.Vector3(1, supercell_y,0),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)
a=1
r = 0.35  # the rod radius in the bulk crystal
h=0.3

Si = mp.Medium(index=2.1376)

geometry = [ mp.Block(material=Si,size=(a,a,h),
                      center=mp.Vector3(),
                      e1=mp.cartesian_to_lattice(mp.Vector3(1,0,0),geometry_lattice),
                      e2=mp.cartesian_to_lattice(mp.Vector3(0,1,0),geometry_lattice),
                      e3=mp.cartesian_to_lattice(mp.Vector3(0,0,1),geometry_lattice),),
             mp.Cylinder(center=mp.Vector3(),radius=r, height=h, material=mp.air)]

# duplicate the bulk crystal rods over the supercell:
geometry = mp.geometric_objects_lattice_duplicates(geometry_lattice_copy, geometry)

# add a rod of Si, to erase a row of rods and form a waveguide:
geometry += [mp.Cylinder(center=mp.Vector3(),radius=r, height=h, material=Si)]


num_k = 11
k_points = mp.interpolate(num_k, [mp.Vector3(0.4,0,),mp.Vector3(0.5,0)])

# the bigger the supercell, the more bands you need to compute to get
# to the defect modes (the lowest band is "folded" supercell_y times):
extra_bands = 20+super_cell  # number of extra bands to compute above the gap
num_bands = extra_bands+supercell_y

resolution = 30

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    geometry=geometry,
    k_points=k_points,
    num_bands=num_bands,
    resolution=resolution,
)
ms.run_te()
te_freqs = ms.all_freqs
# Out:
# Initializing eigensolver data
# Computing 1 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 30 x 270 x 150.
# Solving for 1 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (7.79423, -4.5, 0)
#      (0, 0, 5)
# Cell volume = 38.9711
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.06415, -0.111111, 0)
#      (-0, 0, 0.2)
# Geometric objects:
#      block, center = (0,4,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,3,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,2,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,1,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,0,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-1,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-2,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-3,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      block, center = (0,-4,0)
#           size (1,1,0.3)
#           axes (0.57735,0.57735,0), (1,-1,0), (0,0,1)
#      cylinder, center = (0,4,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,3,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,2,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,1,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-1,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-2,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-3,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,-4,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.35, height 0.3, axis (0, 0, 1)
# Geometric object tree has depth 6 and 182 object nodes (vs. 19 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 3 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.25, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.6842966079711914
# solve_kpoint (0,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1
# zevenfreqs:, 1, 0, 0, 0, 0, 0
# elapsed time for k point: 0.026096343994140625
# solve_kpoint (0.25,0,0):
# Solving for bands 1 to 1...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.07174705371208311 (12.0351% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.06912839171031075 (3.7177% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.06801397031573604 (1.6252% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    4: trace = 0.0597918757344718 (12.8665% change)
#     linmin: converged after 7 iterations.
#     iteration    5: trace = 0.05466162497423866 (8.96478% change)
#     linmin: converged after 6 iterations.
#     iteration    6: trace = 0.05386971714515819 (1.45932% change)
#     linmin: converged after 6 iterations.
#     iteration    7: trace = 0.05327647022711984 (1.10736% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.05319856672031159 (0.146332% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.053120997321702 (0.145917% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 0.0531075753301695 (0.02527% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.05310453336509034 (0.00572809% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.05310407027200352 (0.000872044% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.0531039788324586 (0.000172189% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.05310396764562433 (2.10659e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.05310395578223844 (2.23399e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.05310395046980654 (1.00038e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.05310394971878812 (1.41424e-06% change)
# Finished solving for bands 1 to 1 after 17 iterations.
# zevenfreqs:, 2, 0.25, 0, 0, 0.288675, 0.230443
# elapsed time for k point: 10.64759612083435
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 1...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.1817313411245242 (22.0502% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1679596132169731 (7.87651% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.1613093109456711 (4.03944% change)
#     linmin: converged after 6 iterations.
#     iteration    4: trace = 0.1534111318561054 (5.01917% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 0.1515254672211749 (1.23676% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.1509729894006218 (0.365276% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 0.150566844482614 (0.269381% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.150264367045285 (0.201094% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.1501728004948167 (0.0609555% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.1501521275862156 (0.013767% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 0.1501428294224186 (0.00619269% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.1501393167837272 (0.00233956% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.1501382528126114 (0.000708658% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.1501380394572426 (0.000142106% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.1501379815384322 (3.8577e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.1501379511979633 (2.02084e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.1501379343483975 (1.12227e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 0.1501379300434099 (2.86736e-06% change)
# Finished solving for bands 1 to 1 after 18 iterations.
# zevenfreqs:, 3, 0.5, 0, 0, 0.57735, 0.387476
# elapsed time for k point: 11.586730718612671
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.38747636062527785 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 22.94510054588318
# done

# %%
import matplotlib.pyplot as plt
numk,tmp=np.shape(te_freqs)
klist=np.linspace(0.0,0.5,numk)
fig,ax=plt.subplots()
x = range(len(te_freqs))
ratio=len(te_freqs)
for l in range(num_bands):
    plt.plot(klist,te_freqs[:,l],'b-')
plt.plot(klist,klist,'r-')
plt.ylim([0,0.55])
plt.grid()
plt.ylabel('$\omega a/(2\pi c)$')
# Out:
# Text(0, 0.5, '$\\omega a/(2\\pi c)$')

# %%
md = mpb.MPBData(rectify=True, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps[:,:,45])

fig=plt.figure()
plt.imshow(converted_eps, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-4.56933, mean 1.12965, harm. mean 1.0301, 3.86733% > 1, 3.63246% "fill"
# real part range: 1 .. 1

# %%
from mayavi import mlab
md = mpb.MPBData(rectify=True, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
mlab.contour3d(converted_eps )
mlab.show()
# Out:
# epsilon: 1-4.56933, mean 1.12965, harm. mean 1.0301, 3.86733% > 1, 3.63246% "fill"
# real part range: 1 .. 4.56933

# %%
md = mpb.MPBData(rectify=False, periods=6, resolution=64)
eps = ms.get_epsilon()
# Out:
# epsilon: 1-4.56933, mean 1.60884, harm. mean 1.18258, 22.2245% > 1, 17.0577% "fill"

# %%
np.shape(eps)
# Out:
# (30, 270, 90)

# %%
from mayavi import mlab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from mayavi import mlab
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/mayavi/mlab.py:16
#       8 # Author: Prabhu Ramachandran <prabhu_r@users.sf.net>
#       9 #         Gael Varoquaux <gael dot varoquaux at normalesup dot org>
#      10 # Copyright (c) 2007-2020, Enthought, Inc.
#    (...)
#      13
#      14 # Mayavi imports
#      15 from mayavi.core.common import process_ui_events
# ---> 16 from mayavi.tools.camera import view, roll, yaw, pitch, move
#      17 from mayavi.tools.figure import figure, clf, gcf, savefig, \
#      18     draw, sync_camera, close, screenshot
#      19 from mayavi.tools.engine_manager import get_engine, show_pipeline, \
#      20         options, set_engine
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/mayavi/tools/camera.py:24
#      20 from numpy import pi
#      22 # We can't use gcf, as it creates a circular import in camera management
#      23 # routines.
# ---> 24 from .engine_manager import get_engine
#      27 def world_to_display(x, y, z, figure=None):
#      28     """ Converts 3D world coordinates to screenshot pixel coordinates.
#      29
#      30         **Parameters**
#    (...)
#      46             Screenshot y coordinate
#      47     """
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/mayavi/tools/engine_manager.py:13
#      10 from traits.api import HasTraits, Instance
#      12 # Local imports
# ---> 13 from mayavi.preferences.api import preference_manager
#      14 from mayavi.core.registry import registry
#      15 from mayavi.core.engine import Engine
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/mayavi/preferences/api.py:4
#       1 """The public API for the preferences."""
#       3 # The global PreferenceManager instance
# ----> 4 from .preference_manager import preference_manager
#       5 from .bindings import set_scene_preferences, get_scene_preferences
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/mayavi/preferences/preference_manager.py:29
#      27 from traits.etsconfig.api import ETSConfig
#      28 from traits.api import HasTraits, Instance
# ---> 29 from traitsui.api import View, Group, Item
#      30 from apptools.preferences.api import (ScopedPreferences, IPreferences,
#      31         PreferencesHelper)
#      33 # Local imports.
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/traitsui/api.py:262
#     258 except ImportError:
#     259     # ArrayEditor depends on numpy, so ignore if numpy is not present.
#     260     pass
# --> 262 from .editors.api import (
#     263     BooleanEditor,
#     264     ButtonEditor,
#     265     CheckListEditor,
#     266     CodeEditor,
#     267     ColorEditor,
#     268     CompoundEditor,
#     269     CustomEditor,
#     270     CSVListEditor,
#     271     DNDEditor,
#     272     StyledDateEditor,
#     273     DateEditor,
#     274     DatetimeEditor,
#     275     DateRangeEditor,
#     276     DefaultOverride,
#     277     DirectoryEditor,
#     278     DropEditor,
#     279     EnumEditor,
#     280     FileEditor,
#     281     FontEditor,
#     282     HTMLEditor,
#     283     HistoryEditor,
#     284     ImageEditor,
#     285     ImageEnumEditor,
#     286     InstanceEditor,
#     287     KeyBindingEditor,
#     288     ListEditor,
#     289     ListStrEditor,
#     290     NullEditor,
#     291     PopupEditor,
#     292     ProgressEditor,
#     293     RGBColorEditor,
#     294     RangeEditor,
#     295     ScrubberEditor,
#     296     SearchEditor,
#     297     SetEditor,
#     298     ShellEditor,
#     299     TableEditor,
#     300     TabularEditor,
#     301     TextEditor,
#     302     TimeEditor,
#     303     TitleEditor,
#     304     TreeEditor,
#     305     TupleEditor,
#     306     ValueEditor,
#     307 )
#     309 from .group import (
#     310     Group,
#     311     HFlow,
#    (...)
#     319     VSplit,
#     320 )
#     322 from .handler import (
#     323     Controller,
#     324     Handler,
#    (...)
#     327     default_handler,
#     328 )
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/traitsui/editors/api.py:78
#      74 from ..toolkit import toolkit
#      77 try:
# ---> 78     from .array_editor import ArrayEditor
#      79 except ImportError:
#      80     # check if failure is due to missing numpy, otherwise re-raise
#      81     try:
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/traitsui/editors/array_editor.py:22
#      20 from traitsui.group import Group
#      21 from traitsui.item import Item
# ---> 22 from traitsui.view import View
#      25 class ArrayEditor(EditorFactory):
#      26     """Editor factory for array editors."""
#
# File ~/miniconda3/envs/pmp/lib/python3.11/site-packages/traitsui/view.py:17
#      11 """ Defines the View class used to represent the structural content of a
#      12     Traits-based user interface.
#      13 """
#      16 from pyface.ui_traits import Image
# ---> 17 from pyface.action.schema.api import ActionManagerBuilder
#      18 from traits.api import (
#      19     Any,
#      20     Bool,
#    (...)
#      29     Trait,
#      30 )
#      32 from .view_element import ViewElement, ViewSubElement
#
# ModuleNotFoundError: No module named 'pyface.action.schema'

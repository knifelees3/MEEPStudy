# %% [markdown]
# # Meep 计算光子晶体能带 (三) 三维纳米梁波导模式计算
#
# 日期：2023-04-23
#
# 之前计算的结构的周期都是比较简单，现在来计算周期不再是沿着x或者y方向的结构的能带，
#
# ![image.png](attachment:image.png)
#
# 其主要结构如上图所示，代码基本直接Copy官方文档
#
# https://mpb.readthedocs.io/en/latest/Python_Data_Analysis_Tutorial/

# %% [markdown]
# 和直角的结果不同，对于三角结构，其倒格矢与原基矢有旋转，我们需要用到倒格矢与原基矢量的关系：
# $$
# \left\{\begin{matrix}  \boldsymbol{b}_1=\frac{2\pi  \boldsymbol{a}_2\times \boldsymbol{a}_3}{\boldsymbol{a}_1\cdot (\boldsymbol{a}_2\times \boldsymbol{a}_3)}  \\  \boldsymbol{b}_2=\frac{2\pi  \boldsymbol{a}_3\times \boldsymbol{a}_1}{\boldsymbol{a}_1\cdot (\boldsymbol{a}_2\times \boldsymbol{a}_3)}  \\  \boldsymbol{b}_3=\frac{2\pi  \boldsymbol{a}_1\times \boldsymbol{a}_2}{\boldsymbol{a}_1\cdot (\boldsymbol{a}_2\times \boldsymbol{a}_3)}  \end{matrix}\right.\\
# $$
# 其中分母的物理意义代表着原胞的体积。计算图中结构时，需要首先确定最小原胞，可以有多种选取方式，按照图中的选取方法，最小原胞是一个平行四边形，原胞的两个基矢为
#
# $$
# a_{1}=(1,0)a,a_{2}=(\frac{1}{2},\frac{\sqrt{3}}{2})a
# $$
#
#
# 按照图中的定义，可以计算出倒格子空间的矢量为
#
# $$
# b_{1}=(\frac{1}{\sqrt{3}},1)\frac{2\pi}{a},b_{2}=(\frac{1}{\sqrt{3}},-1)\frac{2\pi}{a}
# $$
#
# 我们计算能带，需要改变波矢来求频率本征值。**在MEEP中，我们一旦手动指定了倒格矢的方向，接下里的能带的`kpoint`都是以该基矢展开的，这与COMSOL是不同的。因此我们需要给出特定点用倒格矢表示的坐标。**
#
# 按照图中的定义，$\Gamma$点为$(0,0)\frac{2\pi}{a}$，$M$点从图中也可以直接看出来，为
#
# $$
# （0,0.5）\frac{2\pi}{a}
# $$
#
# 但是$K$点需要手动计算一下,$K$直接用$k_{x},k_{y}$表示为
#
# $$
# (0,-2/3)\frac{2\pi}{a}=x_{1}b_{1}+b_{2}x_{2}=-\frac{1}{3}b_{1}+\frac{1}{3}b_{2}
# $$
#
# 汇总一下，$\Gamma,M,K$在新的倒格矢空间可以表示为
#
# $$
# (0,0),\quad (0,0.5), \quad (-\frac{1}{3},\frac{1}{3})
# $$
#
# 到此，所有的准备工作就做完了，接下来可以进行代码实现了。

# %% [markdown]
# ## 柱子结构

# %%
import math

import meep as mp
from meep import mpb

# A triangular lattice of dielectric rods in air.  (This structure has
# a band_gap for TM fields.)  This file is used in the "Data Analysis
# Tutorial" section of the MPB manual.

num_bands = 8

# 注意这里的周期方向，要与图中一致，推导已经给出了
geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)

# 实际结构只需要画一个就行
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]

# 注意倒格矢空间
k_points = [
    mp.Vector3(),  # Gamma
    mp.Vector3(y=0.5),  # M
    mp.Vector3(1 / -3, 1 / 3),  # K
    mp.Vector3(),  # Gamma
]

k_points = mp.interpolate(4, k_points)

resolution = 32

ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands,
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3), mpb.fix_efield_phase,
          mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.014000892639160156
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 9 iterations.
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
#     iteration    1: trace = 15.30643043445523 (195.646% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 5.913677654786886 (88.5269% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 5.070863008591771 (15.3455% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.838808060944161 (4.6834% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 4.731233126695964 (2.24816% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 4.632760344347803 (2.10322% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.599727211720591 (0.715585% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.587074101998568 (0.275463% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 66.3796%)
#     iteration    9: trace = 4.581860235265951 (0.113729% change)
#     switching back to exact line minimization
#     iteration   10: trace = 4.579146486136207 (0.0592457% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.578170213535246 (0.0213222% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.5779741461222 (0.00428275% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.577919086358029 (0.00120272% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.577900922190414 (0.000396779% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.577896113396259 (0.000105044% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.577894944094981 (2.55423e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.577894700118686 (5.32944e-06% change)
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.7595548629760742
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.573592874498722 (1.05911% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.9714%)
#     iteration    2: trace = 4.553359985792369 (0.443366% change)
#     iteration    3: trace = 4.549212469522585 (0.0911284% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.547241746954847 (0.0433295% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.546722631993221 (0.0114167% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.0482%)
#     iteration    6: trace = 4.546676222445219 (0.00102073% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.546668791084472 (0.000163446% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.546667449882353 (2.94986e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.7587%)
#     iteration    9: trace = 4.546667089916863 (7.91713e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0711319, 0.538981, 0.559429, 0.617095, 0.834123, 0.839462, 0.988272, 1.08637
# elapsed time for k point: 0.07186269760131836
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.480151649089392 (1.02399% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.462950669234091 (0.384676% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.949%)
#     iteration    3: trace = 4.458417036239892 (0.101635% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.456999333838784 (0.0318034% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.456802929337677 (0.00440675% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 63.9162%)
#     iteration    6: trace = 4.456776895934159 (0.000584129% change)
#     iteration    7: trace = 4.456772347296642 (0.000102061% change)
#     iteration    8: trace = 4.456771876862362 (1.05555e-05% change)
#     iteration    9: trace = 4.456771817643791 (1.32873e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.138898, 0.508574, 0.556587, 0.65398, 0.825087, 0.84452, 0.968999, 1.05281
# elapsed time for k point: 0.07248854637145996
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.372452986047332 (0.692204% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.7881%)
#     iteration    2: trace = 4.366285966374129 (0.141142% change)
#     iteration    3: trace = 4.364948540008974 (0.0306354% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.36462694930062 (0.00736784% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.5403%)
#     iteration    5: trace = 4.364572772474939 (0.00124128% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.364566112532406 (0.000152591% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.364565318036352 (1.82033e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 61.1079%)
#     iteration    8: trace = 4.364565239621323 (1.79663e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198939, 0.479631, 0.553145, 0.693119, 0.813353, 0.850964, 0.932869, 1.02598
# elapsed time for k point: 0.06957149505615234
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.308397019148572 (0.552412% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.9513%)
#     iteration    2: trace = 4.304883729687855 (0.0815784% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.304231470445668 (0.0151528% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.304101793549972 (0.00301282% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60.932%)
#     iteration    5: trace = 4.304072509462332 (0.000680379% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.304070118040752 (5.55618e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.1424%)
#     iteration    7: trace = 4.304069984581595 (3.10077e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.244064, 0.4557, 0.550414, 0.730028, 0.80289, 0.856372, 0.891379, 1.01409
# elapsed time for k point: 0.07318401336669922
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.287294608896842 (0.514415% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.5569%)
#     iteration    2: trace = 4.284125086307025 (0.0739556% change)
#     iteration    3: trace = 4.283595164860747 (0.0123702% change)
#     iteration    4: trace = 4.283502304222651 (0.00216784% change)
#     iteration    5: trace = 4.28347859787408 (0.000553435% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.283477155984929 (3.36616e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.28347707873056 (1.80354e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.262015, 0.445331, 0.549383, 0.749186, 0.797864, 0.85849, 0.870609, 1.01087
# elapsed time for k point: 0.049494028091430664
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 63.4505%)
#     iteration    1: trace = 4.276553249925175 (0.530204% change)
#     switching back to exact line minimization
#     iteration    2: trace = 4.266855838955689 (0.227015% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.264881975313585 (0.0462711% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.4505%)
#     iteration    4: trace = 4.264548398624835 (0.00782178% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.264488721993531 (0.00139938% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.6448%)
#     iteration    6: trace = 4.264476448301955 (0.000287812% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.2644747821095 (3.90714e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.264474642733789 (3.2683e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.262984, 0.4475, 0.545804, 0.752448, 0.797093, 0.860461, 0.870245, 0.99895
# elapsed time for k point: 0.06573605537414551
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.6484%)
#     iteration    1: trace = 4.23248916240106 (0.358172% change)
#     iteration    2: trace = 4.229105620434569 (0.0799741% change)
#     iteration    3: trace = 4.228655924270154 (0.0106339% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.228604972410138 (0.00120493% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 71.7356%)
#     iteration    5: trace = 4.228597155210905 (0.000184865% change)
#     iteration    6: trace = 4.228595847597213 (3.09231e-05% change)
#     iteration    7: trace = 4.228595668523593 (4.23482e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.265671, 0.453801, 0.535912, 0.761319, 0.795166, 0.866056, 0.869135, 0.973413
# elapsed time for k point: 0.06603050231933594
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.19803873560658 (0.248341% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 77.0216%)
#     iteration    2: trace = 4.196704777770447 (0.0317808% change)
#     iteration    3: trace = 4.196585222798251 (0.00284882% change)
#     iteration    4: trace = 4.196578318450884 (0.000164523% change)
#     iteration    5: trace = 4.196577861824733 (1.08809e-05% change)
#     iteration    6: trace = 4.196577824500924 (8.89387e-07% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.269404, 0.463648, 0.52172, 0.773443, 0.792931, 0.867201, 0.874681, 0.94487
# elapsed time for k point: 0.03175067901611328
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.176560612281163 (0.206219% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.175731846036922 (0.0198452% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.175658180018198 (0.00176416% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.175652342398154 (0.000139801% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.175651823528355 (1.24261e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.175651765080817 (1.39972e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.273, 0.476141, 0.505606, 0.78524, 0.791235, 0.864672, 0.885801, 0.918597
# elapsed time for k point: 0.03960585594177246
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.169192706990305 (0.188263% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.168494147455165 (0.0167567% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.168418928467013 (0.00180448% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.168412151808278 (0.000162572% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.168411725529662 (1.02264e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.168411690634591 (8.37131e-07% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.27469, 0.489984, 0.490239, 0.79072, 0.790832, 0.863041, 0.899109, 0.89925
# elapsed time for k point: 0.037654876708984375
# Fixing e-field (band 1) phase by -1 + 1.17764e-06i; max ampl. = 0.939117
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by 1.17764e-06 + 1i; max ampl. = 1.08316
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by -1 + 1.17764e-06i; max ampl. = 0.877941
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by 1 + -1.17764e-06i; max ampl. = 1.24656
# Outputting fields to e.k11.b04.z.tm.h5...
# Fixing e-field (band 5) phase by -1.17764e-06 + -1i; max ampl. = 1.10167
# Outputting fields to e.k11.b05.z.tm.h5...
# Fixing e-field (band 6) phase by 1 + -1.17764e-06i; max ampl. = 1.76187
# Outputting fields to e.k11.b06.z.tm.h5...
# Fixing e-field (band 7) phase by 1 + -1.17764e-06i; max ampl. = 1.08811
# Outputting fields to e.k11.b07.z.tm.h5...
# Fixing e-field (band 8) phase by -1 + 1.17764e-06i; max ampl. = 1.08096
# Outputting fields to e.k11.b08.z.tm.h5...
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.201218387143633 (0.720816% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.19825625816358 (0.0705313% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.197890563319715 (0.00871102% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.197857649514359 (0.000784059% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.197854429373006 (7.67092e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.197854075524685 (8.42927e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.2632, 0.47091, 0.51804, 0.764413, 0.795091, 0.864427, 0.896871, 0.932925
# elapsed time for k point: 0.05127549171447754
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.288244872179968 (0.732715% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.283958817843732 (0.0999989% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.283371690646166 (0.0137062% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.283281442008085 (0.00210698% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.283267825166942 (0.000317907% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.283266579432841 (2.90837e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.283266497838323 (1.90496e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.222593, 0.476537, 0.539917, 0.715636, 0.806516, 0.856013, 0.929969, 0.977199
# elapsed time for k point: 0.04347085952758789
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.420128758718619 (0.818879% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.412260720019018 (0.178163% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.41063372283412 (0.0368813% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.410197903137277 (0.0098816% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.410114422161128 (0.00189293% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.410103888122514 (0.000238861% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.410102421564556 (3.32545e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.410102293673312 (2.89996e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.15856, 0.501245, 0.552927, 0.666818, 0.82116, 0.846938, 0.963589, 1.03113
# elapsed time for k point: 0.06164264678955078
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.563329249693653 (1.02702% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.544560536322282 (0.412142% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.537741040007312 (0.150171% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.535260974244443 (0.0546691% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.534595978095716 (0.0146639% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.534531476630521 (0.00142244% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.534520999897529 (0.000231044% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.534518658359619 (5.16381e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.534517831443807 (1.8236e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.534517685413175 (3.22042e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0819275, 0.534465, 0.558896, 0.622523, 0.832982, 0.840137, 0.98638, 1.08149
# elapsed time for k point: 0.05624508857727051
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.620880146122096 (1.44427% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.585845924982478 (0.761057% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.579348343661806 (0.141788% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.9934%)
#     iteration    4: trace = 4.578210977834427 (0.0248399% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.577956210941322 (0.00556492% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 4.577915075399084 (0.000898561% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.577900178946047 (0.000325399% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.577895727211082 (9.72441e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.577894739281827 (2.15804e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.577894647669044 (2.0012e-06% change)
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.06543827056884766
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2746902260167484 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.44533108106928637 at Vector3<0.0, 0.5, 0.0> to 0.560518145470247 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.49023891496896876 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607966059135 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960880504855 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678293 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764965164 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511195922415 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948533988671 at Vector3<0.0, 0.0, 0.0> to 0.8672009266355516 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8691349975405408 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291112237172 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210427 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183708620605 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2746902260167484) to band 2 (0.44533108106928637), 47.39883483257759%
# Gap from band 3 (0.5605607966059135) to band 4 (0.5932960880504855), 5.674064414725065%
# Gap from band 4 (0.7907195975678293) to band 5 (0.7908320764965164), 0.0142238702069216%
# Gap from band 5 (0.8374511195922415) to band 6 (0.8375948533988671), 0.017161774535526954%
# Gap from band 6 (0.8672009266355516) to band 7 (0.8691349975405408), 0.2227761204568683%
# total elapsed time for run: 1.6824133396148682
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01327824592590332
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 17.57870718796561 (195.046% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 7.919474168453904 (75.7641% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 6.777138964926388 (15.5456% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.450746562429386 (4.93491% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 6.330597633034659 (1.88007% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 6.284352356206411 (0.733182% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.25367801145529 (0.489301% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 6.23823097784528 (0.247313% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 6.227807400547748 (0.167232% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 6.220785689826473 (0.112811% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.217066637212928 (0.0598022% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 6.214514231381885 (0.0410633% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 6.212724152002588 (0.028809% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 6.211098639627993 (0.0261677% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 6.209571058623585 (0.0245974% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 6.208320846453619 (0.0201357% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 6.207138202917633 (0.0190511% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 6.206231989572621 (0.0146006% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 6.205711124681463 (0.00839296% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 6.205489655623268 (0.00356886% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 6.205423588894609 (0.00106466% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 6.205391638809354 (0.000514875% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 6.205370459793864 (0.000341301% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 6.205356860338762 (0.000219156% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 6.205349827373201 (0.000113337% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 6.205346837578824 (4.81809e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 6.205344919564415 (3.09091e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 6.205343120149899 (2.89978e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 6.205341306409468 (2.92287e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 6.205339916100105 (2.2405e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 6.205339161376326 (1.21625e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 6.205338647929452 (8.27428e-06% change)
# Finished solving for bands 2 to 8 after 32 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.561229, 0.793929, 0.794659, 1.03341, 1.03342, 1.11597, 1.11681
# elapsed time for k point: 0.20187664031982422
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.15860972300135 (1.66355% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.098046688270429 (0.988247% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.081913150570246 (0.264919% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.074383849338623 (0.123875% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.072218073042386 (0.0356606% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 6.071225490626065 (0.0163476% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 6.070791758919822 (0.00714431% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.070592842969072 (0.00327666% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 6.070504879984126 (0.00144901% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.070476217157925 (0.000472167% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.070466818878989 (0.00015482% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.070462389972631 (7.29583e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.07046077908981 (2.65364e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.070460336547708 (7.29009e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 2, 0, 0.1, 0, 0.11547, 0.101865, 0.559805, 0.79146, 0.793258, 0.992126, 1.02845, 1.09799, 1.1151
# elapsed time for k point: 0.07798194885253906
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.879599008947569 (0.610683% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.864187615723148 (0.26246% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.859437003637691 (0.0810434% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.857344250478654 (0.0357223% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.856604258421341 (0.0126344% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.856366404892593 (0.00406137% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.856287632037118 (0.00134509% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.856257941530231 (0.000506986% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.856247736467261 (0.000174259% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.856242901568131 (8.25597e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.856240724620517 (3.71731e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.856239124829275 (2.73177e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.85623815877917 (1.64961e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.856237876759403 (4.81572e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 3, 0, 0.2, 0, 0.23094, 0.202662, 0.555133, 0.784265, 0.784932, 0.925328, 1.01804, 1.06979, 1.11298
# elapsed time for k point: 0.08265161514282227
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.688345734873656 (0.328009% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.682025932936444 (0.111163% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.680154867100345 (0.032935% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.679577865148783 (0.0101587% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.679381522427713 (0.00345705% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.679338601707802 (0.000755732% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.679327164455557 (0.000201384% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.679321587791625 (9.81924e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.679318737165678 (5.01931e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.679317087206134 (2.90521e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.6793165386373 (9.65906e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 4, 0, 0.3, 0, 0.34641, 0.300756, 0.545003, 0.752836, 0.776604, 0.881528, 1.00851, 1.04494, 1.1117
# elapsed time for k point: 0.07769155502319336
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.572186962078485 (0.242036% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.568603734073082 (0.0643263% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 61.2458%)
#     iteration    3: trace = 5.567659186616573 (0.0169635% change)
#     switching back to exact line minimization
#     iteration    4: trace = 5.567444872689213 (0.00384934% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.567378034365602 (0.00120053% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.567363749004193 (0.000256591% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.567360155228208 (6.45508e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.56735844903011 (3.06465e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.567357591127442 (1.54095e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.567357134543622 (8.20109e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 5, 0, 0.4, 0, 0.46188, 0.392756, 0.521577, 0.705571, 0.77011, 0.86865, 1.00251, 1.02766, 1.11107
# elapsed time for k point: 0.06664204597473145
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.532738507964364 (0.208668% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.8987%)
#     iteration    2: trace = 5.530094778155782 (0.0477948% change)
#     iteration    3: trace = 5.529443013417637 (0.0117865% change)
#     iteration    4: trace = 5.52931796628765 (0.0022615% change)
#     iteration    5: trace = 5.529282473252321 (0.000641908% change)
#     iteration    6: trace = 5.529274257461614 (0.000148587% change)
#     switching back to exact line minimization
#     iteration    7: trace = 5.529272288764644 (3.5605e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.529271636144451 (1.1803e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.529271454754831 (3.28053e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 6, 0, 0.5, 0, 0.57735, 0.468428, 0.473072, 0.683225, 0.767661, 0.866987, 1.00052, 1.02137, 1.11088
# elapsed time for k point: 0.05139422416687012
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.538977703375338 (0.141208% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.534543161841118 (0.0800927% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.533284347331689 (0.0227473% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.532629775292209 (0.0118304% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.532342338539096 (0.00519544% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.532236512619834 (0.00191288% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.532184627794365 (0.000937868% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.532165299383001 (0.000349382% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.532157003703546 (0.000149954% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.532154382502198 (4.73812e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.532153856195862 (9.51359e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.472654, 0.474197, 0.67604, 0.772695, 0.866879, 0.969813, 1.05066, 1.11081
# elapsed time for k point: 0.0691680908203125
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.545518071868636 (0.156539% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.539704717500369 (0.104885% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.7819%)
#     iteration    3: trace = 5.537423975205342 (0.0411793% change)
#     iteration    4: trace = 5.535869205248776 (0.0280814% change)
#     switching back to exact line minimization
#     iteration    5: trace = 5.535105721073946 (0.0137925% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.53483908055442 (0.00481738% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.534735245526287 (0.00187604% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.534709301964142 (0.000468742% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.534699684301957 (0.00017377% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.534696886604054 (5.05483e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.534696298017745 (1.06345e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.534696085944468 (3.83171e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.477432, 0.485081, 0.657266, 0.784802, 0.866577, 0.932933, 1.08112, 1.11059
# elapsed time for k point: 0.0721287727355957
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.539957656995218 (0.178117% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.532918751270424 (0.127138% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.529982416191018 (0.0530844% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.528260673449878 (0.0311395% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.527478137775651 (0.0141562% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.527260887963391 (0.00393044% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.527174944743921 (0.00155491% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.527154236519698 (0.000374663% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.527144570171079 (0.000174888% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.527141352845257 (5.82096e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.527140474122194 (1.58983e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.527140149763409 (5.86847e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.48232, 0.50501, 0.630584, 0.799745, 0.866126, 0.900465, 1.09936, 1.11024
# elapsed time for k point: 0.08582115173339844
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.522643680730667 (0.153921% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.517647933012089 (0.0905003% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.515892012730554 (0.0318288% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.515135482166238 (0.0137164% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.514756994362374 (0.00686295% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.514652222451398 (0.00189986% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.5146022335937 (0.000906478% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.51458989041338 (0.000223827% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.514584135722917 (0.000104354% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.2731%)
#     iteration   10: trace = 5.51458229943843 (3.32987e-05% change)
#     switching back to exact line minimization
#     iteration   11: trace = 5.514581755393605 (9.86557e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.487852, 0.531427, 0.598151, 0.814208, 0.865617, 0.875643, 1.10711, 1.10983
# elapsed time for k point: 0.06780076026916504
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.513149344796068 (0.118004% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.510123731477502 (0.054895% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.509213072380482 (0.0165284% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.508908697717503 (0.00552498% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.508738146985848 (0.00309596% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.508683619384287 (0.000989843% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.508654047558172 (0.000536823% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.508646674216896 (0.00013385% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.508643584617336 (5.60864e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 61.0398%)
#     iteration   10: trace = 5.508642640157015 (1.71451e-05% change)
#     iteration   11: trace = 5.508642363482867 (5.02255e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.491236, 0.563106, 0.563151, 0.821423, 0.865195, 0.865231, 1.10923, 1.10941
# elapsed time for k point: 0.05424189567565918
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.550578605637584 (0.389249% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.542766045190636 (0.140851% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.540530012810488 (0.0403496% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.0292%)
#     iteration    4: trace = 5.539782249088243 (0.0134972% change)
#     switching back to exact line minimization
#     iteration    5: trace = 5.539265011568275 (0.00933722% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.539067927186515 (0.00355802% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.538979809787812 (0.00159085% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.538958716076305 (0.000380824% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.538951643889474 (0.000127681% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.538948980074153 (4.80924e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.538948194439893 (1.41838e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.538947835986526 (6.47151e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.446126, 0.532191, 0.637012, 0.806654, 0.86614, 0.893198, 1.10593, 1.10866
# elapsed time for k point: 0.04112601280212402
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60.0217%)
#     iteration    1: trace = 5.647301379371287 (0.329695% change)
#     switching back to exact line minimization
#     iteration    2: trace = 5.640935879020203 (0.112781% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.838%)
#     iteration    3: trace = 5.638794448033107 (0.0379695% change)
#     iteration    4: trace = 5.637899092391071 (0.0158798% change)
#     iteration    5: trace = 5.637266298170722 (0.0112246% change)
#     switching back to exact line minimization
#     iteration    6: trace = 5.637036663619075 (0.00407359% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.636936437557484 (0.00177801% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.63690518726491 (0.000554386% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.636896047809623 (0.000162136% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.636893337636494 (4.80792e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.7231%)
#     iteration   11: trace = 5.636892877874027 (8.15631e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 13, -0.2, 0.2, 0, 0.4, 0.345267, 0.542882, 0.713396, 0.795022, 0.875814, 0.938821, 1.09707, 1.10904
# elapsed time for k point: 0.07839584350585938
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.818503218924636 (0.3234% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.81186530133202 (0.114148% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.80959745894768 (0.0390285% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.808664746268613 (0.016056% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.808060508806494 (0.0104029% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.807780344009993 (0.00482384% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.807591594100077 (0.00325% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.807496974215746 (0.00162926% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.807463214357544 (0.000581317% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.807448586738484 (0.000251877% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.807443078219524 (9.48527e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.807439472979837 (6.20797e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.807437473772322 (3.44249e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.807436666388234 (1.39026e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.807436288372564 (6.50917e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.233479, 0.553269, 0.768719, 0.792196, 0.912766, 0.987203, 1.08919, 1.11098
# elapsed time for k point: 0.09306859970092773
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 6.0585806393608 (0.404465% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 6.047224616871889 (0.187613% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.042872512168279 (0.0719945% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 6.041118035090072 (0.029038% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.040283469635204 (0.0138157% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 6.039951446815825 (0.00549696% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 6.03973365885343 (0.00360585% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 6.039536826545234 (0.00325901% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 6.039366375438037 (0.00282229% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 6.039238239466453 (0.0021217% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 6.03919039154305 (0.000792287% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.039166694190205 (0.000392394% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 6.039155035639084 (0.000193049% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 6.039151334533055 (6.12852e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 6.039149881478778 (2.40606e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 6.039149285310671 (9.87172e-06% change)
# Finished solving for bands 1 to 8 after 16 iterations.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.117556, 0.559323, 0.789736, 0.793576, 0.983043, 1.02374, 1.09661, 1.11448
# elapsed time for k point: 0.11002349853515625
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 6.298758275467288 (0.895537% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 6.2454602357978 (0.849763% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 6.223341792642335 (0.354781% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 6.21198062055857 (0.182724% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 6.208148486340636 (0.0617084% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 6.206838432437261 (0.0211044% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 6.206171027131534 (0.0107533% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 6.205806280753978 (0.00587733% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 6.2055335008873 (0.00439566% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 6.20542892231115 (0.00168526% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 6.20540445771988 (0.000394246% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 6.205390158207413 (0.000230437% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 6.20537921526115 (0.000176346% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.8887%)
#     iteration   14: trace = 6.205369303790542 (0.000159724% change)
#     switching back to exact line minimization
#     iteration   15: trace = 6.205362340332973 (0.000112217% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 6.205354361973992 (0.000128572% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 6.205347561432833 (0.000109592% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 6.205343404423443 (6.69908e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 6.205340297645939 (5.00662e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 6.205338899129482 (2.25373e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 6.205338350900782 (8.83479e-06% change)
# Finished solving for bands 2 to 8 after 21 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.561229, 0.793929, 0.794659, 1.03341, 1.03342, 1.11597, 1.11681
# elapsed time for k point: 0.11880636215209961
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.49123581641448494 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.47307223980495294 at Vector3<0.0, 0.5, 0.0> to 0.5631059454925385 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 3 range: 0.5631505237334604 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.7939289543930981 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.7676614802393238 at Vector3<0.0, 0.5, 0.0> to 0.8214230165362851 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.865194816166872 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0334130409697195 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8652308007806733 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0334231173581718 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 1.0213677200533422 at Vector3<0.0, 0.5, 0.0> to 1.1159672189185212 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 1.1086627107633278 at Vector3<-0.26666666666666666, 0.26666666666666666, 0.0> to 1.1168110127835034 at Vector3<0.0, 0.0, 0.0>
# Gap from band 2 (0.5631059454925385) to band 3 (0.5631505237334604), 0.007916179332155498%
# Gap from band 4 (0.8214230165362851) to band 5 (0.865194816166872), 5.190482251742046%
# total elapsed time for run: 1.3640005588531494
# done

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = range(len(tm_freqs))
# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 1])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'M', 'K', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
import numpy as np
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))
# Out:
# epsilon: 1-12, mean 2.59614, harm. mean 1.17149, 17.2852% > 1, 14.5104% "fill"
# real part range: 1 .. 12
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.011232852935791016
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 13.91078823090369 (196.045% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 5.669424631137733 (84.1805% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 5.216893199528734 (8.31376% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 4.982092958695192 (4.60438% change)
#     linmin: converged after 6 iterations.
#     iteration    5: trace = 4.728856487605157 (5.21548% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 4.617411035314039 (2.38481% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 4.592912691914037 (0.531976% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.582335714437474 (0.230555% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.8449%)
#     iteration    9: trace = 4.579397848511023 (0.0641334% change)
#     switching back to exact line minimization
#     iteration   10: trace = 4.578406884691848 (0.021642% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 63.9908%)
#     iteration   11: trace = 4.578074223911893 (0.00726613% change)
#     iteration   12: trace = 4.577958184339227 (0.00253471% change)
#     iteration   13: trace = 4.577910366080483 (0.00104454% change)
#     iteration   14: trace = 4.577899868069644 (0.000229319% change)
#     iteration   15: trace = 4.577896048072993 (8.34443e-05% change)
#     iteration   16: trace = 4.577894889859474 (2.53001e-05% change)
#     iteration   17: trace = 4.577894675832106 (4.67524e-06% change)
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.8000125885009766
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.573589459495642 (1.05892% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.2336%)
#     iteration    2: trace = 4.553359399753418 (0.443304% change)
#     iteration    3: trace = 4.54921192554771 (0.0911275% change)
#     iteration    4: trace = 4.547241639353593 (0.0433199% change)
#     iteration    5: trace = 4.546722740549188 (0.0114119% change)
#     iteration    6: trace = 4.546676207507756 (0.00102345% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.546668809827491 (0.000162705% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.546667456833291 (2.97579e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.9635%)
#     iteration    9: trace = 4.546667089820877 (8.07212e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0711319, 0.538981, 0.559429, 0.617095, 0.834123, 0.839462, 0.988272, 1.08637
# elapsed time for k point: 0.04817485809326172
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.5959%)
#     iteration    1: trace = 4.480160522940551 (1.02422% change)
#     switching back to exact line minimization
#     iteration    2: trace = 4.462964549666732 (0.384563% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.3612%)
#     iteration    3: trace = 4.458421834331145 (0.101839% change)
#     iteration    4: trace = 4.456998975223998 (0.0319191% change)
#     iteration    5: trace = 4.456802817883914 (0.0044012% change)
#     iteration    6: trace = 4.456776800627378 (0.000583767% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.456772308583158 (0.000100791% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.456771860769424 (1.00479e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 64.1387%)
#     iteration    9: trace = 4.456771810984273 (1.11707e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.138898, 0.508574, 0.556587, 0.65398, 0.825087, 0.84452, 0.968999, 1.05281
# elapsed time for k point: 0.05497479438781738
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.5918%)
#     iteration    1: trace = 4.372450291516577 (0.692142% change)
#     iteration    2: trace = 4.366287161617571 (0.141053% change)
#     iteration    3: trace = 4.364948750623961 (0.030658% change)
#     iteration    4: trace = 4.364626834062557 (0.00737531% change)
#     iteration    5: trace = 4.364572745866689 (0.00123925% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.36456610732227 (0.000152101% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.364565316450761 (1.81203e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.364565238983195 (1.77492e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198939, 0.479631, 0.553145, 0.693119, 0.813353, 0.850964, 0.932869, 1.02598
# elapsed time for k point: 0.07136964797973633
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.8017%)
#     iteration    1: trace = 4.308395876359642 (0.552387% change)
#     iteration    2: trace = 4.304883739316693 (0.0815517% change)
#     iteration    3: trace = 4.304231453661005 (0.0151534% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.304101781041798 (0.00301272% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 69.2471%)
#     iteration    5: trace = 4.304072512174774 (0.000680025% change)
#     iteration    6: trace = 4.304070118915403 (5.56045e-05% change)
#     iteration    7: trace = 4.304069984729097 (3.11766e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.244064, 0.4557, 0.550414, 0.730028, 0.80289, 0.856372, 0.891379, 1.01409
# elapsed time for k point: 0.05077791213989258
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.9963%)
#     iteration    1: trace = 4.287293858519799 (0.514386% change)
#     iteration    2: trace = 4.284125123952986 (0.0739372% change)
#     iteration    3: trace = 4.283595169112518 (0.012371% change)
#     iteration    4: trace = 4.283502300627102 (0.00216803% change)
#     iteration    5: trace = 4.283478600456477 (0.000553291% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.283477156675561 (3.37058e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.28347707886808 (1.81646e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.262015, 0.445331, 0.549383, 0.749186, 0.797864, 0.85849, 0.870609, 1.01087
# elapsed time for k point: 0.07278299331665039
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.276553279772287 (0.530205% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.798%)
#     iteration    2: trace = 4.266855844448237 (0.227016% change)
#     iteration    3: trace = 4.264882322003869 (0.0462631% change)
#     iteration    4: trace = 4.264548405919495 (0.00782974% change)
#     iteration    5: trace = 4.264488722509502 (0.00139953% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.264476447290266 (0.000287848% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.264474782188356 (3.90459e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.264474642786477 (3.26891e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.262984, 0.4475, 0.545804, 0.752448, 0.797093, 0.860461, 0.870245, 0.99895
# elapsed time for k point: 0.05011415481567383
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.232489847671814 (0.358211% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.7498%)
#     iteration    2: trace = 4.229105509151279 (0.0799929% change)
#     iteration    3: trace = 4.228655896788455 (0.0106319% change)
#     iteration    4: trace = 4.22860497536026 (0.00120421% change)
#     iteration    5: trace = 4.228597155923596 (0.000184918% change)
#     iteration    6: trace = 4.22859584751092 (3.0942e-05% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.228595668500789 (4.23332e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.265671, 0.453801, 0.535912, 0.761319, 0.795166, 0.866056, 0.869135, 0.973413
# elapsed time for k point: 0.03411984443664551
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.198038846647476 (0.248347% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.196704781878069 (0.0317833% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.196585222853511 (0.00284892% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.1349%)
#     iteration    4: trace = 4.196578318433307 (0.000164525% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.196577861819058 (1.08806e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.19657782450067 (8.89258e-07% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.269404, 0.463648, 0.52172, 0.773443, 0.792931, 0.867201, 0.874681, 0.94487
# elapsed time for k point: 0.05437016487121582
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.176560608250691 (0.206218% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.89%)
#     iteration    2: trace = 4.17573184575366 (0.0198452% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.17565818001213 (0.00176416% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.175652342395693 (0.000139801% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.175651823527904 (1.2426e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 57.1011%)
#     iteration    6: trace = 4.17565176508078 (1.39971e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.273, 0.476141, 0.505606, 0.78524, 0.791235, 0.864672, 0.885801, 0.918597
# elapsed time for k point: 0.06049299240112305
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.169192706118214 (0.188263% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.1305%)
#     iteration    2: trace = 4.168494147370747 (0.0167567% change)
#     iteration    3: trace = 4.168418928469289 (0.00180448% change)
#     iteration    4: trace = 4.168412151810541 (0.000162572% change)
#     iteration    5: trace = 4.16841172553048 (1.02264e-05% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.168411690634692 (8.37148e-07% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.27469, 0.489984, 0.490239, 0.79072, 0.790832, 0.863041, 0.899109, 0.89925
# elapsed time for k point: 0.03581714630126953
# Fixing e-field (band 1) phase by -1 + 5.25164e-06i; max ampl. = 0.939117
# Fixing e-field (band 2) phase by -5.25164e-06 + -1i; max ampl. = 1.08316
# Fixing e-field (band 3) phase by 1 + -5.25164e-06i; max ampl. = 0.877941
# Fixing e-field (band 4) phase by -1 + 5.25164e-06i; max ampl. = 1.24656
# Fixing e-field (band 5) phase by -5.25164e-06 + -1i; max ampl. = 1.10167
# Fixing e-field (band 6) phase by -1 + 5.25164e-06i; max ampl. = 1.76187
# Fixing e-field (band 7) phase by -1 + 5.25164e-06i; max ampl. = 1.08811
# Fixing e-field (band 8) phase by 1 + -5.25164e-06i; max ampl. = 1.08096
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.7581%)
#     iteration    1: trace = 4.201218385090832 (0.720816% change)
#     iteration    2: trace = 4.198256641900255 (0.0705221% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.19789060254115 (0.00871922% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.8278%)
#     iteration    4: trace = 4.197857649353937 (0.000784997% change)
#     iteration    5: trace = 4.197854429361757 (7.67056e-05% change)
#     iteration    6: trace = 4.197854075550334 (8.42839e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.2632, 0.47091, 0.51804, 0.764413, 0.795091, 0.864427, 0.896871, 0.932925
# elapsed time for k point: 0.031203746795654297
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.9106%)
#     iteration    1: trace = 4.288244580913107 (0.732708% change)
#     iteration    2: trace = 4.283959182145685 (0.0999836% change)
#     iteration    3: trace = 4.283371751068693 (0.0137133% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.28328144266482 (0.00210837% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.8291%)
#     iteration    5: trace = 4.283267826646016 (0.000317888% change)
#     iteration    6: trace = 4.283266579677718 (2.91125e-05% change)
#     switching back to exact line minimization
#     iteration    7: trace = 4.28326649787013 (1.90993e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.222593, 0.476537, 0.539917, 0.715636, 0.806516, 0.856013, 0.929969, 0.977199
# elapsed time for k point: 0.04393887519836426
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 53.3909%)
#     iteration    1: trace = 4.420128060206959 (0.818855% change)
#     iteration    2: trace = 4.412261512161623 (0.17813% change)
#     iteration    3: trace = 4.410633899226031 (0.0368952% change)
#     iteration    4: trace = 4.410197923302681 (0.00988514% change)
#     iteration    5: trace = 4.410114430337322 (0.0018932% change)
#     iteration    6: trace = 4.410103889154253 (0.000239023% change)
#     iteration    7: trace = 4.410102421994408 (3.32682e-05% change)
#     iteration    8: trace = 4.410102293812502 (2.90655e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.15856, 0.501245, 0.552927, 0.666818, 0.82116, 0.846938, 0.963589, 1.03113
# elapsed time for k point: 0.03429269790649414
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.563327600135461 (1.027% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.2092%)
#     iteration    2: trace = 4.544559901151608 (0.41212% change)
#     iteration    3: trace = 4.537743684807925 (0.150099% change)
#     iteration    4: trace = 4.535257710577929 (0.0547994% change)
#     iteration    5: trace = 4.534593344865083 (0.01465% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.534529818432697 (0.00140094% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.3457%)
#     iteration    7: trace = 4.534520078178764 (0.000214802% change)
#     iteration    8: trace = 4.534518310829865 (3.89754e-05% change)
#     iteration    9: trace = 4.534517730842259 (1.27905e-05% change)
#     iteration   10: trace = 4.534517645595835 (1.87994e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0819275, 0.534465, 0.558896, 0.622523, 0.832982, 0.840137, 0.98638, 1.08149
# elapsed time for k point: 0.04052901268005371
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.620896823335942 (1.44445% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.2467%)
#     iteration    2: trace = 4.585850614563745 (0.761316% change)
#     iteration    3: trace = 4.579362606600625 (0.141579% change)
#     iteration    4: trace = 4.578209996172822 (0.0251728% change)
#     iteration    5: trace = 4.577956277306011 (0.00554203% change)
#     iteration    6: trace = 4.577915103463277 (0.000899398% change)
#     iteration    7: trace = 4.57790027577926 (0.000323897% change)
#     switching back to exact line minimization
#     iteration    8: trace = 4.577895730858885 (9.92796e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.1165%)
#     iteration    9: trace = 4.577894734769516 (2.17587e-05% change)
#     iteration   10: trace = 4.577894645163893 (1.95735e-06% change)
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.042917728424072266
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2746902260167451 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4453310810708122 at Vector3<0.0, 0.5, 0.0> to 0.5605181456763714 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4902389149689836 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607964181245 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960877465765 at Vector3<0.0, 0.0, 0.0> to 0.7907195975677257 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764963227 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511191078843 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948534442904 at Vector3<0.0, 0.0, 0.0> to 0.8672009266363546 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.86913499760465 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291090524014 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210534 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183631515985 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2746902260167451) to band 2 (0.4453310810708122), 47.39883483290212%
# Gap from band 3 (0.5605607964181245) to band 4 (0.5932960877465765), 5.674064397015699%
# Gap from band 4 (0.7907195975677257) to band 5 (0.7908320764963227), 0.014223870195524065%
# Gap from band 5 (0.8374511191078843) to band 6 (0.8375948534442904), 0.017161837795667375%
# Gap from band 6 (0.8672009266363546) to band 7 (0.86913499760465), 0.2227761277404628%
# total elapsed time for run: 1.5489277839660645
# done

# %%
# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='RdBu', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# real part range: -0.468466 .. 0.936914
# imag part range: -0.811396 .. 0.811396
# real part range: -1.07345 .. 1.07345
# imag part range: -0.936077 .. 0.936512
# real part range: -0.889515 .. 0.984914
# imag part range: -1.0795 .. 1.0795
# real part range: -0.77705 .. 1.24656
# imag part range: -1.08409 .. 1.08409
# real part range: -1.10094 .. 1.10094
# imag part range: -1.07951 .. 1.07827
# real part range: -0.861194 .. 1.72158
# imag part range: -1.49117 .. 1.49117
# real part range: -1.04995 .. 1.06413
# imag part range: -1.01069 .. 1.01069
# real part range: -1.03932 .. 1.03493
# imag part range: -1.08496 .. 1.08496

# %% [markdown]
# ## 空心结构
#
# 空心结构的计算基本一致，只是背景材料和柱子材料折射率发生了变化

# %%
import math

import meep as mp
from meep import mpb

# 2d system: triangular lattice of air holes in dielectric
# This structure has a complete band gap (i.e. a gap in both TE and TM
# simultaneously) for a hole radius of 0.45a and a dielectric constant of
# 12.   (See, e.g., the book "Photonic Crystals" by Joannopoulos et al.)

# first, define the lattice vectors and k-points for a triangular lattice:

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
    basis2=mp.Vector3(math.sqrt(3) / 2, -0.5),
)

kz = 0  # use non-zero kz to consider vertical propagation

k_points = [
    mp.Vector3(z=kz),  # Gamma
    mp.Vector3(0, 0.5, kz),  # M
    mp.Vector3(1 / -3, 1 / 3, kz),  # K
    mp.Vector3(z=kz),  # Gamma
]

k_interp = 4
k_points = mp.interpolate(k_interp, k_points)

# Now, define the geometry, etcetera:

eps = 12  # the dielectric constant of the background
r = 0.45  # the hole radius

# 注意这里的设置！
default_material = mp.Medium(epsilon=eps)
geometry = [mp.Cylinder(r, material=mp.air)]

resolution = 32
num_bands = 8

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    geometry=geometry,
    k_points=k_points,
    default_material=default_material,# 注意这里的设置！改变了背景材料
    resolution=resolution,
    num_bands=num_bands,
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3), mpb.fix_efield_phase,
          mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.45, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 16 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.014001607894897461
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 9.003749574409309 (196.486% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 3.418931725055546 (89.9132% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 2.986801802986355 (13.492% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.908767237357526 (2.64723% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.889656446492673 (0.659172% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.883533672222652 (0.212111% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.877810687790865 (0.198668% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.873865566503359 (0.137182% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 2.872352062606304 (0.0526783% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.870903967405886 (0.0504277% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.868509907025455 (0.0834253% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.864901726127065 (0.125865% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 2.863270415090638 (0.0569575% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 2.862934788670979 (0.0117225% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.862830832127763 (0.00363118% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 2.862736627021945 (0.00329068% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 2.862642007951981 (0.00330525% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 2.862582264137194 (0.00208704% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.862542594384601 (0.00138581% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.862513844468232 (0.00100435% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.862498211017962 (0.000546146% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.862494255705198 (0.000138177% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 2.862493316907793 (3.27965e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 2.862492766573067 (1.92257e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 2.86249189726873 (3.03688e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 2.862491146838124 (2.6216e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 2.862490874705998 (9.50683e-06% change)
# Finished solving for bands 2 to 8 after 27 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.398513, 0.492888, 0.493368, 0.682486, 0.682532, 0.692015, 0.898224
# elapsed time for k point: 0.9397168159484863
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.859267860765488 (1.54837% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.84276276524189 (0.57892% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.837693713364382 (0.178473% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.836744061191491 (0.0334712% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.836192753624752 (0.0194364% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.835586698484608 (0.0213709% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.835329243589576 (0.00907983% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.835307572973802 (0.00076431% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.835302896452745 (0.000164939% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.835301638634502 (4.43628e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.835301372363083 (9.39129e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0581198, 0.391139, 0.491701, 0.498714, 0.658377, 0.683973, 0.717136, 0.879138
# elapsed time for k point: 0.07311797142028809
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.801041034563938 (1.13548% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.796641355026064 (0.157196% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.795927381028037 (0.025533% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.795769769639664 (0.00563734% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.795670407088842 (0.0035541% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.795637800457214 (0.00116633% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.79563140400188 (0.000228802% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.795630929324572 (1.69793e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.795630880361484 (1.75141e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.114967, 0.372435, 0.488376, 0.510297, 0.634188, 0.687769, 0.745313, 0.845031
# elapsed time for k point: 0.05752825736999512
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.774998237489059 (0.956821% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.772244836166055 (0.099271% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.771711799333001 (0.0192295% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.77160306752345 (0.00392299% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.771573338938545 (0.00107262% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.771567875239723 (0.000197134% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.771565848828344 (7.31143e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.771565436095018 (1.48917e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.771565393904965 (1.52225e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.169005, 0.346637, 0.484408, 0.520098, 0.618254, 0.692346, 0.770438, 0.813964
# elapsed time for k point: 0.05890321731567383
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.769862911954049 (0.914066% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.766236542314821 (0.131008% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.76499081204554 (0.0450435% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.76469092641375 (0.0108464% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.764623519677468 (0.00243816% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.764618233260477 (0.000191217% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.764617446388801 (2.84622e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.764617148453994 (1.07767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.764617097733652 (1.83462e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.217539, 0.316063, 0.481302, 0.523954, 0.612544, 0.695969, 0.784104, 0.798008
# elapsed time for k point: 0.043473005294799805
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.776059092699361 (0.931495% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 2.769429696250119 (0.239092% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.766409539724356 (0.109113% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.76565532614475 (0.027267% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.76552242335478 (0.00480559% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.765515118338943 (0.000264146% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.765514721066146 (1.43652e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.765514678102034 (1.55357e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.246221, 0.2936, 0.480139, 0.524322, 0.612077, 0.697337, 0.77948, 0.802954
# elapsed time for k point: 0.05378293991088867
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.767582926034601 (0.367586% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.766063487582723 (0.0549164% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.76572913484112 (0.0120884% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.765669433695015 (0.00215863% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.765658298830646 (0.000402611% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.765656676319167 (5.86664e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.765656191615834 (1.75258e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.765656108853469 (2.9925e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.247714, 0.293902, 0.474174, 0.530395, 0.610517, 0.697722, 0.778384, 0.803945
# elapsed time for k point: 0.04634284973144531
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.768280472104869 (0.361642% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.766861363385911 (0.0512763% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.766538849407765 (0.011657% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.766463906160716 (0.00270895% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.766444674297101 (0.000695181% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.766441156071301 (0.000127175% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.7664404887306 (2.41227e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.766440405377105 (3.01302e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.252117, 0.294341, 0.462144, 0.543033, 0.606057, 0.698701, 0.775411, 0.806864
# elapsed time for k point: 0.029963970184326172
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.770564574149132 (0.348251% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.769310251064963 (0.0452834% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.769019114395907 (0.0105135% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.768934690302586 (0.00304893% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.768909981073336 (0.000892377% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.768906570865702 (0.000123161% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.768906112231446 (1.65637e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.768906047192105 (2.34892e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.259212, 0.293544, 0.450321, 0.556823, 0.599242, 0.699858, 0.771489, 0.811554
# elapsed time for k point: 0.03396105766296387
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.775952109007045 (0.331002% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.774883566195703 (0.0385003% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.774640990595858 (0.00874221% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.774561322146066 (0.00287135% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.774534832559596 (0.000954735% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.774531426698162 (0.000122754% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.77453086860795 (2.01148e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.774530459448286 (1.4747e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.774529880495122 (2.08667e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.774529581080342 (1.07916e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.774529533960834 (1.69829e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.268674, 0.289451, 0.441996, 0.569747, 0.590701, 0.700763, 0.768006, 0.817777
# elapsed time for k point: 0.04049038887023926
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.78600991213659 (0.314215% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.785094844019042 (0.0328505% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.784890638670822 (0.00733235% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.784815556442715 (0.00269609% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.784783051677048 (0.00116722% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.784775064783185 (0.000286805% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.784767419751373 (0.00027453% change)
#     large trace change predicted (0.00145957%)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 2.784726894164569 (0.00145527% change)
#     large trace change predicted (0.0056093%)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.784576814650401 (0.00538953% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.784434575035446 (0.00510825% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 2.784406388024439 (0.00101231% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.784404398363686 (7.14573e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.784404189792864 (7.49068e-06% change)
# Finished solving for bands 1 to 8 after 13 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.280092, 0.280155, 0.439082, 0.58087, 0.581035, 0.701106, 0.766461, 0.825015
# elapsed time for k point: 0.06183052062988281
# Fixing e-field (band 1) phase by -1 + 9.64667e-06i; max ampl. = 0.734996
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by -9.64667e-06 + -1i; max ampl. = 0.688282
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by -1 + 9.64576e-06i; max ampl. = 0.763717
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by -9.64667e-06 + -1i; max ampl. = 0.835041
# Outputting fields to e.k11.b04.z.tm.h5...
# Fixing e-field (band 5) phase by 1 + -9.64667e-06i; max ampl. = 0.9406
# Outputting fields to e.k11.b05.z.tm.h5...
# Fixing e-field (band 6) phase by 9.64667e-06 + 1i; max ampl. = 0.818782
# Outputting fields to e.k11.b06.z.tm.h5...
# Fixing e-field (band 7) phase by 1 + -9.64667e-06i; max ampl. = 1.66052
# Outputting fields to e.k11.b07.z.tm.h5...
# Fixing e-field (band 8) phase by 1 + -9.64667e-06i; max ampl. = 1.09079
# Outputting fields to e.k11.b08.z.tm.h5...
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.772740784291653 (1.31452% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.767396097763437 (0.192944% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.766393987922811 (0.0362178% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.766294435245555 (0.00359871% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.766278382899758 (0.000580285% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.766276105656077 (8.23216e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.766275760456969 (1.24788e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.766275720956362 (1.42793e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.244445, 0.307226, 0.448708, 0.559739, 0.597235, 0.699583, 0.773933, 0.80772
# elapsed time for k point: 0.034515380859375
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.771492862325917 (1.30016% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.766681128768135 (0.173766% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.765870729860534 (0.0292957% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.765784362011475 (0.00312268% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.76576896466428 (0.00055671% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.765766913865432 (7.41493e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.765766616621533 (1.07473e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.765766581577437 (1.26707e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.192601, 0.336978, 0.467722, 0.538055, 0.609757, 0.695231, 0.77985, 0.802206
# elapsed time for k point: 0.04329228401184082
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.791470680161977 (1.28313% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.787458947913228 (0.143817% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.786926198097606 (0.0191142% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.786856197208675 (0.00251179% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.786833403077189 (0.000817919% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.786827002095495 (0.000229687% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.786825618429586 (4.96502e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.786825460368362 (5.67173e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.132075, 0.365778, 0.483253, 0.517524, 0.627555, 0.689432, 0.753492, 0.835064
# elapsed time for k point: 0.06077766418457031
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 2.834933561210762 (1.30705% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 2.830404310478846 (0.159893% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.829621965678058 (0.0276446% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.829419475718046 (0.00715633% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.8293425780956 (0.00271782% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.829305743465432 (0.00130189% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.829276323019402 (0.00103985% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.829270955807994 (0.000189703% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.829270335801563 (2.1914e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.829270284334664 (1.81909e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0670312, 0.388874, 0.490908, 0.500671, 0.654295, 0.684452, 0.721561, 0.874451
# elapsed time for k point: 0.05910229682922363
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.886143985724221 (1.47203% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.874304705368532 (0.411054% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 2.867460985238925 (0.238384% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.9217%)
#     iteration    4: trace = 2.86397206518594 (0.121747% change)
#     switching back to exact line minimization
#     iteration    5: trace = 2.863259307978649 (0.0248901% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 2.863087425836183 (0.0060032% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.862987389555169 (0.00349406% change)
#     large trace change predicted (0.00747938%)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.862771629091654 (0.00753648% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.862593646474912 (0.00621734% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.862541842523826 (0.0018097% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.862503651639796 (0.00133417% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.862492616760774 (0.000385498% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.862491110630745 (5.2616e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.862490888003959 (7.77738e-06% change)
# Finished solving for bands 2 to 8 after 14 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.398513, 0.492888, 0.493368, 0.682486, 0.682532, 0.692015, 0.898224
# elapsed time for k point: 0.07553935050964355
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28009157008621677 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2801552424817495 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.3985126106182983 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4390817242893911 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4928881159193638 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4933684793954563 at Vector3<0.0, 0.0, 0.0> to 0.5808701373972318 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5810352477552739 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.6824860861033601 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.6825317466265789 at Vector3<0.0, 0.0, 0.0> to 0.7011061627078321 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 7 range: 0.6920145752444308 at Vector3<0.0, 0.0, 0.0> to 0.7841042625248503 at Vector3<0.0, 0.4, 0.0>
# Band 8 range: 0.7980077882525735 at Vector3<0.0, 0.4, 0.0> to 0.8982240443723342 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.28009157008621677) to band 2 (0.2801552424817495), 0.022730123261525164%
# Gap from band 2 (0.3985126106182983) to band 3 (0.4390817242893911), 9.687055411033523%
# Gap from band 3 (0.4928881159193638) to band 4 (0.4933684793954563), 0.09741146033890845%
# Gap from band 4 (0.5808701373972318) to band 5 (0.5810352477552739), 0.02842062015582246%
# Gap from band 5 (0.6824860861033601) to band 6 (0.6825317466265789), 0.006690099150929217%
# Gap from band 7 (0.7841042625248503) to band 8 (0.7980077882525735), 1.7575905222251695%
# total elapsed time for run: 1.7496185302734375
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.45, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 16 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01202702522277832
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 12.47910988096024 (195.4% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 5.7584445719949 (73.7014% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 4.896432913364121 (16.1806% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.647003367523678 (5.22725% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 4.555517654720976 (1.98828% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 4.511490025251305 (0.971161% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.3261%)
#     iteration    7: trace = 4.4905936763807 (0.464256% change)
#     iteration    8: trace = 4.477082160771181 (0.301338% change)
#     iteration    9: trace = 4.46718833586576 (0.221233% change)
#     switching back to exact line minimization
#     iteration   10: trace = 4.461613499991744 (0.124873% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.458747674131253 (0.0642536% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 4.457767266006051 (0.0219908% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 4.457403075319601 (0.00817013% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.457243543551678 (0.00357909% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.457153616447711 (0.00201757% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.457099540657865 (0.00121324% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.457063689735742 (0.000804359% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.457016220161547 (0.00106505% change)
#     large trace change predicted (0.00259497%)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 4.456900645590522 (0.00259313% change)
#     large trace change predicted (0.00999664%)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 4.456464315064608 (0.00979048% change)
#     large trace change predicted (0.0258895%)
#     linmin: converged after 5 iterations.
#     iteration   21: trace = 4.455399168832818 (0.023904% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 4.454148641431145 (0.0280716% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 4.453350658377351 (0.0179171% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 4.452854852571939 (0.0111339% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 4.452457545314751 (0.00892293% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 4.452172257002405 (0.00640764% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 4.452022594690607 (0.00336161% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 4.451973816319907 (0.00109565% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 4.451959627722688 (0.000318704% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 4.451954265169638 (0.000120454% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 4.451952007014686 (5.07228e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 4.451950950409704 (2.37335e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 4.451950395181342 (1.24716e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 4.451950125290261 (6.06231e-06% change)
# Finished solving for bands 2 to 8 after 34 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.656836, 0.715623, 0.716068, 0.738377, 0.825979, 0.827163, 1.04116
# elapsed time for k point: 0.1926414966583252
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.475977613335646 (0.531437% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.47009148782073 (0.131591% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.46828516977159 (0.0404171% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 4.467381098579866 (0.0202351% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.466751527431661 (0.0140936% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.466323675641489 (0.00957905% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.465938561609463 (0.00862299% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.465658598507386 (0.00626905% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 4.465309452565506 (0.00781877% change)
#     large trace change predicted (0.0159041%)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 4.464599869156991 (0.0158923% change)
#     large trace change predicted (0.0388854%)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 4.462899583601782 (0.038091% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 4.460834647046505 (0.0462797% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 4.459593645505276 (0.0278238% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 4.459122383562798 (0.0105679% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 4.458965981451563 (0.00350753% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.458930949842968 (0.000785647% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.458912695767165 (0.000409383% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.458904420393768 (0.000185592% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 4.458899411921858 (0.000112325% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 4.458897212945135 (4.93166e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 4.458896134523028 (2.41859e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 4.458895582466276 (1.2381e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 4.458895241707639 (7.64222e-06% change)
# Finished solving for bands 1 to 8 after 23 iterations.
# tefreqs:, 2, 0, 0.1, 0, 0.11547, 0.0694821, 0.652351, 0.679959, 0.706966, 0.760813, 0.839484, 0.84298, 1.03546
# elapsed time for k point: 0.11209416389465332
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.491973318248126 (0.546108% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.485573875799697 (0.142565% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.483425299919855 (0.0479112% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.482531543913341 (0.0199367% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.482148967105053 (0.0085352% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.481989421513277 (0.00355964% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.481888476691488 (0.00225226% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.481822036963047 (0.00148242% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.481765442975369 (0.00126275% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.481700106135516 (0.00145785% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.481632589252468 (0.00150651% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.481585790356683 (0.00104424% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.481566097340197 (0.000439422% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.481558600236087 (0.000167288% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.481555958444037 (5.89481e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.481555114619189 (1.88288e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.481554758291241 (7.95099e-06% change)
# Finished solving for bands 1 to 8 after 17 iterations.
# tefreqs:, 3, 0, 0.2, 0, 0.23094, 0.137272, 0.615214, 0.658316, 0.688898, 0.777327, 0.869983, 0.879951, 1.02022
# elapsed time for k point: 0.09568309783935547
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.543022603043585 (0.515557% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.537383129202369 (0.124212% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.535411593800111 (0.0434604% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.534688691969544 (0.0159403% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.534407552167154 (0.00619995% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.534314533605841 (0.00205141% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.534272798991059 (0.000920422% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.53425644484884 (0.000360679% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.5342503261882 (0.000134943% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.534247118041487 (7.07537e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.534244864866252 (4.96924e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.53424275209829 (4.65958e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 58.8225%)
#     iteration   13: trace = 4.534241203186395 (3.41603e-05% change)
#     iteration   14: trace = 4.534240289647146 (2.01476e-05% change)
#     iteration   15: trace = 4.534239879248345 (9.0511e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 4, 0, 0.3, 0, 0.34641, 0.200458, 0.560713, 0.652934, 0.672026, 0.788475, 0.905474, 0.920288, 1.00658
# elapsed time for k point: 0.07575440406799316
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.62139534197045 (0.557288% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.6140325425743 (0.159447% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.0439%)
#     iteration    3: trace = 4.610471685850432 (0.0772043% change)
#     switching back to exact line minimization
#     iteration    4: trace = 4.608707294077663 (0.0382765% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.607861190875976 (0.0183605% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.607530347241265 (0.00718024% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.60737382955941 (0.00339706% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.607318087737729 (0.00120985% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.607296856834155 (0.000460809% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.607286337884287 (0.000228311% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.607280074923068 (0.000135936% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.607276079423558 (8.67215e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.60727436111866 (3.72955e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.607273708848317 (1.41574e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.60727351050092 (4.30509e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 5, 0, 0.4, 0, 0.46188, 0.251902, 0.513413, 0.649737, 0.660743, 0.79604, 0.93646, 0.952374, 1.00191
# elapsed time for k point: 0.06807804107666016
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.692436579458364 (0.712898% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.67858535886869 (0.295618% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.669219094457175 (0.200395% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 69.6164%)
#     iteration    4: trace = 4.66299541595156 (0.133381% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.65938761631716 (0.0774008% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.657417900603706 (0.0422831% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.656218647301232 (0.0257526% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.655575779673004 (0.0138076% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.655146142472559 (0.00922887% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.654835604314725 (0.00667108% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.654665348780464 (0.00365767% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.6546050692924 (0.00129504% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.654589929362535 (0.000325268% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.654585699344887 (9.08785e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.654584521643363 (2.5302e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.654584087227843 (9.33307e-06% change)
# Finished solving for bands 1 to 8 after 16 iterations.
# tefreqs:, 6, 0, 0.5, 0, 0.57735, 0.274155, 0.492434, 0.648615, 0.656803, 0.798817, 0.949956, 0.963485, 1.00797
# elapsed time for k point: 0.07422518730163574
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.663378776852213 (0.12598% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.661011963659698 (0.0507661% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.659455005774085 (0.0334094% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.658442013261265 (0.0217429% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.658017223406842 (0.00911913% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.657889477609505 (0.00274253% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.657833250273717 (0.00120715% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.657811994377083 (0.000456348% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.65780487389073 (0.000152872% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.657803272258105 (3.4386e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.657802734702861 (1.1541e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.657802572516393 (3.48204e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.276103, 0.493884, 0.623964, 0.680084, 0.79654, 0.952442, 0.963435, 1.00796
# elapsed time for k point: 0.0648806095123291
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.672732450198873 (0.129693% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.670212444226119 (0.0539446% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.668592709726676 (0.0346883% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.667637777658791 (0.0204565% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.66726515890644 (0.00798334% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.667163440324637 (0.00217943% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.667121643737455 (0.00089555% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.66710613629633 (0.00033227% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.667099791640178 (0.000135944% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.667097860859288 (4.137e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.667096984960311 (1.87675e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.667096658165868 (7.00209e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.281494, 0.498189, 0.595471, 0.70467, 0.790197, 0.959226, 0.963379, 1.00792
# elapsed time for k point: 0.06076550483703613
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.687240398973847 (0.138208% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.684500175789315 (0.0584784% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.682870634535869 (0.0347919% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 78.8771%)
#     iteration    4: trace = 4.682035436411196 (0.0178368% change)
#     iteration    5: trace = 4.681731984310602 (0.00648141% change)
#     iteration    6: trace = 4.681656386263874 (0.00161476% change)
#     iteration    7: trace = 4.681630436265978 (0.000554292% change)
#     iteration    8: trace = 4.681622191360193 (0.000176112% change)
#     iteration    9: trace = 4.681618661817945 (7.53915e-05% change)
#     switching back to exact line minimization
#     iteration   10: trace = 4.681617196486724 (3.12997e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.681616182379724 (2.16615e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.681615658381357 (1.11927e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.681615352491791 (6.53385e-06% change)
# Finished solving for bands 1 to 8 after 13 iterations.
# tefreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.288945, 0.505245, 0.568143, 0.726282, 0.780907, 0.962873, 0.969263, 1.00805
# elapsed time for k point: 0.06284594535827637
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.705688256290328 (0.150477% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.702699449980013 (0.0635349% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.701075181271681 (0.034545% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.700330026022922 (0.015852% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.700069085398512 (0.00555169% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.700002141427403 (0.00142433% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.699980797085917 (0.000454136% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.699974019415679 (0.000144206% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.699970735977545 (6.98608e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.699968609553537 (4.52434e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.699966364340109 (4.77708e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.699964771374955 (3.38931e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.699963719323964 (2.23842e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.699962907559941 (1.72717e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.699961996310137 (1.93884e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.699961285860064 (1.51161e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.699960932396825 (7.52056e-06% change)
# Finished solving for bands 1 to 8 after 17 iterations.
# tefreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.29604, 0.514888, 0.544209, 0.744263, 0.76985, 0.962862, 0.97895, 1.00946
# elapsed time for k point: 0.07113099098205566
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.72608829318421 (0.165635% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.722801101610158 (0.0695784% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.72110958448599 (0.0358224% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.72032704714369 (0.0165767% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.720031014298933 (0.00627164% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.719921116073978 (0.00232836% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.719868000254256 (0.00112536% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.719834530978109 (0.000709117% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.719810287031157 (0.000513662% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.719793386627638 (0.000358074% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.719782722167353 (0.000225952% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.719773199863716 (0.000201753% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.719758991445275 (0.000301041% change)
#     large trace change predicted (0.000804704%)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 4.719721046592946 (0.000803961% change)
#     large trace change predicted (0.001756%)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 4.719638530310171 (0.00174834% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 4.719538652731047 (0.00211623% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 4.719445605154375 (0.00197156% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 4.71934152321329 (0.00220541% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 4.719249914995094 (0.00194114% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 4.719204710467071 (0.00095788% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 4.719182025898163 (0.000480687% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 4.719173555625852 (0.000179486% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 4.719169581555692 (8.42112e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 4.719167521305189 (4.36571e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 4.71916595937293 (3.30976e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 4.71916513480479 (1.74728e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 4.719164883071519 (5.33428e-06% change)
# Finished solving for bands 1 to 8 after 27 iterations.
# tefreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.299305, 0.526635, 0.526971, 0.757838, 0.758439, 0.962922, 0.983456, 1.01518
# elapsed time for k point: 0.11659026145935059
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.692897136913456 (0.97038% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.672453437308094 (0.436582% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.661336687177818 (0.238204% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.656896440007757 (0.0953023% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.655008229333129 (0.0405548% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.654399344063266 (0.0130811% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.654116778257407 (0.00607112% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.654018646569462 (0.00210851% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.653979882115134 (0.000832928% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.653966049809292 (0.000297215% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.65396037117639 (0.000122017% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.653958353088361 (4.33628e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.653957587767751 (1.64445e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.653957246474231 (7.3334e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.280656, 0.522942, 0.556626, 0.735071, 0.77423, 0.95812, 0.968138, 0.99842
# elapsed time for k point: 0.0900123119354248
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.588904748556282 (0.874484% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.575239308478491 (0.298237% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.569222846856472 (0.131587% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.567127898341315 (0.0458596% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.566230707130194 (0.0196465% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.565933557403285 (0.00650776% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.565803216955198 (0.00285467% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.565757285717436 (0.00100599% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.565743654776245 (0.000298548% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.565739626756244 (8.82227e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.565738205611876 (3.11263e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.56573774976305 (9.98412e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 13, -0.2, 0.2, 0, 0.4, 0.227959, 0.557659, 0.592002, 0.715363, 0.778635, 0.930406, 0.931674, 1.00032
# elapsed time for k point: 0.05095553398132324
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.508633066695135 (0.753401% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.499722782261828 (0.197823% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.496662620169689 (0.0680309% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.495746843207391 (0.0203678% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.495430452900574 (0.00703779% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.495345385179927 (0.00189233% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.495315603923911 (0.000662493% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.495303669405274 (0.000265488% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.7441%)
#     iteration    9: trace = 4.495300571861137 (6.89063e-05% change)
#     switching back to exact line minimization
#     iteration   10: trace = 4.495299806681547 (1.70218e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.495299632264881 (3.87998e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.157628, 0.611565, 0.627491, 0.703542, 0.775273, 0.887377, 0.887503, 1.01567
# elapsed time for k point: 0.0712428092956543
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.473864535042213 (0.708432% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.466337295360526 (0.168391% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.464014652518035 (0.0520168% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 4.463224196871957 (0.0177088% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.462870602336698 (0.00792272% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.462724035374626 (0.00328419% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.462635255819478 (0.00198938% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.462589773852295 (0.00101918% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.462576111578151 (0.000306152% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.462571879666226 (9.48312e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.462570562891024 (2.95071e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.462570155785365 (9.12267e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0801245, 0.65125, 0.670687, 0.706804, 0.763085, 0.844811, 0.846761, 1.03423
# elapsed time for k point: 0.05954265594482422
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.478657745303382 (0.729581% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.469040915509171 (0.214956% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.465024236861274 (0.0899183% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.46210062497872 (0.0654995% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.460047446882476 (0.0460243% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.459144833561426 (0.0202398% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 70.6739%)
#     iteration    7: trace = 4.45874149206352 (0.00904567% change)
#     iteration    8: trace = 4.458626733896416 (0.00257381% change)
#     iteration    9: trace = 4.458596442387455 (0.000679393% change)
#     iteration   10: trace = 4.458587879312192 (0.000192058% change)
#     iteration   11: trace = 4.458585333600011 (5.70968e-05% change)
#     iteration   12: trace = 4.458584617520103 (1.60607e-05% change)
#     iteration   13: trace = 4.45858440569769 (4.75089e-06% change)
# Finished solving for bands 2 to 8 after 13 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.656836, 0.715623, 0.716068, 0.738377, 0.825979, 0.827163, 1.04434
# elapsed time for k point: 0.056026458740234375
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2993049537891748 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.49243429376740583 at Vector3<0.0, 0.5, 0.0> to 0.6568362742504535 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.5269710575647916 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.7156232282477605 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.6568031514330035 at Vector3<0.0, 0.5, 0.0> to 0.7578382268141542 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7383774307814258 at Vector3<0.0, 0.0, 0.0> to 0.7988168947093482 at Vector3<0.0, 0.5, 0.0>
# Band 6 range: 0.8259787203932638 at Vector3<0.0, 0.0, 0.0> to 0.9629215554729001 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 7 range: 0.8271634581038657 at Vector3<0.0, 0.0, 0.0> to 0.9834563687427669 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 0.9984202143768408 at Vector3<-0.26666666666666666, 0.26666666666666666, 0.0> to 1.0443365634758972 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2993049537891748) to band 2 (0.49243429376740583), 48.78609733551936%
# Gap from band 5 (0.7988168947093482) to band 6 (0.8259787203932638), 3.3434144493552425%
# Gap from band 7 (0.9834563687427669) to band 8 (0.9984202143768408), 1.5100683626343505%
# total elapsed time for run: 1.3363687992095947
# done

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = range(len(tm_freqs))
# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 1])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'M', 'K', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
import numpy as np
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))
# Out:
# epsilon: 1-12, mean 3.91953, harm. mean 1.37943, 32.7148% > 1, 26.5412% "fill"
# real part range: 1 .. 12
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.45, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 16 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.014463663101196289
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 8.589993320583334 (196.589% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 3.195728810162862 (91.539% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.920977609775408 (8.98363% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.883470506989167 (1.29236% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.872580670871383 (0.378379% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.868716431110879 (0.134612% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.866257636386934 (0.0857474% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.865040594837578 (0.04247% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 2.864638354629706 (0.0140406% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.864118150616581 (0.0181611% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.863090966479828 (0.0358703% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.6634%)
#     iteration   12: trace = 2.862644199010344 (0.0156056% change)
#     iteration   13: trace = 2.862557582453948 (0.0030258% change)
#     iteration   14: trace = 2.862526221584639 (0.00109556% change)
#     iteration   15: trace = 2.862507960456096 (0.00063794% change)
#     iteration   16: trace = 2.862500933472867 (0.000245484% change)
#     iteration   17: trace = 2.862498797325239 (7.46252e-05% change)
#     iteration   18: trace = 2.862496852865594 (6.79288e-05% change)
#     iteration   19: trace = 2.862493687909799 (0.000110566% change)
#     iteration   20: trace = 2.86249149967542 (7.64451e-05% change)
#     iteration   21: trace = 2.862490855427291 (2.25066e-05% change)
#     iteration   22: trace = 2.862490762738366 (3.23805e-06% change)
# Finished solving for bands 2 to 8 after 22 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.398513, 0.492888, 0.493368, 0.682486, 0.682532, 0.692015, 0.898224
# elapsed time for k point: 0.8144497871398926
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.859286149144711 (1.54909% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.1775%)
#     iteration    2: trace = 2.84276090057395 (0.579625% change)
#     iteration    3: trace = 2.837700534363195 (0.178167% change)
#     iteration    4: trace = 2.836741798464796 (0.0337914% change)
#     switching back to exact line minimization
#     iteration    5: trace = 2.836200893089336 (0.0190697% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.4021%)
#     iteration    6: trace = 2.835597990738763 (0.0212597% change)
#     iteration    7: trace = 2.835329150883571 (0.00948134% change)
#     iteration    8: trace = 2.835307111343884 (0.000777322% change)
#     iteration    9: trace = 2.83530312917434 (0.000140449% change)
#     iteration   10: trace = 2.835301946138833 (4.17252e-05% change)
#     switching back to exact line minimization
#     iteration   11: trace = 2.835301595485349 (1.23674e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.835301494806031 (3.55092e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0581198, 0.391139, 0.491701, 0.498714, 0.658377, 0.683973, 0.717136, 0.879138
# elapsed time for k point: 0.05247926712036133
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.801024353501782 (1.13528% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.7355%)
#     iteration    2: trace = 2.796629862241949 (0.157012% change)
#     switching back to exact line minimization
#     iteration    3: trace = 2.795920864922495 (0.0253551% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.795766616911864 (0.00551705% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.3667%)
#     iteration    5: trace = 2.795669957059205 (0.00345742% change)
#     iteration    6: trace = 2.7956377828147 (0.00115087% change)
#     switching back to exact line minimization
#     iteration    7: trace = 2.79563140428231 (0.00022816% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.0735%)
#     iteration    8: trace = 2.795630929637474 (1.69781e-05% change)
#     iteration    9: trace = 2.795630880594408 (1.75428e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.114967, 0.372435, 0.488376, 0.510297, 0.634188, 0.687769, 0.745313, 0.845031
# elapsed time for k point: 0.05272364616394043
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.77499789209149 (0.95681% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.772244692202353 (0.0992637% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.771711745687338 (0.0192262% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.9355%)
#     iteration    4: trace = 2.771603049351045 (0.00392171% change)
#     iteration    5: trace = 2.771573334806567 (0.00107211% change)
#     iteration    6: trace = 2.771567874186102 (0.000197023% change)
#     iteration    7: trace = 2.771565848742431 (7.30794e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 2.771565436092012 (1.48887e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.7242%)
#     iteration    9: trace = 2.771565393905146 (1.52213e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.169005, 0.346637, 0.484408, 0.520098, 0.618254, 0.692346, 0.770438, 0.813964
# elapsed time for k point: 0.04796767234802246
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.769862916607907 (0.914067% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.542%)
#     iteration    2: trace = 2.766236542083034 (0.131008% change)
#     switching back to exact line minimization
#     iteration    3: trace = 2.764990814502329 (0.0450434% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.4645%)
#     iteration    4: trace = 2.764690919622364 (0.0108467% change)
#     switching back to exact line minimization
#     iteration    5: trace = 2.764623518652201 (0.00243795% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.764618232737507 (0.000191199% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.764617446201336 (2.84501e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.7802%)
#     iteration    8: trace = 2.764617148435372 (1.07706e-05% change)
#     switching back to exact line minimization
#     iteration    9: trace = 2.764617097731082 (1.83404e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.217539, 0.316063, 0.481302, 0.523954, 0.612544, 0.695969, 0.784104, 0.798008
# elapsed time for k point: 0.06540799140930176
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.776059200033972 (0.9315% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.4111%)
#     iteration    2: trace = 2.769429742968514 (0.239094% change)
#     iteration    3: trace = 2.76640956244722 (0.109114% change)
#     iteration    4: trace = 2.765655546529666 (0.0272598% change)
#     switching back to exact line minimization
#     iteration    5: trace = 2.765522389251286 (0.00481479% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.765515088350774 (0.000263998% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.7655147013283 (1.39946e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.765514668047468 (1.20342e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.246221, 0.2936, 0.480139, 0.524322, 0.612077, 0.697337, 0.77948, 0.802954
# elapsed time for k point: 0.036652565002441406
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.767582749054925 (0.367579% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.766063434269089 (0.0549119% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.2452%)
#     iteration    3: trace = 2.765729120595732 (0.012087% change)
#     iteration    4: trace = 2.765669427738432 (0.00215833% change)
#     iteration    5: trace = 2.765658295679034 (0.000402509% change)
#     switching back to exact line minimization
#     iteration    6: trace = 2.765656674849626 (5.86056e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.765656191114204 (1.74908e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.7545%)
#     iteration    8: trace = 2.765656108635212 (2.98226e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.247714, 0.293902, 0.474174, 0.530395, 0.610517, 0.697722, 0.778384, 0.803945
# elapsed time for k point: 0.07023048400878906
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.2605%)
#     iteration    1: trace = 2.768280477156591 (0.361641% change)
#     iteration    2: trace = 2.766861368347803 (0.0512763% change)
#     switching back to exact line minimization
#     iteration    3: trace = 2.766538849290629 (0.0116572% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.3344%)
#     iteration    4: trace = 2.766463903037649 (0.00270906% change)
#     iteration    5: trace = 2.766444673971406 (0.00069508% change)
#     iteration    6: trace = 2.766441155882533 (0.00012717% change)
#     switching back to exact line minimization
#     iteration    7: trace = 2.766440488616345 (2.412e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 57.4866%)
#     iteration    8: trace = 2.766440405319435 (3.01098e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.252117, 0.294341, 0.462144, 0.543033, 0.606057, 0.698701, 0.775411, 0.806864
# elapsed time for k point: 0.04452705383300781
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.2472%)
#     iteration    1: trace = 2.770564520816039 (0.348251% change)
#     switching back to exact line minimization
#     iteration    2: trace = 2.769310231672868 (0.0452822% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.769019105536014 (0.0105131% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.768934687461248 (0.00304871% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.768909980871571 (0.000892282% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.768906570728456 (0.000123158% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.768906112157218 (1.65615e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 62.6748%)
#     iteration    8: trace = 2.768906047148892 (2.3478e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.259212, 0.293544, 0.450321, 0.556823, 0.599242, 0.699858, 0.771489, 0.811554
# elapsed time for k point: 0.06094050407409668
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.775952062494615 (0.331001% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.774883541611832 (0.0384995% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.774640982763986 (0.00874161% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.774561320885347 (0.00287111% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.774534832380465 (0.000954696% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.774531426567511 (0.000122753% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.77453086849893 (2.0114e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.774530459384317 (1.47454e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.774529880484671 (2.08648e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.774529581080073 (1.07912e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.774529533960829 (1.69828e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.268674, 0.289451, 0.441996, 0.569747, 0.590701, 0.700763, 0.768006, 0.817777
# elapsed time for k point: 0.06432485580444336
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.786009912150329 (0.314215% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.785094844026517 (0.0328505% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.784890638674356 (0.00733235% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.784815556444451 (0.00269609% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.784783051678397 (0.00116722% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.784775064784536 (0.000286805% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.784767419752704 (0.00027453% change)
#     large trace change predicted (0.00145957%)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 2.78472689416597 (0.00145527% change)
#     large trace change predicted (0.0056093%)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.784576814652094 (0.00538953% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.784434575036425 (0.00510825% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 2.784406388024744 (0.00101231% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.784404398363805 (7.14573e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.7844041897929 (7.49068e-06% change)
# Finished solving for bands 1 to 8 after 13 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.280092, 0.280155, 0.439082, 0.58087, 0.581035, 0.701106, 0.766461, 0.825015
# elapsed time for k point: 0.05900931358337402
# Fixing e-field (band 1) phase by -1 + -6.19584e-06i; max ampl. = 0.734996
# Fixing e-field (band 2) phase by 6.19584e-06 + -1i; max ampl. = 0.688282
# Fixing e-field (band 3) phase by -1 + -6.1947e-06i; max ampl. = 0.763717
# Fixing e-field (band 4) phase by 6.19584e-06 + -1i; max ampl. = 0.835041
# Fixing e-field (band 5) phase by -1 + -6.19584e-06i; max ampl. = 0.9406
# Fixing e-field (band 6) phase by -6.19584e-06 + 1i; max ampl. = 0.818782
# Fixing e-field (band 7) phase by -1 + -6.19582e-06i; max ampl. = 1.66052
# Fixing e-field (band 8) phase by 1 + 6.19584e-06i; max ampl. = 1.09079
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.772740784287918 (1.31452% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.767396097762529 (0.192944% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.766393987922718 (0.0362178% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.766294435245542 (0.00359871% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.766278382899756 (0.000580285% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.766276105656075 (8.23216e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.766275760456969 (1.24788e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.766275720956362 (1.42793e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.244445, 0.307226, 0.448708, 0.559739, 0.597235, 0.699583, 0.773933, 0.80772
# elapsed time for k point: 0.04540371894836426
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.771492862325923 (1.30016% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.766681128768137 (0.173766% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.765870729860535 (0.0292957% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.765784362011475 (0.00312268% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.765768964664279 (0.00055671% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.765766913865432 (7.41493e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.765766616621533 (1.07473e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.765766581577439 (1.26707e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.192601, 0.336978, 0.467722, 0.538055, 0.609757, 0.695231, 0.77985, 0.802206
# elapsed time for k point: 0.03853940963745117
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.791470680161977 (1.28313% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.787458947913229 (0.143817% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.786926198097606 (0.0191142% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.786856197208675 (0.00251179% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.78683340307719 (0.000817919% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.786827002095495 (0.000229687% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.786825618429586 (4.96502e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.786825460368361 (5.67173e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.132075, 0.365778, 0.483253, 0.517524, 0.627555, 0.689432, 0.753492, 0.835064
# elapsed time for k point: 0.035733938217163086
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 2.834933561210762 (1.30705% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 2.830404310478849 (0.159893% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.829621965678059 (0.0276446% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.829419475718044 (0.00715633% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.8293425780956 (0.00271782% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.829305743465432 (0.00130189% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.829276323019402 (0.00103985% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.829270955807996 (0.000189703% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.829270335801564 (2.1914e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.829270284334666 (1.81909e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0670312, 0.388874, 0.490908, 0.500671, 0.654295, 0.684452, 0.721561, 0.874451
# elapsed time for k point: 0.04724884033203125
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.886143985724219 (1.47203% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.874304705368531 (0.411054% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 2.867460985238924 (0.238384% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 2.863972065185938 (0.121747% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.863259287707212 (0.0248908% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 2.863087056363486 (0.0060154% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.862987399912071 (0.00348079% change)
#     large trace change predicted (0.00750298%)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.862770963613039 (0.00756009% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.862591906560302 (0.00625487% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.862540785647407 (0.00178584% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.862503520606527 (0.00130183% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.86249261361342 (0.000381031% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.862491126853094 (5.19394e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.862490902483343 (7.83827e-06% change)
# Finished solving for bands 2 to 8 after 14 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.398513, 0.492888, 0.493368, 0.682486, 0.682532, 0.692015, 0.898224
# elapsed time for k point: 0.0672156810760498
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2800915700862181 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2801552424817516 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.3985126107848269 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.43908172428939196 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4928881065194116 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4933684782677049 at Vector3<0.0, 0.0, 0.0> to 0.580870137397233 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5810352477552747 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.6824860816099833 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.6825317461005779 at Vector3<0.0, 0.0, 0.0> to 0.7011061627078331 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 7 range: 0.6920145753880764 at Vector3<0.0, 0.0, 0.0> to 0.7841042625231613 at Vector3<0.0, 0.4, 0.0>
# Band 8 range: 0.7980077882476188 at Vector3<0.0, 0.4, 0.0> to 0.8982240524295511 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2800915700862181) to band 2 (0.2801552424817516), 0.02273012326180246%
# Gap from band 2 (0.3985126107848269) to band 3 (0.43908172428939196), 9.687055369344213%
# Gap from band 3 (0.4928881065194116) to band 4 (0.4933684782677049), 0.09741313887338636%
# Gap from band 4 (0.580870137397233) to band 5 (0.5810352477552747), 0.028420620155745972%
# Gap from band 5 (0.6824860816099833) to band 6 (0.6825317461005779), 0.006690680468431803%
# Gap from band 7 (0.7841042625231613) to band 8 (0.7980077882476188), 1.7575905218197196%
# total elapsed time for run: 1.6224150657653809
# done

# %%
# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='RdBu', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# real part range: -0.381464 .. 0.734588
# imag part range: -0.637588 .. 0.637588
# real part range: -0.689468 .. 0.689468
# imag part range: -0.635696 .. 0.634891
# real part range: -0.664561 .. 0.763717
# imag part range: -0.674646 .. 0.674646
# real part range: -0.830318 .. 0.830318
# imag part range: -0.812233 .. 0.804282
# real part range: -0.753307 .. 0.9406
# imag part range: -0.814584 .. 0.814584
# real part range: -0.821613 .. 0.821613
# imag part range: -0.737388 .. 0.740909
# real part range: -0.829097 .. 1.658
# imag part range: -1.43593 .. 1.43593
# real part range: -0.890974 .. 1.09079
# imag part range: -0.944649 .. 0.944649

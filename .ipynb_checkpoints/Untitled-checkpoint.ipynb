# %%
import math

import meep as mp
from meep import mpb

# A triangular lattice of dielectric rods in air.  (This structure has
# a band_gap for TM fields.)  This file is used in the "Data Analysis
# Tutorial" section of the MPB manual.

num_bands = 8


nslab = 2.48
slab = mp.Medium(index=nslab)


# 注意这里的周期方向，要与图中一致，推导已经给出了
geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(0.5,math.sqrt(3) / 2),
    basis2=mp.Vector3(1, 0),
)

s=0.125
vertices1 = [mp.cartesian_to_lattice(mp.Vector3(-1*s,-1*s),geometry_lattice),
             mp.cartesian_to_lattice(mp.Vector3(-1*s,1*s),geometry_lattice),
             mp.cartesian_to_lattice(mp.Vector3(s*1,s*1),geometry_lattice),
             mp.cartesian_to_lattice(mp.Vector3(1*s,-1*s),geometry_lattice)]

# vertices1 = [mp.Vector3(-1*s,-1*s),
#             mp.Vector3(-1*s,1*s),
#             mp.Vector3(s*1,s*1),
#             mp.Vector3(1*s,-1*s)]

# 实际结构只需要画一个就行
# geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]
geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab)]


# 注意倒格矢空间
k_points = [
    mp.Vector3(),  # Gamma
    mp.Vector3(y=0.5),  # M
    mp.Vector3(1 / -3, 1 / 3),  # K
    mp.Vector3(),  # Gamma
]

k_points = mp.interpolate(4, k_points)

resolution = 32

ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands,
)

ms.run_tm()
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
# ms.run_te()
# te_freqs = ms.all_freqs
# te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (1, 0, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (-0, 1.1547, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      prism, center = (0,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-0.144338,-0.0528312,-5e+19)
#           (0.144338,-0.197169,-5e+19)
#           (0.144338,0.0528312,-5e+19)
#           (-0.144338,0.197169,-5e+19)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.013142824172973633
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 24.77428601260156 (193.424% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 9.031087613970245 (93.1402% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 7.938303691078733 (12.8795% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 7.727235657265138 (2.69468% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.640992318540557 (1.12236% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 7.599231382562341 (0.548036% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.1881%)
#     iteration    7: trace = 7.587739876430301 (0.151334% change)
#     iteration    8: trace = 7.584847604392736 (0.038125% change)
#     iteration    9: trace = 7.583753657554178 (0.0144238% change)
#     switching back to exact line minimization
#     iteration   10: trace = 7.583473463822011 (0.00369473% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.583393663283235 (0.0010523% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.58335822778768 (0.000467279% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.583347386563374 (0.000142961% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7.583345915320093 (1.9401e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 7.583345769864744 (1.91809e-06% change)
# Finished solving for bands 2 to 8 after 15 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.707948, 0.792786, 0.931645, 1.08061, 1.13496, 1.15089, 1.34361
# elapsed time for k point: 0.05784177780151367
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.618501183978122 (0.547319% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 7.598827160781494 (0.258574% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.589868323173302 (0.117967% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.588263052165599 (0.0211524% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.588012290745858 (0.00330465% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.587936455110401 (0.000999419% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.587914136134524 (0.000294138% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.587908262444641 (7.74085e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.587907009694874 (1.65098e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.587906815941102 (2.55345e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0936054, 0.694458, 0.797438, 0.92906, 1.06244, 1.10103, 1.22083, 1.32903
# elapsed time for k point: 0.08321356773376465
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.653327267593421 (0.426491% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.645123580619386 (0.107249% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.642827608981529 (0.0300364% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.642339599911949 (0.00638539% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.642238048042397 (0.00132881% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.642213785745187 (0.000317477% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.642209492657907 (5.6176e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.642208394040797 (1.43756e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.64220800551785 (5.08391e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.185465, 0.662154, 0.802908, 0.914245, 1.02386, 1.12146, 1.27415, 1.32643
# elapsed time for k point: 0.07068133354187012
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.771970301575721 (0.452745% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.756748232727427 (0.196051% change)
#     large trace change predicted (0.609981%)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.722378503991086 (0.444078% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 7.67462503799659 (0.620296% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 7.633537270592113 (0.536809% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.613706595583489 (0.260121% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 7.609306662297662 (0.0578063% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.608321004319865 (0.0129542% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.608081273880091 (0.00315095% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.608000494442475 (0.00106176% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.607953425777993 (0.000618675% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.607928606080332 (0.000326234% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.607920595938182 (0.000105287% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7.607918525408634 (2.72155e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 7.607918119676992 (5.33302e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.27278, 0.618995, 0.803887, 0.880065, 1.02374, 1.15205, 1.25011, 1.3385
# elapsed time for k point: 0.11091399192810059
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.487726138149004 (0.432735% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.483223526533681 (0.0601513% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 7.482767375401446 (0.00609584% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.48269295274409 (0.000994592% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.482684157710491 (0.000117538% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.482682445554389 (2.28816e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.482682157957727 (3.8435e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.348358, 0.570921, 0.804148, 0.847616, 1.04207, 1.17729, 1.22861, 1.29956
# elapsed time for k point: 0.05533623695373535
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.443187143702662 (0.3662% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.440081296232963 (0.0417361% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 7.439897452522226 (0.00247102% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.439876500417087 (0.000281619% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.439874673935156 (2.45499e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.439874557853114 (1.56027e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.385513, 0.543035, 0.80547, 0.834024, 1.05272, 1.18036, 1.23315, 1.27666
# elapsed time for k point: 0.04398322105407715
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.452103034980095 (0.159812% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.449959629264976 (0.0287666% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 7.449790431875883 (0.00227114% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.449771055529878 (0.000260093% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.449768684777053 (3.18232e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.449768365396373 (4.28712e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.387265, 0.54642, 0.776003, 0.862495, 1.05077, 1.16919, 1.23432, 1.2886
# elapsed time for k point: 0.05148148536682129
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.481074237929695 (0.165554% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.478471896231973 (0.0347917% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 7.478137691850746 (0.00446899% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.478081848792066 (0.000746754% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.478075259482573 (8.8115e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.478074535471663 (9.68178e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.392206, 0.556352, 0.735664, 0.89985, 1.0454, 1.14536, 1.23751, 1.3144
# elapsed time for k point: 0.05094289779663086
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.524707394589062 (0.182369% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.520992054892996 (0.0493874% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.520253027204512 (0.00982668% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.520120127202219 (0.00176724% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.520103318248117 (0.00022352% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.520101212750313 (2.79983e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.520100969458692 (3.23522e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.399308, 0.572079, 0.695673, 0.934657, 1.03836, 1.11887, 1.24203, 1.34281
# elapsed time for k point: 0.0630490779876709
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.574049306831434 (0.213778% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.568171875387455 (0.0776297% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.566557196591331 (0.0213374% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.566207261196301 (0.00462487% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.56613551966028 (0.000948188% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.566121540975042 (0.000184753% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.566118891899854 (3.50123e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.566118476668878 (5.48803e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.40653, 0.591499, 0.659777, 0.961695, 1.03482, 1.09347, 1.2468, 1.3674
# elapsed time for k point: 0.07479166984558105
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 7.613476765248044 (0.25618% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.604489946699871 (0.118108% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.601367867486131 (0.0410642% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.600412400210148 (0.0125705% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.600121936343848 (0.00382176% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.600059210405237 (0.000825331% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.60004685008183 (0.000162635% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.600045148691471 (2.23866e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.60004487691898 (3.57593e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.410197, 0.602956, 0.642136, 0.970614, 1.04561, 1.07071, 1.25031, 1.38231
# elapsed time for k point: 0.08205890655517578
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.680521844843669 (0.707617% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.668608656710487 (0.155229% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.665401732812622 (0.0418276% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.663898025123725 (0.0196187% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.663194278503491 (0.00918304% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.662451914396944 (0.00968787% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.662239758948417 (0.00276881% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.662197277747419 (0.000554424% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.662187969566251 (0.000121482% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.662186354247563 (2.10817e-05% change)
#     linmin: converged after 1 iterations.
#     iteration   11: trace = 7.662186156907952 (2.5755e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.384087, 0.607776, 0.663928, 0.962652, 1.00725, 1.13109, 1.25998, 1.37707
# elapsed time for k point: 0.08890557289123535
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.780875147330216 (0.718648% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.767169877287983 (0.176296% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.760581638447759 (0.0848576% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.755437914358411 (0.0663021% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.752027696717435 (0.0439816% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.749554010809167 (0.0319153% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.747352935194892 (0.0284066% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.746193216140928 (0.0149704% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 7.745975238050648 (0.00281404% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.745930634333237 (0.000575833% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.745924732419324 (7.61938e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 66.867%)
#     iteration   12: trace = 7.745924035148879 (9.00177e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.310072, 0.626074, 0.722938, 0.955919, 0.98425, 1.14966, 1.29351, 1.363
# elapsed time for k point: 0.10398507118225098
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.894176439353073 (0.557449% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.886084525473999 (0.102557% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 7.880613542689412 (0.0693992% change)
#     large trace change predicted (0.195911%)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 7.866964014255791 (0.173354% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.848918209931198 (0.229651% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 7.833344106925614 (0.198621% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.822172200285337 (0.142722% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.815520885726546 (0.0850677% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 7.811817299452258 (0.0473988% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 7.80977765814735 (0.0261131% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 7.807789767949684 (0.0254571% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 7.804007858370266 (0.0484494% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 7.802167180505309 (0.0235891% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 7.801523010370148 (0.00825664% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 7.801061331885091 (0.00591797% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 7.800879834158 (0.0023266% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 7.800847069736456 (0.00042001% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 7.80082944733865 (0.000225904% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 7.800813082468616 (0.000209784% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 7.800800896450548 (0.000156215% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 7.800797227909674 (4.70278e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 7.800796127065711 (1.41119e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 7.800795209161195 (1.17668e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 7.800794115233264 (1.40233e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 7.800793461934871 (8.37477e-06% change)
# Finished solving for bands 1 to 8 after 25 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.213129, 0.662753, 0.767339, 0.942331, 1.00313, 1.12671, 1.32342, 1.34616
# elapsed time for k point: 0.12233877182006836
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.703042928064148 (1.12873% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 7.673606503895096 (0.382872% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.655658233722754 (0.23417% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.648025154092511 (0.0997548% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.645540738550289 (0.0324897% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.645035723354 (0.00660557% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.644923325224561 (0.00147022% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.644862770309937 (0.000792096% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.644835036235013 (0.000362781% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.644830189466497 (6.33993e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.644829702647262 (6.36795e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.10798, 0.695009, 0.788062, 0.933459, 1.06062, 1.09555, 1.23462, 1.34473
# elapsed time for k point: 0.06548786163330078
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.588772956684577 (0.489569% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.6179%)
#     iteration    2: trace = 7.584417088407266 (0.0574153% change)
#     iteration    3: trace = 7.583874959585679 (0.00714819% change)
#     iteration    4: trace = 7.583528068583417 (0.00457416% change)
#     iteration    5: trace = 7.583375249913416 (0.00201516% change)
#     iteration    6: trace = 7.583348157707039 (0.000357259% change)
#     iteration    7: trace = 7.583346052576453 (2.77599e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 7.5833458479164 (2.69881e-06% change)
# Finished solving for bands 2 to 8 after 8 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.707948, 0.792786, 0.931645, 1.08061, 1.13496, 1.15089, 1.34361
# elapsed time for k point: 0.06102633476257324
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.4101972796350691 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.5430352991376209 at Vector3<0.0, 0.5, 0.0> to 0.707948405652656 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.6421364566325165 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.805469788029249 at Vector3<0.0, 0.5, 0.0>
# Band 4 range: 0.8340243259029921 at Vector3<0.0, 0.5, 0.0> to 0.9706135247434164 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.9842503365452407 at Vector3<-0.19999999999999998, 0.19999999999999998, 0.0> to 1.0806116735821762 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 1.070710556002058 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.180357198785237 at Vector3<0.0, 0.5, 0.0>
# Band 7 range: 1.1508852990404475 at Vector3<0.0, 0.0, 0.0> to 1.3234200212368392 at Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
# Band 8 range: 1.2766617617994174 at Vector3<0.0, 0.5, 0.0> to 1.3823111773843022 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 1 (0.4101972796350691) to band 2 (0.5430352991376209), 27.871061577350623%
# Gap from band 3 (0.805469788029249) to band 4 (0.8340243259029921), 3.4833352106713713%
# Gap from band 4 (0.9706135247434164) to band 5 (0.9842503365452407), 1.395167415170777%
# total elapsed time for run: 1.2006471157073975
# done

# %%
vertices1
# Out:
# [Vector3<0.4330127018922192, 0.15849364905389035, 0.0>,
#  Vector3<0.721687836487032, 0.014156081756483918, 0.0>,
#  Vector3<0.721687836487032, 0.2641560817564839, 0.0>,
#  Vector3<0.4330127018922192, 0.40849364905389035, 0.0>]

# %%
import matplotlib.pyplot as plt
md = mpb.MPBData(rectify=True, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 1.51316, harm. mean 1.09757, 11.8164% > 1, 9.96346% "fill"
# real part range: 1 .. 6.1504

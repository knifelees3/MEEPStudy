# %% [markdown]
# ## 六角结构的正确设计
# 田朝华
# 2023-04-29
# 一直被这个六角设计卡住了，最后再试一次

# %%
import math
import meep as mp
from meep import mpb
import numpy as np
import matplotlib.pyplot as plt

num_bands = 4

# 定义好扫描的k波矢
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(1/3,2/3),       # K
            mp.Vector3(0.5,0.5),  # M
            mp.Vector3()]          # Gamma

# 对k波矢进行插值
k_points = mp.interpolate(40, k_points)

#  units of nm
a=1



# 基本结构和材料性质
# 折射率设置
nslab = 2.48
slab = mp.Medium(index=nslab)

nair = 1
air = mp.Medium(index=nair)



s=0.25
geometry = [mp.Cylinder(0.1,center=mp.Vector3(-1*s,0), material=air),
            mp.Cylinder(0.1,center=mp.Vector3(-0.5*s,math.sqrt(3)/2*s), material=air),
            mp.Cylinder(0.1,center=mp.Vector3(0.5*s,math.sqrt(3)/2*s), material=air),
            mp.Cylinder(0.1,center=mp.Vector3(1*s,0), material=air),
           mp.Cylinder(0.1,center=mp.Vector3(0.5*s,-math.sqrt(3)/2*s), material=air),
            mp.Cylinder(0.1,center=mp.Vector3(-0.5*s,-math.sqrt(3)/2*s), material=air)]



geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(0.5, np.sqrt(3) / 2),
    basis2=mp.Vector3(1,0),
)


resolution = 100

# mode solver设置
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    default_material=slab,
                    resolution=resolution)

ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 100 x 100 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (1, 0, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (-0, 1.1547, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (-0.25,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.125,0.216506,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.125,0.216506,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.25,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.125,-0.216506,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.125,-0.216506,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 6 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 124 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.008130081300813007, 0.016260162601626015, 0.0>
#   Vector3<0.016260162601626015, 0.03252032520325203, 0.0>
#   Vector3<0.024390243902439022, 0.048780487804878044, 0.0>
#   Vector3<0.03252032520325203, 0.06504065040650406, 0.0>
#   Vector3<0.04065040650406504, 0.08130081300813008, 0.0>
#   Vector3<0.048780487804878044, 0.09756097560975609, 0.0>
#   Vector3<0.05691056910569105, 0.1138211382113821, 0.0>
#   Vector3<0.06504065040650406, 0.13008130081300812, 0.0>
#   Vector3<0.07317073170731707, 0.14634146341463414, 0.0>
#   Vector3<0.08130081300813008, 0.16260162601626016, 0.0>
#   Vector3<0.08943089430894308, 0.17886178861788615, 0.0>
#   Vector3<0.09756097560975609, 0.19512195121951217, 0.0>
#   Vector3<0.1056910569105691, 0.2113821138211382, 0.0>
#   Vector3<0.1138211382113821, 0.2276422764227642, 0.0>
#   Vector3<0.1219512195121951, 0.2439024390243902, 0.0>
#   Vector3<0.13008130081300812, 0.26016260162601623, 0.0>
#   Vector3<0.1382113821138211, 0.2764227642276422, 0.0>
#   Vector3<0.14634146341463414, 0.2926829268292683, 0.0>
#   Vector3<0.15447154471544713, 0.30894308943089427, 0.0>
#   Vector3<0.16260162601626016, 0.3252032520325203, 0.0>
#   Vector3<0.17073170731707316, 0.3414634146341463, 0.0>
#   Vector3<0.17886178861788615, 0.3577235772357723, 0.0>
#   Vector3<0.18699186991869918, 0.37398373983739835, 0.0>
#   Vector3<0.19512195121951217, 0.39024390243902435, 0.0>
#   Vector3<0.20325203252032517, 0.40650406504065034, 0.0>
#   Vector3<0.2113821138211382, 0.4227642276422764, 0.0>
#   Vector3<0.2195121951219512, 0.4390243902439024, 0.0>
#   Vector3<0.2276422764227642, 0.4552845528455284, 0.0>
#   Vector3<0.23577235772357721, 0.47154471544715443, 0.0>
#   Vector3<0.2439024390243902, 0.4878048780487804, 0.0>
#   Vector3<0.25203252032520324, 0.5040650406504065, 0.0>
#   Vector3<0.26016260162601623, 0.5203252032520325, 0.0>
#   Vector3<0.26829268292682923, 0.5365853658536585, 0.0>
#   Vector3<0.2764227642276422, 0.5528455284552845, 0.0>
#   Vector3<0.2845528455284553, 0.5691056910569106, 0.0>
#   Vector3<0.2926829268292683, 0.5853658536585366, 0.0>
#   Vector3<0.30081300813008127, 0.6016260162601625, 0.0>
#   Vector3<0.30894308943089427, 0.6178861788617885, 0.0>
#   Vector3<0.31707317073170727, 0.6341463414634145, 0.0>
#   Vector3<0.3252032520325203, 0.6504065040650406, 0.0>
#   Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
#   Vector3<0.33739837398373984, 0.6626016260162602, 0.0>
#   Vector3<0.3414634146341463, 0.6585365853658536, 0.0>
#   Vector3<0.34552845528455284, 0.6544715447154471, 0.0>
#   Vector3<0.3495934959349593, 0.6504065040650406, 0.0>
#   Vector3<0.35365853658536583, 0.6463414634146342, 0.0>
#   Vector3<0.35772357723577236, 0.6422764227642276, 0.0>
#   Vector3<0.36178861788617883, 0.6382113821138211, 0.0>
#   Vector3<0.36585365853658536, 0.6341463414634146, 0.0>
#   Vector3<0.36991869918699183, 0.6300813008130081, 0.0>
#   Vector3<0.37398373983739835, 0.6260162601626016, 0.0>
#   Vector3<0.3780487804878049, 0.6219512195121951, 0.0>
#   Vector3<0.38211382113821135, 0.6178861788617886, 0.0>
#   Vector3<0.3861788617886179, 0.6138211382113821, 0.0>
#   Vector3<0.3902439024390244, 0.6097560975609756, 0.0>
#   Vector3<0.3943089430894309, 0.6056910569105691, 0.0>
#   Vector3<0.3983739837398374, 0.6016260162601625, 0.0>
#   Vector3<0.40243902439024387, 0.5975609756097561, 0.0>
#   Vector3<0.4065040650406504, 0.5934959349593496, 0.0>
#   Vector3<0.41056910569105687, 0.589430894308943, 0.0>
#   Vector3<0.4146341463414634, 0.5853658536585366, 0.0>
#   Vector3<0.4186991869918699, 0.5813008130081301, 0.0>
#   Vector3<0.4227642276422764, 0.5772357723577236, 0.0>
#   Vector3<0.4268292682926829, 0.573170731707317, 0.0>
#   Vector3<0.43089430894308944, 0.5691056910569106, 0.0>
#   Vector3<0.4349593495934959, 0.5650406504065041, 0.0>
#   Vector3<0.43902439024390244, 0.5609756097560976, 0.0>
#   Vector3<0.44308943089430897, 0.556910569105691, 0.0>
#   Vector3<0.44715447154471544, 0.5528455284552846, 0.0>
#   Vector3<0.45121951219512196, 0.5487804878048781, 0.0>
#   Vector3<0.45528455284552843, 0.5447154471544715, 0.0>
#   Vector3<0.45934959349593496, 0.540650406504065, 0.0>
#   Vector3<0.46341463414634143, 0.5365853658536586, 0.0>
#   Vector3<0.46747967479674796, 0.532520325203252, 0.0>
#   Vector3<0.4715447154471545, 0.5284552845528455, 0.0>
#   Vector3<0.47560975609756095, 0.524390243902439, 0.0>
#   Vector3<0.4796747967479675, 0.5203252032520325, 0.0>
#   Vector3<0.483739837398374, 0.516260162601626, 0.0>
#   Vector3<0.4878048780487805, 0.5121951219512195, 0.0>
#   Vector3<0.491869918699187, 0.508130081300813, 0.0>
#   Vector3<0.49593495934959353, 0.5040650406504066, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4878048780487805, 0.4878048780487805, 0.0>
#   Vector3<0.47560975609756095, 0.47560975609756095, 0.0>
#   Vector3<0.46341463414634143, 0.46341463414634143, 0.0>
#   Vector3<0.45121951219512196, 0.45121951219512196, 0.0>
#   Vector3<0.43902439024390244, 0.43902439024390244, 0.0>
#   Vector3<0.4268292682926829, 0.4268292682926829, 0.0>
#   Vector3<0.4146341463414634, 0.4146341463414634, 0.0>
#   Vector3<0.4024390243902439, 0.4024390243902439, 0.0>
#   Vector3<0.3902439024390244, 0.3902439024390244, 0.0>
#   Vector3<0.3780487804878049, 0.3780487804878049, 0.0>
#   Vector3<0.36585365853658536, 0.36585365853658536, 0.0>
#   Vector3<0.35365853658536583, 0.35365853658536583, 0.0>
#   Vector3<0.3414634146341463, 0.3414634146341463, 0.0>
#   Vector3<0.3292682926829268, 0.3292682926829268, 0.0>
#   Vector3<0.3170731707317073, 0.3170731707317073, 0.0>
#   Vector3<0.3048780487804878, 0.3048780487804878, 0.0>
#   Vector3<0.2926829268292683, 0.2926829268292683, 0.0>
#   Vector3<0.2804878048780488, 0.2804878048780488, 0.0>
#   Vector3<0.2682926829268293, 0.2682926829268293, 0.0>
#   Vector3<0.25609756097560976, 0.25609756097560976, 0.0>
#   Vector3<0.24390243902439024, 0.24390243902439024, 0.0>
#   Vector3<0.23170731707317072, 0.23170731707317072, 0.0>
#   Vector3<0.2195121951219512, 0.2195121951219512, 0.0>
#   Vector3<0.20731707317073167, 0.20731707317073167, 0.0>
#   Vector3<0.1951219512195122, 0.1951219512195122, 0.0>
#   Vector3<0.18292682926829268, 0.18292682926829268, 0.0>
#   Vector3<0.17073170731707316, 0.17073170731707316, 0.0>
#   Vector3<0.15853658536585363, 0.15853658536585363, 0.0>
#   Vector3<0.1463414634146341, 0.1463414634146341, 0.0>
#   Vector3<0.13414634146341464, 0.13414634146341464, 0.0>
#   Vector3<0.12195121951219512, 0.12195121951219512, 0.0>
#   Vector3<0.1097560975609756, 0.1097560975609756, 0.0>
#   Vector3<0.09756097560975607, 0.09756097560975607, 0.0>
#   Vector3<0.08536585365853655, 0.08536585365853655, 0.0>
#   Vector3<0.07317073170731708, 0.07317073170731708, 0.0>
#   Vector3<0.06097560975609756, 0.06097560975609756, 0.0>
#   Vector3<0.04878048780487804, 0.04878048780487804, 0.0>
#   Vector3<0.036585365853658514, 0.036585365853658514, 0.0>
#   Vector3<0.02439024390243899, 0.02439024390243899, 0.0>
#   Vector3<0.012195121951219523, 0.012195121951219523, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.022658586502075195
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 3.351988417073811 (199.302% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.9815083227199489 (109.403% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.906369192193205 (7.96017% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.8830278333321731 (2.60885% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 0.858266536988225 (2.84401% change)
#     linmin: converged after 6 iterations.
#     iteration    6: trace = 0.833773160672322 (2.89513% change)
#     linmin: converged after 5 iterations.
#     iteration    7: trace = 0.823367887035247 (1.25581% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.8136502497167173 (1.18724% change)
#     linmin: converged after 5 iterations.
#     iteration    9: trace = 0.8044561953559517 (1.1364% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 0.8013761992610047 (0.383601% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 0.8004092907463429 (0.120729% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 0.7997419346825834 (0.0834116% change)
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/tzh/miniconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 0.799526688988085 (0.026918% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.7994682466696681 (0.00730988% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 0.7994349945214672 (0.00415937% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.7994159938185612 (0.00237679% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.7994126976610509 (0.000412322% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 0.7994117980469639 (0.000112534% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 0.7994112820693708 (6.45447e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 0.7994110778447642 (2.55469e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 0.799411041699609 (4.52147e-06% change)
# Finished solving for bands 2 to 4 after 21 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.509972, 0.514843, 0.523714
# elapsed time for k point: 0.286182165145874
# solve_kpoint (0.00813008,0.0162602,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.7992336043523885 (0.0649019% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7987156995656903 (0.0648212% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7986199056655905 (0.0119942% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7986020589850364 (0.00223472% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7985880794587916 (0.00175051% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.798580829063555 (0.000907906% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7985790056441981 (0.000228333% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7985786837007327 (4.03145e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7985785256783193 (1.9788e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7985784305201539 (1.19159e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7985783907884483 (4.9753e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 2, 0.00813008, 0.0162602, 0, 0.0162602, 0.00776053, 0.507965, 0.516431, 0.523248
# elapsed time for k point: 0.19957304000854492
# solve_kpoint (0.0162602,0.0325203,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7967575800512181 (0.062762% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7962519499651275 (0.0634811% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7961536543871837 (0.0123455% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7961329988528244 (0.00259445% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7961169705211562 (0.00201329% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7961101754738205 (0.000853527% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7961089446398213 (0.000154606% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7961086784588218 (3.34353e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7961085222823268 (1.96175e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7961084620202292 (7.56958e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 3, 0.0162602, 0.0325203, 0, 0.0325203, 0.0155206, 0.504295, 0.51879, 0.52193
# elapsed time for k point: 0.17150497436523438
# solve_kpoint (0.0243902,0.0487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7927148336686149 (0.0596354% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7922497950912266 (0.0586813% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.792155328959075 (0.0119245% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.792132129870577 (0.00292865% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.792113962380062 (0.00229352% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7921072143664767 (0.000851903% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7921059947724149 (0.000153968% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7921056531198285 (4.31322e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7921054458200072 (2.61707e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7921053794878952 (8.37415e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 4, 0.0243902, 0.0487805, 0, 0.0487805, 0.0232799, 0.500122, 0.518946, 0.521667
# elapsed time for k point: 0.1352062225341797
# solve_kpoint (0.0325203,0.0650407,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7873072246397417 (0.0547482% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7869087858539628 (0.0506206% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7868250383738377 (0.0106432% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7868022048828882 (0.00290202% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7867850257451248 (0.00218344% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7867792695237635 (0.000731616% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7867781446784927 (0.000142968% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7867777045939797 (5.5935e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7867774339529021 (3.43987e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.786777356535415 (9.83982e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 5, 0.0325203, 0.0650407, 0, 0.0650407, 0.031038, 0.49566, 0.515876, 0.523456
# elapsed time for k point: 0.1531374454498291
# solve_kpoint (0.0406504,0.0813008,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7808400088001524 (0.0487039% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7805206980414987 (0.0409016% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7804517196111145 (0.00883788% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7804318859676739 (0.00254134% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7804177271251824 (0.00181425% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7804132213301341 (0.000577358% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7804121939854015 (0.000131641% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7804116473171401 (7.00487e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7804113410372013 (3.9246e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7804112635987337 (9.92278e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 6, 0.0406504, 0.0813008, 0, 0.0813008, 0.0387943, 0.490999, 0.511906, 0.525146
# elapsed time for k point: 0.19778943061828613
# solve_kpoint (0.0487805,0.097561,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7736405422129082 (0.0425948% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7733967401911541 (0.0315186% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.773342719611582 (0.00698509% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7733269274181487 (0.00204209% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7733162004062009 (0.00138713% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7733128352892454 (0.000435155% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7733119204666794 (0.000118299% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7733113412023098 (7.4907e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7733110631074496 (3.59616e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7733109985513843 (8.34801e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 7, 0.0487805, 0.097561, 0, 0.097561, 0.0465486, 0.486192, 0.50733, 0.526667
# elapsed time for k point: 0.1818084716796875
# solve_kpoint (0.0569106,0.113821,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7659937975504332 (0.0372128% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7658124419806498 (0.0236787% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7657712201364344 (0.0053829% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7657592640171332 (0.00156133% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7657515092663523 (0.00101269% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7657490728686698 (0.000318171% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.765748301194639 (0.000100774% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7657477813784612 (6.78834e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7657475631833857 (2.84944e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7657475126946089 (6.5934e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 8, 0.0569106, 0.113821, 0, 0.113821, 0.0543003, 0.481277, 0.502303, 0.528075
# elapsed time for k point: 0.18267583847045898
# solve_kpoint (0.0650407,0.130081,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7581210564498729 (0.0328362% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.757987234943136 (0.0176533% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7579560293887941 (0.00411698% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.757947199295274 (0.00116499% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7579417323072866 (0.000721291% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7579400117528778 (0.000227004% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7579394000024828 (8.07123e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.757938985536843 (5.46832e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7579388248925373 (2.11949e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7579387849139241 (5.27465e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 9, 0.0650407, 0.130081, 0, 0.130081, 0.062049, 0.476283, 0.496944, 0.529424
# elapsed time for k point: 0.18222332000732422
# solve_kpoint (0.0731707,0.146341,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.750186045307797 (0.0294175% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7500869210558998 (0.0132142% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7500632256203117 (0.00315908% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7500567596037541 (0.000862067% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7500529529367961 (0.000507518% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7500517650126222 (0.000158379% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7500513073618122 (6.10159e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7500510011291953 (4.08282e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7500508850472409 (1.54765e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7500508526003316 (4.32596e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 10, 0.0731707, 0.146341, 0, 0.146341, 0.0697942, 0.47123, 0.491343, 0.530758
# elapsed time for k point: 0.20392584800720215
# solve_kpoint (0.0813008,0.162602,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7423083730955758 (0.0267894% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7422341561236354 (0.00999863% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7422159989050952 (0.00244632% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.742211255937209 (0.00063903% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7422086163268057 (0.000355642% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7422078134711791 (0.000108171% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7422074889873979 (4.37187e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7422072748013731 (2.8858e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7422071913977686 (1.12372e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7422071649295123 (3.56615e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 11, 0.0813008, 0.162602, 0, 0.162602, 0.0775355, 0.466135, 0.485566, 0.532108
# elapsed time for k point: 0.18671774864196777
# solve_kpoint (0.0894309,0.178862,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.73457571154134 (0.024774% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7345193355447344 (0.00767493% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7345052529190497 (0.00191728% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7345017448451132 (0.000477612% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7344999107748658 (0.000249703% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7344993789896032 (7.2401e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7344991610742957 (2.96686e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7344990190382588 (1.93378e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7344989599023083 (8.0512e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 12, 0.0894309, 0.178862, 0, 0.178862, 0.0852724, 0.461009, 0.479665, 0.533498
# elapsed time for k point: 0.16372036933898926
# solve_kpoint (0.097561,0.195122,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7270529829385988 (0.0232233% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.7270094659255462 (0.00598558% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7269984010645588 (0.00152198% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7269957751808389 (0.000361196% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7269944788932801 (0.000178308% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7269941230400299 (4.89486e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7269939794679721 (1.97487e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7269938869520084 (1.27258e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7269938456469769 (5.68162e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 13, 0.097561, 0.195122, 0, 0.195122, 0.0930042, 0.455862, 0.473677, 0.534942
# elapsed time for k point: 0.14834833145141602
# solve_kpoint (0.105691,0.211382,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.719788757979556 (0.0220159% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.7197545976925284 (0.00474599% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.719745782459411 (0.00122476% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7197437851939693 (0.000277496% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7197428675600245 (0.000127495% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7197426381262506 (3.18772e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7197425524714826 (1.19008e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7197424999324109 (7.2997e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 14, 0.105691, 0.211382, 0, 0.211382, 0.10073, 0.450702, 0.467634, 0.536453
# elapsed time for k point: 0.12804198265075684
# solve_kpoint (0.113821,0.227642,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7128200284858569 (0.021078% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.7127927521927147 (0.00382661% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7127856290139053 (0.000999339% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7127840813394803 (0.000217131% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7127833969628636 (9.60146e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7127832437634303 (2.14931e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7127831908908624 (7.41776e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 15, 0.113821, 0.227642, 0, 0.227642, 0.108451, 0.445532, 0.461561, 0.538037
# elapsed time for k point: 0.14656996726989746
# solve_kpoint (0.121951,0.243902,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7061750678590637 (0.0203334% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.7061529159802185 (0.00313693% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7061470788684476 (0.000826611% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7061458361242687 (0.00017599% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7061453200317619 (7.30859e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7061452174824528 (1.45224e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7061451870799167 (4.30542e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 16, 0.121951, 0.243902, 0, 0.243902, 0.116164, 0.440356, 0.455479, 0.5397
# elapsed time for k point: 0.1342179775238037
# solve_kpoint (0.130081,0.260163,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6998758277693888 (0.019739% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6998575327430097 (0.00261407% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6998526780266792 (0.000693674% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6998516733958062 (0.000143549% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6998512828102574 (5.58098e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6998512141383966 (9.81235e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 17, 0.130081, 0.260163, 0, 0.260163, 0.123869, 0.435174, 0.449408, 0.541445
# elapsed time for k point: 0.12302827835083008
# solve_kpoint (0.138211,0.276423,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6939396725440197 (0.019269% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6939242879839032 (0.00221701% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6939201743082286 (0.000592815% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6939193094568048 (0.000124633% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6939189910030155 (4.58921e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6939189371206395 (7.76494e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 18, 0.138211, 0.276423, 0, 0.276423, 0.131567, 0.429987, 0.443366, 0.543274
# elapsed time for k point: 0.11455702781677246
# solve_kpoint (0.146341,0.292683,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6883800710923964 (0.0188878% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6883669272726166 (0.0019094% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.688363381785015 (0.000515059% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6883626266077758 (0.000109706% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6883623425468484 (4.12662e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6883622872255228 (8.03666e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 19, 0.146341, 0.292683, 0, 0.292683, 0.139255, 0.42479, 0.437371, 0.545189
# elapsed time for k point: 0.1177985668182373
# solve_kpoint (0.154472,0.308943,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6832078212604911 (0.0185844% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6831963992854202 (0.00167183% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6831932856143208 (0.000455752% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6831925873715941 (0.000102203% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6831922977842939 (4.23874e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6831922204429439 (1.13206e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6831921787395046 (6.1042e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 20, 0.154472, 0.308943, 0, 0.308943, 0.146933, 0.41958, 0.431441, 0.547188
# elapsed time for k point: 0.1369953155517578
# solve_kpoint (0.162602,0.325203,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6784312499803784 (0.0183442% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6784211606903854 (0.00148716% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6784183850542009 (0.000409133% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6784177490646885 (9.3746e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6784174454196975 (4.47578e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6784173402900761 (1.54963e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6784172711695969 (1.01885e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6784172265292097 (6.58008e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 21, 0.162602, 0.325203, 0, 0.325203, 0.1546, 0.414349, 0.425594, 0.549273
# elapsed time for k point: 0.15014123916625977
# solve_kpoint (0.170732,0.341463,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6740570121594052 (0.0181448% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6740479471124783 (0.00134486% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6740454212020641 (0.000374738% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6740448250341573 (8.84463e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6740445270663451 (4.42059e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6740444082867872 (1.76219e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6740443275379924 (1.19797e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6740442792141756 (7.16923e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 22, 0.170732, 0.341463, 0, 0.341463, 0.162255, 0.409092, 0.41985, 0.551441
# elapsed time for k point: 0.16125106811523438
# solve_kpoint (0.178862,0.357724,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6700904572963096 (0.0179841% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6700821639541394 (0.00123765% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6700797974763673 (0.000353163% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.670079195329133 (8.98621e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6700788609388195 (4.99031e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6700787029623173 (2.35758e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6700785961175035 (1.59451e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6700785422508941 (8.03885e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 23, 0.178862, 0.357724, 0, 0.357724, 0.169896, 0.4038, 0.414226, 0.553693
# elapsed time for k point: 0.15441036224365234
# solve_kpoint (0.186992,0.373984,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6665353412571935 (0.0178599% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6665276154241533 (0.00115911% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.666525340188946 (0.000341357% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6665247122664328 (9.42084e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6665243281931559 (5.76233e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6665241226328602 (3.08406e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6665239915452241 (1.96674e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6665239356968951 (8.37904e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 24, 0.186992, 0.373984, 0, 0.373984, 0.177521, 0.398469, 0.408739, 0.556026
# elapsed time for k point: 0.15632295608520508
# solve_kpoint (0.195122,0.390244,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6633944037980291 (0.0177648% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6633870690211332 (0.00110565% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6633848164129379 (0.000339562% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6633841399916767 (0.000101965% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6633836919757299 (6.75349e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6633834302120472 (3.94589e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6633832765351598 (2.31656e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6633832207437511 (8.41013e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 25, 0.195122, 0.390244, 0, 0.390244, 0.18513, 0.393099, 0.403399, 0.558438
# elapsed time for k point: 0.15520572662353516
# solve_kpoint (0.203252,0.406504,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6606693249082733 (0.0176957% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6606622208966213 (0.00107528% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6606599197976208 (0.000348302% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6606591705724456 (0.000113406% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.660658645741901 (7.94405e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6606583199720844 (4.93099e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6606581443474331 (2.65833e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6606580892023761 (8.34699e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 26, 0.203252, 0.406504, 0, 0.406504, 0.192718, 0.387694, 0.398211, 0.560927
# elapsed time for k point: 0.17193937301635742
# solve_kpoint (0.211382,0.422764,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6583607654074717 (0.0176509% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6583537369038882 (0.00106758% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6583513077013821 (0.000368982% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6583504584466845 (0.000128997% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6583498455695878 (9.30929e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6583494481757228 (6.03621e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6583492489963103 (3.02544e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6583491935675247 (8.41936e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 27, 0.211382, 0.422764, 0, 0.422764, 0.200284, 0.382266, 0.393176, 0.56349
# elapsed time for k point: 0.16091418266296387
# solve_kpoint (0.219512,0.439024,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6564683367716559 (0.0176301% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6564612214911287 (0.00108388% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.656458568365534 (0.000404157% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6564575873567489 (0.00014944% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6564568763068311 (0.000108316% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6564563988045335 (7.27394e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6564561715799961 (3.46138e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6564561134303948 (8.85811e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 28, 0.219512, 0.439024, 0, 0.439024, 0.207824, 0.376831, 0.38829, 0.566123
# elapsed time for k point: 0.16519522666931152
# solve_kpoint (0.227642,0.455285,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.6549904988985269 (0.0176344% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6549831129693973 (0.00112765% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6549801130987876 (0.000458008% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6549789617781856 (0.00017578% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6549781419574798 (0.000125168% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6549775738537817 (8.67363e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6549773110076131 (4.01306e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6549772461525869 (9.90187e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 29, 0.227642, 0.455285, 0, 0.455285, 0.215333, 0.371406, 0.383546, 0.568822
# elapsed time for k point: 0.154862642288208
# solve_kpoint (0.235772,0.471545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.6539243631237122 (0.0176671% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6539164812869653 (0.00120532% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6539129688366703 (0.000537142% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6539115981151132 (0.000209619% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6539106559805485 (0.000144077% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6539099838284153 (0.00010279% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6539096745875939 (4.7291e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6539095972090495 (1.18332e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6539095809236557 (2.49047e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 30, 0.235772, 0.471545, 0, 0.471545, 0.222806, 0.366013, 0.378939, 0.571582
# elapsed time for k point: 0.1735241413116455
# solve_kpoint (0.243902,0.487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.6532653363330172 (0.0177339% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6532566564397426 (0.0013287% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6532523923848683 (0.00065274% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6532507362810677 (0.000253517% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6532496846182236 (0.000160989% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6532488906486196 (0.000121542% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6532485223594112 (5.63781e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6532484253161822 (1.48555e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6532484033151954 (3.36794e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 31, 0.243902, 0.487805, 0, 0.487805, 0.230235, 0.360673, 0.374463, 0.574398
# elapsed time for k point: 0.1838080883026123
# solve_kpoint (0.252033,0.504065,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.6530066736876421 (0.0178436% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6529967820845981 (0.00151479% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6529914254179592 (0.000820324% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6529893918658575 (0.000311421% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6529881790770118 (0.000185729% change)
# ...
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7602443151271596 (0.00131948% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7602409961030054 (0.000436574% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7602394899930782 (0.00019811% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7602391150369349 (4.93208e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7602389968412253 (1.55472e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7602389580343006 (5.10457e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 114, 0.121951, 0.121951, 0, 0.140817, 0.0667377, 0.466724, 0.500548, 0.536102
# elapsed time for k point: 0.19563651084899902
# solve_kpoint (0.109756,0.109756,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7686463765564912 (0.0219864% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7685343843535294 (0.0145711% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.768476887645878 (0.00748162% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7684096676899043 (0.00874755% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.7683530738245357 (0.00736534% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.7683311039782778 (0.00285938% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7683238878428176 (0.0009392% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7683205527604895 (0.000434073% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7683197021853683 (0.000110706% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7683194251272335 (3.60603e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.768319322319618 (1.33808e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7683192879809236 (4.46933e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 115, 0.109756, 0.109756, 0, 0.126735, 0.0600672, 0.47198, 0.503489, 0.537071
# elapsed time for k point: 0.23564553260803223
# solve_kpoint (0.097561,0.097561,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7761413226893239 (0.0251576% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7759572650791134 (0.0237173% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.7758547087641577 (0.0132176% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7757179712742015 (0.0176257% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.7756051044618105 (0.014551% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.7755649542946413 (0.00517676% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7755524390214685 (0.00161371% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7755466374019165 (0.000748066% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7755451279114169 (0.000194636% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7755446354100453 (6.35039e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7755444270686837 (2.68639e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7755443465033249 (1.03882e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7755443257848706 (2.67147e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 116, 0.097561, 0.097561, 0, 0.112654, 0.0533956, 0.477081, 0.506483, 0.537179
# elapsed time for k point: 0.1920166015625
# solve_kpoint (0.0853659,0.0853659,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7821627051180753 (0.0284639% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7819042692034884 (0.0330467% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7817678631769134 (0.0174469% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7815937930498189 (0.0222687% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.7814576578750942 (0.0174192% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.7814136937566011 (0.00562607% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7814016418463243 (0.00154233% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7813961194783046 (0.000706728% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7813946473311539 (0.0001884% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7813941973316612 (5.75893e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7813939837847954 (2.7329e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7813938817810064 (1.30541e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7813938535342189 (3.61492e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 117, 0.0853659, 0.0853659, 0, 0.098572, 0.0467231, 0.482017, 0.509498, 0.535987
# elapsed time for k point: 0.20800042152404785
# solve_kpoint (0.0731707,0.0731707,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.786551461679314 (0.0290825% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7863063304827066 (0.0311702% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.786204644227204 (0.012933% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.786099855008493 (0.0133294% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.7860126447891895 (0.0110947% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7859836793821681 (0.00368517% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7859766119775626 (0.000899184% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7859734677843135 (0.000400037% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7859725556643771 (0.00011605% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7859723154881564 (3.05578e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7859722052692363 (1.40233e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7859721392530643 (8.3993e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 118, 0.0731707, 0.0731707, 0, 0.0844903, 0.0400499, 0.486781, 0.512479, 0.533646
# elapsed time for k point: 0.2304704189300537
# solve_kpoint (0.0609756,0.0609756,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7901057795067913 (0.028459% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7899023144871742 (0.0257549% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7898409455084272 (0.00776949% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7898000553019371 (0.00517715% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7897610952644224 (0.00493302% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7897452556666655 (0.00200564% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7897414405488863 (0.000483083% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.789739780396655 (0.000210215% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7897392086870723 (7.23922e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.789739075138063 (1.69105e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7897390269968769 (6.09583e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 119, 0.0609756, 0.0609756, 0, 0.0704086, 0.0333759, 0.49137, 0.51535, 0.530655
# elapsed time for k point: 0.20322394371032715
# solve_kpoint (0.0487805,0.0487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7932278779946673 (0.0290879% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7930323682035075 (0.0246504% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7929865858179703 (0.00577325% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7929699748554943 (0.00209476% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7929545538978993 (0.00194473% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7929465322667409 (0.00101162% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.792944529494194 (0.000252574% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7929436404982679 (0.000112113% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7929432600453976 (4.79798e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7929431707925925 (1.12559e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7929431473147063 (2.96085e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 120, 0.0487805, 0.0487805, 0, 0.0563269, 0.0267014, 0.495784, 0.518008, 0.527347
# elapsed time for k point: 0.19504928588867188
# solve_kpoint (0.0365854,0.0365854,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7958937461899858 (0.0310612% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7956782349591637 (0.0270816% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7956347651512001 (0.00546339% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7956250661007309 (0.00121904% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.795617890762697 (0.000901853% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7956138312626737 (0.000510234% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7956128188947618 (0.000127244% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7956123932909573 (5.34938e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7956121543677034 (3.00301e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7956120882159277 (8.31458e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 121, 0.0365854, 0.0365854, 0, 0.0422451, 0.0200265, 0.500023, 0.520322, 0.523883
# elapsed time for k point: 0.18901991844177246
# solve_kpoint (0.0243902,0.0243902,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.7979741117915371 (0.0338942% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7977231661983193 (0.0314528% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7976771342209326 (0.00577059% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7976688984253875 (0.00103248% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.797663956242333 (0.00061958% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7976612763990557 (0.000335962% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7976607002015653 (7.22359e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.797660519138412 (2.26993e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7976603978673926 (1.52033e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7976603509004997 (5.88808e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 122, 0.0243902, 0.0243902, 0, 0.0281634, 0.0133512, 0.504064, 0.520356, 0.522142
# elapsed time for k point: 0.21514391899108887
# solve_kpoint (0.0121951,0.0121951,0):
# Solving for bands 1 to 4...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7993149498500007 (0.0371591% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.799027457263495 (0.0359738% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7989797811442679 (0.00596695% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7989714204981204 (0.00104642% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7989663052138638 (0.000640236% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7989635053682143 (0.000350434% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7989628041083147 (8.77712e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7989626605876902 (1.79634e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7989625835239322 (9.64548e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 123, 0.0121951, 0.0121951, 0, 0.0140817, 0.00667565, 0.507775, 0.516943, 0.52331
# elapsed time for k point: 0.16353130340576172
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7997879970517096 (0.037056% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7994775786918968 (0.0388201% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.7994270943364084 (0.00631487% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7994185143094278 (0.00107328% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7994137639676218 (0.000594226% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7994114967079138 (0.000283616% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.799411115829994 (4.76448e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7994110537607451 (7.76437e-06% change)
# Finished solving for bands 2 to 4 after 8 iterations.
# tefreqs:, 124, 0, 0, 0, 0, 0, 0.509972, 0.514843, 0.523714
# elapsed time for k point: 0.1351182460784912
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.29225835094460223 at Vector3<0.33739837398373984, 0.6626016260162602, 0.0>
# Band 2 range: 0.28111168751427 at Vector3<0.5, 0.5, 0.0> to 0.5099719441022563 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.33722001140422103 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0> to 0.5203555009276847 at Vector3<0.02439024390243899, 0.02439024390243899, 0.0>
# Band 4 range: 0.5037789557500357 at Vector3<0.5, 0.5, 0.0> to 0.6098813930086117 at Vector3<0.35772357723577236, 0.6422764227642276, 0.0>
# total elapsed time for run: 18.064836025238037
# done

# %%
md = mpb.MPBData(rectify=True, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 5.0357, harm. mean 2.9903, 80.8% > 1, 78.3571% "fill"
# real part range: 1 .. 6.1504

# %%
import math
import meep as mp
from meep import mpb
import numpy as np
import matplotlib.pyplot as plt

num_bands = 4

# 定义好扫描的k波矢
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(1/3,2/3),       # K
            mp.Vector3(0.5,0.5),  # M
            mp.Vector3()]          # Gamma

# 对k波矢进行插值
k_points = mp.interpolate(40, k_points)

#  units of nm
a=1



# 基本结构和材料性质
# 折射率设置
nslab = 2.48
slab = mp.Medium(index=nslab)

nair = 1
air = mp.Medium(index=nair)



s=0.25
geometry = [mp.Cylinder(0.1,center=mp.Vector3(0,0), material=air),
            mp.Cylinder(0.2,center=mp.Vector3(0.25,math.sqrt(3)/4), material=air)]



geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(0.5, np.sqrt(3) / 2),
    basis2=mp.Vector3(1,0),
)


resolution = 32

# mode solver设置
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    default_material=slab,
                    resolution=resolution)

ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (1, 0, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (-0, 1.1547, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.25,0.433013,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 124 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.008130081300813007, 0.016260162601626015, 0.0>
#   Vector3<0.016260162601626015, 0.03252032520325203, 0.0>
#   Vector3<0.024390243902439022, 0.048780487804878044, 0.0>
#   Vector3<0.03252032520325203, 0.06504065040650406, 0.0>
#   Vector3<0.04065040650406504, 0.08130081300813008, 0.0>
#   Vector3<0.048780487804878044, 0.09756097560975609, 0.0>
#   Vector3<0.05691056910569105, 0.1138211382113821, 0.0>
#   Vector3<0.06504065040650406, 0.13008130081300812, 0.0>
#   Vector3<0.07317073170731707, 0.14634146341463414, 0.0>
#   Vector3<0.08130081300813008, 0.16260162601626016, 0.0>
#   Vector3<0.08943089430894308, 0.17886178861788615, 0.0>
#   Vector3<0.09756097560975609, 0.19512195121951217, 0.0>
#   Vector3<0.1056910569105691, 0.2113821138211382, 0.0>
#   Vector3<0.1138211382113821, 0.2276422764227642, 0.0>
#   Vector3<0.1219512195121951, 0.2439024390243902, 0.0>
#   Vector3<0.13008130081300812, 0.26016260162601623, 0.0>
#   Vector3<0.1382113821138211, 0.2764227642276422, 0.0>
#   Vector3<0.14634146341463414, 0.2926829268292683, 0.0>
#   Vector3<0.15447154471544713, 0.30894308943089427, 0.0>
#   Vector3<0.16260162601626016, 0.3252032520325203, 0.0>
#   Vector3<0.17073170731707316, 0.3414634146341463, 0.0>
#   Vector3<0.17886178861788615, 0.3577235772357723, 0.0>
#   Vector3<0.18699186991869918, 0.37398373983739835, 0.0>
#   Vector3<0.19512195121951217, 0.39024390243902435, 0.0>
#   Vector3<0.20325203252032517, 0.40650406504065034, 0.0>
#   Vector3<0.2113821138211382, 0.4227642276422764, 0.0>
#   Vector3<0.2195121951219512, 0.4390243902439024, 0.0>
#   Vector3<0.2276422764227642, 0.4552845528455284, 0.0>
#   Vector3<0.23577235772357721, 0.47154471544715443, 0.0>
#   Vector3<0.2439024390243902, 0.4878048780487804, 0.0>
#   Vector3<0.25203252032520324, 0.5040650406504065, 0.0>
#   Vector3<0.26016260162601623, 0.5203252032520325, 0.0>
#   Vector3<0.26829268292682923, 0.5365853658536585, 0.0>
#   Vector3<0.2764227642276422, 0.5528455284552845, 0.0>
#   Vector3<0.2845528455284553, 0.5691056910569106, 0.0>
#   Vector3<0.2926829268292683, 0.5853658536585366, 0.0>
#   Vector3<0.30081300813008127, 0.6016260162601625, 0.0>
#   Vector3<0.30894308943089427, 0.6178861788617885, 0.0>
#   Vector3<0.31707317073170727, 0.6341463414634145, 0.0>
#   Vector3<0.3252032520325203, 0.6504065040650406, 0.0>
#   Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
#   Vector3<0.33739837398373984, 0.6626016260162602, 0.0>
#   Vector3<0.3414634146341463, 0.6585365853658536, 0.0>
#   Vector3<0.34552845528455284, 0.6544715447154471, 0.0>
#   Vector3<0.3495934959349593, 0.6504065040650406, 0.0>
#   Vector3<0.35365853658536583, 0.6463414634146342, 0.0>
#   Vector3<0.35772357723577236, 0.6422764227642276, 0.0>
#   Vector3<0.36178861788617883, 0.6382113821138211, 0.0>
#   Vector3<0.36585365853658536, 0.6341463414634146, 0.0>
#   Vector3<0.36991869918699183, 0.6300813008130081, 0.0>
#   Vector3<0.37398373983739835, 0.6260162601626016, 0.0>
#   Vector3<0.3780487804878049, 0.6219512195121951, 0.0>
#   Vector3<0.38211382113821135, 0.6178861788617886, 0.0>
#   Vector3<0.3861788617886179, 0.6138211382113821, 0.0>
#   Vector3<0.3902439024390244, 0.6097560975609756, 0.0>
#   Vector3<0.3943089430894309, 0.6056910569105691, 0.0>
#   Vector3<0.3983739837398374, 0.6016260162601625, 0.0>
#   Vector3<0.40243902439024387, 0.5975609756097561, 0.0>
#   Vector3<0.4065040650406504, 0.5934959349593496, 0.0>
#   Vector3<0.41056910569105687, 0.589430894308943, 0.0>
#   Vector3<0.4146341463414634, 0.5853658536585366, 0.0>
#   Vector3<0.4186991869918699, 0.5813008130081301, 0.0>
#   Vector3<0.4227642276422764, 0.5772357723577236, 0.0>
#   Vector3<0.4268292682926829, 0.573170731707317, 0.0>
#   Vector3<0.43089430894308944, 0.5691056910569106, 0.0>
#   Vector3<0.4349593495934959, 0.5650406504065041, 0.0>
#   Vector3<0.43902439024390244, 0.5609756097560976, 0.0>
#   Vector3<0.44308943089430897, 0.556910569105691, 0.0>
#   Vector3<0.44715447154471544, 0.5528455284552846, 0.0>
#   Vector3<0.45121951219512196, 0.5487804878048781, 0.0>
#   Vector3<0.45528455284552843, 0.5447154471544715, 0.0>
#   Vector3<0.45934959349593496, 0.540650406504065, 0.0>
#   Vector3<0.46341463414634143, 0.5365853658536586, 0.0>
#   Vector3<0.46747967479674796, 0.532520325203252, 0.0>
#   Vector3<0.4715447154471545, 0.5284552845528455, 0.0>
#   Vector3<0.47560975609756095, 0.524390243902439, 0.0>
#   Vector3<0.4796747967479675, 0.5203252032520325, 0.0>
#   Vector3<0.483739837398374, 0.516260162601626, 0.0>
#   Vector3<0.4878048780487805, 0.5121951219512195, 0.0>
#   Vector3<0.491869918699187, 0.508130081300813, 0.0>
#   Vector3<0.49593495934959353, 0.5040650406504066, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4878048780487805, 0.4878048780487805, 0.0>
#   Vector3<0.47560975609756095, 0.47560975609756095, 0.0>
#   Vector3<0.46341463414634143, 0.46341463414634143, 0.0>
#   Vector3<0.45121951219512196, 0.45121951219512196, 0.0>
#   Vector3<0.43902439024390244, 0.43902439024390244, 0.0>
#   Vector3<0.4268292682926829, 0.4268292682926829, 0.0>
#   Vector3<0.4146341463414634, 0.4146341463414634, 0.0>
#   Vector3<0.4024390243902439, 0.4024390243902439, 0.0>
#   Vector3<0.3902439024390244, 0.3902439024390244, 0.0>
#   Vector3<0.3780487804878049, 0.3780487804878049, 0.0>
#   Vector3<0.36585365853658536, 0.36585365853658536, 0.0>
#   Vector3<0.35365853658536583, 0.35365853658536583, 0.0>
#   Vector3<0.3414634146341463, 0.3414634146341463, 0.0>
#   Vector3<0.3292682926829268, 0.3292682926829268, 0.0>
#   Vector3<0.3170731707317073, 0.3170731707317073, 0.0>
#   Vector3<0.3048780487804878, 0.3048780487804878, 0.0>
#   Vector3<0.2926829268292683, 0.2926829268292683, 0.0>
#   Vector3<0.2804878048780488, 0.2804878048780488, 0.0>
#   Vector3<0.2682926829268293, 0.2682926829268293, 0.0>
#   Vector3<0.25609756097560976, 0.25609756097560976, 0.0>
#   Vector3<0.24390243902439024, 0.24390243902439024, 0.0>
#   Vector3<0.23170731707317072, 0.23170731707317072, 0.0>
#   Vector3<0.2195121951219512, 0.2195121951219512, 0.0>
#   Vector3<0.20731707317073167, 0.20731707317073167, 0.0>
#   Vector3<0.1951219512195122, 0.1951219512195122, 0.0>
#   Vector3<0.18292682926829268, 0.18292682926829268, 0.0>
#   Vector3<0.17073170731707316, 0.17073170731707316, 0.0>
#   Vector3<0.15853658536585363, 0.15853658536585363, 0.0>
#   Vector3<0.1463414634146341, 0.1463414634146341, 0.0>
#   Vector3<0.13414634146341464, 0.13414634146341464, 0.0>
#   Vector3<0.12195121951219512, 0.12195121951219512, 0.0>
#   Vector3<0.1097560975609756, 0.1097560975609756, 0.0>
#   Vector3<0.09756097560975607, 0.09756097560975607, 0.0>
#   Vector3<0.08536585365853655, 0.08536585365853655, 0.0>
#   Vector3<0.07317073170731708, 0.07317073170731708, 0.0>
#   Vector3<0.06097560975609756, 0.06097560975609756, 0.0>
#   Vector3<0.04878048780487804, 0.04878048780487804, 0.0>
#   Vector3<0.036585365853658514, 0.036585365853658514, 0.0>
#   Vector3<0.02439024390243899, 0.02439024390243899, 0.0>
#   Vector3<0.012195121951219523, 0.012195121951219523, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.013934850692749023
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 2.34880170256283 (195.062% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.8804627893269195 (90.9395% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.7990824982191307 (9.69075% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7599726569900684 (5.01712% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.741292787136979 (2.48855% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.7330567855296155 (1.11724% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.7305397938875438 (0.343946% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.7279206392330673 (0.359167% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.7549%)
#     iteration    9: trace = 0.726414728748477 (0.207093% change)
#     switching back to exact line minimization
#     iteration   10: trace = 0.7256773285441434 (0.101564% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 0.7252091463349856 (0.0645374% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 0.7250717129564301 (0.0189527% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 0.7249935549709237 (0.0107799% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 0.7249466221966769 (0.00647375% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.7249278429083678 (0.00259047% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.7249190413189984 (0.00121414% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.7249131291956452 (0.00081556% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.2359%)
#     iteration   18: trace = 0.7249108804860848 (0.000310204% change)
#     switching back to exact line minimization
#     iteration   19: trace = 0.7249099474520591 (0.00012871% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 0.7249094900518751 (6.30975e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 0.7249093982980024 (1.26573e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 0.7249093848512326 (1.85496e-06% change)
# Finished solving for bands 2 to 4 after 22 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.474542, 0.49546, 0.50422
# elapsed time for k point: 0.03707766532897949
# solve_kpoint (0.00813008,0.0162602,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.7248008043568019 (0.0603356% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7245443550774733 (0.0353883% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7245079537939272 (0.00502415% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7244989893938423 (0.00123732% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7244928006260085 (0.000854217% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.7244892470875794 (0.000490488% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7244880946680456 (0.000159067% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7244868045312551 (0.000178076% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.7244862529212114 (7.61381e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 66.6834%)
#     iteration   10: trace = 0.7244860480639487 (2.82762e-05% change)
#     iteration   11: trace = 0.7244859494963112 (1.36052e-05% change)
#     iteration   12: trace = 0.7244858937082217 (7.70037e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 2, 0.00813008, 0.0162602, 0, 0.0162602, 0.00750699, 0.473881, 0.495236, 0.504587
# elapsed time for k point: 0.023905277252197266
# solve_kpoint (0.0162602,0.0325203,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7235429628321464 (0.0589152% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7232848594057932 (0.0356785% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7232521192546548 (0.00452669% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7232402516653164 (0.00164088% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7232327888163315 (0.00103187% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.6653%)
#     iteration    6: trace = 0.7232284477867202 (0.000600228% change)
#     switching back to exact line minimization
#     iteration    7: trace = 0.7232267740398975 (0.000231427% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7232251326686929 (0.000226951% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7232245039274761 (8.69358e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7232243045031537 (2.75743e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 86.6411%)
#     iteration   11: trace = 0.7232241717141502 (1.83607e-05% change)
#     iteration   12: trace = 0.7232240976666742 (1.02385e-05% change)
#     iteration   13: trace = 0.7232240792502129 (2.54644e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 3, 0.0162602, 0.0325203, 0, 0.0325203, 0.0150136, 0.472043, 0.494409, 0.505702
# elapsed time for k point: 0.02327251434326172
# solve_kpoint (0.0243902,0.0487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7214645271230082 (0.0570317% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.721215374297929 (0.0345403% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7211831084903713 (0.00447391% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7211670909220093 (0.00222104% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7211570387864076 (0.00139388% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.721151342299604 (0.000789912% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.721148620838767 (0.000377378% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7211462131569741 (0.000333868% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.72114539921036 (0.000112869% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7211450883264157 (4.31098e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7211448277111987 (3.61391e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7211446874037615 (1.94562e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7211446520375915 (4.90417e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 4, 0.0243902, 0.0487805, 0, 0.0487805, 0.0225193, 0.469337, 0.492785, 0.507467
# elapsed time for k point: 0.020049333572387695
# solve_kpoint (0.0325203,0.0650407,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7186008310451927 (0.0545048% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7183666880003514 (0.0325885% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7183342536849711 (0.00451511% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7183127236450033 (0.00299726% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7182996386968596 (0.00182164% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7182921098385922 (0.00104816% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7182873080228017 (0.000668507% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.718283465327419 (0.000534982% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.718282238969274 (0.000170735% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7182816520590792 (8.17103e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7182811421686917 (7.09876e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.718280932124663 (2.92426e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7182808918792932 (5.60301e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 5, 0.0325203, 0.0650407, 0, 0.0650407, 0.0300236, 0.466047, 0.490365, 0.509629
# elapsed time for k point: 0.02656412124633789
# solve_kpoint (0.0406504,0.0813008,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7149948286130907 (0.0513894% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7147795063625435 (0.0301198% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7147467894456904 (0.00457731% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7147189454580127 (0.00389572% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.714702592610308 (0.00228804% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7146922686255589 (0.00144453% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7146835383008978 (0.00122156% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7146775347250641 (0.000840036% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7146757691766972 (0.000247042% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7146748452826421 (0.000129275% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7146741435150141 (9.8194e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7146739228741725 (3.08729e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.714673891854768 (4.34036e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 6, 0.0406504, 0.0813008, 0, 0.0813008, 0.0375263, 0.462373, 0.487247, 0.511925
# elapsed time for k point: 0.02457284927368164
# solve_kpoint (0.0487805,0.097561,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.2787%)
#     iteration    1: trace = 0.7106917195119029 (0.047883% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.7104979039881201 (0.0272751% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7104651450577379 (0.00461081% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7104311955114238 (0.00477861% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7104115820543228 (0.00276082% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7103972578157407 (0.00201635% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.7103828827798728 (0.00202354% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7103749214449568 (0.00112072% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7103728913263339 (0.000285782% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7103718763722545 (0.000142876% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.3632%)
#     iteration   11: trace = 0.7103712181133535 (9.2664e-05% change)
#     switching back to exact line minimization
#     iteration   12: trace = 0.7103710388278885 (2.52383e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7103710176662648 (2.97895e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 7, 0.0487805, 0.097561, 0, 0.097561, 0.0450267, 0.458442, 0.483549, 0.514155
# elapsed time for k point: 0.022198915481567383
# solve_kpoint (0.0569106,0.113821,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7057468441934585 (0.0440728% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.705577291068165 (0.0240275% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7055456161473042 (0.00448932% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.705508171342856 (0.00530735% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.705486468492147 (0.00307625% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7054682779083774 (0.00257848% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.70544944844361 (0.00266911% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.705441178633237 (0.00117228% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7054394480188514 (0.000245324% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7054386905206771 (0.00010738% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.705438250475712 (6.23789e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7054381349668932 (1.63741e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7054381230955225 (1.68284e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 8, 0.0569106, 0.113821, 0, 0.113821, 0.0525246, 0.454335, 0.479375, 0.516196
# elapsed time for k point: 0.024240970611572266
# solve_kpoint (0.0650407,0.130081,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7002562707402948 (0.0402903% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7001129876049619 (0.0204636% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.70008424450606 (0.00410558% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7000480115355519 (0.00517565% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7000269225986062 (0.00301254% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7000074531052479 (0.00278129% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.6999885383323636 (0.00270212% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6999817441975638 (0.000970611% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6999805705306058 (0.000167671% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6999801421769021 (6.11951e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6999799250313211 (3.10217e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 90.7211%)
#     iteration   12: trace = 0.6999798658226267 (8.45863e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 9, 0.0650407, 0.130081, 0, 0.130081, 0.0600193, 0.450105, 0.474816, 0.518008
# elapsed time for k point: 0.02297210693359375
# solve_kpoint (0.0731707,0.146341,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6943661496012152 (0.0365293% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6942502172895334 (0.0166975% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6942262004712296 (0.00345945% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6941961452344028 (0.00432941% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 70.1299%)
#     iteration    5: trace = 0.6941786407109479 (0.00252158% change)
#     iteration    6: trace = 0.6941615659866596 (0.00245973% change)
#     iteration    7: trace = 0.6941465157136598 (0.00216815% change)
#     iteration    8: trace = 0.6941417881448644 (0.000681064% change)
#     iteration    9: trace = 0.6941410679054972 (0.00010376% change)
#     iteration   10: trace = 0.6941408467798034 (3.1856e-05% change)
#     iteration   11: trace = 0.694140755735939 (1.31161e-05% change)
#     iteration   12: trace = 0.6941407313152769 (3.51811e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 10, 0.0731707, 0.146341, 0, 0.146341, 0.0675104, 0.445788, 0.469948, 0.51962
# elapsed time for k point: 0.021116971969604492
# solve_kpoint (0.0813008,0.162602,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6882492790133359 (0.0331025% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6881582214365226 (0.0132312% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6881394185908147 (0.00273238% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6881172624825498 (0.00321976% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6881043927207435 (0.0018703% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6880914737582686 (0.00187749% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.688081145678105 (0.00150099% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6880781255440269 (0.000438922% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6880776870148749 (6.37325e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6880775568043269 (1.89238e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.688077514226769 (6.1879e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 11, 0.0813008, 0.162602, 0, 0.162602, 0.0749975, 0.44141, 0.464832, 0.521096
# elapsed time for k point: 0.018635988235473633
# solve_kpoint (0.0894309,0.178862,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 86.8828%)
#     iteration    1: trace = 0.6820560902455703 (0.0301619% change)
#     iteration    2: trace = 0.681985431170632 (0.0103603% change)
#     iteration    3: trace = 0.681971219563976 (0.00208388% change)
#     iteration    4: trace = 0.6819560588265734 (0.0022231% change)
#     iteration    5: trace = 0.6819472843991767 (0.00128666% change)
#     iteration    6: trace = 0.6819382782695838 (0.00132066% change)
#     iteration    7: trace = 0.6819317525634906 (0.00095694% change)
#     iteration    8: trace = 0.6819298588052299 (0.000277705% change)
#     iteration    9: trace = 0.6819295711432395 (4.21835e-05% change)
#     iteration   10: trace = 0.6819294786560134 (1.35626e-05% change)
#     iteration   11: trace = 0.681929453232577 (3.72816e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 12, 0.0894309, 0.178862, 0, 0.178862, 0.08248, 0.43699, 0.459519, 0.522502
# elapsed time for k point: 0.016217708587646484
# solve_kpoint (0.097561,0.195122,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6758996856000998 (0.0277162% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6758446655370969 (0.0081406% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6758339495540497 (0.00158558% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6758237792008932 (0.00150487% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6758179234396331 (0.000866466% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6758118840395273 (0.000893647% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6758077994411342 (0.000604401% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6758065986613282 (0.000177681% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6758063984723073 (2.96222e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6758063277912227 (1.04588e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6758063109890315 (2.48624e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 13, 0.097561, 0.195122, 0, 0.195122, 0.0899573, 0.432544, 0.454049, 0.523888
# elapsed time for k point: 0.017841815948486328
# solve_kpoint (0.105691,0.211382,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6698597399597218 (0.0257272% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6698164567620586 (0.00646174% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6698083266633905 (0.00121379% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6698015790594571 (0.0010074% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6697977180588384 (0.000576441% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6697937294205878 (0.000595501% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6697911742994205 (0.00038148% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6697903865426413 (0.000117612% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6697902389061063 (2.20422e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 95.2742%)
#     iteration   10: trace = 0.6697901839635367 (8.20295e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 14, 0.105691, 0.211382, 0, 0.211382, 0.097429, 0.428083, 0.448457, 0.52529
# elapsed time for k point: 0.02341318130493164
# solve_kpoint (0.113821,0.227642,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 78.3399%)
#     iteration    1: trace = 0.663994772878286 (0.0241012% change)
#     iteration    2: trace = 0.6639602010998694 (0.00520677% change)
#     iteration    3: trace = 0.6639539066247626 (0.000948024% change)
#     iteration    4: trace = 0.6639493565824608 (0.000685297% change)
#     iteration    5: trace = 0.6639467636420948 (0.000390534% change)
#     iteration    6: trace = 0.6639440678257071 (0.00040603% change)
#     iteration    7: trace = 0.6639424498576505 (0.000243691% change)
#     iteration    8: trace = 0.6639419103295769 (8.12613e-05% change)
#     iteration    9: trace = 0.6639417979484206 (1.69264e-05% change)
#     iteration   10: trace = 0.6639417558154448 (6.34588e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 15, 0.113821, 0.227642, 0, 0.227642, 0.104894, 0.423616, 0.442769, 0.526729
# elapsed time for k point: 0.01377725601196289
# solve_kpoint (0.121951,0.243902,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6583476073423841 (0.0227571% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6583195711915057 (0.00425865% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6583145981442178 (0.000755418% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6583114707897596 (0.000475056% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6583096957951382 (0.000269629% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6583078667792385 (0.000277836% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6583068099461685 (0.000160538% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.658306428953892 (5.78746e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 59.7368%)
#     iteration    9: trace = 0.658306341210288 (1.33287e-05% change)
#     switching back to exact line minimization
#     iteration   10: trace = 0.658306309732907 (4.78157e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 16, 0.121951, 0.243902, 0, 0.243902, 0.112353, 0.419153, 0.437008, 0.528222
# elapsed time for k point: 0.02104043960571289
# solve_kpoint (0.130081,0.260163,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6529509573608534 (0.0216632% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.652927844567192 (0.00353981% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.1345%)
#     iteration    3: trace = 0.6529238379809339 (0.000613636% change)
#     iteration    4: trace = 0.652921658738851 (0.000333767% change)
#     iteration    5: trace = 0.6529204273596225 (0.000188595% change)
#     iteration    6: trace = 0.652919172153275 (0.000192245% change)
#     iteration    7: trace = 0.6529184680756017 (0.000107835% change)
#     iteration    8: trace = 0.6529181901570887 (4.25656e-05% change)
#     iteration    9: trace = 0.6529181207969923 (1.06231e-05% change)
#     iteration   10: trace = 0.6529180976290347 (3.54837e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 17, 0.130081, 0.260163, 0, 0.260163, 0.119804, 0.414699, 0.431193, 0.529776
# elapsed time for k point: 0.012614727020263672
# solve_kpoint (0.138211,0.276423,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6478301517951479 (0.0207541% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6478107773605599 (0.00299071% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6478074788650952 (0.000509177% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6478059308931119 (0.000238956% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6478050615735611 (0.000134195% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6478041847556695 (0.000135352% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6478037050154557 (7.40564e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6478034970281441 (3.21065e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6478034418012881 (8.52525e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 18, 0.138211, 0.276423, 0, 0.276423, 0.127247, 0.410261, 0.425341, 0.531397
# elapsed time for k point: 0.013178110122680664
# solve_kpoint (0.146341,0.292683,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.643004991099656 (0.0200035% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6429884502015202 (0.00257247% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.642985674752254 (0.000431649% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6429845558073346 (0.000174023% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6429839219267948 (9.85841e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6429832823676096 (9.94674e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6429829474592018 (5.20867e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6429827927215497 (2.40656e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6429827493591114 (6.74395e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 19, 0.146341, 0.292683, 0, 0.292683, 0.13468, 0.405845, 0.419465, 0.533088
# elapsed time for k point: 0.01585245132446289
# solve_kpoint (0.154472,0.308943,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6384909365504172 (0.0193763% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6384765698872812 (0.00225012% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6384741793756245 (0.000374409% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6384733544038513 (0.00012921% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6384729025598561 (7.07695e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6384724453405763 (7.16114e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6384722069824904 (3.73326e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6384720875525045 (1.87056e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6384720528602467 (5.43364e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 20, 0.154472, 0.308943, 0, 0.308943, 0.142104, 0.401456, 0.413577, 0.534851
# elapsed time for k point: 0.02123117446899414
# solve_kpoint (0.162602,0.325203,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6343003240959041 (0.0188631% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6342875872289675 (0.00200804% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6342854709219174 (0.000333652% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6342848460110788 (9.85221e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6342845249260658 (5.06216e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6342841981308797 (5.15219e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 75.8435%)
#     iteration    7: trace = 0.6342840243996027 (2.73901e-05% change)
#     iteration    8: trace = 0.6342839317347486 (1.46094e-05% change)
#     iteration    9: trace = 0.6342839041356405 (4.35122e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 21, 0.162602, 0.325203, 0, 0.325203, 0.149516, 0.397098, 0.407688, 0.536687
# elapsed time for k point: 0.015334606170654297
# solve_kpoint (0.170732,0.341463,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6304427185428656 (0.0184446% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6304311783470422 (0.00183051% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.63042924694632 (0.000306362% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6304287553689936 (7.7975e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 92.5007%)
#     iteration    5: trace = 0.630428528730911 (3.59498e-05% change)
#     iteration    6: trace = 0.630428298912918 (3.64543e-05% change)
#     iteration    7: trace = 0.6304281696691848 (2.05009e-05% change)
#     iteration    8: trace = 0.6304280974342137 (1.14581e-05% change)
#     iteration    9: trace = 0.6304280758039482 (3.43104e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 22, 0.170732, 0.341463, 0, 0.341463, 0.156917, 0.392775, 0.401808, 0.538593
# elapsed time for k point: 0.021186351776123047
# solve_kpoint (0.178862,0.357724,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6269254506888176 (0.0181098% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6269147435386908 (0.0017079% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6269129191183394 (0.000291016% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 90.2909%)
#     iteration    4: trace = 0.6269125114610226 (6.50262e-05% change)
#     iteration    5: trace = 0.6269123516967748 (2.54843e-05% change)
#     iteration    6: trace = 0.62691219635299 (2.47792e-05% change)
#     iteration    7: trace = 0.6269120996503769 (1.54252e-05% change)
#     iteration    8: trace = 0.6269120428245956 (9.06439e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 23, 0.178862, 0.357724, 0, 0.357724, 0.164305, 0.388492, 0.395947, 0.54057
# elapsed time for k point: 0.01747608184814453
# solve_kpoint (0.186992,0.373984,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6237539307987152 (0.0178548% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6237437302610642 (0.00163536% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6237419388075902 (0.00028721% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6237415771461026 (5.79826e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6237414550009038 (1.95827e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6237413453881042 (1.75734e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6237412676315921 (1.24661e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6237412207326467 (7.51897e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 24, 0.186992, 0.373984, 0, 0.373984, 0.171677, 0.384252, 0.390113, 0.542614
# elapsed time for k point: 0.012376070022583008
# solve_kpoint (0.195122,0.390244,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6209316582431127 (0.0176629% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6209216810987068 (0.00160682% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 67.5439%)
#     iteration    3: trace = 0.6209198529718993 (0.000294422% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.6209195072974564 (5.56714e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6209194162523792 (1.46629e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6209193533685571 (1.01275e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6209193017825705 (8.308e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 25, 0.195122, 0.390244, 0, 0.390244, 0.179034, 0.380057, 0.384316, 0.544724
# elapsed time for k point: 0.01644158363342285
# solve_kpoint (0.203252,0.406504,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 92.0304%)
#     iteration    1: trace = 0.6184606465070516 (0.0175492% change)
#     iteration    2: trace = 0.6184505923436086 (0.00162569% change)
#     iteration    3: trace = 0.6184486482823044 (0.000314344% change)
#     iteration    4: trace = 0.6184482814502397 (5.93149e-05% change)
#     iteration    5: trace = 0.6184481955838722 (1.38842e-05% change)
#     iteration    6: trace = 0.6184481455183852 (8.09534e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 26, 0.203252, 0.406504, 0, 0.406504, 0.186371, 0.375906, 0.378569, 0.546895
# elapsed time for k point: 0.016620159149169922
# solve_kpoint (0.211382,0.422764,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6163409701266256 (0.0174988% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6163305212238818 (0.00169533% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.616328371846514 (0.000348738% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6163279477509745 (6.881e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 71.0237%)
#     iteration    5: trace = 0.6163278622483277 (1.38729e-05% change)
#     iteration    6: trace = 0.6163278223997513 (6.46548e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 27, 0.211382, 0.422764, 0, 0.422764, 0.193688, 0.371776, 0.372908, 0.549122
# elapsed time for k point: 0.012642621994018555
# solve_kpoint (0.219512,0.439024,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6145708558217592 (0.0175124% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6145596302567758 (0.00182659% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.614557160993182 (0.000401795% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 87.9946%)
#     iteration    4: trace = 0.6145566805483482 (7.81774e-05% change)
#     iteration    5: trace = 0.6145566015669001 (1.28518e-05% change)
#     iteration    6: trace = 0.614556581616116 (3.24637e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 28, 0.219512, 0.439024, 0, 0.439024, 0.200981, 0.367069, 0.367941, 0.5514
# elapsed time for k point: 0.013509273529052734
# solve_kpoint (0.227642,0.455285,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6131466079654233 (0.0176105% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6131341264523765 (0.00203567% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.613131175370198 (0.000481312% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6131306075425806 (9.26112e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6131305274363084 (1.30651e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6131305171926049 (1.67072e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 29, 0.227642, 0.455285, 0, 0.455285, 0.208247, 0.361562, 0.363906, 0.553723
# elapsed time for k point: 0.013800382614135742
# solve_kpoint (0.235772,0.471545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6120618983517072 (0.0177966% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6120475626784752 (0.00234222% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6120439290096031 (0.000593692% change)
#     linmin: converged after 2 iterations.
# ...
#     iteration    2: trace = 0.6776248815889048 (0.00998756% change)
#     iteration    3: trace = 0.6776151209200616 (0.00144043% change)
#     iteration    4: trace = 0.6776106696811626 (0.0006569% change)
#     iteration    5: trace = 0.6776090650372033 (0.000236809% change)
#     iteration    6: trace = 0.6776083441823121 (0.000106382% change)
#     iteration    7: trace = 0.677608117736846 (3.34183e-05% change)
#     iteration    8: trace = 0.6776080514839935 (9.77746e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 113, 0.134146, 0.134146, 0, 0.154899, 0.071183, 0.442909, 0.473904, 0.501784
# elapsed time for k point: 0.015616416931152344
# solve_kpoint (0.121951,0.121951,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6842011712672524 (0.0249842% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 84.2932%)
#     iteration    2: trace = 0.6841203428259988 (0.0118142% change)
#     iteration    3: trace = 0.6841086778069532 (0.00170513% change)
#     iteration    4: trace = 0.6841028967790856 (0.000845049% change)
#     iteration    5: trace = 0.6841006354779814 (0.00033055% change)
#     iteration    6: trace = 0.6840996053320274 (0.000150584% change)
#     iteration    7: trace = 0.6840992575220421 (5.0842e-05% change)
#     iteration    8: trace = 0.6840991501517892 (1.56951e-05% change)
#     iteration    9: trace = 0.6840991363493596 (2.01761e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 114, 0.121951, 0.121951, 0, 0.140817, 0.0647215, 0.447305, 0.476898, 0.502391
# elapsed time for k point: 0.015422344207763672
# solve_kpoint (0.109756,0.109756,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6905821072474179 (0.0269693% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 76.9384%)
#     iteration    2: trace = 0.6904851098053155 (0.0140467% change)
#     iteration    3: trace = 0.6904710971259485 (0.00202942% change)
#     iteration    4: trace = 0.6904635605009668 (0.00109153% change)
#     iteration    5: trace = 0.6904604122042908 (0.00045597% change)
#     iteration    6: trace = 0.6904589451165853 (0.00021248% change)
#     iteration    7: trace = 0.690458413260131 (7.70294e-05% change)
#     iteration    8: trace = 0.6904582375302212 (2.54512e-05% change)
#     iteration    9: trace = 0.6904582132117351 (3.52208e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 115, 0.109756, 0.109756, 0, 0.126735, 0.058257, 0.451493, 0.479901, 0.502906
# elapsed time for k point: 0.015244722366333008
# solve_kpoint (0.097561,0.097561,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 51.1905%)
#     iteration    1: trace = 0.6967547630774129 (0.0292537% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.6966381610200069 (0.0167364% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6966212845559954 (0.00242259% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 78.0597%)
#     iteration    4: trace = 0.6966115181761316 (0.00140197% change)
#     iteration    5: trace = 0.6966071770421232 (0.000623181% change)
#     iteration    6: trace = 0.6966051405015394 (0.000292352% change)
#     iteration    7: trace = 0.6966043304104783 (0.000116291% change)
#     iteration    8: trace = 0.696604038879771 (4.18503e-05% change)
#     iteration    9: trace = 0.6966039945369824 (6.36557e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 116, 0.097561, 0.097561, 0, 0.112654, 0.0517901, 0.455459, 0.482861, 0.503313
# elapsed time for k point: 0.016959428787231445
# solve_kpoint (0.0853659,0.0853659,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 51.2563%)
#     iteration    1: trace = 0.7026235404678758 (0.0318911% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.7024831676560225 (0.0199804% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7024628632916797 (0.00289041% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7024503562963154 (0.00178047% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7024444966154002 (0.000834181% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7024417311131959 (0.000393698% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7024405209299688 (0.000172283% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7024400381510503 (6.87288e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7024399555795817 (1.17549e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7024399379194198 (2.51412e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 117, 0.0853659, 0.0853659, 0, 0.098572, 0.045321, 0.459188, 0.485715, 0.5036
# elapsed time for k point: 0.015394926071166992
# solve_kpoint (0.0731707,0.0731707,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7080756499130295 (0.0348079% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7079078135290486 (0.023706% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7078837090713516 (0.00340509% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7078683041101816 (0.00217622% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7078608574758313 (0.00105199% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.707857252795931 (0.000509237% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7078555505534159 (0.000240479% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7078547625601985 (0.000111321% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7078546090168325 (2.16914e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7078545716694667 (5.27614e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 118, 0.0731707, 0.0731707, 0, 0.0844903, 0.03885, 0.462656, 0.488378, 0.503767
# elapsed time for k point: 0.022478103637695312
# solve_kpoint (0.0609756,0.0609756,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7129864939619852 (0.0379576% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7127879635342622 (0.0278488% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.712759920218349 (0.00393439% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7127418849826811 (0.00253037% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7127329770476452 (0.00124982% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7127286372728676 (0.000608894% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7127264189611832 (0.000311243% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7127252376293935 (0.000165748% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7127249747028871 (3.68903e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7127249035847967 (9.97834e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 119, 0.0609756, 0.0609756, 0, 0.0704086, 0.0323774, 0.46583, 0.490744, 0.503835
# elapsed time for k point: 0.02176189422607422
# solve_kpoint (0.0487805,0.0487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7172255904711258 (0.0412359% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7169947674371938 (0.0321879% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7169630648644092 (0.00442169% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7169433001112653 (0.00275677% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7169335189674817 (0.00136429% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.7169287715965433 (0.000662179% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.7169262137714874 (0.000356776% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7169246266103046 (0.000221384% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7169242182499933 (5.696e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.716924097048307 (1.69058e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.4478%)
#     iteration   11: trace = 0.7169240365387314 (8.44017e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 120, 0.0487805, 0.0487805, 0, 0.0563269, 0.0259035, 0.468656, 0.492692, 0.503854
# elapsed time for k point: 0.025417327880859375
# solve_kpoint (0.0365854,0.0365854,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.7206683444319393 (0.0444852% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7204063253063583 (0.0363644% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7203717265940094 (0.00480278% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7203515674552236 (0.00279847% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7203417957445906 (0.00135653% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.7203372593450358 (0.000629759% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.72033474204461 (0.000349462% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7203329432954142 (0.00024971% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7203323876434452 (7.71382e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7203322079851998 (2.4941e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 94.6564%)
#     iteration   11: trace = 0.7203321168723517 (1.26487e-05% change)
#     iteration   12: trace = 0.7203320858338034 (4.30892e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 121, 0.0365854, 0.0365854, 0, 0.0422451, 0.0194285, 0.471058, 0.49411, 0.5039
# elapsed time for k point: 0.031101703643798828
# solve_kpoint (0.0243902,0.0243902,0):
# Solving for bands 1 to 4...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.7232082551696839 (0.0475825% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7229194633783159 (0.03994% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7228833635162273 (0.00499375% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 85.1254%)
#     iteration    4: trace = 0.7228640599795119 (0.00267039% change)
#     iteration    5: trace = 0.7228550826681405 (0.00124192% change)
#     iteration    6: trace = 0.7228512077222622 (0.000536063% change)
#     iteration    7: trace = 0.7228491534073312 (0.000284197% change)
#     iteration    8: trace = 0.7228474508660014 (0.000235532% change)
#     iteration    9: trace = 0.7228468172400253 (8.7657e-05% change)
#     iteration   10: trace = 0.7228465845633116 (3.21889e-05% change)
#     iteration   11: trace = 0.7228464638259782 (1.6703e-05% change)
#     iteration   12: trace = 0.7228464278782004 (4.97309e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 122, 0.0243902, 0.0243902, 0, 0.0281634, 0.0129527, 0.472924, 0.494964, 0.504015
# elapsed time for k point: 0.01822829246520996
# solve_kpoint (0.0121951,0.0121951,0):
# Solving for bands 1 to 4...
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 0.7247616562782178 (0.0508807% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7244548008488134 (0.0423478% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.724421355501897 (0.00461673% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7244053513928765 (0.00220925% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 90.2233%)
#     iteration    5: trace = 0.7243969547323301 (0.00115912% change)
#     iteration    6: trace = 0.7243931320039835 (0.000527713% change)
#     iteration    7: trace = 0.7243917493283993 (0.000190874% change)
#     iteration    8: trace = 0.7243901406116059 (0.000222079% change)
#     iteration    9: trace = 0.7243894313606185 (9.79101e-05% change)
#     iteration   10: trace = 0.724389031561008 (5.51913e-05% change)
#     iteration   11: trace = 0.7243888514405658 (2.48652e-05% change)
#     iteration   12: trace = 0.7243887523490414 (1.36793e-05% change)
#     iteration   13: trace = 0.724388729358135 (3.17384e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 123, 0.0121951, 0.0121951, 0, 0.0140817, 0.00647649, 0.474125, 0.495357, 0.504156
# elapsed time for k point: 0.020669937133789062
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7252932008692016 (0.0497332% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7249677270768905 (0.0448849% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7249402333605619 (0.00379248% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.7249225245147297 (0.00244283% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.7249149946517637 (0.00103872% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 90.551%)
#     iteration    6: trace = 0.7249127603616685 (0.000308215% change)
#     iteration    7: trace = 0.724911460492573 (0.000179314% change)
#     iteration    8: trace = 0.7249103808462281 (0.000148935% change)
#     iteration    9: trace = 0.7249098246913666 (7.67205e-05% change)
#     iteration   10: trace = 0.7249095544254927 (3.72827e-05% change)
#     iteration   11: trace = 0.72490941304641 (1.9503e-05% change)
#     iteration   12: trace = 0.7249093843640818 (3.95668e-06% change)
# Finished solving for bands 2 to 4 after 12 iterations.
# tefreqs:, 124, 0, 0, 0, 0, 0, 0.474542, 0.49546, 0.50422
# elapsed time for k point: 0.017838001251220703
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28294013416068137 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
# Band 2 range: 0.2862670560104177 at Vector3<0.5, 0.5, 0.0> to 0.47454241314949175 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3209157045774281 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0> to 0.49546016183966024 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.48406793346858107 at Vector3<0.5, 0.5, 0.0> to 0.5756248364497014 at Vector3<0.31707317073170727, 0.6341463414634145, 0.0>
# Gap from band 1 (0.28294013416068137) to band 2 (0.2862670560104177), 1.1689669094785236%
# total elapsed time for run: 1.9429945945739746
# done

# %%
md = mpb.MPBData(rectify=True, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 5.21622, harm. mean 3.34398, 86.2305% > 1, 81.862% "fill"
# real part range: 1 .. 6.1504

# %%
import math
import meep as mp
from meep import mpb
import numpy as np
import matplotlib.pyplot as plt

num_bands = 4

# 定义好扫描的k波矢
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(1/3,2/3),       # K
            mp.Vector3(0.5,0.5),  # M
            mp.Vector3()]          # Gamma

# 对k波矢进行插值
k_points = mp.interpolate(40, k_points)

#  units of nm
a=1



# 基本结构和材料性质
# 折射率设置
nslab = 2.48
slab = mp.Medium(index=nslab)

nair = 1
air = mp.Medium(index=nair)



s=0.25

# geometry = [mp.Block(mp.Vector3(0.2,0.2),center=mp.Vector3(-0.25/2,-np.sqrt(3)/4/2), material=air),
#            mp.Block(mp.Vector3(0.2,0.2),center=mp.Vector3(0.25/2,np.sqrt(3)/4/2), material=air)]

s1=0.1
s2=0.2
vertices1 = [mp.Vector3(-1*s1,0),
            mp.Vector3(-0.5*s1,math.sqrt(3)/2*s1),
            mp.Vector3(0.5*s1,math.sqrt(3)/2*s1),
            mp.Vector3(1*s1,0),
            mp.Vector3(0.5*s1,-math.sqrt(3)/2*s1),
            mp.Vector3(-0.5*s1,-math.sqrt(3)/2*s1)]

vertices2 = [mp.Vector3(-1*s2,0),
            mp.Vector3(-0.5*s2,math.sqrt(3)/2*s2),
            mp.Vector3(0.5*s2,math.sqrt(3)/2*s2),
            mp.Vector3(1*s2,0),
            mp.Vector3(0.5*s2,-math.sqrt(3)/2*s2),
            mp.Vector3(-0.5*s2,-math.sqrt(3)/2*s2)]
geometry = [mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=air),
            
           mp.Prism(vertices2, height=mp.inf, center=mp.Vector3(0,np.sqrt(3)/4),material=air)]



geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(0.5, np.sqrt(3) / 2),
    basis2=mp.Vector3(1,0),
)


resolution = 32

# mode solver设置
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    default_material=slab,
                    resolution=resolution)

ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (1, 0, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (-0, 1.1547, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      prism, center = (0,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (-0.1,0,-5e+19)
#           (-0.05,0.0866025,-5e+19)
#           (0.05,0.0866025,-5e+19)
#           (0.1,0,-5e+19)
#           (0.05,-0.0866025,-5e+19)
#           (-0.05,-0.0866025,-5e+19)
#      prism, center = (0,0.433013,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (-0.2,0.433013,-5e+19)
#           (-0.1,0.606218,-5e+19)
#           (0.1,0.606218,-5e+19)
#           (0.2,0.433013,-5e+19)
#           (0.1,0.259808,-5e+19)
#           (-0.1,0.259808,-5e+19)
# Geometric object tree has depth 2 and 3 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 124 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.008130081300813007, 0.016260162601626015, 0.0>
#   Vector3<0.016260162601626015, 0.03252032520325203, 0.0>
#   Vector3<0.024390243902439022, 0.048780487804878044, 0.0>
#   Vector3<0.03252032520325203, 0.06504065040650406, 0.0>
#   Vector3<0.04065040650406504, 0.08130081300813008, 0.0>
#   Vector3<0.048780487804878044, 0.09756097560975609, 0.0>
#   Vector3<0.05691056910569105, 0.1138211382113821, 0.0>
#   Vector3<0.06504065040650406, 0.13008130081300812, 0.0>
#   Vector3<0.07317073170731707, 0.14634146341463414, 0.0>
#   Vector3<0.08130081300813008, 0.16260162601626016, 0.0>
#   Vector3<0.08943089430894308, 0.17886178861788615, 0.0>
#   Vector3<0.09756097560975609, 0.19512195121951217, 0.0>
#   Vector3<0.1056910569105691, 0.2113821138211382, 0.0>
#   Vector3<0.1138211382113821, 0.2276422764227642, 0.0>
#   Vector3<0.1219512195121951, 0.2439024390243902, 0.0>
#   Vector3<0.13008130081300812, 0.26016260162601623, 0.0>
#   Vector3<0.1382113821138211, 0.2764227642276422, 0.0>
#   Vector3<0.14634146341463414, 0.2926829268292683, 0.0>
#   Vector3<0.15447154471544713, 0.30894308943089427, 0.0>
#   Vector3<0.16260162601626016, 0.3252032520325203, 0.0>
#   Vector3<0.17073170731707316, 0.3414634146341463, 0.0>
#   Vector3<0.17886178861788615, 0.3577235772357723, 0.0>
#   Vector3<0.18699186991869918, 0.37398373983739835, 0.0>
#   Vector3<0.19512195121951217, 0.39024390243902435, 0.0>
#   Vector3<0.20325203252032517, 0.40650406504065034, 0.0>
#   Vector3<0.2113821138211382, 0.4227642276422764, 0.0>
#   Vector3<0.2195121951219512, 0.4390243902439024, 0.0>
#   Vector3<0.2276422764227642, 0.4552845528455284, 0.0>
#   Vector3<0.23577235772357721, 0.47154471544715443, 0.0>
#   Vector3<0.2439024390243902, 0.4878048780487804, 0.0>
#   Vector3<0.25203252032520324, 0.5040650406504065, 0.0>
#   Vector3<0.26016260162601623, 0.5203252032520325, 0.0>
#   Vector3<0.26829268292682923, 0.5365853658536585, 0.0>
#   Vector3<0.2764227642276422, 0.5528455284552845, 0.0>
#   Vector3<0.2845528455284553, 0.5691056910569106, 0.0>
#   Vector3<0.2926829268292683, 0.5853658536585366, 0.0>
#   Vector3<0.30081300813008127, 0.6016260162601625, 0.0>
#   Vector3<0.30894308943089427, 0.6178861788617885, 0.0>
#   Vector3<0.31707317073170727, 0.6341463414634145, 0.0>
#   Vector3<0.3252032520325203, 0.6504065040650406, 0.0>
#   Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
#   Vector3<0.33739837398373984, 0.6626016260162602, 0.0>
#   Vector3<0.3414634146341463, 0.6585365853658536, 0.0>
#   Vector3<0.34552845528455284, 0.6544715447154471, 0.0>
#   Vector3<0.3495934959349593, 0.6504065040650406, 0.0>
#   Vector3<0.35365853658536583, 0.6463414634146342, 0.0>
#   Vector3<0.35772357723577236, 0.6422764227642276, 0.0>
#   Vector3<0.36178861788617883, 0.6382113821138211, 0.0>
#   Vector3<0.36585365853658536, 0.6341463414634146, 0.0>
#   Vector3<0.36991869918699183, 0.6300813008130081, 0.0>
#   Vector3<0.37398373983739835, 0.6260162601626016, 0.0>
#   Vector3<0.3780487804878049, 0.6219512195121951, 0.0>
#   Vector3<0.38211382113821135, 0.6178861788617886, 0.0>
#   Vector3<0.3861788617886179, 0.6138211382113821, 0.0>
#   Vector3<0.3902439024390244, 0.6097560975609756, 0.0>
#   Vector3<0.3943089430894309, 0.6056910569105691, 0.0>
#   Vector3<0.3983739837398374, 0.6016260162601625, 0.0>
#   Vector3<0.40243902439024387, 0.5975609756097561, 0.0>
#   Vector3<0.4065040650406504, 0.5934959349593496, 0.0>
#   Vector3<0.41056910569105687, 0.589430894308943, 0.0>
#   Vector3<0.4146341463414634, 0.5853658536585366, 0.0>
#   Vector3<0.4186991869918699, 0.5813008130081301, 0.0>
#   Vector3<0.4227642276422764, 0.5772357723577236, 0.0>
#   Vector3<0.4268292682926829, 0.573170731707317, 0.0>
#   Vector3<0.43089430894308944, 0.5691056910569106, 0.0>
#   Vector3<0.4349593495934959, 0.5650406504065041, 0.0>
#   Vector3<0.43902439024390244, 0.5609756097560976, 0.0>
#   Vector3<0.44308943089430897, 0.556910569105691, 0.0>
#   Vector3<0.44715447154471544, 0.5528455284552846, 0.0>
#   Vector3<0.45121951219512196, 0.5487804878048781, 0.0>
#   Vector3<0.45528455284552843, 0.5447154471544715, 0.0>
#   Vector3<0.45934959349593496, 0.540650406504065, 0.0>
#   Vector3<0.46341463414634143, 0.5365853658536586, 0.0>
#   Vector3<0.46747967479674796, 0.532520325203252, 0.0>
#   Vector3<0.4715447154471545, 0.5284552845528455, 0.0>
#   Vector3<0.47560975609756095, 0.524390243902439, 0.0>
#   Vector3<0.4796747967479675, 0.5203252032520325, 0.0>
#   Vector3<0.483739837398374, 0.516260162601626, 0.0>
#   Vector3<0.4878048780487805, 0.5121951219512195, 0.0>
#   Vector3<0.491869918699187, 0.508130081300813, 0.0>
#   Vector3<0.49593495934959353, 0.5040650406504066, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4878048780487805, 0.4878048780487805, 0.0>
#   Vector3<0.47560975609756095, 0.47560975609756095, 0.0>
#   Vector3<0.46341463414634143, 0.46341463414634143, 0.0>
#   Vector3<0.45121951219512196, 0.45121951219512196, 0.0>
#   Vector3<0.43902439024390244, 0.43902439024390244, 0.0>
#   Vector3<0.4268292682926829, 0.4268292682926829, 0.0>
#   Vector3<0.4146341463414634, 0.4146341463414634, 0.0>
#   Vector3<0.4024390243902439, 0.4024390243902439, 0.0>
#   Vector3<0.3902439024390244, 0.3902439024390244, 0.0>
#   Vector3<0.3780487804878049, 0.3780487804878049, 0.0>
#   Vector3<0.36585365853658536, 0.36585365853658536, 0.0>
#   Vector3<0.35365853658536583, 0.35365853658536583, 0.0>
#   Vector3<0.3414634146341463, 0.3414634146341463, 0.0>
#   Vector3<0.3292682926829268, 0.3292682926829268, 0.0>
#   Vector3<0.3170731707317073, 0.3170731707317073, 0.0>
#   Vector3<0.3048780487804878, 0.3048780487804878, 0.0>
#   Vector3<0.2926829268292683, 0.2926829268292683, 0.0>
#   Vector3<0.2804878048780488, 0.2804878048780488, 0.0>
#   Vector3<0.2682926829268293, 0.2682926829268293, 0.0>
#   Vector3<0.25609756097560976, 0.25609756097560976, 0.0>
#   Vector3<0.24390243902439024, 0.24390243902439024, 0.0>
#   Vector3<0.23170731707317072, 0.23170731707317072, 0.0>
#   Vector3<0.2195121951219512, 0.2195121951219512, 0.0>
#   Vector3<0.20731707317073167, 0.20731707317073167, 0.0>
#   Vector3<0.1951219512195122, 0.1951219512195122, 0.0>
#   Vector3<0.18292682926829268, 0.18292682926829268, 0.0>
#   Vector3<0.17073170731707316, 0.17073170731707316, 0.0>
#   Vector3<0.15853658536585363, 0.15853658536585363, 0.0>
#   Vector3<0.1463414634146341, 0.1463414634146341, 0.0>
#   Vector3<0.13414634146341464, 0.13414634146341464, 0.0>
#   Vector3<0.12195121951219512, 0.12195121951219512, 0.0>
#   Vector3<0.1097560975609756, 0.1097560975609756, 0.0>
#   Vector3<0.09756097560975607, 0.09756097560975607, 0.0>
#   Vector3<0.08536585365853655, 0.08536585365853655, 0.0>
#   Vector3<0.07317073170731708, 0.07317073170731708, 0.0>
#   Vector3<0.06097560975609756, 0.06097560975609756, 0.0>
#   Vector3<0.04878048780487804, 0.04878048780487804, 0.0>
#   Vector3<0.036585365853658514, 0.036585365853658514, 0.0>
#   Vector3<0.02439024390243899, 0.02439024390243899, 0.0>
#   Vector3<0.012195121951219523, 0.012195121951219523, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01736736297607422
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 2.622847542656091 (193.834% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.8364888498425452 (103.278% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.7639120876566006 (9.06982% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7416935780748817 (2.95144% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.7285784942034856 (1.78403% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.7161186307192304 (1.72491% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.9815%)
#     iteration    7: trace = 0.7122618115002006 (0.540027% change)
#     switching back to exact line minimization
#     iteration    8: trace = 0.708684522823727 (0.503508% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.7057736689865264 (0.411586% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 78.988%)
#     iteration   10: trace = 0.7047127311997579 (0.150436% change)
#     iteration   11: trace = 0.7044650791965956 (0.0351484% change)
#     iteration   12: trace = 0.704326436995373 (0.0196824% change)
#     iteration   13: trace = 0.7042973586617389 (0.00412862% change)
#     iteration   14: trace = 0.7042771803747766 (0.00286506% change)
#     iteration   15: trace = 0.7042612896973054 (0.00225634% change)
#     iteration   16: trace = 0.7042559216620647 (0.000762225% change)
#     iteration   17: trace = 0.704254201856937 (0.000244202% change)
#     iteration   18: trace = 0.7042532412568391 (0.0001364% change)
#     iteration   19: trace = 0.7042529122062715 (4.67233e-05% change)
#     iteration   20: trace = 0.7042528479078326 (9.13002e-06% change)
# Finished solving for bands 2 to 4 after 20 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.478356, 0.485819, 0.489293
# elapsed time for k point: 0.0325472354888916
# solve_kpoint (0.00813008,0.0162602,0):
# Solving for bands 1 to 4...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.7043272452775388 (0.0254807% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.7041475774579018 (0.0255124% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.7041027721365415 (0.00636326% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7040671533231389 (0.00505888% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7040464509856421 (0.00294044% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.7040384444856393 (0.00113722% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 0.7040353865185122 (0.000434348% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.7040331931470845 (0.000311543% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7040323413721848 (0.000120985% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7040318621986272 (6.80613e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 88.7767%)
#     iteration   11: trace = 0.7040315060580276 (5.05859e-05% change)
#     iteration   12: trace = 0.7040312470083314 (3.67952e-05% change)
#     iteration   13: trace = 0.7040311789948039 (9.66058e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 2, 0.00813008, 0.0162602, 0, 0.0162602, 0.00748427, 0.477004, 0.485146, 0.490995
# elapsed time for k point: 0.026560306549072266
# solve_kpoint (0.0162602,0.0325203,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.7036114397344457 (0.0274742% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7033793802531343 (0.0329866% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7033079296971616 (0.0101587% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 59.2748%)
#     iteration    4: trace = 0.7032335958503477 (0.0105697% change)
#     iteration    5: trace = 0.7031900072597201 (0.0061985% change)
#     iteration    6: trace = 0.7031715962682379 (0.00261824% change)
#     iteration    7: trace = 0.7031652549525942 (0.00090182% change)
#     iteration    8: trace = 0.7031605416111091 (0.000670306% change)
#     iteration    9: trace = 0.7031594500718565 (0.000155233% change)
#     iteration   10: trace = 0.7031588643613138 (8.3297e-05% change)
#     iteration   11: trace = 0.7031585260684179 (4.81105e-05% change)
#     switching back to exact line minimization
#     iteration   12: trace = 0.7031583781352788 (2.10384e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7031583387622389 (5.59946e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 3, 0.0162602, 0.0325203, 0, 0.0325203, 0.014968, 0.473676, 0.48472, 0.49357
# elapsed time for k point: 0.021697998046875
# solve_kpoint (0.0243902,0.0487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.7017839793486071 (0.035934% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.7014296265107178 (0.0505059% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7012945403105639 (0.0192606% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.701131898438403 (0.0231944% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7010469541166993 (0.012116% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.7010160998333861 (0.00440127% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 0.7010065406031086 (0.00136363% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.7009995914572167 (0.000991315% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7009982583367738 (0.000190174% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7009977093488944 (7.83152e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7009973863754976 (4.60734e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7009972303956236 (2.22511e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.700997158749649 (1.02206e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.7009971158913136 (6.11391e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# tefreqs:, 4, 0.0243902, 0.0487805, 0, 0.0487805, 0.0224506, 0.469475, 0.484735, 0.495094
# elapsed time for k point: 0.020451784133911133
# solve_kpoint (0.0325203,0.0650407,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6978640897795645 (0.0467684% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.6268%)
#     iteration    2: trace = 0.6974274543028356 (0.062587% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.6972550727555884 (0.0247198% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6970541349355519 (0.0288226% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 51.5709%)
#     iteration    5: trace = 0.6969642076927556 (0.0129019% change)
#     iteration    6: trace = 0.6969365111429937 (0.00397396% change)
#     iteration    7: trace = 0.6969292131669086 (0.00104716% change)
#     iteration    8: trace = 0.6969239806863632 (0.000750794% change)
#     iteration    9: trace = 0.6969229946105594 (0.00014149% change)
#     iteration   10: trace = 0.696922690800034 (4.35931e-05% change)
#     iteration   11: trace = 0.6969225530936265 (1.97592e-05% change)
#     iteration   12: trace = 0.6969224710670876 (1.17698e-05% change)
#     iteration   13: trace = 0.6969224349301701 (5.18521e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 5, 0.0325203, 0.0650407, 0, 0.0650407, 0.0299315, 0.464916, 0.484956, 0.494669
# elapsed time for k point: 0.026888132095336914
# solve_kpoint (0.0406504,0.0813008,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6918482265772501 (0.0484718% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6915024849640031 (0.0499861% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.6913811852154864 (0.017543% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6912569605655112 (0.0179692% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.6912045969085948 (0.00757542% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6911904810993104 (0.00204223% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6911874306176283 (0.000441338% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6911853187789994 (0.000305538% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6911848902766021 (6.19953e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6911847761731389 (1.65084e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6911847358253744 (5.83748e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 6, 0.0406504, 0.0813008, 0, 0.0813008, 0.0374103, 0.460189, 0.485235, 0.492502
# elapsed time for k point: 0.016197681427001953
# solve_kpoint (0.0487805,0.097561,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6848573323414914 (0.042827% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.684637458386631 (0.0321102% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.6845721553283487 (0.0095388% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6845178117843999 (0.00793864% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.6844941454607176 (0.00345743% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6844880833834134 (0.000885633% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6844869868966447 (0.000160191% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6844863187117074 (9.76184e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6844861626999775 (2.27925e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6844861215970397 (6.00493e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 7, 0.0487805, 0.097561, 0, 0.097561, 0.0448863, 0.455374, 0.485183, 0.489595
# elapsed time for k point: 0.02127218246459961
# solve_kpoint (0.0569106,0.113821,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6775401521974808 (0.0368627% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6773988236053612 (0.0208612% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6773627247740451 (0.00532918% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6773395979729938 (0.0034143% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6773291323900184 (0.00154511% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6773265112175725 (0.000386987% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6773260796336925 (6.37188e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6773258517253589 (3.36482e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6773257921590788 (8.79433e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 8, 0.0569106, 0.113821, 0, 0.113821, 0.052359, 0.450512, 0.483087, 0.488109
# elapsed time for k point: 0.015679597854614258
# solve_kpoint (0.0650407,0.130081,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.670120422288032 (0.0321157% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6700248187977283 (0.0142676% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6700029529485505 (0.00326349% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6699923127407283 (0.0015881% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 85.1232%)
#     iteration    5: trace = 0.6699873884669965 (0.000734977% change)
#     iteration    6: trace = 0.6699861790573109 (0.000180512% change)
#     iteration    7: trace = 0.6699859837877893 (2.91453e-05% change)
#     iteration    8: trace = 0.669985887595984 (1.43573e-05% change)
#     iteration    9: trace = 0.6699858588703 (4.28751e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 9, 0.0650407, 0.130081, 0, 0.130081, 0.0598278, 0.445626, 0.478823, 0.488419
# elapsed time for k point: 0.018755674362182617
# solve_kpoint (0.0731707,0.146341,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6627234579504879 (0.0284733% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 80.4446%)
#     iteration    2: trace = 0.6626558832862049 (0.010197% change)
#     iteration    3: trace = 0.662641531621845 (0.0021658% change)
#     iteration    4: trace = 0.6626361224359119 (0.00081631% change)
#     iteration    5: trace = 0.6626336363877312 (0.000375176% change)
#     iteration    6: trace = 0.6626330212976598 (9.28251e-05% change)
#     iteration    7: trace = 0.662632914168338 (1.61672e-05% change)
#     iteration    8: trace = 0.6626328603124403 (8.12756e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 10, 0.0731707, 0.146341, 0, 0.146341, 0.0672922, 0.44073, 0.473844, 0.489218
# elapsed time for k point: 0.013819694519042969
# solve_kpoint (0.0813008,0.162602,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6554377468742636 (0.0256702% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.655388355866518 (0.00753586% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6553783369215764 (0.00152872% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 83.4565%)
#     iteration    4: trace = 0.6553753071712423 (0.000462291% change)
#     iteration    5: trace = 0.6553739173587764 (0.000212064% change)
#     iteration    6: trace = 0.6553735700053779 (5.30008e-05% change)
#     iteration    7: trace = 0.6553734995453653 (1.07511e-05% change)
#     iteration    8: trace = 0.6553734610483015 (5.87406e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 11, 0.0813008, 0.162602, 0, 0.162602, 0.0747516, 0.435834, 0.468525, 0.490223
# elapsed time for k point: 0.018813133239746094
# solve_kpoint (0.0894309,0.178862,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6483280371153066 (0.0234805% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6482910020125616 (0.00571257% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6482836999200824 (0.00112637% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6482818581798999 (0.000284095% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6482810268837003 (0.000128231% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 85.6045%)
#     iteration    6: trace = 0.6482808113873706 (3.32412e-05% change)
#     iteration    7: trace = 0.6482807599449107 (7.93521e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 12, 0.0894309, 0.178862, 0, 0.178862, 0.0822053, 0.430947, 0.462988, 0.491376
# elapsed time for k point: 0.013795137405395508
# solve_kpoint (0.097561,0.195122,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6414429835642377 (0.0217607% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6414145818094424 (0.00442789% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6414090617394725 (0.000860612% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6414078261882574 (0.000192631% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6414072655578302 (8.74063e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6414071117639267 (2.39776e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6414070683279607 (6.77198e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 13, 0.097561, 0.195122, 0, 0.195122, 0.0896527, 0.426073, 0.457298, 0.492656
# elapsed time for k point: 0.011878252029418945
# solve_kpoint (0.105691,0.211382,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.634819097401923 (0.0203849% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.634796914671971 (0.0034944% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 92.4968%)
#     iteration    3: trace = 0.6347926387036751 (0.000673599% change)
#     iteration    4: trace = 0.6347917786704291 (0.000135483% change)
#     iteration    5: trace = 0.6347913817917605 (6.25211e-05% change)
#     iteration    6: trace = 0.6347912653469443 (1.83438e-05% change)
#     iteration    7: trace = 0.6347912283156474 (5.83362e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 14, 0.105691, 0.211382, 0, 0.211382, 0.0970933, 0.421217, 0.451498, 0.494055
# elapsed time for k point: 0.015810251235961914
# solve_kpoint (0.113821,0.227642,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6284848027014305 (0.0192851% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6284671515026322 (0.00280857% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.4065%)
#     iteration    3: trace = 0.6284637582217618 (0.000539931% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.6284631245431849 (0.00010083% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.628462823614059 (4.78834e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6284627291660033 (1.50284e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6284626969527055 (5.12573e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 15, 0.113821, 0.227642, 0, 0.227642, 0.104526, 0.416382, 0.445618, 0.495568
# elapsed time for k point: 0.011649608612060547
# solve_kpoint (0.121951,0.243902,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6224621248686103 (0.0183982% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6224478308532528 (0.00229639% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6224450818739691 (0.000441641% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6224445916586439 (7.87564e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6224443491820648 (3.89555e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6224442683852709 (1.29806e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6224442401907125 (4.52965e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 16, 0.121951, 0.243902, 0, 0.243902, 0.111951, 0.411571, 0.439683, 0.497191
# elapsed time for k point: 0.013638019561767578
# solve_kpoint (0.130081,0.260163,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6167684477926012 (0.0176799% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 90.8213%)
#     iteration    2: trace = 0.6167566682075817 (0.00190991% change)
#     iteration    3: trace = 0.616754397259672 (0.000368209% change)
#     iteration    4: trace = 0.6167540008918941 (6.42667e-05% change)
#     iteration    5: trace = 0.6167537948883219 (3.34013e-05% change)
#     iteration    6: trace = 0.6167537230214144 (1.16524e-05% change)
#     iteration    7: trace = 0.6167536983436048 (4.00124e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 17, 0.130081, 0.260163, 0, 0.260163, 0.119367, 0.406787, 0.433712, 0.498922
# elapsed time for k point: 0.01745748519897461
# solve_kpoint (0.138211,0.276423,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6114175933776527 (0.0170972% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6114077115426061 (0.00161623% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.611405798439683 (0.000312902% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 76.1523%)
#     iteration    4: trace = 0.61140546451627 (5.46157e-05% change)
#     iteration    5: trace = 0.6114052815089047 (2.99322e-05% change)
#     iteration    6: trace = 0.6114052157892899 (1.07489e-05% change)
#     iteration    7: trace = 0.6114051941834304 (3.5338e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 18, 0.138211, 0.276423, 0, 0.276423, 0.126774, 0.40203, 0.427722, 0.500759
# elapsed time for k point: 0.011769771575927734
# solve_kpoint (0.146341,0.292683,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6064206115410848 (0.0166249% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6064121676471826 (0.00139243% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6064105225628902 (0.000271282% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6064102301159149 (4.82259e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.606410061649636 (2.77809e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6064100003490598 (1.01088e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6064099813208551 (3.13784e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 19, 0.146341, 0.292683, 0, 0.292683, 0.13417, 0.397302, 0.421727, 0.502698
# elapsed time for k point: 0.014666318893432617
# solve_kpoint (0.154472,0.308943,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6017863530368452 (0.0162441% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6017789973520773 (0.00122232% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6017775506438477 (0.000240406% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.3261%)
#     iteration    4: trace = 0.6017772848221845 (4.41728e-05% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.6017771256086679 (2.64572e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 64.83%)
#     iteration    6: trace = 0.6017770675237174 (9.65224e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 20, 0.154472, 0.308943, 0, 0.308943, 0.141554, 0.392604, 0.415741, 0.504739
# elapsed time for k point: 0.015265941619873047
# solve_kpoint (0.162602,0.325203,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5975219268603973 (0.0159434% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5975153844530401 (0.00109493% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5975140775364662 (0.000218725% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5975138087869456 (4.49779e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.597513642106177 (2.78957e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.6499%)
#     iteration    6: trace = 0.5975135833595231 (9.83185e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 21, 0.162602, 0.325203, 0, 0.325203, 0.148927, 0.387934, 0.409776, 0.506878
# elapsed time for k point: 0.012203454971313477
# solve_kpoint (0.170732,0.341463,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.593632828238661 (0.015701% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5936268922267829 (0.000999952% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5936256830269486 (0.000203697% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5936254224629709 (4.38937e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5936252617808991 (2.70679e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5936252048234598 (9.59485e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 22, 0.170732, 0.341463, 0, 0.341463, 0.156286, 0.383292, 0.403844, 0.509114
# elapsed time for k point: 0.009673357009887695
# solve_kpoint (0.178862,0.357724,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5901234541616238 (0.0155201% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5901179395721469 (0.000934485% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5901167834119505 (0.00019592% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5901165216110095 (4.43643e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.8626%)
#     iteration    5: trace = 0.5901163650955339 (2.65228e-05% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.59011630855598 (9.58109e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 23, 0.178862, 0.357724, 0, 0.357724, 0.163631, 0.378675, 0.39796, 0.511443
# elapsed time for k point: 0.018935203552246094
# solve_kpoint (0.186992,0.373984,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5869970190607985 (0.0153908% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5869917716382496 (0.000893948% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5869906283663685 (0.000194768% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5869903572015515 (4.61958e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 73.8179%)
#     iteration    5: trace = 0.5869902039987837 (2.60997e-05% change)
#     iteration    6: trace = 0.5869901467257929 (9.75706e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 24, 0.186992, 0.373984, 0, 0.373984, 0.170961, 0.374081, 0.392136, 0.513863
# elapsed time for k point: 0.012629270553588867
# solve_kpoint (0.195122,0.390244,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5842557377560981 (0.0153088% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5842506172602318 (0.000876417% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5842494459510915 (0.000200481% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.584249157220549 (4.94191e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5842490065821981 (2.57832e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5842489476354236 (1.00893e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.584248928073584 (3.3482e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 25, 0.195122, 0.390244, 0, 0.390244, 0.178273, 0.369503, 0.386388, 0.516372
# elapsed time for k point: 0.011524677276611328
# solve_kpoint (0.203252,0.406504,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5819008399230978 (0.0152735% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5818957005783236 (0.000883203% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5818944527104014 (0.000214449% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5818941579738817 (5.06512e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5818940220355315 (2.33614e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5818939648871937 (9.82109e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 26, 0.203252, 0.406504, 0, 0.406504, 0.185567, 0.364935, 0.380733, 0.518964
# elapsed time for k point: 0.015216827392578125
# solve_kpoint (0.211382,0.422764,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5799327070049731 (0.0152841% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5799274190009304 (0.000911835% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5799260469339349 (0.000236593% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5799256945268809 (6.07676e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5799255456905427 (2.56647e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5799254818916153 (1.10012e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5799254555549764 (4.54138e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 27, 0.211382, 0.422764, 0, 0.422764, 0.19284, 0.360368, 0.375189, 0.521638
# elapsed time for k point: 0.014037370681762695
# solve_kpoint (0.219512,0.439024,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 61.1068%)
#     iteration    1: trace = 0.5783504826706657 (0.0153355% change)
#     iteration    2: trace = 0.5783448802089002 (0.000968701% change)
#     iteration    3: trace = 0.5783433179258137 (0.00027013% change)
#     iteration    4: trace = 0.5783429448744533 (6.45035e-05% change)
#     iteration    5: trace = 0.5783428106321105 (2.32115e-05% change)
#     iteration    6: trace = 0.5783427521725489 (1.01081e-05% change)
#     iteration    7: trace = 0.5783427235451337 (4.9499e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 28, 0.219512, 0.439024, 0, 0.439024, 0.200089, 0.355793, 0.369777, 0.524389
# elapsed time for k point: 0.012217044830322266
# solve_kpoint (0.227642,0.455285,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5771524645057026 (0.0154376% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5771463611104074 (0.00105751% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5771445283089316 (0.000317563% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5771440948764612 (7.50995e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5771439582043312 (2.36808e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5771439003092507 (1.00313e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5771438684158217 (5.52608e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 29, 0.227642, 0.455285, 0, 0.455285, 0.207312, 0.351198, 0.36452, 0.527211
# elapsed time for k point: 0.015928030014038086
# solve_kpoint (0.235772,0.471545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5763354778341472 (0.0155951% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 65.0765%)
#     iteration    2: trace = 0.5763286373772132 (0.0011869% change)
#     iteration    3: trace = 0.5763264291224517 (0.00038316% change)
#     iteration    4: trace = 0.5763259150469886 (8.91987e-05% change)
#     iteration    5: trace = 0.5763257728246929 (2.46774e-05% change)
#     iteration    6: trace = 0.5763257166989617 (9.73854e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 30, 0.235772, 0.471545, 0, 0.471545, 0.214504, 0.346575, 0.359437, 0.530099
# elapsed time for k point: 0.011112213134765625
# solve_kpoint (0.243902,0.487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5758948711018781 (0.0158195% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5758869856535894 (0.00136926% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5758842615859436 (0.000473022% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5758835987277646 (0.000115103% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5758834305976943 (2.91952e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5758833665570019 (1.11204e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5758833255573821 (7.11943e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 31, 0.243902, 0.487805, 0, 0.487805, 0.221659, 0.34192, 0.354547, 0.533046
# elapsed time for k point: 0.010618925094604492
# solve_kpoint (0.252033,0.504065,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5758237058655609 (0.0161142% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 55.0864%)
#     iteration    2: trace = 0.5758143349040732 (0.00162741% change)
#     iteration    3: trace = 0.5758108883672521 (0.000598552% change)
#     iteration    4: trace = 0.5758101116156844 (0.000134897% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.5758099419683345 (2.94624e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 69.3889%)
#     iteration    6: trace = 0.5758098918046803 (8.71184e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 32, 0.252033, 0.504065, 0, 0.504065, 0.22877, 0.337236, 0.349862, 0.536043
# elapsed time for k point: 0.015912532806396484
# solve_kpoint (0.260163,0.520325,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5761128049707727 (0.0165076% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5761013335252102 (0.0019912% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5760968734162866 (0.000774191% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5760958342532529 (0.00018038% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.3656%)
#     iteration    5: trace = 0.576095625742204 (3.61938e-05% change)
#     iteration    6: trace = 0.5760955697665626 (9.71638e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 33, 0.260163, 0.520325, 0, 0.520325, 0.235825, 0.33254, 0.345386, 0.53908
# elapsed time for k point: 0.01035165786743164
# solve_kpoint (0.268293,0.536585,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5767487306525603 (0.0170155% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5767342680069985 (0.00250765% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5767283766861087 (0.0010215% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5767270150564457 (0.000236096% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5767267652960735 (4.33065e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5767267121689879 (9.21183e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 34, 0.268293, 0.536585, 0, 0.536585, 0.242808, 0.327859, 0.341117, 0.542143
# elapsed time for k point: 0.016161441802978516
# solve_kpoint (0.276423,0.552846,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5777130636296659 (0.01769% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5776942081330029 (0.00326387% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5776862097999211 (0.00138454% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5776843694467286 (0.000318574% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5776840550582441 (5.44222e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5776840025761545 (9.08491e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 35, 0.276423, 0.552846, 0, 0.552846, 0.249692, 0.323234, 0.337047, 0.545213
# elapsed time for k point: 0.010390996932983398
# solve_kpoint (0.284553,0.569106,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5789792749806788 (0.0185864% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5789538531703122 (0.00439089% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5789427068363275 (0.00192527% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5789401274750718 (0.000445531% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5789397058693125 (7.28238e-05% change)
# ...
#     iteration    9: trace = 0.6623764281934232 (1.95413e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 114, 0.121951, 0.121951, 0, 0.140817, 0.0652274, 0.445606, 0.475997, 0.482684
# elapsed time for k point: 0.018845319747924805
# solve_kpoint (0.109756,0.109756,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6695471371241526 (0.023868% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 73.4076%)
#     iteration    2: trace = 0.6694612281311484 (0.0128317% change)
#     iteration    3: trace = 0.6694397396361076 (0.00320987% change)
#     iteration    4: trace = 0.669430280627591 (0.00141298% change)
#     iteration    5: trace = 0.6694262918838287 (0.000595843% change)
#     iteration    6: trace = 0.6694249855140377 (0.000195148% change)
#     iteration    7: trace = 0.669424682180789 (4.53125e-05% change)
#     iteration    8: trace = 0.6694245238037926 (2.36587e-05% change)
#     iteration    9: trace = 0.6694245001518166 (3.53318e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 115, 0.109756, 0.109756, 0, 0.126735, 0.0587112, 0.449771, 0.47858, 0.484401
# elapsed time for k point: 0.01625514030456543
# solve_kpoint (0.097561,0.097561,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6764351709951711 (0.0261084% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6763273903326197 (0.0159349% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6762990434384462 (0.00419139% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.676283619423926 (0.00228068% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 87.2291%)
#     iteration    5: trace = 0.6762766150683076 (0.00103572% change)
#     iteration    6: trace = 0.6762742636772034 (0.000347697% change)
#     iteration    7: trace = 0.6762737211574772 (8.02219e-05% change)
#     iteration    8: trace = 0.6762734267624861 (4.35319e-05% change)
#     iteration    9: trace = 0.6762733825931904 (6.53128e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 116, 0.097561, 0.097561, 0, 0.112654, 0.0521928, 0.453802, 0.48074, 0.486315
# elapsed time for k point: 0.016376733779907227
# solve_kpoint (0.0853659,0.0853659,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6830043243292495 (0.0286858% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6828674490518473 (0.0200422% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6828290453339954 (0.00562405% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6828029347561461 (0.00382396% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6827904296823822 (0.00183145% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6827862094745345 (0.000618084% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6827852398160528 (0.000142015% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6827846926970965 (8.01305e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6827846090309576 (1.22537e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6827845893290114 (2.88553e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 117, 0.0853659, 0.0853659, 0, 0.098572, 0.0456726, 0.457704, 0.482445, 0.488315
# elapsed time for k point: 0.019373416900634766
# solve_kpoint (0.0731707,0.0731707,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6890710026115562 (0.0314508% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6888961352185065 (0.0253805% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6888431615488539 (0.00768994% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6887986363397818 (0.00646397% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 75.2055%)
#     iteration    5: trace = 0.6887768632885936 (0.00316107% change)
#     iteration    6: trace = 0.6887694457040296 (0.00107693% change)
#     iteration    7: trace = 0.6887677507236293 (0.000246089% change)
#     iteration    8: trace = 0.6887667533252614 (0.000144809% change)
#     iteration    9: trace = 0.6887665948532973 (2.30081e-05% change)
#     iteration   10: trace = 0.6887665555546414 (5.70566e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 118, 0.0731707, 0.0731707, 0, 0.0844903, 0.0391508, 0.461481, 0.483774, 0.490135
# elapsed time for k point: 0.017716646194458008
# solve_kpoint (0.0609756,0.0609756,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6943859051882774 (0.0340227% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 51.8085%)
#     iteration    2: trace = 0.6941641951940405 (0.031934% change)
#     iteration    3: trace = 0.6940921537826176 (0.0103787% change)
#     iteration    4: trace = 0.6940200668725937 (0.0103863% change)
#     iteration    5: trace = 0.6939847662948736 (0.00508652% change)
#     iteration    6: trace = 0.6939727741477361 (0.00172803% change)
#     iteration    7: trace = 0.6939699846787257 (0.000401957% change)
#     iteration    8: trace = 0.6939683054798719 (0.00024197% change)
#     switching back to exact line minimization
#     iteration    9: trace = 0.6939680240074948 (4.05598e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6939679467453903 (1.11334e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6939678955854 (7.3721e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 119, 0.0609756, 0.0609756, 0, 0.0704086, 0.0326277, 0.465128, 0.484813, 0.491443
# elapsed time for k point: 0.017349958419799805
# solve_kpoint (0.0487805,0.0487805,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6986517155367005 (0.0354537% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6983835159379046 (0.0383955% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6982915913742362 (0.0131633% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.6981915943627141 (0.0143213% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.6981449243410902 (0.00668464% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.6981293660701804 (0.00222854% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6981256465261169 (0.000532789% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6981233262925441 (0.000332352% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6981229157458653 (5.88072e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6981227886786885 (1.82013e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6981226802077534 (1.55375e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.6981226156688991 (9.24463e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 120, 0.0487805, 0.0487805, 0, 0.0563269, 0.0261034, 0.468628, 0.485603, 0.491953
# elapsed time for k point: 0.0177001953125
# solve_kpoint (0.0365854,0.0365854,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.1442%)
#     iteration    1: trace = 0.7016537664132629 (0.034226% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.7013622274037506 (0.0415589% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.701263988938821 (0.0140078% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.7011577971752281 (0.0151441% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7011113360903989 (0.00662656% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.7010954696115982 (0.00226307% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 0.7010912035912097 (0.000608481% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7010885859976846 (0.000373361% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7010880845736953 (7.15208e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.701087869212931 (3.07181e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7010876482050378 (3.15236e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7010875456400956 (1.46294e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7010875200229147 (3.65392e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 121, 0.0365854, 0.0365854, 0, 0.0422451, 0.0195783, 0.471937, 0.48614, 0.491577
# elapsed time for k point: 0.028013229370117188
# solve_kpoint (0.0243902,0.0243902,0):
# Solving for bands 1 to 4...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.7034520728203204 (0.0304421% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7031726834474122 (0.0397248% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.7030890449113611 (0.0118952% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7030075838164571 (0.0115868% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.7029718973879127 (0.00507638% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 66.8122%)
#     iteration    6: trace = 0.7029596175595899 (0.00174686% change)
#     switching back to exact line minimization
#     iteration    7: trace = 0.7029562442795489 (0.000479869% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.7029540005170563 (0.00031919% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.7029535208863146 (6.82308e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.7029532200562646 (4.27952e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.7029528903343935 (4.69052e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.7029527524689171 (1.96123e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.7029527208021191 (4.50483e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 122, 0.0243902, 0.0243902, 0, 0.0281634, 0.0130526, 0.474941, 0.486349, 0.49059
# elapsed time for k point: 0.02447819709777832
# solve_kpoint (0.0121951,0.0121951,0):
# Solving for bands 1 to 4...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.7043409567036847 (0.0273878% change)
#     linmin: converged after 6 iterations.
#     switching to approximate line minimization (decrease time by 82.15%)
#     iteration    2: trace = 0.7040929417550471 (0.0352185% change)
#     iteration    3: trace = 0.7040654235616308 (0.00390839% change)
#     iteration    4: trace = 0.7040264351780268 (0.00553776% change)
#     iteration    5: trace = 0.7039997129211588 (0.0037957% change)
#     iteration    6: trace = 0.7039800241675747 (0.00279674% change)
#     iteration    7: trace = 0.7039696241387371 (0.00147733% change)
#     iteration    8: trace = 0.7039643103351139 (0.000754837% change)
#     iteration    9: trace = 0.703960998883458 (0.000470402% change)
#     iteration   10: trace = 0.703958747689422 (0.00031979% change)
#     iteration   11: trace = 0.7039571940730259 (0.000220697% change)
#     iteration   12: trace = 0.7039560193121757 (0.00016688% change)
#     iteration   13: trace = 0.7039549536701324 (0.000151379% change)
#     iteration   14: trace = 0.7039538311499205 (0.000159459% change)
#     iteration   15: trace = 0.7039527518196463 (0.000153324% change)
#     iteration   16: trace = 0.7039519169237569 (0.000118601% change)
#     iteration   17: trace = 0.7039512349264525 (9.68813e-05% change)
#     iteration   18: trace = 0.703950450506617 (0.000111431% change)
#     iteration   19: trace = 0.7039494353150897 (0.000144214% change)
#     iteration   20: trace = 0.7039484751550457 (0.000136396% change)
#     iteration   21: trace = 0.7039478456703065 (8.9422e-05% change)
#     iteration   22: trace = 0.7039474596831612 (5.48318e-05% change)
#     iteration   23: trace = 0.7039471908159243 (3.81942e-05% change)
#     iteration   24: trace = 0.7039469981118156 (2.73748e-05% change)
#     iteration   25: trace = 0.703946862417012 (1.92763e-05% change)
#     iteration   26: trace = 0.7039467445506682 (1.67436e-05% change)
#     iteration   27: trace = 0.7039465953805861 (2.11905e-05% change)
#     iteration   28: trace = 0.7039463814034043 (3.03968e-05% change)
#     iteration   29: trace = 0.7039461480296922 (3.31522e-05% change)
#     iteration   30: trace = 0.7039459769986025 (2.42961e-05% change)
#     iteration   31: trace = 0.7039458746721189 (1.45361e-05% change)
#     iteration   32: trace = 0.7039458100243322 (9.18363e-06% change)
# Finished solving for bands 1 to 4 after 32 iterations.
# tefreqs:, 123, 0.0121951, 0.0121951, 0, 0.0140817, 0.00652644, 0.477334, 0.486117, 0.489638
# elapsed time for k point: 0.03829026222229004
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.7046000916918027 (0.0224562% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.7043803641466764 (0.0311896% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.7043281409764648 (0.00741433% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 77.4665%)
#     iteration    4: trace = 0.704284820267985 (0.00615083% change)
#     iteration    5: trace = 0.704263765245972 (0.00298961% change)
#     iteration    6: trace = 0.704255950888877 (0.00110958% change)
#     iteration    7: trace = 0.7042542723073395 (0.000238349% change)
#     iteration    8: trace = 0.7042532794492391 (0.00014098% change)
#     iteration    9: trace = 0.7042530797223027 (2.83601e-05% change)
#     iteration   10: trace = 0.7042529578401299 (1.73066e-05% change)
#     iteration   11: trace = 0.7042528392890568 (1.68336e-05% change)
#     iteration   12: trace = 0.7042528022455175 (5.25998e-06% change)
# Finished solving for bands 2 to 4 after 12 iterations.
# tefreqs:, 124, 0, 0, 0, 0, 0, 0.478356, 0.485819, 0.489293
# elapsed time for k point: 0.019559144973754883
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2809614033741629 at Vector3<0.3414634146341463, 0.6585365853658536, 0.0>
# Band 2 range: 0.2828527107116749 at Vector3<0.5, 0.5, 0.0> to 0.4783564013915075 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3139140822648043 at Vector3<0.3414634146341463, 0.6585365853658536, 0.0> to 0.48634865435645364 at Vector3<0.02439024390243899, 0.02439024390243899, 0.0>
# Band 4 range: 0.45599315597697465 at Vector3<0.5, 0.5, 0.0> to 0.5620045833123704 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
# Gap from band 1 (0.2809614033741629) to band 2 (0.2828527107116749), 0.6708974785345759%
# total elapsed time for run: 1.8212482929229736
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 5.4022, harm. mean 3.60033, 86.8164% > 1, 85.4731% "fill"
# real part range: 1 .. 6.1504

# %%
md = mpb.MPBData(rectify=False, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 6.04739, harm. mean 5.62812, 98.2422% > 1, 98% "fill"
# real part range: 1 .. 6.1504

# %%
import math
import meep as mp
from meep import mpb
import numpy as np
import matplotlib.pyplot as plt

num_bands = 4

# 定义好扫描的k波矢
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(1/3,2/3),       # K
            mp.Vector3(0.5,0.5),  # M
            mp.Vector3()]          # Gamma

# 对k波矢进行插值
k_points = mp.interpolate(10, k_points)

#  units of nm
a=1



# 基本结构和材料性质
# 折射率设置
nslab = 2.48
slab = mp.Medium(index=nslab)

nair = 1
air = mp.Medium(index=nair)



s=0.25
geometry = [mp.Cylinder(0.1,center=mp.Vector3(0,-0.25), material=air),
            mp.Cylinder(0.2,center=mp.Vector3(0,0.25), material=air)]

# geometry = [mp.Block(mp.Vector3(0.2,0.2),center=mp.Vector3(-0.25/2,-np.sqrt(3)/4/2), material=air),
#            mp.Block(mp.Vector3(0.2,0.2),center=mp.Vector3(0.25/2,np.sqrt(3)/4/2), material=air)]

geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(0,1),
    basis2=mp.Vector3(1,0),
)


resolution = 32

# mode solver设置
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    default_material=slab,
                    resolution=resolution)

ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0, 1, 0)
#      (1, 0, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (-0, 1, -0)
#      (1, -0, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,-0.25,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0.25,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 34 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0303030303030303, 0.0606060606060606, 0.0>
#   Vector3<0.0606060606060606, 0.1212121212121212, 0.0>
#   Vector3<0.0909090909090909, 0.1818181818181818, 0.0>
#   Vector3<0.1212121212121212, 0.2424242424242424, 0.0>
#   Vector3<0.1515151515151515, 0.303030303030303, 0.0>
#   Vector3<0.1818181818181818, 0.3636363636363636, 0.0>
#   Vector3<0.2121212121212121, 0.4242424242424242, 0.0>
#   Vector3<0.2424242424242424, 0.4848484848484848, 0.0>
#   Vector3<0.2727272727272727, 0.5454545454545454, 0.0>
#   Vector3<0.303030303030303, 0.606060606060606, 0.0>
#   Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
#   Vector3<0.34848484848484845, 0.6515151515151515, 0.0>
#   Vector3<0.36363636363636365, 0.6363636363636364, 0.0>
#   Vector3<0.3787878787878788, 0.6212121212121212, 0.0>
#   Vector3<0.3939393939393939, 0.6060606060606061, 0.0>
#   Vector3<0.40909090909090906, 0.5909090909090908, 0.0>
#   Vector3<0.42424242424242425, 0.5757575757575757, 0.0>
#   Vector3<0.4393939393939394, 0.5606060606060606, 0.0>
#   Vector3<0.45454545454545453, 0.5454545454545454, 0.0>
#   Vector3<0.4696969696969697, 0.5303030303030303, 0.0>
#   Vector3<0.48484848484848486, 0.5151515151515151, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.45454545454545453, 0.45454545454545453, 0.0>
#   Vector3<0.40909090909090906, 0.40909090909090906, 0.0>
#   Vector3<0.36363636363636365, 0.36363636363636365, 0.0>
#   Vector3<0.3181818181818182, 0.3181818181818182, 0.0>
#   Vector3<0.2727272727272727, 0.2727272727272727, 0.0>
#   Vector3<0.2272727272727273, 0.2272727272727273, 0.0>
#   Vector3<0.18181818181818182, 0.18181818181818182, 0.0>
#   Vector3<0.13636363636363635, 0.13636363636363635, 0.0>
#   Vector3<0.09090909090909088, 0.09090909090909088, 0.0>
#   Vector3<0.045454545454545414, 0.045454545454545414, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.011557340621948242
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 2.400718942861853 (192.591% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.7045663828455173 (109.243% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.6238158257400814 (12.1577% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.1905%)
#     iteration    4: trace = 0.601269248160559 (3.68082% change)
#     iteration    5: trace = 0.5917855482446386 (1.58982% change)
#     iteration    6: trace = 0.5815424129167391 (1.746% change)
#     iteration    7: trace = 0.5767820098249841 (0.821946% change)
#     iteration    8: trace = 0.5734885941471515 (0.572633% change)
#     iteration    9: trace = 0.5717379357080759 (0.305731% change)
#     iteration   10: trace = 0.5689783262215899 (0.483838% change)
#     iteration   11: trace = 0.5667437842055734 (0.393502% change)
#     iteration   12: trace = 0.5655086932490627 (0.218165% change)
#     iteration   13: trace = 0.5652032307489219 (0.0540301% change)
#     iteration   14: trace = 0.5651092035357217 (0.0166374% change)
#     iteration   15: trace = 0.5650775871235244 (0.0055949% change)
#     iteration   16: trace = 0.5650648078843272 (0.00226153% change)
#     iteration   17: trace = 0.5650610313961939 (0.000668331% change)
#     iteration   18: trace = 0.5650601803510075 (0.000150611% change)
#     iteration   19: trace = 0.56505985598164 (5.74044e-05% change)
#     iteration   20: trace = 0.5650596081167448 (4.38653e-05% change)
#     iteration   21: trace = 0.5650594519049532 (2.76452e-05% change)
#     iteration   22: trace = 0.5650593832210776 (1.21552e-05% change)
#     iteration   23: trace = 0.5650593571454601 (4.61467e-06% change)
# Finished solving for bands 2 to 4 after 23 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.416206, 0.425656, 0.458964
# elapsed time for k point: 0.021056175231933594
# solve_kpoint (0.030303,0.0606061,0):
# Solving for bands 1 to 4...
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 67.2854%)
#     iteration    1: trace = 0.5671412608113287 (0.490846% change)
#     iteration    2: trace = 0.5657824513732891 (0.239877% change)
#     iteration    3: trace = 0.5654516593379563 (0.0584834% change)
#     iteration    4: trace = 0.5653531902361646 (0.0174158% change)
#     iteration    5: trace = 0.5653449205308569 (0.00146276% change)
#     iteration    6: trace = 0.5653414122785001 (0.000620553% change)
#     iteration    7: trace = 0.5653407270272044 (0.00012121% change)
#     iteration    8: trace = 0.5653405213924455 (3.63736e-05% change)
#     iteration    9: trace = 0.565340437667461 (1.48097e-05% change)
#     iteration   10: trace = 0.5653403392400607 (1.74103e-05% change)
#     iteration   11: trace = 0.565340231281109 (1.90963e-05% change)
#     iteration   12: trace = 0.5653401471331572 (1.48845e-05% change)
#     iteration   13: trace = 0.5653401106173821 (6.45908e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# tefreqs:, 2, 0.030303, 0.0606061, 0, 0.0677596, 0.0308215, 0.407051, 0.421066, 0.470535
# elapsed time for k point: 0.012284517288208008
# solve_kpoint (0.0606061,0.121212,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5682012123675885 (0.471981% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.566944711871056 (0.221381% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.5667417508434947 (0.0358055% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 53.5655%)
#     iteration    4: trace = 0.5666947137829311 (0.0082999% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.5666898772446927 (0.000853468% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5666880072563123 (0.000329985% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5666864442496778 (0.000275815% change)
#     large trace change predicted (0.00106703%)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.5666804011274279 (0.0010664% change)
#     large trace change predicted (0.00844778%)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 0.5666344396874774 (0.00811097% change)
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration   10: trace = 0.5662946997718077 (0.0599755% change)
#     linmin: converged after 9 iterations.
#     iteration   11: trace = 0.5660588422602904 (0.0416579% change)
#     linmin: converged after 6 iterations.
#     iteration   12: trace = 0.565831934228382 (0.0400936% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 84.3806%)
#     iteration   13: trace = 0.5656985396901151 (0.0235777% change)
#     iteration   14: trace = 0.5656288639679732 (0.0123175% change)
#     iteration   15: trace = 0.5655703041353405 (0.0103536% change)
#     iteration   16: trace = 0.5655339381141393 (0.00643018% change)
#     iteration   17: trace = 0.5655065696442596 (0.00483952% change)
#     iteration   18: trace = 0.5654856571943235 (0.00369807% change)
#     iteration   19: trace = 0.5654692973220983 (0.00289311% change)
#     iteration   20: trace = 0.5654556320773834 (0.00241665% change)
#     iteration   21: trace = 0.5654442431027333 (0.00201414% change)
#     iteration   22: trace = 0.5654357206739458 (0.00150722% change)
#     iteration   23: trace = 0.5654298850006647 (0.00103207% change)
#     iteration   24: trace = 0.5654257563433376 (0.000730183% change)
#     iteration   25: trace = 0.5654224424990422 (0.000586081% change)
#     iteration   26: trace = 0.5654195004821118 (0.000520323% change)
#     iteration   27: trace = 0.5654168449854641 (0.000469652% change)
#     iteration   28: trace = 0.5654144921139224 (0.000416131% change)
#     iteration   29: trace = 0.5654124066992769 (0.00036883% change)
#     iteration   30: trace = 0.5654105483602538 (0.00032867% change)
#     iteration   31: trace = 0.5654089450801211 (0.000283561% change)
#     iteration   32: trace = 0.5654076598049533 (0.000227318% change)
#     iteration   33: trace = 0.5654067019410359 (0.000169411% change)
#     iteration   34: trace = 0.5654059998996646 (0.000124166% change)
#     iteration   35: trace = 0.565405443902472 (9.8336e-05% change)
#     iteration   36: trace = 0.5654049327421866 (9.0406e-05% change)
#     iteration   37: trace = 0.5654044021340265 (9.38457e-05% change)
#     iteration   38: trace = 0.5654038550195915 (9.67652e-05% change)
#     iteration   39: trace = 0.5654033573964617 (8.8012e-05% change)
#     iteration   40: trace = 0.5654029576711468 (7.06974e-05% change)
#     iteration   41: trace = 0.5654026413314146 (5.59494e-05% change)
#     iteration   42: trace = 0.5654023708450973 (4.78396e-05% change)
#     iteration   43: trace = 0.5654021250879413 (4.34659e-05% change)
#     iteration   44: trace = 0.565401903624962 (3.91691e-05% change)
#     iteration   45: trace = 0.5654017069751205 (3.47805e-05% change)
#     iteration   46: trace = 0.5654015229646671 (3.25451e-05% change)
#     iteration   47: trace = 0.5654013334960828 (3.35105e-05% change)
#     iteration   48: trace = 0.5654011286156829 (3.62363e-05% change)
#     iteration   49: trace = 0.5654009146775358 (3.78383e-05% change)
#     iteration   50: trace = 0.565400706854732 (3.67567e-05% change)
#     iteration   51: trace = 0.5654005156735004 (3.38134e-05% change)
#     iteration   52: trace = 0.5654003441849309 (3.03305e-05% change)
#     iteration   53: trace = 0.5654001897382962 (2.73163e-05% change)
#     iteration   54: trace = 0.5654000426843959 (2.60088e-05% change)
#     iteration   55: trace = 0.5653998860640992 (2.77008e-05% change)
#     iteration   56: trace = 0.5653997002668313 (3.28612e-05% change)
#     iteration   57: trace = 0.565399475247748 (3.97982e-05% change)
#     iteration   58: trace = 0.5653992237028325 (4.44898e-05% change)
#     iteration   59: trace = 0.5653989720437178 (4.451e-05% change)
#     iteration   60: trace = 0.5653987360661692 (4.17365e-05% change)
#     iteration   61: trace = 0.5653985165470149 (3.88256e-05% change)
#     iteration   62: trace = 0.5653983101177005 (3.65104e-05% change)
#     iteration   63: trace = 0.5653981129981533 (3.48638e-05% change)
#     iteration   64: trace = 0.5653979161076924 (3.48233e-05% change)
#     iteration   65: trace = 0.5653977025115653 (3.7778e-05% change)
#     iteration   66: trace = 0.5653974538594506 (4.39783e-05% change)
#     iteration   67: trace = 0.5653971674459324 (5.0657e-05% change)
#     iteration   68: trace = 0.5653968716339399 (5.23193e-05% change)
#     iteration   69: trace = 0.5653966091624738 (4.64225e-05% change)
#     resetting CG direction...
#     iteration   70: trace = 0.5653956565110873 (0.000168493% change)
#     iteration   71: trace = 0.5653953948126784 (4.62859e-05% change)
#     iteration   72: trace = 0.5653953424858233 (9.25491e-06% change)
# Finished solving for bands 1 to 4 after 72 iterations.
# tefreqs:, 3, 0.0606061, 0.121212, 0, 0.135519, 0.0616152, 0.38667, 0.415696, 0.489165
# elapsed time for k point: 0.058904170989990234
# solve_kpoint (0.0909091,0.181818,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.6997%)
#     iteration    1: trace = 0.5609970884710855 (0.311837% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.5606373897265755 (0.0641383% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.5605412255059508 (0.0171541% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.5604245977364336 (0.0208084% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5603190350467993 (0.018838% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.5601872717119547 (0.0235185% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.5600825678827364 (0.0186926% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.1561%)
#     iteration    8: trace = 0.5600197224712192 (0.0112214% change)
#     iteration    9: trace = 0.559998480010097 (0.00379323% change)
#     iteration   10: trace = 0.5599911436908457 (0.00131007% change)
#     iteration   11: trace = 0.5599886672318661 (0.000442233% change)
#     iteration   12: trace = 0.5599881747905947 (8.79378e-05% change)
#     iteration   13: trace = 0.5599881053296717 (1.2404e-05% change)
#     iteration   14: trace = 0.5599880943383955 (1.96277e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# tefreqs:, 4, 0.0909091, 0.181818, 0, 0.203279, 0.0923509, 0.364054, 0.410363, 0.500526
# elapsed time for k point: 0.01824331283569336
# solve_kpoint (0.121212,0.242424,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5584981635025328 (0.406904% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5560978069318406 (0.430713% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.5544462748822993 (0.297428% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.5529988943345012 (0.261391% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5519334810491543 (0.192847% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 0.5508330106404769 (0.199584% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 0.5504954451399413 (0.0613015% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 0.5503842847635844 (0.0201948% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.2775%)
#     iteration    9: trace = 0.5503395638919979 (0.00812572% change)
#     iteration   10: trace = 0.5503275897681739 (0.00217579% change)
#     iteration   11: trace = 0.5503260127901761 (0.000286553% change)
#     iteration   12: trace = 0.5503257300869708 (5.13701e-05% change)
#     iteration   13: trace = 0.5503256037467992 (2.29573e-05% change)
#     iteration   14: trace = 0.5503255088746042 (1.72393e-05% change)
#     iteration   15: trace = 0.5503254516522251 (1.03979e-05% change)
#     iteration   16: trace = 0.5503254090139597 (7.74783e-06% change)
# Finished solving for bands 1 to 4 after 16 iterations.
# tefreqs:, 5, 0.121212, 0.242424, 0, 0.271039, 0.122992, 0.341226, 0.405795, 0.504077
# elapsed time for k point: 0.01853156089782715
# solve_kpoint (0.151515,0.30303,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5297173462964351 (0.960312% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5252819859581085 (0.840827% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.5245891475176846 (0.131985% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.5243216830355948 (0.0509985% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5242261802579372 (0.0182162% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.9936%)
#     iteration    6: trace = 0.5241750217957607 (0.00975933% change)
#     iteration    7: trace = 0.5241672269232304 (0.00148709% change)
#     iteration    8: trace = 0.5241655886211563 (0.000312554% change)
#     iteration    9: trace = 0.5241652748138201 (5.9868e-05% change)
#     iteration   10: trace = 0.5241652048470531 (1.33482e-05% change)
#     iteration   11: trace = 0.5241651954483502 (1.79308e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 6, 0.151515, 0.30303, 0, 0.338798, 0.153485, 0.318822, 0.402561, 0.486729
# elapsed time for k point: 0.010527372360229492
# solve_kpoint (0.181818,0.363636,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.4983081097848511 (0.568093% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.4974983989047262 (0.162624% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.4974050125291791 (0.018773% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 57.9693%)
#     iteration    4: trace = 0.4973869110693419 (0.00363925% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.4973843608557694 (0.000512724% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.497383127454962 (0.000247978% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4973829302184251 (3.96549e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4973828951746723 (7.04563e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 7, 0.181818, 0.363636, 0, 0.406558, 0.18374, 0.297266, 0.40095, 0.463135
# elapsed time for k point: 0.014810800552368164
# solve_kpoint (0.212121,0.424242,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.4755789263618969 (0.433434% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 60.1978%)
#     iteration    2: trace = 0.475341622518165 (0.0499103% change)
#     iteration    3: trace = 0.4753165195497998 (0.00528118% change)
#     iteration    4: trace = 0.4753131870061155 (0.000701123% change)
#     iteration    5: trace = 0.4753129109564416 (5.80774e-05% change)
#     iteration    6: trace = 0.4753128403509702 (1.48545e-05% change)
#     iteration    7: trace = 0.4753128282763105 (2.54036e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 8, 0.212121, 0.424242, 0, 0.474317, 0.213497, 0.277101, 0.400977, 0.438366
# elapsed time for k point: 0.008728981018066406
# solve_kpoint (0.242424,0.484848,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.4593532940004057 (0.384387% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.4592498887243961 (0.0225136% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4592394804754653 (0.00226638% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4592383657926751 (0.000242724% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4592382794697979 (1.8797e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4592382663039563 (2.86689e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 9, 0.242424, 0.484848, 0, 0.542077, 0.240486, 0.260877, 0.401099, 0.415292
# elapsed time for k point: 0.009631156921386719
# solve_kpoint (0.272727,0.545455,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4496628085393137 (0.363641% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4495997191466075 (0.0140314% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4495934666958852 (0.00139068% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.3445%)
#     iteration    4: trace = 0.4495928798243251 (0.000130534% change)
#     iteration    5: trace = 0.449592829695051 (1.11499e-05% change)
#     iteration    6: trace = 0.4495928232382869 (1.43614e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 10, 0.272727, 0.545455, 0, 0.609837, 0.237894, 0.275633, 0.385625, 0.410267
# elapsed time for k point: 0.006997346878051758
# solve_kpoint (0.30303,0.606061,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.446580681456593 (0.355717% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.4465271190949672 (0.0119946% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.5154%)
#     iteration    3: trace = 0.4465216316933275 (0.00122891% change)
#     iteration    4: trace = 0.4465211417044509 (0.000109735% change)
#     iteration    5: trace = 0.4465210960572876 (1.02228e-05% change)
#     iteration    6: trace = 0.4465210904994892 (1.24469e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 11, 0.30303, 0.606061, 0, 0.677596, 0.224076, 0.302795, 0.363016, 0.415747
# elapsed time for k point: 0.00953817367553711
# solve_kpoint (0.333333,0.666667,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4500769914251254 (0.35631% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.4500148322901268 (0.0138117% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 72.4818%)
#     iteration    3: trace = 0.4500078065376116 (0.00156124% change)
#     iteration    4: trace = 0.4500070326582402 (0.00017197% change)
#     iteration    5: trace = 0.4500069451034436 (1.94563e-05% change)
#     iteration    6: trace = 0.4500069307244975 (3.19527e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 12, 0.333333, 0.666667, 0, 0.745356, 0.212509, 0.322544, 0.348245, 0.423719
# elapsed time for k point: 0.009021282196044922
# solve_kpoint (0.348485,0.651515,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4429787719159841 (0.0387656% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 88.6986%)
#     iteration    2: trace = 0.4429682840055157 (0.00236762% change)
#     iteration    3: trace = 0.4429673129629757 (0.000219213% change)
#     iteration    4: trace = 0.4429671783082471 (3.03983e-05% change)
#     iteration    5: trace = 0.4429671657063592 (2.84488e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 13, 0.348485, 0.651515, 0, 0.73886, 0.222054, 0.319542, 0.345868, 0.414641
# elapsed time for k point: 0.008972644805908203
# solve_kpoint (0.363636,0.636364,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.43656988917603 (0.0378581% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.3218%)
#     iteration    2: trace = 0.4365618718896552 (0.00183644% change)
#     iteration    3: trace = 0.4365611778057681 (0.000158989% change)
#     iteration    4: trace = 0.4365610908964326 (1.99077e-05% change)
#     iteration    5: trace = 0.4365610826829288 (1.88141e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 14, 0.363636, 0.636364, 0, 0.732933, 0.23157, 0.316796, 0.343699, 0.405521
# elapsed time for k point: 0.009686470031738281
# solve_kpoint (0.378788,0.621212,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.430809435092435 (0.0371551% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4308031638456573 (0.0014557% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4308026572068667 (0.000117603% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4308026009789342 (1.30519e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4308025955230662 (1.26644e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 15, 0.378788, 0.621212, 0, 0.727588, 0.241047, 0.314315, 0.341745, 0.396378
# elapsed time for k point: 0.006898164749145508
# solve_kpoint (0.393939,0.606061,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.3874%)
#     iteration    1: trace = 0.4257078083665375 (0.0366138% change)
#     iteration    2: trace = 0.4257027788893043 (0.00118145% change)
#     iteration    3: trace = 0.4257023987918793 (8.92871e-05% change)
#     iteration    4: trace = 0.4257023616980581 (8.71356e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 16, 0.393939, 0.606061, 0, 0.72284, 0.250471, 0.312106, 0.340009, 0.387234
# elapsed time for k point: 0.007443428039550781
# solve_kpoint (0.409091,0.590909,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.9434%)
#     iteration    1: trace = 0.4212730670742099 (0.0361944% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.4212689348818908 (0.000980887% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4212686353703926 (7.10975e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4212686100845107 (6.00232e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 17, 0.409091, 0.590909, 0, 0.718699, 0.259821, 0.310178, 0.338495, 0.378116
# elapsed time for k point: 0.008548974990844727
# solve_kpoint (0.424242,0.575758,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4175114753916789 (0.0358664% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.2521%)
#     iteration    2: trace = 0.4175079906434629 (0.000834651% change)
#     iteration    3: trace = 0.4175077525230378 (5.70338e-05% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.4175077350197853 (4.19232e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 18, 0.424242, 0.575758, 0, 0.715177, 0.269059, 0.308537, 0.337208, 0.369067
# elapsed time for k point: 0.007027864456176758
# solve_kpoint (0.439394,0.560606,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4144278944737092 (0.0356123% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4144248768466166 (0.000728146% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.9041%)
#     iteration    3: trace = 0.4144246808849548 (4.72852e-05% change)
#     iteration    4: trace = 0.4144246683380173 (3.02756e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 19, 0.439394, 0.560606, 0, 0.712282, 0.278115, 0.30719, 0.33615, 0.360158
# elapsed time for k point: 0.005521297454833984
# solve_kpoint (0.454545,0.545455,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4120260190741737 (0.0354149% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4120233330070958 (0.000651919% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.412023165516048 (4.06509e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4120231560930087 (2.28702e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 20, 0.454545, 0.545455, 0, 0.710023, 0.286841, 0.306146, 0.335324, 0.351536
# elapsed time for k point: 0.008535623550415039
# solve_kpoint (0.469697,0.530303,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4103085640165385 (0.0352628% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.6149%)
#     iteration    2: trace = 0.4103061041724796 (0.000599513% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.410305955069408 (3.63395e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.410305947553064 (1.83189e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 21, 0.469697, 0.530303, 0, 0.708404, 0.294885, 0.305425, 0.334731, 0.34354
# elapsed time for k point: 0.007337331771850586
# solve_kpoint (0.484848,0.515152,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4092773890112536 (0.0351477% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4092750693229635 (0.000566778% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4092749307638859 (3.38548e-05% change)
#     linmin: converged after 1 iterations.
#     iteration    4: trace = 0.4092749243074 (1.57754e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 22, 0.484848, 0.515152, 0, 0.707431, 0.301242, 0.30513, 0.334364, 0.337083
# elapsed time for k point: 0.008850336074829102
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 4...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.408933578588512 (0.0350646% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4089313246239079 (0.000551183% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.9591%)
#     iteration    3: trace = 0.4089311900342674 (3.29125e-05% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.4089311839963514 (1.47651e-06% change)
# Finished solving for bands 1 to 4 after 4 iterations.
# tefreqs:, 23, 0.5, 0.5, 0, 0.707107, 0.303518, 0.305487, 0.334062, 0.334497
# elapsed time for k point: 0.00805521011352539
# solve_kpoint (0.454545,0.454545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.5406%)
#     iteration    1: trace = 0.4120476729504099 (0.312797% change)
#     iteration    2: trace = 0.4120262153378532 (0.00520769% change)
#     iteration    3: trace = 0.4120249752300381 (0.000300978% change)
#     iteration    4: trace = 0.4120249176693502 (1.39702e-05% change)
#     iteration    5: trace = 0.4120249127173272 (1.20187e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 24, 0.454545, 0.454545, 0, 0.642824, 0.286832, 0.30615, 0.335329, 0.351538
# elapsed time for k point: 0.007387876510620117
# solve_kpoint (0.409091,0.409091,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.4213023139136483 (0.311012% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.4212742779138548 (0.00665483% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.6959%)
#     iteration    3: trace = 0.4212721593509402 (0.000502895% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.4212720133956233 (3.46463e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4212720002833521 (3.11254e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 25, 0.409091, 0.409091, 0, 0.578542, 0.259812, 0.310181, 0.3385, 0.37812
# elapsed time for k point: 0.008709907531738281
# solve_kpoint (0.363636,0.363636,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4366171872438495 (0.313098% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.4365712351241278 (0.0105251% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4365665553318587 (0.00107195% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.436566051834076 (0.000115331% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4365660089719172 (9.81802e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 26, 0.363636, 0.363636, 0, 0.514259, 0.231562, 0.316799, 0.343704, 0.405525
# elapsed time for k point: 0.009415149688720703
# solve_kpoint (0.318182,0.318182,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.3805%)
#     iteration    1: trace = 0.4577757211696972 (0.322684% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.4576832399040099 (0.0202043% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4576705166933216 (0.00277995% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4576685063950395 (0.000439247% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4576683345211434 (3.75542e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.45766830831435 (5.72615e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 27, 0.318182, 0.318182, 0, 0.449977, 0.202933, 0.325796, 0.350829, 0.432738
# elapsed time for k point: 0.009611845016479492
# solve_kpoint (0.272727,0.272727,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4843057172899129 (0.348461% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.4840753647280521 (0.0475748% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 75.7812%)
#     iteration    3: trace = 0.4840327237276807 (0.00880914% change)
#     iteration    4: trace = 0.4840231893949732 (0.00196979% change)
#     iteration    5: trace = 0.4840222543365418 (0.000193185% change)
#     iteration    6: trace = 0.4840220368756671 (4.49279e-05% change)
#     iteration    7: trace = 0.4840220027267378 (7.05524e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 28, 0.272727, 0.272727, 0, 0.385695, 0.174125, 0.336925, 0.359723, 0.459111
# elapsed time for k point: 0.010130882263183594
# solve_kpoint (0.227273,0.227273,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5149937895301149 (0.415317% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5142481431073354 (0.144892% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.51406121161874 (0.0363571% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5140026173748707 (0.011399% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.7438%)
#     iteration    5: trace = 0.5139950610382555 (0.00147011% change)
#     iteration    6: trace = 0.5139922042423243 (0.000555804% change)
#     iteration    7: trace = 0.5139914076439088 (0.000154983% change)
#     iteration    8: trace = 0.5139911249467063 (5.50004e-05% change)
#     iteration    9: trace = 0.51399106759639 (1.11578e-05% change)
#     iteration   10: trace = 0.5139910524164462 (2.95335e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 29, 0.227273, 0.227273, 0, 0.321412, 0.145213, 0.34989, 0.370195, 0.483153
# elapsed time for k point: 0.009422540664672852
# solve_kpoint (0.181818,0.181818,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5456581013829804 (0.611164% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5425328925550643 (0.574386% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.5416136144537552 (0.169586% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.5412443062538791 (0.0682099% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5411727039847319 (0.0132301% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 89.2813%)
#     iteration    6: trace = 0.5411228883507543 (0.00920555% change)
#     iteration    7: trace = 0.5410948776620353 (0.00517653% change)
#     iteration    8: trace = 0.5410822307864377 (0.0023373% change)
#     iteration    9: trace = 0.5410782883189806 (0.000728629% change)
#     iteration   10: trace = 0.5410772618900728 (0.000189701% change)
#     iteration   11: trace = 0.5410770722506354 (3.50485e-05% change)
#     iteration   12: trace = 0.5410770451325742 (5.01187e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 30, 0.181818, 0.181818, 0, 0.25713, 0.116233, 0.364341, 0.382, 0.498897
# elapsed time for k point: 0.016112327575683594
# solve_kpoint (0.136364,0.136364,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5606527507185142 (0.973261% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 61.5385%)
#     iteration    2: trace = 0.5545006865755311 (1.10336% change)
#     iteration    3: trace = 0.5535730412817281 (0.167434% change)
#     iteration    4: trace = 0.5531686454404686 (0.0730786% change)
#     iteration    5: trace = 0.553023572820193 (0.0262292% change)
#     iteration    6: trace = 0.552913381154757 (0.0199273% change)
#     iteration    7: trace = 0.5528214199532886 (0.0166335% change)
#     iteration    8: trace = 0.5527509867602818 (0.0127415% change)
#     iteration    9: trace = 0.5527138526589099 (0.00671828% change)
#     iteration   10: trace = 0.5526997217379704 (0.00255668% change)
#     iteration   11: trace = 0.552694204392629 (0.000998259% change)
#     iteration   12: trace = 0.5526929897950588 (0.00021976% change)
#     iteration   13: trace = 0.5526924699939221 (9.40488e-05% change)
#     iteration   14: trace = 0.5526922587694575 (3.82174e-05% change)
#     iteration   15: trace = 0.5526921276990231 (2.37149e-05% change)
#     switching back to exact line minimization
#     iteration   16: trace = 0.552692046839577 (1.46301e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.5526919746250324 (1.3066e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.916%)
#     iteration   18: trace = 0.5526919100767002 (1.16789e-05% change)
#     iteration   19: trace = 0.5526918835372034 (4.80186e-06% change)
# Finished solving for bands 1 to 4 after 19 iterations.
# tefreqs:, 31, 0.136364, 0.136364, 0, 0.192847, 0.0872091, 0.379814, 0.394786, 0.494946
# elapsed time for k point: 0.020195484161376953
# solve_kpoint (0.0909091,0.0909091,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5593922025111284 (0.573187% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5575738252343806 (0.325592% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.5573840676757028 (0.0340385% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.4286%)
#     iteration    4: trace = 0.5573322837096735 (0.00929097% change)
#     iteration    5: trace = 0.5573205214109378 (0.00211049% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.5573077999636421 (0.00228263% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5572969740348104 (0.00194256% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.557290359746256 (0.00118686% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5572880543769201 (0.000413676% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5572874626883506 (0.000106173% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60.1439%)
#     iteration   11: trace = 0.5572873720026637 (1.62727e-05% change)
#     iteration   12: trace = 0.5572873594538011 (2.25178e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 32, 0.0909091, 0.0909091, 0, 0.128565, 0.0581547, 0.395531, 0.407913, 0.480696
# elapsed time for k point: 0.016546964645385742
# solve_kpoint (0.0454545,0.0454545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 0.5637225252606578 (0.443581% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5624960079445692 (0.217812% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.5623040879985985 (0.0341252% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 80.6009%)
#     iteration    4: trace = 0.5622464919743405 (0.0102434% change)
#     iteration    5: trace = 0.5622378236313585 (0.00154175% change)
#     iteration    6: trace = 0.5622348991160531 (0.000520158% change)
#     iteration    7: trace = 0.5622344307985939 (8.32957e-05% change)
#     iteration    8: trace = 0.5622343022773414 (2.2859e-05% change)
#     iteration    9: trace = 0.5622342651656428 (6.60075e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 33, 0.0454545, 0.0454545, 0, 0.0642824, 0.0290818, 0.409565, 0.419794, 0.466281
# elapsed time for k point: 0.010964632034301758
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5681603912557267 (0.498742% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 78.4539%)
#     iteration    2: trace = 0.5655150692979596 (0.466681% change)
#     iteration    3: trace = 0.5651803032666978 (0.0592142% change)
#     iteration    4: trace = 0.5650794187641895 (0.0178516% change)
#     iteration    5: trace = 0.5650659474181363 (0.002384% change)
#     iteration    6: trace = 0.5650614979726781 (0.000787424% change)
#     iteration    7: trace = 0.5650601686530544 (0.000235252% change)
#     iteration    8: trace = 0.5650597202610633 (7.9353e-05% change)
#     iteration    9: trace = 0.565059507440324 (3.76634e-05% change)
#     iteration   10: trace = 0.565059441011347 (1.17561e-05% change)
#     iteration   11: trace = 0.5650594018455249 (6.93127e-06% change)
# Finished solving for bands 2 to 4 after 11 iterations.
# tefreqs:, 34, 0, 0, 0, 0, 0, 0.416206, 0.425656, 0.458964
# elapsed time for k point: 0.009448051452636719
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.30351782378510045 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.2608765045970209 at Vector3<0.2424242424242424, 0.4848484848484848, 0.0> to 0.4162064447794531 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.33406244174551103 at Vector3<0.5, 0.5, 0.0> to 0.4256564445855327 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.3344971043525905 at Vector3<0.5, 0.5, 0.0> to 0.5040768438813122 at Vector3<0.1212121212121212, 0.2424242424242424, 0.0>
# total elapsed time for run: 0.4264976978302002
# done

# %%
md = mpb.MPBData(rectify=False, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 5.34138, harm. mean 3.58544, 88.0859% > 1, 84.2921% "fill"
# real part range: 1 .. 6.1504

# %%
import math
import meep as mp
from meep import mpb
import numpy as np
import matplotlib.pyplot as plt

num_bands = 4

# 定义好扫描的k波矢
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(1/3,2/3),       # K
            mp.Vector3(0.5,0.5),  # M
            mp.Vector3()]          # Gamma

# 对k波矢进行插值
k_points = mp.interpolate(10, k_points)

#  units of nm
a=1



# 基本结构和材料性质
# 折射率设置
nslab = 2.48
slab = mp.Medium(index=nslab)

nair = 1
air = mp.Medium(index=nair)



s=0.25
geometry = [mp.Cylinder(0.1,center=mp.Vector3(1/6,1/6), material=air),
            mp.Cylinder(0.2,center=mp.Vector3(-1/6,-1/6), material=air)]



geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis1=mp.Vector3(1/np.sqrt(3)/2,0.5),
    basis2=mp.Vector3(-1/np.sqrt(3)/2,0.5),
)


resolution = 32

# mode solver设置
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    default_material=slab,
                    resolution=resolution)

ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (-0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (-1, 0.57735, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 34 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0303030303030303, 0.0606060606060606, 0.0>
#   Vector3<0.0606060606060606, 0.1212121212121212, 0.0>
#   Vector3<0.0909090909090909, 0.1818181818181818, 0.0>
#   Vector3<0.1212121212121212, 0.2424242424242424, 0.0>
#   Vector3<0.1515151515151515, 0.303030303030303, 0.0>
#   Vector3<0.1818181818181818, 0.3636363636363636, 0.0>
#   Vector3<0.2121212121212121, 0.4242424242424242, 0.0>
#   Vector3<0.2424242424242424, 0.4848484848484848, 0.0>
#   Vector3<0.2727272727272727, 0.5454545454545454, 0.0>
#   Vector3<0.303030303030303, 0.606060606060606, 0.0>
#   Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
#   Vector3<0.34848484848484845, 0.6515151515151515, 0.0>
#   Vector3<0.36363636363636365, 0.6363636363636364, 0.0>
#   Vector3<0.3787878787878788, 0.6212121212121212, 0.0>
#   Vector3<0.3939393939393939, 0.6060606060606061, 0.0>
#   Vector3<0.40909090909090906, 0.5909090909090908, 0.0>
#   Vector3<0.42424242424242425, 0.5757575757575757, 0.0>
#   Vector3<0.4393939393939394, 0.5606060606060606, 0.0>
#   Vector3<0.45454545454545453, 0.5454545454545454, 0.0>
#   Vector3<0.4696969696969697, 0.5303030303030303, 0.0>
#   Vector3<0.48484848484848486, 0.5151515151515151, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.45454545454545453, 0.45454545454545453, 0.0>
#   Vector3<0.40909090909090906, 0.40909090909090906, 0.0>
#   Vector3<0.36363636363636365, 0.36363636363636365, 0.0>
#   Vector3<0.3181818181818182, 0.3181818181818182, 0.0>
#   Vector3<0.2727272727272727, 0.2727272727272727, 0.0>
#   Vector3<0.2272727272727273, 0.2272727272727273, 0.0>
#   Vector3<0.18181818181818182, 0.18181818181818182, 0.0>
#   Vector3<0.13636363636363635, 0.13636363636363635, 0.0>
#   Vector3<0.09090909090909088, 0.09090909090909088, 0.0>
#   Vector3<0.045454545454545414, 0.045454545454545414, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01266932487487793
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 2.955096942071057 (193.406% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.9263520065182606 (104.535% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 0.7729257198970714 (18.0578% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.7442859393271513 (3.77532% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.7385476348929438 (0.773965% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.3411%)
#     iteration    6: trace = 0.7353104203494636 (0.439284% change)
#     switching back to exact line minimization
#     iteration    7: trace = 0.7340760611580508 (0.16801% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.1116%)
#     iteration    8: trace = 0.7333753690837889 (0.0954978% change)
#     iteration    9: trace = 0.7326892794651998 (0.0935961% change)
#     iteration   10: trace = 0.7323604542535852 (0.0448893% change)
#     iteration   11: trace = 0.7322528478507284 (0.0146942% change)
#     iteration   12: trace = 0.7321634181046109 (0.0122137% change)
#     iteration   13: trace = 0.7321160658154299 (0.00646766% change)
#     iteration   14: trace = 0.7321025399377565 (0.00184752% change)
#     iteration   15: trace = 0.7320973290043028 (0.000711779% change)
#     iteration   16: trace = 0.7320958873927466 (0.000196915% change)
#     iteration   17: trace = 0.7320956895601921 (2.70228e-05% change)
#     iteration   18: trace = 0.7320956546499956 (4.76853e-06% change)
# Finished solving for bands 2 to 4 after 18 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.472418, 0.495165, 0.513545
# elapsed time for k point: 0.02056407928466797
# solve_kpoint (0.030303,0.0606061,0):
# Solving for bands 1 to 4...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 0.729578966562453 (0.971793% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.7242083275981481 (0.738848% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.7233618154531798 (0.116956% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 79.9197%)
#     iteration    4: trace = 0.7228237153229995 (0.0744165% change)
#     iteration    5: trace = 0.7225824537188792 (0.0333832% change)
#     iteration    6: trace = 0.7224418701582288 (0.0194576% change)
#     iteration    7: trace = 0.7222574952563918 (0.0255243% change)
#     iteration    8: trace = 0.7219022293653137 (0.0492004% change)
#     iteration    9: trace = 0.7217249171665659 (0.0245648% change)
#     iteration   10: trace = 0.7216032319536099 (0.0168618% change)
#     iteration   11: trace = 0.721534269070907 (0.00955735% change)
#     iteration   12: trace = 0.7214874580924194 (0.00648791% change)
#     iteration   13: trace = 0.721463178003017 (0.00336534% change)
#     iteration   14: trace = 0.721445924582953 (0.00239148% change)
#     iteration   15: trace = 0.7214408024391316 (0.000709986% change)
#     iteration   16: trace = 0.7214391223987089 (0.000232873% change)
#     iteration   17: trace = 0.721438476008222 (8.95974e-05% change)
#     iteration   18: trace = 0.7214381709593016 (4.22834e-05% change)
#     iteration   19: trace = 0.7214379956094679 (2.43056e-05% change)
#     iteration   20: trace = 0.7214377697989038 (3.13001e-05% change)
#     iteration   21: trace = 0.7214374717200638 (4.13173e-05% change)
#     iteration   22: trace = 0.721437270851591 (2.78428e-05% change)
#     iteration   23: trace = 0.7214370554758175 (2.98537e-05% change)
#     iteration   24: trace = 0.721436854974038 (2.7792e-05% change)
#     iteration   25: trace = 0.7214367688420972 (1.19389e-05% change)
#     iteration   26: trace = 0.7214367486092206 (2.80453e-06% change)
# Finished solving for bands 1 to 4 after 26 iterations.
# tefreqs:, 2, 0.030303, 0.0606061, 0, 0.0606061, 0.0278801, 0.466083, 0.490123, 0.513036
# elapsed time for k point: 0.021810531616210938
# solve_kpoint (0.0606061,0.121212,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.2017%)
#     iteration    1: trace = 0.701771589048247 (0.737733% change)
#     iteration    2: trace = 0.699068830722809 (0.385877% change)
#     iteration    3: trace = 0.6987932356768171 (0.0394309% change)
#     iteration    4: trace = 0.6986988395701998 (0.0135094% change)
#     iteration    5: trace = 0.6986809933046718 (0.00255425% change)
#     iteration    6: trace = 0.698676646554074 (0.000622139% change)
#     iteration    7: trace = 0.6986762343755154 (5.89942e-05% change)
#     iteration    8: trace = 0.6986761480251995 (1.23591e-05% change)
#     iteration    9: trace = 0.6986761267956451 (3.03854e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 3, 0.0606061, 0.121212, 0, 0.121212, 0.0557405, 0.452389, 0.476373, 0.513792
# elapsed time for k point: 0.011002063751220703
# solve_kpoint (0.0909091,0.181818,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 69.4475%)
#     iteration    1: trace = 0.6748842168178977 (0.481809% change)
#     iteration    2: trace = 0.6738517987410886 (0.153094% change)
#     iteration    3: trace = 0.6737573758004052 (0.0140134% change)
#     iteration    4: trace = 0.6737380972722119 (0.00286139% change)
#     iteration    5: trace = 0.6737346993081395 (0.000504346% change)
#     iteration    6: trace = 0.6737341037184066 (8.84013e-05% change)
#     iteration    7: trace = 0.6737340595985253 (6.54856e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 4, 0.0909091, 0.181818, 0, 0.181818, 0.0835602, 0.436339, 0.457642, 0.516647
# elapsed time for k point: 0.008601188659667969
# solve_kpoint (0.121212,0.242424,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6513708127619652 (0.354412% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.6509275636118588 (0.0680718% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6508863904278204 (0.00632551% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.2125%)
#     iteration    4: trace = 0.6508806759520704 (0.000877957% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.650879792405314 (0.000135746% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6508796247834392 (2.57531e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6508795764766504 (7.42177e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 5, 0.121212, 0.242424, 0, 0.242424, 0.111315, 0.419615, 0.43679, 0.521178
# elapsed time for k point: 0.01055288314819336
# solve_kpoint (0.151515,0.30303,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.8813%)
#     iteration    1: trace = 0.6321293703483604 (0.291445% change)
#     switching back to exact line minimization
#     iteration    2: trace = 0.6319066584779255 (0.0352382% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6318847293385218 (0.00347037% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6318824703179757 (0.000357506% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6318821045660381 (5.78829e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.631881988557416 (1.83592e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6318819008199952 (1.38851e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6318818433408872 (9.0965e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 6, 0.151515, 0.30303, 0, 0.30303, 0.138975, 0.402873, 0.415206, 0.527129
# elapsed time for k point: 0.03508186340332031
# solve_kpoint (0.181818,0.363636,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6176898102822193 (0.258209% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 69.1979%)
#     iteration    2: trace = 0.6175557000525134 (0.0217139% change)
#     iteration    3: trace = 0.6175411043374541 (0.00236349% change)
#     iteration    4: trace = 0.6175397156061413 (0.000224881% change)
#     iteration    5: trace = 0.6175394612575934 (4.11874e-05% change)
#     iteration    6: trace = 0.6175393434922658 (1.90701e-05% change)
#     iteration    7: trace = 0.617539258730351 (1.37258e-05% change)
#     iteration    8: trace = 0.6175392211094404 (6.09207e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 7, 0.181818, 0.363636, 0, 0.363636, 0.166497, 0.38647, 0.39361, 0.53435
# elapsed time for k point: 0.010544538497924805
# solve_kpoint (0.212121,0.424242,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6083372236822091 (0.240537% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.7145%)
#     iteration    2: trace = 0.6082351776820462 (0.016776% change)
#     iteration    3: trace = 0.608221283242827 (0.00228441% change)
#     iteration    4: trace = 0.6082190997709742 (0.000358994% change)
#     iteration    5: trace = 0.6082185301093631 (9.36606e-05% change)
#     iteration    6: trace = 0.6082182376581299 (4.80833e-05% change)
#     iteration    7: trace = 0.6082180722181414 (2.72008e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 0.6082179800065364 (1.51609e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6082179648335273 (2.49467e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 8, 0.212121, 0.424242, 0, 0.424242, 0.193813, 0.370654, 0.372481, 0.542704
# elapsed time for k point: 0.01099085807800293
# solve_kpoint (0.242424,0.484848,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 64.1642%)
#     iteration    1: trace = 0.6041669255432366 (0.233023% change)
#     iteration    2: trace = 0.6040595303149277 (0.0177773% change)
#     iteration    3: trace = 0.604037695577446 (0.00361473% change)
#     iteration    4: trace = 0.6040317132665244 (0.000990392% change)
#     iteration    5: trace = 0.6040301397736341 (0.000260499% change)
#     iteration    6: trace = 0.6040292450163074 (0.000148131% change)
#     iteration    7: trace = 0.6040287281746424 (8.55657e-05% change)
#     iteration    8: trace = 0.6040284764569446 (4.16731e-05% change)
#     iteration    9: trace = 0.6040284452758897 (5.16218e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 9, 0.242424, 0.484848, 0, 0.484848, 0.220787, 0.352223, 0.355666, 0.552017
# elapsed time for k point: 0.011440277099609375
# solve_kpoint (0.272727,0.545455,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6050571956153634 (0.235521% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.6048868605633542 (0.0281559% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.6048320627895396 (0.00905959% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6048131210247847 (0.00313179% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.6048077119339327 (0.000894345% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6048036275926583 (0.000675315% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 82.1527%)
#     iteration    7: trace = 0.6048017467375879 (0.000310987% change)
#     iteration    8: trace = 0.6048009467033404 (0.000132281% change)
#     iteration    9: trace = 0.6048008305053627 (1.92126e-05% change)
#     iteration   10: trace = 0.6048008097221961 (3.43637e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 10, 0.272727, 0.545455, 0, 0.545455, 0.24706, 0.333458, 0.3417, 0.561969
# elapsed time for k point: 0.014187097549438477
# solve_kpoint (0.30303,0.606061,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6104091875706796 (0.256079% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.8246%)
#     iteration    2: trace = 0.6099730457964532 (0.0714763% change)
#     iteration    3: trace = 0.6097704064866896 (0.0332265% change)
#     iteration    4: trace = 0.6096935531687953 (0.0126044% change)
#     iteration    5: trace = 0.60966537486019 (0.00462182% change)
#     iteration    6: trace = 0.6096413381245009 (0.00394269% change)
#     iteration    7: trace = 0.609633127492458 (0.00134681% change)
#     iteration    8: trace = 0.6096295348924936 (0.000589307% change)
#     iteration    9: trace = 0.6096289521849316 (9.55839e-05% change)
#     iteration   10: trace = 0.609628868181181 (1.37795e-05% change)
#     iteration   11: trace = 0.6096288594674897 (1.42934e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 11, 0.30303, 0.606061, 0, 0.606061, 0.271133, 0.317769, 0.329116, 0.571682
# elapsed time for k point: 0.011956930160522461
# solve_kpoint (0.333333,0.666667,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6176847480467439 (0.335036% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 53.6313%)
#     iteration    2: trace = 0.6158169227467308 (0.302849% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.6147893534900677 (0.167002% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6143761434583519 (0.0672342% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.0248%)
#     iteration    5: trace = 0.614192771594219 (0.0298513% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.6140534069522652 (0.0226933% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.6140184012232994 (0.00570093% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6140036964787116 (0.00239487% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.6140012242123827 (0.000402648% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.6140009006935363 (5.26903e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.6140008648208266 (5.84245e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 12, 0.333333, 0.666667, 0, 0.666667, 0.283607, 0.312348, 0.320567, 0.577272
# elapsed time for k point: 0.01495814323425293
# solve_kpoint (0.348485,0.651515,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6141207854712698 (0.144262% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6127225730350609 (0.227937% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.6122564111985425 (0.0761094% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 81.0239%)
#     iteration    4: trace = 0.6120789832509046 (0.0289836% change)
#     iteration    5: trace = 0.6119987958978909 (0.0131017% change)
#     iteration    6: trace = 0.6119489627605101 (0.00814302% change)
#     iteration    7: trace = 0.6119394737687559 (0.00155063% change)
#     iteration    8: trace = 0.611936589607627 (0.000471316% change)
#     iteration    9: trace = 0.6119360874927492 (8.20535e-05% change)
#     iteration   10: trace = 0.6119360206399376 (1.09248e-05% change)
#     iteration   11: trace = 0.6119360130325112 (1.24317e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# tefreqs:, 13, 0.348485, 0.651515, 0, 0.652043, 0.281178, 0.310229, 0.325515, 0.575041
# elapsed time for k point: 0.01271200180053711
# solve_kpoint (0.363636,0.636364,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6079430014483045 (0.150643% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.4073%)
#     iteration    2: trace = 0.6067426298693359 (0.197643% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.6064329857138102 (0.0510469% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.6063291966417731 (0.0171161% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.6062897592458206 (0.0065045% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6062677573500919 (0.00362901% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.6062641991023966 (0.000586912% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.6062632298811995 (0.000159868% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.606263064250969 (2.73199e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.0766%)
#     iteration   10: trace = 0.6062630403702982 (3.93899e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 14, 0.363636, 0.636364, 0, 0.638524, 0.276262, 0.306134, 0.335756, 0.568763
# elapsed time for k point: 0.012799978256225586
# solve_kpoint (0.378788,0.621212,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.4993%)
#     iteration    1: trace = 0.5996848676086454 (0.123167% change)
#     iteration    2: trace = 0.5990383911911623 (0.107861% change)
#     iteration    3: trace = 0.5988941561946937 (0.0240807% change)
#     iteration    4: trace = 0.5988531881031778 (0.00684086% change)
#     iteration    5: trace = 0.5988411189370181 (0.0020154% change)
#     iteration    6: trace = 0.5988347399473168 (0.00106523% change)
#     iteration    7: trace = 0.5988337781173316 (0.000160617% change)
#     iteration    8: trace = 0.5988335362344359 (4.03923e-05% change)
#     iteration    9: trace = 0.5988334988842269 (6.23716e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 15, 0.378788, 0.621212, 0, 0.626181, 0.270811, 0.302024, 0.347417, 0.55998
# elapsed time for k point: 0.00792694091796875
# solve_kpoint (0.393939,0.606061,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.591520736936439 (0.0992756% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5911978220937499 (0.0546055% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5911305305931822 (0.0113829% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5911139320224539 (0.00280798% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5911103429049653 (0.00060718% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5911086173521712 (0.000291918% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 76.9947%)
#     iteration    7: trace = 0.5911083526579451 (4.47793e-05% change)
#     iteration    8: trace = 0.591108290125226 (1.05789e-05% change)
#     iteration    9: trace = 0.5911082817819941 (1.41146e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 16, 0.393939, 0.606061, 0, 0.615084, 0.265517, 0.298241, 0.359487, 0.549937
# elapsed time for k point: 0.01543426513671875
# solve_kpoint (0.409091,0.590909,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5840489503091917 (0.0848228% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5838778342579393 (0.0293025% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5838438969241162 (0.00581257% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5838362566810205 (0.00130862% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5838350371328576 (0.000208886% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5838345390782032 (8.53075e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.6213%)
#     iteration    7: trace = 0.5838344583860987 (1.38211e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 0.5838344401054705 (3.13113e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 17, 0.409091, 0.590909, 0, 0.605303, 0.260662, 0.294882, 0.371587, 0.539312
# elapsed time for k point: 0.011455535888671875
# solve_kpoint (0.424242,0.575758,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.2535%)
#     iteration    1: trace = 0.5775047932539255 (0.0763073% change)
#     iteration    2: trace = 0.5774063627540013 (0.0170456% change)
#     iteration    3: trace = 0.5773879752723641 (0.00318455% change)
#     iteration    4: trace = 0.5773840762792521 (0.000675284% change)
#     iteration    5: trace = 0.5773835842614441 (8.5215e-05% change)
#     iteration    6: trace = 0.5773834255070607 (2.74955e-05% change)
#     iteration    7: trace = 0.5773833983203052 (4.70861e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 18, 0.424242, 0.575758, 0, 0.5969, 0.256394, 0.29199, 0.383481, 0.528517
# elapsed time for k point: 0.00804448127746582
# solve_kpoint (0.439394,0.560606,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5720259115023342 (0.0711181% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5719644044087567 (0.0107531% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 79.359%)
#     iteration    3: trace = 0.5719538548454872 (0.00184446% change)
#     iteration    4: trace = 0.5719517427385963 (0.00036928% change)
#     iteration    5: trace = 0.5719515126723986 (4.02248e-05% change)
#     iteration    6: trace = 0.5719514556465077 (9.97041e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 19, 0.439394, 0.560606, 0, 0.589937, 0.252802, 0.289592, 0.394924, 0.517894
# elapsed time for k point: 0.009996891021728516
# solve_kpoint (0.454545,0.545455,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5676983124445768 (0.0678686% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5676565396932685 (0.00735854% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.567650143184208 (0.00112683% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5676489811563318 (0.000204709% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5676488586337951 (2.15842e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5676488341840571 (4.30719e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 20, 0.454545, 0.545455, 0, 0.584464, 0.249949, 0.287709, 0.405553, 0.507863
# elapsed time for k point: 0.009319543838500977
# solve_kpoint (0.469697,0.530303,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5645755562064273 (0.0657944% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5645446201292159 (0.00547968% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5645404610591175 (0.000736715% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5645398482882515 (0.000108543% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 85.24%)
#     iteration    5: trace = 0.5645397784106574 (1.23778e-05% change)
#     iteration    6: trace = 0.5645397657009069 (2.25135e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 21, 0.469697, 0.530303, 0, 0.580523, 0.247881, 0.286353, 0.414727, 0.499097
# elapsed time for k point: 0.008308172225952148
# solve_kpoint (0.484848,0.515152,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.562689953647622 (0.064505% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 86.5076%)
#     iteration    2: trace = 0.5626648057805712 (0.00446932% change)
#     iteration    3: trace = 0.5626617986060622 (0.000534454% change)
#     iteration    4: trace = 0.5626614822709197 (5.62212e-05% change)
#     iteration    5: trace = 0.5626614421504499 (7.13048e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 22, 0.484848, 0.515152, 0, 0.578145, 0.246628, 0.285536, 0.421325, 0.492737
# elapsed time for k point: 0.008280515670776367
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5620586452957891 (0.0637814% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5620360890823155 (0.00401322% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.8174%)
#     iteration    3: trace = 0.562033541239052 (0.000453325% change)
#     iteration    4: trace = 0.5620333344636774 (3.67906e-05% change)
#     iteration    5: trace = 0.5620333080523624 (4.69924e-06% change)
# Finished solving for bands 1 to 4 after 5 iterations.
# tefreqs:, 23, 0.5, 0.5, 0, 0.57735, 0.246208, 0.285263, 0.423809, 0.490333
# elapsed time for k point: 0.008763551712036133
# solve_kpoint (0.454545,0.454545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5641083803296271 (0.166403% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5640491193284722 (0.0105058% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.1739%)
#     iteration    3: trace = 0.5640407008642691 (0.00149252% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.564039880567913 (0.000145432% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5640398161829525 (1.1415e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5640398110926359 (9.02475e-07% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 24, 0.454545, 0.454545, 0, 0.524864, 0.234955, 0.296363, 0.42454, 0.490684
# elapsed time for k point: 0.007462024688720703
# solve_kpoint (0.409091,0.409091,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5701148838417311 (0.166864% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.570049860085025 (0.011406% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.75%)
#     iteration    3: trace = 0.5700403649478467 (0.00166568% change)
#     iteration    4: trace = 0.570039327125787 (0.000182061% change)
#     iteration    5: trace = 0.5700392344435145 (1.62589e-05% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.5700392243577311 (1.76931e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 25, 0.409091, 0.409091, 0, 0.472377, 0.214207, 0.316634, 0.426733, 0.491728
# elapsed time for k point: 0.010734319686889648
# solve_kpoint (0.363636,0.363636,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5800544367737261 (0.169495% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.5799760690260474 (0.0135113% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.7926%)
#     iteration    3: trace = 0.5799643793882729 (0.00201556% change)
#     iteration    4: trace = 0.5799628903068492 (0.000256754% change)
#     iteration    5: trace = 0.5799627428274206 (2.54291e-05% change)
#     iteration    6: trace = 0.5799627247750712 (3.11267e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 26, 0.363636, 0.363636, 0, 0.419891, 0.191457, 0.338536, 0.43038, 0.49343
# elapsed time for k point: 0.009142398834228516
# solve_kpoint (0.318182,0.318182,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.5938021463451815 (0.174948% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 52.5424%)
#     iteration    2: trace = 0.593699235690172 (0.0173323% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.5936838046741928 (0.00259916% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5936815241231791 (0.000384136% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5936812798155573 (4.11513e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.1949%)
#     iteration    6: trace = 0.5936812480430604 (5.35178e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 27, 0.318182, 0.318182, 0, 0.367405, 0.168046, 0.360633, 0.435476, 0.495728
# elapsed time for k point: 0.008668899536132812
# solve_kpoint (0.272727,0.272727,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 52.5806%)
#     iteration    1: trace = 0.6111501375216901 (0.184441% change)
#     iteration    2: trace = 0.6110040950446346 (0.0238992% change)
#     iteration    3: trace = 0.6109825784064082 (0.00352158% change)
#     iteration    4: trace = 0.6109790001236814 (0.000585662% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.6109785795723349 (6.88324e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 61.6216%)
#     iteration    6: trace = 0.6109785186541146 (9.9706e-06% change)
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 28, 0.272727, 0.272727, 0, 0.314918, 0.14433, 0.382401, 0.442027, 0.498527
# elapsed time for k point: 0.011013507843017578
# solve_kpoint (0.227273,0.227273,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 62.1951%)
#     iteration    1: trace = 0.6317597458916137 (0.200133% change)
#     iteration    2: trace = 0.6315370509803641 (0.0352562% change)
#     iteration    3: trace = 0.6315056298651561 (0.00497546% change)
#     iteration    4: trace = 0.6315000286045567 (0.000886973% change)
#     iteration    5: trace = 0.6314992833838985 (0.000118008% change)
#     iteration    6: trace = 0.6314991571756609 (1.99855e-05% change)
#     iteration    7: trace = 0.6314991468446846 (1.63594e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 29, 0.227273, 0.227273, 0, 0.262432, 0.120443, 0.403421, 0.450062, 0.501686
# elapsed time for k point: 0.008959293365478516
# solve_kpoint (0.181818,0.181818,0):
# Solving for bands 1 to 4...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.6550697483812162 (0.226011% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.4323%)
#     iteration    2: trace = 0.6547053072571611 (0.0556494% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.6546570993130552 (0.00736358% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 70.8022%)
#     iteration    4: trace = 0.6546484033983848 (0.00132832% change)
#     iteration    5: trace = 0.6546470765660086 (0.000202679% change)
#     iteration    6: trace = 0.6546468220379329 (3.88802e-05% change)
#     iteration    7: trace = 0.654646798626948 (3.57612e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 30, 0.181818, 0.181818, 0, 0.209946, 0.0964498, 0.423162, 0.459616, 0.505007
# elapsed time for k point: 0.011005401611328125
# solve_kpoint (0.136364,0.136364,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.6801106718983857 (0.269293% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 0.6794693705124283 (0.0943382% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.6793899522906015 (0.011689% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.6793755207254908 (0.00212422% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.679372933611555 (0.000380808% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.6793723919987666 (7.97225e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 62.4531%)
#     iteration    7: trace = 0.6793723470197117 (6.62068e-06% change)
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 31, 0.136364, 0.136364, 0, 0.157459, 0.0723878, 0.440934, 0.470559, 0.508217
# elapsed time for k point: 0.01062464714050293
# solve_kpoint (0.0909091,0.0909091,0):
# Solving for bands 1 to 4...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.7051052848967128 (0.344076% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 80.356%)
#     iteration    2: trace = 0.7038918392846751 (0.172242% change)
#     iteration    3: trace = 0.7037522563722858 (0.0198321% change)
#     iteration    4: trace = 0.7037203926095714 (0.0045278% change)
#     iteration    5: trace = 0.7037069355318732 (0.00191229% change)
#     iteration    6: trace = 0.7037027908472555 (0.000588981% change)
#     iteration    7: trace = 0.7037018834833162 (0.000128941% change)
#     iteration    8: trace = 0.7037015438440268 (4.82647e-05% change)
#     iteration    9: trace = 0.7037013425048388 (2.86115e-05% change)
#     iteration   10: trace = 0.7037012731585722 (9.8545e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 32, 0.0909091, 0.0909091, 0, 0.104973, 0.048281, 0.45603, 0.482001, 0.510962
# elapsed time for k point: 0.011460542678833008
# solve_kpoint (0.0454545,0.0454545,0):
# Solving for bands 1 to 4...
#     linmin: converged after 7 iterations.
#     switching to approximate line minimization (decrease time by 76.7473%)
#     iteration    1: trace = 0.7265488363949695 (0.477697% change)
#     iteration    2: trace = 0.7245948776663387 (0.269299% change)
#     iteration    3: trace = 0.7240267302173687 (0.0784397% change)
#     iteration    4: trace = 0.7238027415604658 (0.0309413% change)
#     iteration    5: trace = 0.723751960746735 (0.00701608% change)
#     iteration    6: trace = 0.7237004848713353 (0.00711262% change)
#     iteration    7: trace = 0.7236845601318718 (0.00220048% change)
#     iteration    8: trace = 0.7236802909244761 (0.000589928% change)
#     iteration    9: trace = 0.7236755864974872 (0.000650072% change)
#     iteration   10: trace = 0.7236733770745285 (0.000305306% change)
#     iteration   11: trace = 0.7236723093014753 (0.000147549% change)
#     iteration   12: trace = 0.7236717506629899 (7.7195e-05% change)
#     iteration   13: trace = 0.7236714727456574 (3.84038e-05% change)
#     iteration   14: trace = 0.7236713964250661 (1.05463e-05% change)
#     iteration   15: trace = 0.7236713604012243 (4.97793e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# tefreqs:, 33, 0.0454545, 0.0454545, 0, 0.0524864, 0.024147, 0.467516, 0.491434, 0.512844
# elapsed time for k point: 0.014531135559082031
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 56.4236%)
#     iteration    1: trace = 0.7377166073386514 (0.637356% change)
#     iteration    2: trace = 0.7332773344276047 (0.603575% change)
#     iteration    3: trace = 0.7327858591482521 (0.0670469% change)
#     iteration    4: trace = 0.7322980553715241 (0.0665906% change)
#     iteration    5: trace = 0.7321357470535147 (0.0221667% change)
#     iteration    6: trace = 0.7321075410936826 (0.00385263% change)
#     iteration    7: trace = 0.7320949853248336 (0.00171503% change)
#     iteration    8: trace = 0.7320823085807394 (0.00173159% change)
#     iteration    9: trace = 0.7320743041665 (0.00109338% change)
#     iteration   10: trace = 0.7320703361293446 (0.000542028% change)
#     iteration   11: trace = 0.7320685901732131 (0.000238496% change)
#     iteration   12: trace = 0.7320682154218547 (5.11908e-05% change)
#     iteration   13: trace = 0.7320681523441747 (8.61637e-06% change)
# Finished solving for bands 2 to 4 after 13 iterations.
# tefreqs:, 34, 0, 0, 0, 0, 0, 0.472418, 0.495165, 0.513518
# elapsed time for k point: 0.011773347854614258
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28360730498282727 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
# Band 2 range: 0.28526325233032085 at Vector3<0.5, 0.5, 0.0> to 0.47241808581409206 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.32056749700156284 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0> to 0.49516519901362616 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.49033264775763563 at Vector3<0.5, 0.5, 0.0> to 0.5772722039030167 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
# Gap from band 1 (0.28360730498282727) to band 2 (0.28526325233032085), 0.5821877494644271%
# total elapsed time for run: 0.42462992668151855
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 5.21623, harm. mean 3.3422, 85.8398% > 1, 81.8621% "fill"
# real part range: 1 .. 6.1504

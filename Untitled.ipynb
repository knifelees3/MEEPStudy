# %%
# we first use the function mp.cartesian_to_lattice to transform the coordinates

import math

import meep as mp
from meep import mpb
import numpy as np
# A triangular lattice of dielectric rods in air.  (This structure has
# a band_gap for TM fields.)  This file is used in the "Data Analysis
# Tutorial" section of the MPB manual.

num_bands = 8


nslab = 2.48
slab = mp.Medium(index=nslab)


# # Lattice geometry I
# geometry_lattice = mp.Lattice(
#     size=mp.Vector3(1, 1),
#     basis2=mp.Vector3(0.5,math.sqrt(3) / 2),
#     basis1=mp.Vector3(1, 0),
# )

# Lattice geometry II
geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis2=mp.Vector3(0,1),
    basis1=mp.Vector3(1, 0),
)

# (1) For squares in cartesian coordinates
# s=0.125
# vertices1 = [mp.Vector3(-1*s,-1*s),
#              mp.Vector3(-1*s,1*s),
#              mp.Vector3(s*1,s*1),
#              mp.Vector3(1*s,-1*s)]
# geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab)]



#(2) For squares in Lattice coordinates method 1
# s=0.125
# vertices1 = [mp.cartesian_to_lattice(mp.Vector3(-1*s,-1*s),geometry_lattice),
#              mp.cartesian_to_lattice(mp.Vector3(-1*s,1*s),geometry_lattice),
#              mp.cartesian_to_lattice(mp.Vector3(s*1,s*1),geometry_lattice),
#              mp.cartesian_to_lattice(mp.Vector3(1*s,-1*s),geometry_lattice)]
# geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab)]

# # (3) For squares in Lattice coordinates method 2
# s=0.125
# geometry=[mp.Block(mp.Vector3(0.25,0.25),center=mp.Vector3(0,0), material=slab)]

# #(4) For squares in Lattice coordinates method 2
# s=0.125
# geometry=[mp.Block(mp.Vector3(0.25,0.25),center=mp.Vector3(0,0), material=slab,
#                   e1 = mp.cartesian_to_lattice(mp.Vector3(1,0,0), geometry_lattice),
#                   e2 = mp.cartesian_to_lattice(mp.Vector3(0,1,0), geometry_lattice))]

# # #(5) For squares in Lattice coordinates method 3
# s=0.2
# vertices1 = [mp.Vector3(0*s,0*s),
#              mp.Vector3(1*s,0*s),
#              mp.Vector3(s*3/2,s*np.sqrt(3)/2),
#              mp.Vector3(s*1/2,s*np.sqrt(3)/2),]
# geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab,axis=mp.Vector3(0,0,1))]

# # #(5) For triangle in Lattice coordinates
s1=0.2
vertices1 = [mp.Vector3(-1*s1,0),
            mp.Vector3(0*s1,math.sqrt(3)/2*s1),
            mp.Vector3(1*s1,0),]
geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab,axis=mp.Vector3(0,0,1))]

# 注意倒格矢空间
k_points = [
    mp.Vector3(),  # Gamma
    mp.Vector3(y=0.5),  # M
    mp.Vector3(1 / -3, 1 / 3),  # K
    mp.Vector3(),  # Gamma
]

k_points = mp.interpolate(4, k_points)

resolution = 32

ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands,
)

ms.run_tm()
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      prism, center = (0,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.2,-0.057735,-5e+19)
#           (0,0.11547,-5e+19)
#           (0.2,-0.057735,-5e+19)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.013904333114624023
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 27.14266725172824 (190.645% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 10.18326619230701 (90.8719% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 8.738008709206115 (15.2765% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 8.144806788273119 (7.02729% change)
#     linmin: converged after 6 iterations.
#     iteration    5: trace = 7.798924823377793 (4.33878% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.732427170440197 (0.856302% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.717324899913423 (0.195502% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 60.1888%)
#     iteration    8: trace = 7.711473768520244 (0.0758469% change)
#     iteration    9: trace = 7.708183161283142 (0.0426807% change)
#     iteration   10: trace = 7.70691046923741 (0.0165123% change)
#     iteration   11: trace = 7.706324936611367 (0.00759779% change)
#     switching back to exact line minimization
#     iteration   12: trace = 7.706190037304734 (0.00175052% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.706164665280475 (0.000329243% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7.706161082067236 (4.6498e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 7.706160387833845 (9.00881e-06% change)
# Finished solving for bands 2 to 8 after 15 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.687537, 0.836507, 0.960176, 0.992723, 1.17449, 1.23667, 1.31054
# elapsed time for k point: 0.07725358009338379
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.740098188768766 (0.400461% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 7.730615842340908 (0.122584% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 7.729618900658881 (0.0128969% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 7.729460023702972 (0.00205545% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.729413043888039 (0.000607804% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.729408517373171 (5.85622e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.729407944303846 (7.41414e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.1, 0.087586, 0.678083, 0.838575, 0.917714, 1.04533, 1.16768, 1.21006, 1.34018
# elapsed time for k point: 0.06162714958190918
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.810710183512354 (0.384174% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.800209419806333 (0.134531% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.798127116887377 (0.026699% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.797264786094656 (0.0110588% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.797120272019951 (0.00185341% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.8656%)
#     iteration    6: trace = 7.797100729040723 (0.000250644% change)
#     iteration    7: trace = 7.797095693738891 (6.45792e-05% change)
#     iteration    8: trace = 7.797094774789296 (1.17858e-05% change)
#     iteration    9: trace = 7.797094692594703 (1.05417e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.2, 0.174289, 0.647555, 0.844209, 0.880327, 1.11257, 1.15089, 1.17225, 1.38679
# elapsed time for k point: 0.04304814338684082
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.913692035220091 (0.420043% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.898076858003048 (0.197513% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.893916850169791 (0.052685% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.892741718019961 (0.0148877% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.8022%)
#     iteration    5: trace = 7.892558017863369 (0.00232748% change)
#     iteration    6: trace = 7.892365882662134 (0.00243441% change)
#     iteration    7: trace = 7.89228297220737 (0.00105052% change)
#     switching back to exact line minimization
#     iteration    8: trace = 7.892274554101812 (0.000106663% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.892273895273631 (8.34776e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.3, 0.258628, 0.596522, 0.851683, 0.862521, 1.1256, 1.13147, 1.19637, 1.42188
# elapsed time for k point: 0.039606332778930664
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 8.021786614351809 (0.441011% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 8.006238312828415 (0.194014% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.002731387658956 (0.043812% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.000897798036739 (0.0229147% change)
#     large trace change predicted (0.134078%)
#     linmin: converged after 6 iterations.
#     iteration    5: trace = 7.992972168516687 (0.0991083% change)
#     large trace change predicted (0.475723%)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.976823807901747 (0.202236% change)
#     linmin: converged after 6 iterations.
#     iteration    7: trace = 7.957063618849336 (0.248027% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.942927044714787 (0.177819% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 7.938857386140485 (0.0512494% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 69.313%)
#     iteration   10: trace = 7.937940458746072 (0.0115505% change)
#     switching back to exact line minimization
#     iteration   11: trace = 7.937732322496326 (0.00262208% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.93763092545515 (0.00127741% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.937594884367875 (0.000454054% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7.937579311343659 (0.000196193% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 7.937555339511699 (0.000302005% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 7.937527818271004 (0.000346722% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 7.9375101321252 (0.000222817% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 7.937499878459128 (0.00012918% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 7.937495413781726 (5.62479e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 7.93749216159492 (4.09725e-05% change)
#     large trace change predicted (0.000176609%)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 57.3662%)
#     iteration   21: trace = 7.937478153429057 (0.000176481% change)
#     switching back to exact line minimization
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration   22: trace = 7.936317866555921 (0.0146189% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 7.936260309232848 (0.000725242% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 7.936206934166694 (0.000672549% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 7.936157147581758 (0.000627337% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 7.936110204210204 (0.000591514% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 7.936065457860087 (0.000563834% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 7.936022391162181 (0.000542672% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 7.935980595398526 (0.00052666% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 7.935939745008629 (0.00051475% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 7.935899576537537 (0.00050616% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 7.935859872926155 (0.000500305% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 7.935820452159525 (0.000496743% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 7.935781159156358 (0.000495136% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 7.93574186002718 (0.000495216% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 7.935702438063297 (0.000496766% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 7.935662791048936 (0.000499604% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 7.935622829599201 (0.000503569% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 7.935582476341434 (0.000508509% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 7.935541665813638 (0.000514274% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 7.93550034498989 (0.000520707% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 7.935458474354093 (0.000527638% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 7.935416029433061 (0.000534878% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 7.935373002666812 (0.000542213% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 7.935329405439988 (0.000549405% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 7.935285270028564 (0.00055619% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 7.935240651141641 (0.000562286% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 7.935195626680253 (0.0005674% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 7.935150297321361 (0.000571246% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 7.935104784595962 (0.00057356% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 7.935059227285114 (0.000574125% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 7.935013776200592 (0.00057279% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 7.934968587707008 (0.000569484% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 7.934923816606138 (0.000564227% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 7.934879609161088 (0.000557127% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 7.93483609703235 (0.000548367% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 7.93479339272771 (0.000538189% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 7.934751586886195 (0.000526869% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 7.93471074740757 (0.000514693% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 7.934670920183002 (0.000501938% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 7.934632131026794 (0.000488858% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 7.934594388360647 (0.000475671% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 7.934557686238483 (0.000462559% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 7.934522007385203 (0.000449665% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 7.934487326024596 (0.000437095% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 7.93445361036558 (0.000424926% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 7.934420824691359 (0.000413207% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 7.93438893104853 (0.000401966% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 7.93435789056593 (0.000391215% change)
#     resetting CG direction...
#     large trace change predicted (0.360138%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 7.905766361259358 (0.361001% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 7.900190671464076 (0.0705518% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 7.898358204525287 (0.0231979% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 7.897629199965435 (0.00923025% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 7.896872118355786 (0.00958665% change)
#     linmin: converged after 3 iterations.
#     iteration   75: trace = 7.896122599562301 (0.00949179% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 7.896040455908219 (0.00104031% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 7.895968814482087 (0.000907312% change)
#     large trace change predicted (0.00192377%)
#     linmin: converged after 3 iterations.
#     iteration   78: trace = 7.895816747280128 (0.0019259% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 7.895741762246184 (0.000949685% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 7.895731666993269 (0.000127857% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 7.895730226705693 (1.82413e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 7.895729834381552 (4.96881e-06% change)
# Finished solving for bands 1 to 8 after 82 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.4, 0.336116, 0.535245, 0.857434, 0.85823, 1.10395, 1.11633, 1.26572, 1.39913
# elapsed time for k point: 0.41757941246032715
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 8.047938765775395 (0.365609% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.4651%)
#     iteration    2: trace = 8.029970847723677 (0.223511% change)
#     switching back to exact line minimization
#     iteration    3: trace = 8.01892487501685 (0.137654% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 62.3102%)
#     iteration    4: trace = 8.008629469414746 (0.128471% change)
#     iteration    5: trace = 8.004944247333054 (0.0460262% change)
#     iteration    6: trace = 8.004260087317105 (0.00854708% change)
#     iteration    7: trace = 8.004176051679067 (0.00104989% change)
#     iteration    8: trace = 8.004158778473824 (0.000215803% change)
#     iteration    9: trace = 8.004152879069814 (7.37043e-05% change)
#     iteration   10: trace = 8.004150849055401 (2.5362e-05% change)
#     switching back to exact line minimization
#     iteration   11: trace = 8.004150061952334 (9.83369e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.5, 0.379947, 0.496183, 0.856828, 0.860871, 1.09565, 1.11061, 1.31905, 1.40163
# elapsed time for k point: 0.05868196487426758
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.987509316249007 (0.650697% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.4195%)
#     iteration    2: trace = 7.927455872095236 (0.754679% change)
#     iteration    3: trace = 7.907997754252203 (0.245754% change)
#     switching back to exact line minimization
#     iteration    4: trace = 7.897849884215505 (0.128407% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.889366242321731 (0.107475% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.881360833981514 (0.101522% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 7.879867278480801 (0.0189523% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 7.879668504381589 (0.00252259% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.5463%)
#     iteration    9: trace = 7.879614273551621 (0.00068824% change)
#     iteration   10: trace = 7.879598954040035 (0.00019442% change)
#     switching back to exact line minimization
#     iteration   11: trace = 7.879588759391225 (0.00012938% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.879582908358469 (7.42556e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.879579799162545 (3.94589e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7.879578451343105 (1.71052e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 7.879578092655873 (4.55211e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.471405, 0.3768, 0.506113, 0.823665, 0.893582, 1.04676, 1.16069, 1.30898, 1.35949
# elapsed time for k point: 0.09137201309204102
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.7513%)
#     iteration    1: trace = 7.860419034805037 (0.212859% change)
#     iteration    2: trace = 7.845854658695226 (0.185459% change)
#     iteration    3: trace = 7.837721397698162 (0.103717% change)
#     iteration    4: trace = 7.83604668571394 (0.0213696% change)
#     switching back to exact line minimization
#     iteration    5: trace = 7.835744235124563 (0.00385981% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.9467%)
#     iteration    6: trace = 7.835698635205654 (0.000581949% change)
#     iteration    7: trace = 7.835686516276083 (0.000154663% change)
#     iteration    8: trace = 7.835683990279504 (3.22371e-05% change)
#     iteration    9: trace = 7.835683278431436 (9.0847e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.453382, 0.371573, 0.531301, 0.788161, 0.927656, 0.994018, 1.21569, 1.28842, 1.34447
# elapsed time for k point: 0.0403139591217041
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.2291%)
#     iteration    1: trace = 7.820248670278502 (0.14544% change)
#     iteration    2: trace = 7.815148366114505 (0.0652405% change)
#     iteration    3: trace = 7.813038249846129 (0.027004% change)
#     switching back to exact line minimization
#     iteration    4: trace = 7.812671786305549 (0.00469052% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.0088%)
#     iteration    5: trace = 7.812597672656261 (0.000948638% change)
#     iteration    6: trace = 7.812589366090958 (0.000106323% change)
#     iteration    7: trace = 7.812587906603647 (1.86812e-05% change)
#     switching back to exact line minimization
#     iteration    8: trace = 7.812587672742664 (2.99339e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.447214, 0.370412, 0.563875, 0.752786, 0.945133, 0.961589, 1.24228, 1.28909, 1.32959
# elapsed time for k point: 0.04065513610839844
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.833434189015189 (0.125549% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.830010632427526 (0.043714% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.82872129206045 (0.016468% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.828415943823286 (0.00390044% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 7.828339846474374 (0.00097207% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 7.828328461600785 (0.000145432% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.828325441835037 (3.85749e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.7981%)
#     iteration    8: trace = 7.828324794450337 (8.26977e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.453382, 0.376249, 0.595065, 0.721265, 0.903791, 0.993416, 1.21772, 1.30838, 1.34685
# elapsed time for k point: 0.046705007553100586
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 58.7194%)
#     iteration    1: trace = 7.888332381300237 (0.132855% change)
#     iteration    2: trace = 7.883562725346517 (0.060483% change)
#     iteration    3: trace = 7.880698182042723 (0.0363422% change)
#     iteration    4: trace = 7.879331052309507 (0.0173493% change)
#     iteration    5: trace = 7.878884185561017 (0.00567154% change)
#     iteration    6: trace = 7.878706995503676 (0.00224895% change)
#     iteration    7: trace = 7.87861346060936 (0.00118719% change)
#     iteration    8: trace = 7.878577346609558 (0.000458381% change)
#     iteration    9: trace = 7.878567117628024 (0.000129833% change)
#     iteration   10: trace = 7.878565244117171 (2.37798e-05% change)
#     iteration   11: trace = 7.878565028299063 (2.73931e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.471405, 0.389101, 0.606031, 0.709377, 0.87093, 1.02374, 1.18598, 1.30249, 1.39538
# elapsed time for k point: 0.037084341049194336
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.4227%)
#     iteration    1: trace = 7.810072542259272 (0.425812% change)
#     switching back to exact line minimization
#     iteration    2: trace = 7.792069864447389 (0.230772% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 62.3733%)
#     iteration    3: trace = 7.787924059616647 (0.0532196% change)
#     switching back to exact line minimization
#     iteration    4: trace = 7.787126456689672 (0.0102421% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.5223%)
#     iteration    5: trace = 7.786667776033193 (0.00589042% change)
#     iteration    6: trace = 7.786520130350041 (0.00189615% change)
#     iteration    7: trace = 7.786476303344429 (0.000562859% change)
#     iteration    8: trace = 7.786469153795529 (9.18201e-05% change)
#     iteration    9: trace = 7.786468272439468 (1.13191e-05% change)
#     iteration   10: trace = 7.786468107605029 (2.11693e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.377124, 0.320972, 0.615711, 0.739296, 0.941827, 0.993093, 1.1731, 1.29246, 1.35569
# elapsed time for k point: 0.049513816833496094
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.406%)
#     iteration    1: trace = 7.728765289140529 (0.343995% change)
#     switching back to exact line minimization
#     iteration    2: trace = 7.714843984092483 (0.180286% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.711676795200574 (0.0410616% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.711016665942839 (0.00856049% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 55.3499%)
#     iteration    5: trace = 7.710815344734968 (0.00261086% change)
#     switching back to exact line minimization
#     iteration    6: trace = 7.710783629056964 (0.000411315% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 7.710776470088613 (9.28436e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.2276%)
#     iteration    8: trace = 7.710775361181943 (1.43813e-05% change)
#     switching back to exact line minimization
#     iteration    9: trace = 7.710775211880268 (1.93627e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.282843, 0.244584, 0.635796, 0.775063, 0.959401, 1.01192, 1.14463, 1.27558, 1.32826
# elapsed time for k point: 0.06780791282653809
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.687115890638712 (0.279718% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 58.2657%)
#     iteration    2: trace = 7.676729073013316 (0.135211% change)
#     iteration    3: trace = 7.674630893529211 (0.0273354% change)
#     iteration    4: trace = 7.674201996051637 (0.00558867% change)
#     switching back to exact line minimization
#     iteration    5: trace = 7.674114049390971 (0.00114601% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.8561%)
#     iteration    6: trace = 7.674099987418244 (0.000183239% change)
#     iteration    7: trace = 7.67409743412076 (3.32716e-05% change)
#     iteration    8: trace = 7.674096965162081 (6.11093e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.188562, 0.164464, 0.65926, 0.810422, 0.938628, 1.05168, 1.12311, 1.25923, 1.31208
# elapsed time for k point: 0.03944730758666992
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 7.699347556170897 (0.266434% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 7.688518496542295 (0.140748% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 7.685810500432307 (0.0352275% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.8169%)
#     iteration    4: trace = 7.684718534619808 (0.0142086% change)
#     iteration    5: trace = 7.68443384476785 (0.00370469% change)
#     iteration    6: trace = 7.68435715659585 (0.000997973% change)
#     iteration    7: trace = 7.684342110927776 (0.000195796% change)
#     iteration    8: trace = 7.684340411904817 (2.21102e-05% change)
#     iteration    9: trace = 7.68434019960647 (2.76274e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.0942809, 0.0825913, 0.67927, 0.832301, 0.940152, 1.02501, 1.15273, 1.24515, 1.30755
# elapsed time for k point: 0.04503512382507324
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 53.2374%)
#     iteration    1: trace = 7.741146644730234 (0.363272% change)
#     iteration    2: trace = 7.721734242441591 (0.251084% change)
#     iteration    3: trace = 7.713648408986955 (0.10477% change)
#     iteration    4: trace = 7.707895783004809 (0.0746051% change)
#     iteration    5: trace = 7.706579410678879 (0.0170797% change)
#     iteration    6: trace = 7.706243392940372 (0.00436024% change)
#     switching back to exact line minimization
#     iteration    7: trace = 7.70617720448243 (0.000858898% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 58.332%)
#     iteration    8: trace = 7.706162719998345 (0.00018796% change)
#     iteration    9: trace = 7.706160581653037 (2.77485e-05% change)
#     iteration   10: trace = 7.706160268489846 (4.0638e-06% change)
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.687537, 0.836507, 0.960176, 0.992723, 1.17449, 1.23667, 1.31054
# elapsed time for k point: 0.049019575119018555
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.38910087150029554 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4961828794040126 at Vector3<0.0, 0.5, 0.0> to 0.6875373220278264 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.7093774668500915 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8574335587512836 at Vector3<0.0, 0.4, 0.0>
# Band 4 range: 0.8582298688726772 at Vector3<0.0, 0.4, 0.0> to 0.9601756387180541 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.9615885258438898 at Vector3<-0.2, 0.39999999999999997, 0.0> to 1.12560010756727 at Vector3<0.0, 0.30000000000000004, 0.0>
# Band 6 range: 1.1106129937074365 at Vector3<0.0, 0.5, 0.0> to 1.2422760300760232 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 1.172248726062329 at Vector3<0.0, 0.2, 0.0> to 1.3190453777728979 at Vector3<0.0, 0.5, 0.0>
# Band 8 range: 1.307552034752731 at Vector3<-0.06666666666666665, 0.06666666666666665, 0.0> to 1.4218819573216985 at Vector3<0.0, 0.30000000000000004, 0.0>
# Gap from band 1 (0.38910087150029554) to band 2 (0.4961828794040126), 24.19156745943522%
# Gap from band 2 (0.6875373220278264) to band 3 (0.7093774668500915), 3.126911533352497%
# Gap from band 3 (0.8574335587512836) to band 4 (0.8582298688726772), 0.09282824458132816%
# Gap from band 4 (0.9601756387180541) to band 5 (0.9615885258438898), 0.14704063608738477%
# total elapsed time for run: 1.2219703197479248
# done

# %%
import matplotlib.pyplot as plt
md = mpb.MPBData(rectify=False, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

md = mpb.MPBData(rectify=True, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 1.29961, harm. mean 1.0569, 6.93359% > 1, 5.8172% "fill"
# real part range: 1 .. 6.1504
# epsilon: 1-6.1504, mean 1.29961, harm. mean 1.0569, 6.93359% > 1, 5.8172% "fill"
# real part range: 1 .. 6.1504

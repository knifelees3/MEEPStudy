# %%
# we first use the function mp.cartesian_to_lattice to transform the coordinates

import math

import meep as mp
from meep import mpb
import numpy as np
# A triangular lattice of dielectric rods in air.  (This structure has
# a band_gap for TM fields.)  This file is used in the "Data Analysis
# Tutorial" section of the MPB manual.

num_bands = 8


nslab = 2.48
slab = mp.Medium(index=nslab)


# Lattice geometry
geometry_lattice = mp.Lattice(
    size=mp.Vector3(1, 1),
    basis2=mp.Vector3(0.5,math.sqrt(3) / 2),
    basis1=mp.Vector3(1, 0),
)

# (1) For squares in cartesian coordinates
# s=0.125
# vertices1 = [mp.Vector3(-1*s,-1*s),
#              mp.Vector3(-1*s,1*s),
#              mp.Vector3(s*1,s*1),
#              mp.Vector3(1*s,-1*s)]
# geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab)]



#(2) For squares in Lattice coordinates method 1
# s=0.125
# vertices1 = [mp.cartesian_to_lattice(mp.Vector3(-1*s,-1*s),geometry_lattice),
#              mp.cartesian_to_lattice(mp.Vector3(-1*s,1*s),geometry_lattice),
#              mp.cartesian_to_lattice(mp.Vector3(s*1,s*1),geometry_lattice),
#              mp.cartesian_to_lattice(mp.Vector3(1*s,-1*s),geometry_lattice)]
# geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab)]

# # (3) For squares in Lattice coordinates method 2
# s=0.125
# geometry=[mp.Block(mp.Vector3(0.25,0.25),center=mp.Vector3(0,0), material=slab)]

# #(4) For squares in Lattice coordinates method 2
# s=0.125
# geometry=[mp.Block(mp.Vector3(0.25,0.25),center=mp.Vector3(0,0), material=slab,
#                   e1 = mp.cartesian_to_lattice(mp.Vector3(1,0,0), geometry_lattice),
#                   e2 = mp.cartesian_to_lattice(mp.Vector3(0,1,0), geometry_lattice))]

# # #(5) For squares in Lattice coordinates method 3
# s=0.2
# vertices1 = [mp.Vector3(0*s,0*s),
#              mp.Vector3(1*s,0*s),
#              mp.Vector3(s*3/2,s*np.sqrt(3)/2),
#              mp.Vector3(s*1/2,s*np.sqrt(3)/2),]
# geometry=[mp.Prism(vertices1, height=mp.inf, center=mp.Vector3(0,0), material=slab)]


# 注意倒格矢空间
k_points = [
    mp.Vector3(),  # Gamma
    mp.Vector3(y=0.5),  # M
    mp.Vector3(1 / -3, 1 / 3),  # K
    mp.Vector3(),  # Gamma
]

k_points = mp.interpolate(4, k_points)

resolution = 32

ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands,
)

ms.run_tm()
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      prism, center = (0,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-0.15,-0.0866025,-5e+19)
#           (0.05,-0.0866025,-5e+19)
#           (0.15,0.0866025,-5e+19)
#           (-0.05,0.0866025,-5e+19)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.013411283493041992
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 27.17617770169488 (193.072% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 10.54501882423957 (88.1794% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 9.265621441277897 (12.9163% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 9.02207409465878 (2.66351% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.957557265448376 (0.717666% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 8.935373731451307 (0.247959% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 8.931597987133054 (0.0422651% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 8.929702195676938 (0.0212279% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 8.928918071075779 (0.00878147% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.868%)
#     iteration   10: trace = 8.928758548937516 (0.00178659% change)
#     iteration   11: trace = 8.928737131896193 (0.000239866% change)
#     iteration   12: trace = 8.92873527386741 (2.08095e-05% change)
#     iteration   13: trace = 8.928735137366582 (1.52878e-06% change)
# Finished solving for bands 2 to 8 after 13 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.771583, 0.965017, 1.1118, 1.14685, 1.15237, 1.15447, 1.47987
# elapsed time for k point: 0.04964256286621094
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 8.997235492488322 (0.242405% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 8.993049236447398 (0.0465391% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.991346426564625 (0.0189365% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.99034187931419 (0.011173% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.990112439535533 (0.0025521% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 8.990075066802534 (0.00041571% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 8.990066913528636 (9.0692e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 8.990065303828338 (1.79053e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.6414%)
#     iteration    9: trace = 8.990065125379139 (1.98496e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.103387, 0.76207, 0.95689, 1.0501, 1.13508, 1.16393, 1.2443, 1.47949
# elapsed time for k point: 0.02127671241760254
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.177487794111215 (0.265701% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.171670708584081 (0.0634044% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.168955549875946 (0.0296081% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.166741091094305 (0.0241546% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.165966271245589 (0.00845287% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.165802767808522 (0.00178383% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.165764904008967 (0.000413099% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.165755445880201 (0.00010319% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.165754642135758 (8.76899e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.205823, 0.73337, 0.938238, 0.971807, 1.15898, 1.19562, 1.34394, 1.47715
# elapsed time for k point: 0.03950977325439453
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.447765901126273 (0.342004% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.436605126942347 (0.118201% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 9.42820073959258 (0.0891012% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.417572553445176 (0.112791% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.413959295623936 (0.0383746% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.413153055803903 (0.00856467% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 9.412947771862088 (0.00218084% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.412853206929009 (0.00100463% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.412810859558297 (0.00044989% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.412789797540967 (0.000223759% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.412782940975143 (7.28431e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 9.412781750514522 (1.26473e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 9.412781679934517 (7.49832e-07% change)
# Finished solving for bands 1 to 8 after 13 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.305692, 0.684417, 0.907896, 0.923858, 1.19463, 1.23084, 1.44278, 1.46607
# elapsed time for k point: 0.08644723892211914
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.707751577288894 (0.477328% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.684326404346551 (0.241595% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 9.652739994013386 (0.326693% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.60077928185477 (0.539753% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.551163422961007 (0.518129% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 9.517518057487205 (0.352886% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 9.5101937434288 (0.0769858% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 9.50896852293199 (0.0128841% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.508807650492386 (0.00169181% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.50878325448261 (0.000256563% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.508777475942789 (6.07706e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 9.508772082735554 (5.67182e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 9.508769892779855 (2.30309e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 9.508769352806009 (5.67869e-06% change)
# Finished solving for bands 1 to 8 after 14 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.398125, 0.619329, 0.874889, 0.909402, 1.23227, 1.25671, 1.43187, 1.49204
# elapsed time for k point: 0.06796884536743164
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 9.513087631827883 (0.504649% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.494046877235714 (0.200354% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.491374306195597 (0.0281539% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 9.491062356784525 (0.00328672% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.491014399596345 (0.000505289% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.491004522563655 (0.000104067% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.491002791334074 (1.82407e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.491002457755743 (3.51468e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.451973, 0.573654, 0.864144, 0.904704, 1.25461, 1.26192, 1.4151, 1.49111
# elapsed time for k point: 0.03342580795288086
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.509320725388548 (0.111552% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.504948849481192 (0.0459852% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.50401154846263 (0.00986168% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 9.50384241966275 (0.00177957% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.503821272070692 (0.000222516% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.503817216911212 (4.26687e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.503816842225103 (3.94248e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.454332, 0.577458, 0.831334, 0.936193, 1.22086, 1.29747, 1.40323, 1.50112
# elapsed time for k point: 0.03131103515625
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.546750305924759 (0.117897% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.541503689254579 (0.0549722% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.540276094098523 (0.0128667% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 9.540010189680887 (0.00278722% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.539949481692334 (0.000636353% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.539925224361838 (0.000254271% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.539912411473393 (0.000134308% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.539908705818556 (3.88437e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.539908111448653 (6.23035e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.461088, 0.588719, 0.78355, 0.980191, 1.18591, 1.33613, 1.37996, 1.5199
# elapsed time for k point: 0.039960622787475586
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.600784175543813 (0.138858% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.592782397155297 (0.0833798% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.590009717849462 (0.028908% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.58786656063117 (0.0223503% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.585539856602077 (0.0242701% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.584332393088022 (0.0125975% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 9.584032866059681 (0.00312522% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.583975019371076 (0.000603575% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.583959026903049 (0.000166867% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.583955741570755 (3.42795e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.583955068489173 (7.023e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.471163, 0.607008, 0.734745, 1.02337, 1.15333, 1.34138, 1.38769, 1.53337
# elapsed time for k point: 0.04655814170837402
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 9.614740565257325 (0.239739% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.59268062291433 (0.229702% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.57937872103604 (0.138763% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.567768825248475 (0.12127% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.563567108077194 (0.043925% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.562641797958246 (0.00967583% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.562460497193635 (0.00189595% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.562426846155789 (0.000351908% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.562419249001618 (7.9448e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.5624180885934 (1.21351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.562417865754314 (2.33036e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.482153, 0.631649, 0.687984, 1.06387, 1.12391, 1.31377, 1.42674, 1.51693
# elapsed time for k point: 0.03764081001281738
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.542658372359117 (0.0942843% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.539258949150026 (0.0356298% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.538192896691843 (0.011176% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.537840280581545 (0.00369695% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 9.537741060002414 (0.00104029% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.537696622536608 (0.000465913% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.537676007435834 (0.000216144% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.537670633710476 (5.63421e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.537669603272917 (1.08039e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.537669340086191 (2.75944e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.488596, 0.647383, 0.662959, 1.08655, 1.11235, 1.28522, 1.44911, 1.50689
# elapsed time for k point: 0.04310131072998047
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.640980544593713 (0.737255% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.596685903169544 (0.460499% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.566670391633352 (0.313259% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.544500108491215 (0.232014% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.533783335375801 (0.112345% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.530912337276202 (0.0301185% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 9.52995889405728 (0.0100042% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 9.529717234128999 (0.00253582% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.529686123695033 (0.000326458% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.529683415928297 (2.8414e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.529683122007398 (3.08427e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.447672, 0.640066, 0.720821, 1.07037, 1.09698, 1.34037, 1.42196, 1.49412
# elapsed time for k point: 0.04564476013183594
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.498352991770268 (0.768507% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 9.445355887555275 (0.559522% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.414526600794138 (0.32693% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.406433675343994 (0.0859991% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.404492827237256 (0.0206353% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 9.404175018726875 (0.00337938% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.404085524751292 (0.000951645% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.404062422154066 (0.000245666% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.404057448307185 (5.28904e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.404056327408629 (1.19193e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 9.404055984307366 (3.64844e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.350303, 0.677232, 0.80409, 1.04678, 1.08285, 1.35271, 1.38828, 1.46652
# elapsed time for k point: 0.047501564025878906
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 9.242257677383899 (0.991376% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.198635705673301 (0.4731% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.186089256007413 (0.136488% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.181704079673096 (0.0477485% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.180291268943547 (0.0153884% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.180009233468576 (0.00307223% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 9.179939017526863 (0.000764882% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 9.17992784675679 (0.000121687% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 9.179924935454896 (3.17138e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 9.179924602584457 (3.62607e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.237118, 0.7239, 0.889311, 1.03758, 1.07658, 1.2737, 1.34879, 1.46002
# elapsed time for k point: 0.04770040512084961
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 9.023464194165214 (0.55743% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 9.006156694024529 (0.19199% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.998903065863045 (0.0805732% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.996408984564512 (0.0277192% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.995744401110908 (0.00738748% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 8.995521988401267 (0.00247245% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 8.995480776889988 (0.000458135% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 8.995477483121565 (3.66158e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 8.995477137596275 (3.8411e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.119324, 0.758911, 0.950185, 1.06463, 1.09196, 1.19814, 1.25175, 1.47452
# elapsed time for k point: 0.041081905364990234
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 8.947289862644233 (0.410996% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 8.936835938619769 (0.116907% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.931488076038317 (0.0598586% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8.929231524142281 (0.0252683% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.928833389862525 (0.00445887% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 8.928752543209203 (0.00090546% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 8.928737460423282 (0.000168924% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 8.928735359699822 (2.35277e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 8.928735126635305 (2.61027e-06% change)
# Finished solving for bands 2 to 8 after 9 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.771583, 0.965017, 1.1118, 1.14685, 1.15237, 1.15447, 1.47987
# elapsed time for k point: 0.043591976165771484
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.48859638530671173 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.5736541815491694 at Vector3<0.0, 0.5, 0.0> to 0.771582885128248 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.6629594228693106 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.9650171997680849 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.9047038078118332 at Vector3<0.0, 0.5, 0.0> to 1.1117968888397847 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 1.0765795436781362 at Vector3<-0.1333333333333333, 0.1333333333333333, 0.0> to 1.254611230422624 at Vector3<0.0, 0.5, 0.0>
# Band 6 range: 1.1523739804934465 at Vector3<0.0, 0.0, 0.0> to 1.3527127296134662 at Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
# Band 7 range: 1.154466741692053 at Vector3<0.0, 0.0, 0.0> to 1.4491076698819465 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 1.4600195370414677 at Vector3<-0.1333333333333333, 0.1333333333333333, 0.0> to 1.5333740457365765 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Gap from band 1 (0.48859638530671173) to band 2 (0.5736541815491694), 16.01463889903439%
# Gap from band 7 (1.4491076698819465) to band 8 (1.4600195370414677), 0.7501815069174086%
# total elapsed time for run: 0.7373054027557373
# done

# %%
import matplotlib.pyplot as plt
md = mpb.MPBData(rectify=False, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

md = mpb.MPBData(rectify=True, periods=6, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)

plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.1504, mean 1.24398, harm. mean 1.04673, 6.15234% > 1, 4.73711% "fill"
# real part range: 1 .. 6.1504
# epsilon: 1-6.1504, mean 1.24398, harm. mean 1.04673, 6.15234% > 1, 4.73711% "fill"
# real part range: 1 .. 6.1504
